# %%
# ============================================================
# PS S6E5 - exp_20260518_035_xgb_laptime_delta_nonlinear_min
#
# Base:
#   017: exp_20260509_017_xgb_shared005_no_pitstop_pairte_min
#
# Change from 017:
#   Add safe EDA-derived LapTime_Delta non-linear features.
#
# Purpose:
#   Test whether LapTime_Delta non-linear features help the XGB branch
#   after the LGB version 034 was weak.
#
# Keep:
#   - PitStop as base feature
#   - PitStop removed from pairwise FE/TE source columns
#   - 5 outer folds
#   - 5 seed ensemble
#   - original rows appended to fold train
#   - cuML TargetEncoder
#   - XGB params
#   - OOF/pred artifact format
#
# Do not add:
#   - Driver TE extensions
#   - Normalized_TyreLife or proxy
#   - Compound median stint ratio
#   - future endpoint proxy
# ============================================================

# %%
import os
import gc
import json
import random
import warnings
from pathlib import Path
from itertools import combinations

import numpy as np
import pandas as pd

warnings.simplefilter("ignore")
pd.set_option("display.max_columns", 300)

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, log_loss

import cudf
from cuml.preprocessing import TargetEncoder as cuTargetEncoder

from xgboost import XGBClassifier

# %%
# ============================================================
# Config
# ============================================================

class CFG:
    EXP_ID = "exp_20260518_035_xgb_laptime_delta_nonlinear_min"
    COMPETITION = "PS S6E5 Predicting F1 Pit Stops"
    METRIC = "AUC"

    TARGET_CANDIDATES = ["PitNextLap", "PitNextLab"]
    TARGET = "PitNextLap"
    ID_COL = "id"
    DANGER_COL = "Normalized_TyreLife"

    COMP_PATHS = [
        "/kaggle/input/competitions/playground-series-s6e5",
        "/kaggle/input/playground-series-s6e5",
        ".",
    ]

    ORIGINAL_PATHS = [
        "/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/f1_strategy_dataset_v4.csv",
        "/kaggle/input/f1-strategy-dataset-pit-stop-prediction/f1_strategy_dataset_v4.csv",
        "./f1_strategy_dataset_v4.csv",
    ]

    OUTDIR = Path(f"/kaggle/working/{EXP_ID}")

    SEED = 42
    N_SPLITS = 5

    N_TE_FOLDS = 5
    TE_SMOOTH = 20

    # 5seed指定。016と同じ。
    SEEDS = [42, 43, 44, 45, 46]

    USE_ORIGINAL = True

    LOSSGUIDE_MAX_LEAVES = 64

    # 017差分:
    # PitStop is kept as base feature but removed from pairwise FE/TE source columns.
    DROP_FROM_PAIRWISE_FE_TE = ["PitStop"]

    # 035 EDA-derived safe LapTime_Delta non-linear features.
    USE_LAPTIME_DELTA_NONLINEAR_035 = True

    XGB_PARAMS = {
        "n_estimators": 10000,
        "learning_rate": 0.03,

        "grow_policy": "lossguide",
        "max_depth": 0,
        "max_leaves": LOSSGUIDE_MAX_LEAVES,

        "min_child_weight": 5,
        "subsample": 0.8,
        "colsample_bytree": 0.8,

        "reg_alpha": 0.0,
        "reg_lambda": 2.0,

        "objective": "binary:logistic",
        "eval_metric": "auc",

        "tree_method": "hist",
        "device": "cuda",
        "n_jobs": -1,
        "enable_categorical": True,

        "early_stopping_rounds": 200,
    }

    CLIP_LOW = 1e-6
    CLIP_HIGH = 1.0 - 1e-6

    VERBOSE = 200


CFG.OUTDIR.mkdir(parents=True, exist_ok=True)

# %%
# ============================================================
# Utilities
# ============================================================

def seed_everything(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)


def print_section(title: str) -> None:
    print("\n" + "=" * 90)
    print(title)
    print("=" * 90)


def first_existing_dir(paths):
    for p in paths:
        path = Path(p)
        if (path / "train.csv").exists() and (path / "test.csv").exists():
            return path
    raise FileNotFoundError(f"No valid competition path found: {paths}")


def first_existing_file(paths, required=True):
    for p in paths:
        path = Path(p)
        if path.exists():
            return path
    if required:
        raise FileNotFoundError(f"No valid file path found: {paths}")
    return None


def resolve_target_column(df: pd.DataFrame) -> str:
    for c in CFG.TARGET_CANDIDATES:
        if c in df.columns:
            return c
    raise ValueError(f"No target column found among {CFG.TARGET_CANDIDATES}")


def clip_pred(x):
    return np.clip(x, CFG.CLIP_LOW, CFG.CLIP_HIGH)


def to_numpy(x):
    if hasattr(x, "get"):
        return x.get()
    return np.asarray(x)


def safe_colname(c):
    return (
        c.replace(" ", "_")
         .replace("(", "")
         .replace(")", "")
         .replace("/", "_")
         .replace("-", "_")
    )


def to_numeric_array(s):
    x = pd.to_numeric(s, errors="coerce").astype(float).values
    x = np.round(x, 6)
    return x


def round_to_step(s, step):
    return np.round(s / step) * step


seed_everything(CFG.SEED)

# %%
# ============================================================
# Load Data
# ============================================================

print_section("Load Data")

COMP_PATH = first_existing_dir(CFG.COMP_PATHS)

train = pd.read_csv(COMP_PATH / "train.csv")
test = pd.read_csv(COMP_PATH / "test.csv")
sample_submission = pd.read_csv(COMP_PATH / "sample_submission.csv")

target_col_train = resolve_target_column(train)
if target_col_train != CFG.TARGET:
    train = train.rename(columns={target_col_train: CFG.TARGET})

target_col_sub = resolve_target_column(sample_submission)
if target_col_sub != CFG.TARGET:
    sample_submission = sample_submission.rename(columns={target_col_sub: CFG.TARGET})

original_path = first_existing_file(CFG.ORIGINAL_PATHS, required=False)
orig = None

if CFG.USE_ORIGINAL and original_path is not None:
    orig = pd.read_csv(original_path)

    if CFG.TARGET not in orig.columns:
        target_col_orig = resolve_target_column(orig)
        orig = orig.rename(columns={target_col_orig: CFG.TARGET})

    if CFG.DANGER_COL in orig.columns:
        orig = orig.drop(columns=[CFG.DANGER_COL])
        print(f"Dropped danger column from original: {CFG.DANGER_COL}")

print("COMP_PATH:", COMP_PATH)
print("train:", train.shape)
print("test :", test.shape)
print("sample_submission:", sample_submission.shape)

if orig is not None:
    print("orig:", orig.shape)
    print("original path:", original_path)

print("target mean train:", train[CFG.TARGET].mean())
if orig is not None:
    print("target mean orig :", orig[CFG.TARGET].mean())

assert CFG.ID_COL in train.columns
assert CFG.ID_COL in test.columns
assert CFG.ID_COL in sample_submission.columns
assert CFG.TARGET in train.columns
assert CFG.TARGET in sample_submission.columns
assert test[CFG.ID_COL].equals(sample_submission[CFG.ID_COL])

if orig is not None:
    assert CFG.TARGET in orig.columns
    assert CFG.DANGER_COL not in orig.columns

train_ids = train[CFG.ID_COL].copy()
test_ids = test[CFG.ID_COL].copy()
# Out:
# ==========================================================================================
# Load Data
# ==========================================================================================
# Dropped danger column from original: Normalized_TyreLife
# COMP_PATH: /kaggle/input/competitions/playground-series-s6e5
# train: (439140, 16)
# test : (188165, 15)
# sample_submission: (188165, 2)
# orig: (101371, 15)
# original path: /kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/f1_strategy_dataset_v4.csv
# target mean train: 0.19898210137996994
# target mean orig : 0.25479673673930414

# %%
# ============================================================
# Base Columns
# ============================================================

TARGET = CFG.TARGET

BASE = [col for col in train.columns if col not in [CFG.ID_COL, TARGET]]
CATS = [col for col in BASE if train[col].dtype == "object"]

print(len(BASE), "Baseline Features.")
print(len(CATS), "Categorical Features.")
print("Categorical Columns:", CATS)

# Driver / Compound / Race are mapped using train + test + original combined values.
for col in CATS:
    frames = [
        train[col].astype(str),
        test[col].astype(str),
    ]
    if orig is not None and col in orig.columns:
        frames.append(orig[col].astype(str))

    combined = pd.concat(frames, axis=0)
    uniques = combined.unique()
    mapping = {v: i for i, v in enumerate(uniques)}

    train[col] = train[col].astype(str).map(mapping).astype("int32").astype("category")
    test[col] = test[col].astype(str).map(mapping).astype("int32").astype("category")

    if orig is not None and col in orig.columns:
        orig[col] = orig[col].astype(str).map(mapping).astype("int32").astype("category")
# Out:
# 14 Baseline Features.
# 3 Categorical Features.
# Categorical Columns: ['Driver', 'Compound', 'Race']

# %%
# ============================================================
# Feature Engineering: NUM as CAT
# ============================================================

print_section("Feature Engineering: NUM as CAT")

NUM_as_CAT = []

NUM_CAT_BASE = [
    "LapTime (s)",
    "LapTime_Delta",
    "Cumulative_Degradation",
]

for c in NUM_CAT_BASE:
    new_col = f"{c}_cat"
    for df in [train, test] + ([orig] if orig is not None else []):
        if c in df.columns:
            df[new_col] = df[c].astype(str)
    NUM_as_CAT.append(new_col)

ROUND_CONFIG = {
    "LapTime (s)": {
        "round_digits": [1, 0],
        "round_steps": [0.5, 1.0, 2.0, 5.0],
    },
    "LapTime_Delta": {
        "round_digits": [1, 0],
        "round_steps": [0.5, 1.0, 2.0, 5.0, 10.0],
    },
    "Cumulative_Degradation": {
        "round_digits": [1, 0],
        "round_steps": [1.0, 2.0, 5.0, 10.0, 20.0],
    },
}

for c, cfg in ROUND_CONFIG.items():
    for d in cfg["round_digits"]:
        new_col = f"{c}_round{d}_cat"
        for df in [train, test] + ([orig] if orig is not None else []):
            if c in df.columns:
                df[new_col] = df[c].round(d).astype(str)
        NUM_as_CAT.append(new_col)

    for step in cfg["round_steps"]:
        step_name = str(step).replace(".", "p")
        new_col = f"{c}_round_step_{step_name}_cat"

        for df in [train, test] + ([orig] if orig is not None else []):
            if c in df.columns:
                df[new_col] = round_to_step(df[c], step).astype(str)

        NUM_as_CAT.append(new_col)

NUM_as_CAT = [c for c in NUM_as_CAT if c in train.columns and c in test.columns]
if orig is not None:
    NUM_as_CAT = [c for c in NUM_as_CAT if c in orig.columns]

print(len(NUM_as_CAT), "Total Num->Cat Features Created!")
print(NUM_as_CAT)
# Out:
# ==========================================================================================
# Feature Engineering: NUM as CAT
# ==========================================================================================
# 23 Total Num->Cat Features Created!
# ['LapTime (s)_cat', 'LapTime_Delta_cat', 'Cumulative_Degradation_cat', 'LapTime (s)_round1_cat', 'LapTime (s)_round0_cat', 'LapTime (s)_round_step_0p5_cat', 'LapTime (s)_round_step_1p0_cat', 'LapTime (s)_round_step_2p0_cat', 'LapTime (s)_round_step_5p0_cat', 'LapTime_Delta_round1_cat', 'LapTime_Delta_round0_cat', 'LapTime_Delta_round_step_0p5_cat', 'LapTime_Delta_round_step_1p0_cat', 'LapTime_Delta_round_step_2p0_cat', 'LapTime_Delta_round_step_5p0_cat', 'LapTime_Delta_round_step_10p0_cat', 'Cumulative_Degradation_round1_cat', 'Cumulative_Degradation_round0_cat', 'Cumulative_Degradation_round_step_1p0_cat', 'Cumulative_Degradation_round_step_2p0_cat', 'Cumulative_Degradation_round_step_5p0_cat', 'Cumulative_Degradation_round_step_10p0_cat', 'Cumulative_Degradation_round_step_20p0_cat']

# %%
# ============================================================
# Feature Engineering: DIGIT
# ============================================================

print_section("Feature Engineering: DIGIT")

DIGIT_FEATURES = []

DIGIT_BASE = [
    "Year",
    "PitStop",
    "LapNumber",
    "Stint",
    "TyreLife",
    "Position",
    "LapTime (s)",
    "LapTime_Delta",
    "Cumulative_Degradation",
    "RaceProgress",
    "Position_Change",
]

DECIMAL_DIGIT_BASE = [
    "LapTime (s)",
    "LapTime_Delta",
    "Cumulative_Degradation",
    "RaceProgress",
]

INT_POSITIONS = [1, 10, 100, 1000]
DECIMAL_POSITIONS = [1, 2, 3]

all_dfs = [train, test] + ([orig] if orig is not None else [])

for c in DIGIT_BASE:
    if not all(c in df.columns for df in all_dfs):
        print(f"[Skip] {c} is not found in all dataframes.")
        continue

    sc = safe_colname(c)

    sign_col = f"{sc}_sign"
    for df in all_dfs:
        x = to_numeric_array(df[c])
        sign = np.sign(np.nan_to_num(x, nan=0.0)).astype(np.int8)
        df[sign_col] = sign
    DIGIT_FEATURES.append(sign_col)

    for p in INT_POSITIONS:
        nc = f"{sc}_digit_{p}s"

        for df in all_dfs:
            x = to_numeric_array(df[c])
            x_abs = np.abs(np.nan_to_num(x, nan=0.0))
            int_part = np.floor(x_abs).astype(np.int64)
            digit = ((int_part // p) % 10).astype(np.int8)
            df[nc] = digit

        DIGIT_FEATURES.append(nc)

for c in DECIMAL_DIGIT_BASE:
    if not all(c in df.columns for df in all_dfs):
        print(f"[Skip] {c} is not found in all dataframes.")
        continue

    sc = safe_colname(c)

    for d in DECIMAL_POSITIONS:
        nc = f"{sc}_decimal_digit_{d}"

        for df in all_dfs:
            x = to_numeric_array(df[c])
            x_abs = np.abs(np.nan_to_num(x, nan=0.0))
            digit = (np.floor(x_abs * (10 ** d)).astype(np.int64) % 10).astype(np.int8)
            df[nc] = digit

        DIGIT_FEATURES.append(nc)

DIGIT_FEATURES = [c for c in DIGIT_FEATURES if c in train.columns and c in test.columns]
if orig is not None:
    DIGIT_FEATURES = [c for c in DIGIT_FEATURES if c in orig.columns]

print(len(DIGIT_FEATURES), "DIGIT Features Created!")
print(DIGIT_FEATURES[:30])
# Out:
# ==========================================================================================
# Feature Engineering: DIGIT
# ==========================================================================================
# 67 DIGIT Features Created!
# ['Year_sign', 'Year_digit_1s', 'Year_digit_10s', 'Year_digit_100s', 'Year_digit_1000s', 'PitStop_sign', 'PitStop_digit_1s', 'PitStop_digit_10s', 'PitStop_digit_100s', 'PitStop_digit_1000s', 'LapNumber_sign', 'LapNumber_digit_1s', 'LapNumber_digit_10s', 'LapNumber_digit_100s', 'LapNumber_digit_1000s', 'Stint_sign', 'Stint_digit_1s', 'Stint_digit_10s', 'Stint_digit_100s', 'Stint_digit_1000s', 'TyreLife_sign', 'TyreLife_digit_1s', 'TyreLife_digit_10s', 'TyreLife_digit_100s', 'TyreLife_digit_1000s', 'Position_sign', 'Position_digit_1s', 'Position_digit_10s', 'Position_digit_100s', 'Position_digit_1000s']

# %%
# ============================================================
# 035 component: safe LapTime_Delta non-linear features
# ============================================================

print_section("Feature Engineering: LapTime_Delta nonlinear 035")

LAPTIME_DELTA_FEATURES_035 = [
    "LapTime_Delta_abs_035",
    "LapTime_Delta_sq_035",
    "LapTime_Delta_sign_035",
    "LapTime_Delta_abs_x_TyreLife_035",
    "LapTime_Delta_abs_x_RaceProgress_035",
    "LapTime_Delta_abs_x_Cumulative_Degradation_abs_035",
    "LapTime_Delta_abs_bin20_035",
]

def add_laptime_delta_nonlinear_035(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add safe non-linear LapTime_Delta features from EDA.

    This function does not use target.
    It intentionally avoids:
      - Normalized_TyreLife reconstruction
      - compound median stint ratio
      - endpoint/future stint proxy
      - target encoding
    """
    out = df.copy()

    if "LapTime_Delta" not in out.columns:
        return out

    delta = pd.to_numeric(out["LapTime_Delta"], errors="coerce")
    delta_abs = delta.abs()

    out["LapTime_Delta_abs_035"] = delta_abs.astype(np.float32)
    out["LapTime_Delta_sq_035"] = (delta ** 2).clip(0, 1e6).astype(np.float32)
    out["LapTime_Delta_sign_035"] = np.sign(delta.fillna(0)).astype(np.int8)

    if "TyreLife" in out.columns:
        tyre_life = pd.to_numeric(out["TyreLife"], errors="coerce")
        out["LapTime_Delta_abs_x_TyreLife_035"] = (delta_abs * tyre_life).astype(np.float32)

    if "RaceProgress" in out.columns:
        race_progress = pd.to_numeric(out["RaceProgress"], errors="coerce")
        out["LapTime_Delta_abs_x_RaceProgress_035"] = (delta_abs * race_progress).astype(np.float32)

    if "Cumulative_Degradation" in out.columns:
        deg_abs = pd.to_numeric(out["Cumulative_Degradation"], errors="coerce").abs()
        out["LapTime_Delta_abs_x_Cumulative_Degradation_abs_035"] = (delta_abs * deg_abs).astype(np.float32)

    try:
        out["LapTime_Delta_abs_bin20_035"] = pd.qcut(
            delta_abs.rank(method="first"),
            q=20,
            labels=False,
            duplicates="drop",
        ).astype("float").fillna(-1).astype(np.int16)
    except Exception:
        out["LapTime_Delta_abs_bin20_035"] = -1

    return out

if CFG.USE_LAPTIME_DELTA_NONLINEAR_035:
    for df_name, df in [("train", train), ("test", test)] + ([("orig", orig)] if orig is not None else []):
        updated = add_laptime_delta_nonlinear_035(df)
        if df_name == "train":
            train = updated
        elif df_name == "test":
            test = updated
        else:
            orig = updated

print("035 features:")
for c in LAPTIME_DELTA_FEATURES_035:
    print(c, "train:", c in train.columns, "test:", c in test.columns, "orig:", (orig is not None and c in orig.columns))
# Out:
# ==========================================================================================
# Feature Engineering: LapTime_Delta nonlinear 035
# ==========================================================================================
# 035 features:
# LapTime_Delta_abs_035 train: True test: True orig: True
# LapTime_Delta_sq_035 train: True test: True orig: True
# LapTime_Delta_sign_035 train: True test: True orig: True
# LapTime_Delta_abs_x_TyreLife_035 train: True test: True orig: True
# LapTime_Delta_abs_x_RaceProgress_035 train: True test: True orig: True
# LapTime_Delta_abs_x_Cumulative_Degradation_abs_035 train: True test: True orig: True
# LapTime_Delta_abs_bin20_035 train: True test: True orig: True

# %%
# ============================================================
# Model Feature Configuration
# ============================================================

print_section("Model Feature Configuration")

# 016 original source columns
TE_BASE_ORIGINAL = [
    "Driver",
    "Compound",
    "Race",
    "Year",
    "PitStop",
    "LapNumber",
    "Stint",
    "TyreLife",
    "Position",
    "RaceProgress",
    "Position_Change",
]

TE_BASE_ORIGINAL = [c for c in TE_BASE_ORIGINAL if c in train.columns and c in test.columns]
if orig is not None:
    TE_BASE_ORIGINAL = [c for c in TE_BASE_ORIGINAL if c in orig.columns]

# 017差分:
# PitStop remains in FEATURES/base and single columns,
# but is removed from pairwise source columns.
PAIRWISE_TE_BASE = [
    c for c in TE_BASE_ORIGINAL
    if c not in CFG.DROP_FROM_PAIRWISE_FE_TE
]

BIGRAM_SPECS = list(combinations(PAIRWISE_TE_BASE, 2))

FEATURES = BASE + NUM_as_CAT + DIGIT_FEATURES + LAPTIME_DELTA_FEATURES_035
FEATURES = [c for c in FEATURES if c in train.columns and c in test.columns]
if orig is not None:
    FEATURES = [c for c in FEATURES if c in orig.columns]

# Deduplicate while preserving order
FEATURES = list(dict.fromkeys(FEATURES))

print("TE_BASE_ORIGINAL:", TE_BASE_ORIGINAL)
print("PAIRWISE_TE_BASE:", PAIRWISE_TE_BASE)
print("DROP_FROM_PAIRWISE_FE_TE:", CFG.DROP_FROM_PAIRWISE_FE_TE)

print(len(BIGRAM_SPECS), "BIGRAM specs")
print(len(FEATURES), "Base features")
print("FEATURES sample:", FEATURES[:30])

# Guardrails
assert "PitStop" in FEATURES, "017 violation: PitStop must remain in base FEATURES."
assert "PitStop" in TE_BASE_ORIGINAL, "017 violation: PitStop should exist in original TE base."
assert "PitStop" not in PAIRWISE_TE_BASE, "017 violation: PitStop must be removed from pairwise source."
assert all("PitStop" not in pair for pair in BIGRAM_SPECS), "017 violation: PitStop pairwise specs remain."
assert CFG.DANGER_COL not in FEATURES
# Out:
# ==========================================================================================
# Model Feature Configuration
# ==========================================================================================
# TE_BASE_ORIGINAL: ['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint', 'TyreLife', 'Position', 'RaceProgress', 'Position_Change']
# PAIRWISE_TE_BASE: ['Driver', 'Compound', 'Race', 'Year', 'LapNumber', 'Stint', 'TyreLife', 'Position', 'RaceProgress', 'Position_Change']
# DROP_FROM_PAIRWISE_FE_TE: ['PitStop']
# 45 BIGRAM specs
# 111 Base features
# FEATURES sample: ['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint', 'TyreLife', 'Position', 'LapTime (s)', 'LapTime_Delta', 'Cumulative_Degradation', 'RaceProgress', 'Position_Change', 'LapTime (s)_cat', 'LapTime_Delta_cat', 'Cumulative_Degradation_cat', 'LapTime (s)_round1_cat', 'LapTime (s)_round0_cat', 'LapTime (s)_round_step_0p5_cat', 'LapTime (s)_round_step_1p0_cat', 'LapTime (s)_round_step_2p0_cat', 'LapTime (s)_round_step_5p0_cat', 'LapTime_Delta_round1_cat', 'LapTime_Delta_round0_cat', 'LapTime_Delta_round_step_0p5_cat', 'LapTime_Delta_round_step_1p0_cat', 'LapTime_Delta_round_step_2p0_cat', 'LapTime_Delta_round_step_5p0_cat', 'LapTime_Delta_round_step_10p0_cat']

# %%
# ============================================================
# Encoding Helpers
# ============================================================

def make_inner_fold_ids(y, n_splits=5, seed=42):
    fold_ids = np.zeros(len(y), dtype=np.int32)

    inner = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed,
    )

    dummy_X = np.zeros((len(y), 1))

    for fold, (_, va_idx) in enumerate(inner.split(dummy_X, y)):
        fold_ids[va_idx] = fold

    return cudf.Series(fold_ids)


def add_frequency_encode(
    X_tr,
    X_va,
    X_test,
    cols,
    out_col=None,
    normalize=True,
):
    cols = list(cols)

    if out_col is None:
        out_col = "fe__" + "__".join(cols)

    X_tr_key = X_tr[cols].astype(str)
    X_va_key = X_va[cols].astype(str)
    X_test_key = X_test[cols].astype(str)

    denom = len(X_tr) if normalize else 1.0

    if len(cols) == 1:
        c = cols[0]
        freq_map = X_tr_key[c].value_counts(dropna=False)

        X_tr[out_col] = (
            X_tr_key[c]
            .map(freq_map)
            .fillna(0)
            .astype(np.float32)
            .values / denom
        )

        X_va[out_col] = (
            X_va_key[c]
            .map(freq_map)
            .fillna(0)
            .astype(np.float32)
            .values / denom
        )

        X_test[out_col] = (
            X_test_key[c]
            .map(freq_map)
            .fillna(0)
            .astype(np.float32)
            .values / denom
        )

    else:
        freq_df = (
            X_tr_key
            .groupby(cols, dropna=False)
            .size()
            .reset_index(name=out_col)
        )

        def map_joint_freq(df_key):
            return (
                df_key
                .reset_index(drop=True)
                .merge(freq_df, on=cols, how="left")[out_col]
                .fillna(0)
                .astype(np.float32)
                .values / denom
            )

        X_tr[out_col] = map_joint_freq(X_tr_key)
        X_va[out_col] = map_joint_freq(X_va_key)
        X_test[out_col] = map_joint_freq(X_test_key)


def add_cuml_te(
    X_tr,
    X_va,
    X_test,
    X_tr_g,
    X_va_g,
    X_test_g,
    y_tr_g,
    cols,
    out_col,
    fold_ids_g,
    seed=42,
    smooth=20,
    n_folds=5,
):
    cols = list(cols)

    te = cuTargetEncoder(
        n_folds=n_folds,
        smooth=smooth,
        seed=seed,
        split_method="random",
        output_type="numpy",
        stat="mean",
        multi_feature_mode="combination",
    )

    tr_enc = te.fit_transform(
        X_tr_g[cols],
        y_tr_g,
        fold_ids=fold_ids_g,
    )

    va_enc = te.transform(X_va_g[cols])
    test_enc = te.transform(X_test_g[cols])

    X_tr[out_col] = to_numpy(tr_enc).reshape(-1).astype(np.float32)
    X_va[out_col] = to_numpy(va_enc).reshape(-1).astype(np.float32)
    X_test[out_col] = to_numpy(test_enc).reshape(-1).astype(np.float32)

# %%
# ============================================================
# 5fold OOF Training
# ============================================================

print_section("5fold OOF Training")

oof_preds = np.zeros(len(train), dtype=np.float32)
test_preds = np.zeros(len(test), dtype=np.float32)

fold_records = []
seed_records = []
all_feature_cols_after_fe_te = None

skf = StratifiedKFold(
    n_splits=CFG.N_SPLITS,
    shuffle=True,
    random_state=CFG.SEED,
)

if orig is not None and CFG.USE_ORIGINAL:
    X_orig = orig[FEATURES].copy()
    y_orig = orig[TARGET].copy().reset_index(drop=True)
else:
    X_orig = None
    y_orig = None

for fold, (tr_idx, va_idx) in enumerate(skf.split(train[FEATURES], train[TARGET]), 1):
    print("\n" + "=" * 90)
    print(f"Fold {fold}/{CFG.N_SPLITS}")
    print("=" * 90)

    X_tr_base = train[FEATURES].iloc[tr_idx].copy().reset_index(drop=True)
    y_tr_base = train[TARGET].iloc[tr_idx].copy().reset_index(drop=True)

    X_va = train[FEATURES].iloc[va_idx].copy().reset_index(drop=True)
    y_va = train[TARGET].iloc[va_idx].copy().reset_index(drop=True)

    X_test = test[FEATURES].copy().reset_index(drop=True)

    if X_orig is not None and CFG.USE_ORIGINAL:
        X_tr = pd.concat(
            [X_tr_base.reset_index(drop=True), X_orig.reset_index(drop=True)],
            axis=0,
            ignore_index=True,
        )
        y_tr = pd.concat(
            [y_tr_base.reset_index(drop=True), y_orig.reset_index(drop=True)],
            axis=0,
            ignore_index=True,
        )
    else:
        X_tr = X_tr_base.copy()
        y_tr = y_tr_base.copy()

    print("Base:", X_tr.shape, X_va.shape, X_test.shape)
    print("target mean train fold:", float(y_tr.mean()))
    print("target mean valid fold:", float(y_va.mean()))

    # include PitStop for single TE source if present, but pairwise specs exclude it
    te_source_cols = sorted(set(["Driver"] + NUM_as_CAT + TE_BASE_ORIGINAL))
    te_source_cols = [c for c in te_source_cols if c in X_tr.columns]

    X_tr_g = cudf.from_pandas(X_tr[te_source_cols].astype(str))
    X_va_g = cudf.from_pandas(X_va[te_source_cols].astype(str))
    X_test_g = cudf.from_pandas(X_test[te_source_cols].astype(str))
    y_tr_g = cudf.Series(y_tr.values)

    te_seed = 1000 + fold

    fold_ids_g = make_inner_fold_ids(
        y_tr,
        n_splits=CFG.N_TE_FOLDS,
        seed=te_seed,
    )

    # -------------------------
    # Frequency Encoding
    # -------------------------

    FE_SINGLE_COLS = sorted(set(["Driver"] + NUM_as_CAT))
    FE_SINGLE_COLS = [c for c in FE_SINGLE_COLS if c in X_tr.columns]

    for c in FE_SINGLE_COLS:
        add_frequency_encode(
            X_tr,
            X_va,
            X_test,
            cols=(c,),
            out_col=f"fe__{c}",
            normalize=True,
        )

    for cols in BIGRAM_SPECS:
        if all(c in X_tr.columns for c in cols):
            add_frequency_encode(
                X_tr,
                X_va,
                X_test,
                cols=cols,
                out_col="fe2__" + "__".join(cols),
                normalize=True,
            )

    print("After FE:", X_tr.shape, X_va.shape, X_test.shape)

    # -------------------------
    # Target Encoding
    # -------------------------

    if "Driver" in X_tr.columns:
        add_cuml_te(
            X_tr,
            X_va,
            X_test,
            X_tr_g,
            X_va_g,
            X_test_g,
            y_tr_g,
            cols=("Driver",),
            out_col="te_Driver",
            fold_ids_g=fold_ids_g,
            seed=te_seed,
            smooth=CFG.TE_SMOOTH,
            n_folds=CFG.N_TE_FOLDS,
        )

    for c in NUM_as_CAT:
        if c in X_tr.columns:
            # shared_005 behavior: overwrite NUM_as_CAT column with TE numeric.
            add_cuml_te(
                X_tr,
                X_va,
                X_test,
                X_tr_g,
                X_va_g,
                X_test_g,
                y_tr_g,
                cols=(c,),
                out_col=c,
                fold_ids_g=fold_ids_g,
                seed=te_seed,
                smooth=CFG.TE_SMOOTH,
                n_folds=CFG.N_TE_FOLDS,
            )

    for cols in BIGRAM_SPECS:
        if all(c in X_tr.columns for c in cols):
            add_cuml_te(
                X_tr,
                X_va,
                X_test,
                X_tr_g,
                X_va_g,
                X_test_g,
                y_tr_g,
                cols=cols,
                out_col="te2__" + "__".join(cols),
                fold_ids_g=fold_ids_g,
                seed=te_seed,
                smooth=CFG.TE_SMOOTH,
                n_folds=CFG.N_TE_FOLDS,
            )

    print("After TE:", X_tr.shape, X_va.shape, X_test.shape)

    # Guardrail: no PitStop pairwise FE/TE columns should exist
    pitstop_pair_cols = [
        c for c in X_tr.columns
        if ("__PitStop" in c or "PitStop__" in c)
    ]
    assert len(pitstop_pair_cols) == 0, (
        "017 violation: PitStop pairwise FE/TE columns remain: "
        + str(pitstop_pair_cols[:20])
    )

    if all_feature_cols_after_fe_te is None:
        all_feature_cols_after_fe_te = list(X_tr.columns)

    fold_va_preds = np.zeros(len(X_va), dtype=np.float32)
    fold_test_preds = np.zeros(len(X_test), dtype=np.float32)

    seed_aucs = []
    seed_best_iters = []

    for s, seed in enumerate(CFG.SEEDS):
        model_seed = seed + (fold - 1) * 100

        print(f"  Seed {s + 1}/{len(CFG.SEEDS)}: {model_seed}")

        params = CFG.XGB_PARAMS.copy()
        params["random_state"] = model_seed

        model = XGBClassifier(**params)

        model.fit(
            X_tr,
            y_tr,
            eval_set=[(X_va, y_va)],
            verbose=CFG.VERBOSE,
        )

        va_pred = clip_pred(model.predict_proba(X_va)[:, 1]).astype(np.float32)
        test_pred = clip_pred(model.predict_proba(X_test)[:, 1]).astype(np.float32)

        fold_va_preds += va_pred / len(CFG.SEEDS)
        fold_test_preds += test_pred / len(CFG.SEEDS)

        seed_auc = roc_auc_score(y_va, va_pred)

        try:
            best_iter = int(model.best_iteration)
        except Exception:
            best_iter = -1

        seed_aucs.append(seed_auc)
        seed_best_iters.append(best_iter)

        seed_records.append({
            "fold": fold,
            "seed_index": s + 1,
            "model_seed": model_seed,
            "auc": float(seed_auc),
            "best_iteration": int(best_iter),
            "n_train": int(len(X_tr)),
            "n_valid": int(len(X_va)),
            "n_features": int(X_tr.shape[1]),
        })

        print(f"    Seed AUC: {seed_auc:.9f}")
        print(f"    Best iteration: {best_iter}")

        del model, va_pred, test_pred
        gc.collect()

    oof_preds[va_idx] = fold_va_preds
    test_preds += fold_test_preds / CFG.N_SPLITS

    fold_auc = roc_auc_score(y_va, fold_va_preds)
    fold_logloss = log_loss(y_va, clip_pred(fold_va_preds))

    print(f"Fold {fold} Ensemble AUC    : {fold_auc:.9f}")
    print(f"Fold {fold} Ensemble LogLoss: {fold_logloss:.9f}")

    fold_records.append({
        "fold": fold,
        "auc": float(fold_auc),
        "logloss": float(fold_logloss),
        "seed_auc_mean": float(np.mean(seed_aucs)),
        "seed_auc_std": float(np.std(seed_aucs)),
        "seed_best_iter_mean": float(np.mean(seed_best_iters)),
        "seed_best_iter_min": int(np.min(seed_best_iters)),
        "seed_best_iter_max": int(np.max(seed_best_iters)),
        "n_train_comp": int(len(X_tr_base)),
        "n_train_orig": int(len(X_orig)) if X_orig is not None and CFG.USE_ORIGINAL else 0,
        "n_valid": int(len(X_va)),
        "n_features_after_fe_te": int(X_tr.shape[1]),
        "pitstop_pairwise_features_removed": True,
    })

    del X_tr_base, y_tr_base, X_va, y_va, X_test, X_tr, y_tr
    del X_tr_g, X_va_g, X_test_g, y_tr_g, fold_ids_g
    gc.collect()
# Out:
# ==========================================================================================
# 5fold OOF Training
# ==========================================================================================
#
# ==========================================================================================
# Fold 1/5
# ==========================================================================================
# Base: (452683, 111) (87828, 111) (188165, 111)
# target mean train fold: 0.21147911452385001
# target mean valid fold: 0.19899121009245344
# After FE: (452683, 180) (87828, 180) (188165, 180)
# After TE: (452683, 226) (87828, 226) (188165, 226)
#   Seed 1/5: 42
# [0]	validation_0-auc:0.92282
# [200]	validation_0-auc:0.94774
# [400]	validation_0-auc:0.95032
# [600]	validation_0-auc:0.95120
# [800]	validation_0-auc:0.95168
# [1000]	validation_0-auc:0.95193
# [1200]	validation_0-auc:0.95209
# [1400]	validation_0-auc:0.95223
# [1600]	validation_0-auc:0.95235
# [1800]	validation_0-auc:0.95240
# [2000]	validation_0-auc:0.95245
# [2200]	validation_0-auc:0.95249
# [2400]	validation_0-auc:0.95252
# [2600]	validation_0-auc:0.95255
# [2800]	validation_0-auc:0.95256
# [2828]	validation_0-auc:0.95256
#     Seed AUC: 0.952565366
#     Best iteration: 2628
#   Seed 2/5: 43
# [0]	validation_0-auc:0.92777
# [200]	validation_0-auc:0.94766
# [400]	validation_0-auc:0.95029
# [600]	validation_0-auc:0.95112
# [800]	validation_0-auc:0.95159
# [1000]	validation_0-auc:0.95187
# [1200]	validation_0-auc:0.95207
# [1400]	validation_0-auc:0.95224
# [1600]	validation_0-auc:0.95231
# [1800]	validation_0-auc:0.95236
# [2000]	validation_0-auc:0.95240
# [2200]	validation_0-auc:0.95241
# [2400]	validation_0-auc:0.95243
# [2518]	validation_0-auc:0.95242
#     Seed AUC: 0.952443518
#     Best iteration: 2318
#   Seed 3/5: 44
# [0]	validation_0-auc:0.92537
# [200]	validation_0-auc:0.94772
# [400]	validation_0-auc:0.95042
# [600]	validation_0-auc:0.95131
# [800]	validation_0-auc:0.95175
# [1000]	validation_0-auc:0.95208
# [1200]	validation_0-auc:0.95230
# [1400]	validation_0-auc:0.95242
# [1600]	validation_0-auc:0.95258
# [1800]	validation_0-auc:0.95261
# [2000]	validation_0-auc:0.95271
# [2200]	validation_0-auc:0.95276
# [2400]	validation_0-auc:0.95279
# [2543]	validation_0-auc:0.95280
#     Seed AUC: 0.952807764
#     Best iteration: 2343
#   Seed 4/5: 45
# [0]	validation_0-auc:0.92574
# [200]	validation_0-auc:0.94778
# [400]	validation_0-auc:0.95036
# [600]	validation_0-auc:0.95117
# [800]	validation_0-auc:0.95159
# [1000]	validation_0-auc:0.95188
# [1200]	validation_0-auc:0.95210
# [1400]	validation_0-auc:0.95226
# [1600]	validation_0-auc:0.95233
# [1800]	validation_0-auc:0.95244
# [2000]	validation_0-auc:0.95249
# [2200]	validation_0-auc:0.95253
# [2400]	validation_0-auc:0.95254
# [2600]	validation_0-auc:0.95255
# [2800]	validation_0-auc:0.95257
# [3000]	validation_0-auc:0.95259
# [3128]	validation_0-auc:0.95258
#     Seed AUC: 0.952595348
#     Best iteration: 2928
#   Seed 5/5: 46
# [0]	validation_0-auc:0.92974
# [200]	validation_0-auc:0.94783
# [400]	validation_0-auc:0.95043
# [600]	validation_0-auc:0.95128
# [800]	validation_0-auc:0.95176
# [1000]	validation_0-auc:0.95200
# [1200]	validation_0-auc:0.95221
# [1400]	validation_0-auc:0.95236
# [1600]	validation_0-auc:0.95246
# [1800]	validation_0-auc:0.95253
# [2000]	validation_0-auc:0.95259
# [2200]	validation_0-auc:0.95261
# [2400]	validation_0-auc:0.95262
# [2600]	validation_0-auc:0.95263
# [2712]	validation_0-auc:0.95262
#     Seed AUC: 0.952650352
#     Best iteration: 2512
# Fold 1 Ensemble AUC    : 0.953113605
# Fold 1 Ensemble LogLoss: 0.217072070
#
# ==========================================================================================
# Fold 2/5
# ==========================================================================================
# Base: (452683, 111) (87828, 111) (188165, 111)
# target mean train fold: 0.2114813235752171
# target mean valid fold: 0.19897982420184906
# After FE: (452683, 180) (87828, 180) (188165, 180)
# After TE: (452683, 226) (87828, 226) (188165, 226)
#   Seed 1/5: 142
# [0]	validation_0-auc:0.92529
# [200]	validation_0-auc:0.94588
# [400]	validation_0-auc:0.94847
# [600]	validation_0-auc:0.94927
# [800]	validation_0-auc:0.94962
# [1000]	validation_0-auc:0.94991
# [1200]	validation_0-auc:0.95005
# [1400]	validation_0-auc:0.95015
# [1600]	validation_0-auc:0.95022
# [1800]	validation_0-auc:0.95024
# [2000]	validation_0-auc:0.95030
# [2200]	validation_0-auc:0.95031
# [2229]	validation_0-auc:0.95030
#     Seed AUC: 0.950318408
#     Best iteration: 2029
#   Seed 2/5: 143
# [0]	validation_0-auc:0.92555
# [200]	validation_0-auc:0.94591
# [400]	validation_0-auc:0.94860
# [600]	validation_0-auc:0.94946
# [800]	validation_0-auc:0.94986
# [1000]	validation_0-auc:0.95008
# [1200]	validation_0-auc:0.95026
# [1400]	validation_0-auc:0.95038
# [1600]	validation_0-auc:0.95043
# [1800]	validation_0-auc:0.95047
# [2000]	validation_0-auc:0.95048
# [2200]	validation_0-auc:0.95047
# [2317]	validation_0-auc:0.95044
#     Seed AUC: 0.950481642
#     Best iteration: 2117
#   Seed 3/5: 144
# [0]	validation_0-auc:0.92622
# [200]	validation_0-auc:0.94597
# [400]	validation_0-auc:0.94853
# [600]	validation_0-auc:0.94943
# [800]	validation_0-auc:0.94983
# [1000]	validation_0-auc:0.95009
# [1200]	validation_0-auc:0.95026
# [1400]	validation_0-auc:0.95038
# [1600]	validation_0-auc:0.95042
# [1800]	validation_0-auc:0.95047
# [2000]	validation_0-auc:0.95051
# [2200]	validation_0-auc:0.95051
# [2252]	validation_0-auc:0.95052
#     Seed AUC: 0.950532501
#     Best iteration: 2052
#   Seed 4/5: 145
# [0]	validation_0-auc:0.92478
# [200]	validation_0-auc:0.94583
# [400]	validation_0-auc:0.94856
# [600]	validation_0-auc:0.94943
# [800]	validation_0-auc:0.94988
# [1000]	validation_0-auc:0.95013
# [1200]	validation_0-auc:0.95028
# [1400]	validation_0-auc:0.95037
# [1600]	validation_0-auc:0.95042
# [1800]	validation_0-auc:0.95048
# [2000]	validation_0-auc:0.95051
# [2200]	validation_0-auc:0.95055
# [2400]	validation_0-auc:0.95057
# [2574]	validation_0-auc:0.95057
#     Seed AUC: 0.950579571
#     Best iteration: 2374
#   Seed 5/5: 146
# [0]	validation_0-auc:0.92775
# [200]	validation_0-auc:0.94598
# [400]	validation_0-auc:0.94862
# [600]	validation_0-auc:0.94945
# [800]	validation_0-auc:0.94981
# [1000]	validation_0-auc:0.95008
# [1200]	validation_0-auc:0.95026
# [1400]	validation_0-auc:0.95036
# [1600]	validation_0-auc:0.95039
# [1800]	validation_0-auc:0.95043
# [2000]	validation_0-auc:0.95047
# [2200]	validation_0-auc:0.95050
# [2383]	validation_0-auc:0.95050
#     Seed AUC: 0.950517893
#     Best iteration: 2183
# Fold 2 Ensemble AUC    : 0.950937470
# Fold 2 Ensemble LogLoss: 0.221968955
#
# ==========================================================================================
# Fold 3/5
# ==========================================================================================
# Base: (452683, 111) (87828, 111) (188165, 111)
# target mean train fold: 0.2114813235752171
# target mean valid fold: 0.19897982420184906
# After FE: (452683, 180) (87828, 180) (188165, 180)
# After TE: (452683, 226) (87828, 226) (188165, 226)
#   Seed 1/5: 242
# [0]	validation_0-auc:0.92462
# [200]	validation_0-auc:0.94702
# [400]	validation_0-auc:0.94937
# [600]	validation_0-auc:0.95019
# [800]	validation_0-auc:0.95055
# [1000]	validation_0-auc:0.95076
# [1200]	validation_0-auc:0.95086
# [1400]	validation_0-auc:0.95091
# [1600]	validation_0-auc:0.95103
# [1800]	validation_0-auc:0.95113
# [1983]	validation_0-auc:0.95110
#     Seed AUC: 0.951133586
#     Best iteration: 1783
#   Seed 2/5: 243
# [0]	validation_0-auc:0.92186
# [200]	validation_0-auc:0.94695
# [400]	validation_0-auc:0.94934
# [600]	validation_0-auc:0.95016
# [800]	validation_0-auc:0.95055
# [1000]	validation_0-auc:0.95083
# [1200]	validation_0-auc:0.95104
# [1400]	validation_0-auc:0.95113
# [1600]	validation_0-auc:0.95115
# [1800]	validation_0-auc:0.95120
# [2000]	validation_0-auc:0.95121
# [2057]	validation_0-auc:0.95119
#     Seed AUC: 0.951213729
#     Best iteration: 1857
#   Seed 3/5: 244
# [0]	validation_0-auc:0.92861
# [200]	validation_0-auc:0.94679
# [400]	validation_0-auc:0.94928
# [600]	validation_0-auc:0.95017
# [800]	validation_0-auc:0.95051
# [1000]	validation_0-auc:0.95074
# [1200]	validation_0-auc:0.95092
# [1400]	validation_0-auc:0.95101
# [1600]	validation_0-auc:0.95104
# [1800]	validation_0-auc:0.95111
# [2000]	validation_0-auc:0.95114
# [2200]	validation_0-auc:0.95118
# [2367]	validation_0-auc:0.95118
#     Seed AUC: 0.951182840
#     Best iteration: 2167
#   Seed 4/5: 245
# [0]	validation_0-auc:0.92836
# [200]	validation_0-auc:0.94689
# [400]	validation_0-auc:0.94931
# [600]	validation_0-auc:0.95016
# [800]	validation_0-auc:0.95061
# [1000]	validation_0-auc:0.95081
# [1200]	validation_0-auc:0.95099
# [1400]	validation_0-auc:0.95111
# [1600]	validation_0-auc:0.95116
# [1800]	validation_0-auc:0.95117
# [1935]	validation_0-auc:0.95115
#     Seed AUC: 0.951193171
#     Best iteration: 1735
#   Seed 5/5: 246
# [0]	validation_0-auc:0.92504
# [200]	validation_0-auc:0.94684
# [400]	validation_0-auc:0.94947
# [600]	validation_0-auc:0.95024
# [800]	validation_0-auc:0.95058
# [1000]	validation_0-auc:0.95076
# [1200]	validation_0-auc:0.95088
# [1400]	validation_0-auc:0.95095
# [1600]	validation_0-auc:0.95101
# [1800]	validation_0-auc:0.95106
# [2000]	validation_0-auc:0.95107
# [2200]	validation_0-auc:0.95111
# [2355]	validation_0-auc:0.95112
#     Seed AUC: 0.951125247
#     Best iteration: 2155
# Fold 3 Ensemble AUC    : 0.951591648
# Fold 3 Ensemble LogLoss: 0.220136314
#
# ==========================================================================================
# Fold 4/5
# ==========================================================================================
# Base: (452683, 111) (87828, 111) (188165, 111)
# target mean train fold: 0.2114813235752171
# target mean valid fold: 0.19897982420184906
# After FE: (452683, 180) (87828, 180) (188165, 180)
# After TE: (452683, 226) (87828, 226) (188165, 226)
#   Seed 1/5: 342
# [0]	validation_0-auc:0.92585
# [200]	validation_0-auc:0.94596
# [400]	validation_0-auc:0.94855
# [600]	validation_0-auc:0.94944
# [800]	validation_0-auc:0.94990
# [1000]	validation_0-auc:0.95019
# [1200]	validation_0-auc:0.95035
# [1400]	validation_0-auc:0.95053
# [1600]	validation_0-auc:0.95066
# [1800]	validation_0-auc:0.95077
# [2000]	validation_0-auc:0.95078
# [2200]	validation_0-auc:0.95083
# [2400]	validation_0-auc:0.95087
# [2561]	validation_0-auc:0.95087
#     Seed AUC: 0.950888092
#     Best iteration: 2361
#   Seed 2/5: 343
# [0]	validation_0-auc:0.92706
# [200]	validation_0-auc:0.94603
# [400]	validation_0-auc:0.94867
# [600]	validation_0-auc:0.94954
# [800]	validation_0-auc:0.94997
# [1000]	validation_0-auc:0.95024
# [1200]	validation_0-auc:0.95048
# [1400]	validation_0-auc:0.95068
# [1600]	validation_0-auc:0.95076
# [1800]	validation_0-auc:0.95080
# [2000]	validation_0-auc:0.95084
# [2200]	validation_0-auc:0.95091
# [2400]	validation_0-auc:0.95095
# [2600]	validation_0-auc:0.95100
# [2800]	validation_0-auc:0.95101
# [3000]	validation_0-auc:0.95104
# [3200]	validation_0-auc:0.95106
# [3284]	validation_0-auc:0.95105
#     Seed AUC: 0.951075173
#     Best iteration: 3084
#   Seed 3/5: 344
# [0]	validation_0-auc:0.92790
# [200]	validation_0-auc:0.94602
# [400]	validation_0-auc:0.94861
# [600]	validation_0-auc:0.94956
# [800]	validation_0-auc:0.94989
# [1000]	validation_0-auc:0.95018
# [1200]	validation_0-auc:0.95036
# [1400]	validation_0-auc:0.95053
# [1600]	validation_0-auc:0.95058
# [1800]	validation_0-auc:0.95066
# [2000]	validation_0-auc:0.95073
# [2200]	validation_0-auc:0.95080
# [2400]	validation_0-auc:0.95080
# [2600]	validation_0-auc:0.95083
# [2800]	validation_0-auc:0.95082
# [2841]	validation_0-auc:0.95082
#     Seed AUC: 0.950851730
#     Best iteration: 2641
#   Seed 4/5: 345
# [0]	validation_0-auc:0.92842
# [200]	validation_0-auc:0.94598
# [400]	validation_0-auc:0.94860
# [600]	validation_0-auc:0.94952
# [800]	validation_0-auc:0.94995
# [1000]	validation_0-auc:0.95021
# [1200]	validation_0-auc:0.95043
# [1400]	validation_0-auc:0.95059
# [1600]	validation_0-auc:0.95071
# [1800]	validation_0-auc:0.95081
# [2000]	validation_0-auc:0.95087
# [2200]	validation_0-auc:0.95094
# [2400]	validation_0-auc:0.95095
# [2600]	validation_0-auc:0.95101
# [2800]	validation_0-auc:0.95103
# [2969]	validation_0-auc:0.95099
#     Seed AUC: 0.951031026
#     Best iteration: 2769
#   Seed 5/5: 346
# [0]	validation_0-auc:0.92475
# [200]	validation_0-auc:0.94589
# [400]	validation_0-auc:0.94863
# [600]	validation_0-auc:0.94951
# [800]	validation_0-auc:0.94998
# [1000]	validation_0-auc:0.95026
# [1200]	validation_0-auc:0.95052
# [1400]	validation_0-auc:0.95062
# [1600]	validation_0-auc:0.95078
# [1800]	validation_0-auc:0.95080
# [2000]	validation_0-auc:0.95090
# [2200]	validation_0-auc:0.95096
# [2400]	validation_0-auc:0.95097
# [2600]	validation_0-auc:0.95098
# [2720]	validation_0-auc:0.95098
#     Seed AUC: 0.951007570
#     Best iteration: 2520
# Fold 4 Ensemble AUC    : 0.951465911
# Fold 4 Ensemble LogLoss: 0.220982488
#
# ==========================================================================================
# Fold 5/5
# ==========================================================================================
# Base: (452683, 111) (87828, 111) (188165, 111)
# target mean train fold: 0.2114813235752171
# target mean valid fold: 0.19897982420184906
# After FE: (452683, 180) (87828, 180) (188165, 180)
# After TE: (452683, 226) (87828, 226) (188165, 226)
#   Seed 1/5: 442
# [0]	validation_0-auc:0.92286
# [200]	validation_0-auc:0.94744
# [400]	validation_0-auc:0.95001
# [600]	validation_0-auc:0.95091
# [800]	validation_0-auc:0.95137
# [1000]	validation_0-auc:0.95158
# [1200]	validation_0-auc:0.95172
# [1400]	validation_0-auc:0.95183
# [1600]	validation_0-auc:0.95188
# [1800]	validation_0-auc:0.95196
# [2000]	validation_0-auc:0.95199
# [2200]	validation_0-auc:0.95200
# [2400]	validation_0-auc:0.95200
# [2600]	validation_0-auc:0.95203
# [2800]	validation_0-auc:0.95202
# [2937]	validation_0-auc:0.95201
#     Seed AUC: 0.952045963
#     Best iteration: 2737
#   Seed 2/5: 443
# [0]	validation_0-auc:0.92650
# [200]	validation_0-auc:0.94738
# [400]	validation_0-auc:0.95003
# [600]	validation_0-auc:0.95080
# [800]	validation_0-auc:0.95117
# [1000]	validation_0-auc:0.95142
# [1200]	validation_0-auc:0.95156
# [1400]	validation_0-auc:0.95173
# [1600]	validation_0-auc:0.95185
# [1800]	validation_0-auc:0.95193
# [2000]	validation_0-auc:0.95199
# [2200]	validation_0-auc:0.95203
# [2400]	validation_0-auc:0.95205
# [2600]	validation_0-auc:0.95206
# [2800]	validation_0-auc:0.95209
# [3000]	validation_0-auc:0.95209
# [3062]	validation_0-auc:0.95210
#     Seed AUC: 0.952106588
#     Best iteration: 2862
#   Seed 3/5: 444
# [0]	validation_0-auc:0.92866
# [200]	validation_0-auc:0.94747
# [400]	validation_0-auc:0.95004
# [600]	validation_0-auc:0.95091
# [800]	validation_0-auc:0.95127
# [1000]	validation_0-auc:0.95151
# [1200]	validation_0-auc:0.95166
# [1400]	validation_0-auc:0.95175
# [1600]	validation_0-auc:0.95186
# [1800]	validation_0-auc:0.95191
# [2000]	validation_0-auc:0.95190
# [2044]	validation_0-auc:0.95189
#     Seed AUC: 0.951923949
#     Best iteration: 1844
#   Seed 4/5: 445
# [0]	validation_0-auc:0.92851
# [200]	validation_0-auc:0.94750
# [400]	validation_0-auc:0.95002
# [600]	validation_0-auc:0.95083
# [800]	validation_0-auc:0.95124
# [1000]	validation_0-auc:0.95152
# [1200]	validation_0-auc:0.95169
# [1400]	validation_0-auc:0.95180
# [1600]	validation_0-auc:0.95190
# [1800]	validation_0-auc:0.95194
# [2000]	validation_0-auc:0.95198
# [2200]	validation_0-auc:0.95204
# [2397]	validation_0-auc:0.95202
#     Seed AUC: 0.952038577
#     Best iteration: 2197
#   Seed 5/5: 446
# [0]	validation_0-auc:0.92820
# [200]	validation_0-auc:0.94736
# [400]	validation_0-auc:0.94990
# [600]	validation_0-auc:0.95081
# [800]	validation_0-auc:0.95123
# [1000]	validation_0-auc:0.95148
# [1200]	validation_0-auc:0.95168
# [1400]	validation_0-auc:0.95183
# [1600]	validation_0-auc:0.95189
# [1800]	validation_0-auc:0.95196
# [2000]	validation_0-auc:0.95200
# [2200]	validation_0-auc:0.95205
# [2400]	validation_0-auc:0.95208
# [2538]	validation_0-auc:0.95208
#     Seed AUC: 0.952094884
#     Best iteration: 2338
# Fold 5 Ensemble AUC    : 0.952524065
# Fold 5 Ensemble LogLoss: 0.218396603

# %%
# ============================================================
# CV Result
# ============================================================

print_section("CV Result")

cv_auc = roc_auc_score(train[TARGET], oof_preds)
cv_logloss = log_loss(train[TARGET], clip_pred(oof_preds))

fold_df = pd.DataFrame(fold_records)
seed_df = pd.DataFrame(seed_records)

print(f"Overall CV AUC    : {cv_auc:.9f}")
print(f"Overall CV LogLoss: {cv_logloss:.9f}")
print("fold auc mean:", fold_df["auc"].mean())
print("fold auc std :", fold_df["auc"].std())

display(fold_df)
display(seed_df.head())
# Out:
# ==========================================================================================
# CV Result
# ==========================================================================================
# Overall CV AUC    : 0.951919782
# Overall CV LogLoss: 0.219711286
# fold auc mean: 0.9519265396745282
# fold auc std : 0.0008758924377205993
#    fold       auc   logloss  seed_auc_mean  seed_auc_std  seed_best_iter_mean  \
# 0     1  0.953114  0.217072       0.952612      0.000119               2545.8
# 1     2  0.950937  0.221969       0.950486      0.000089               2151.0
# 2     3  0.951592  0.220136       0.951170      0.000034               1939.4
# 3     4  0.951466  0.220982       0.950971      0.000086               2675.0
# 4     5  0.952524  0.218397       0.952042      0.000065               2395.6
#
#    seed_best_iter_min  seed_best_iter_max  n_train_comp  n_train_orig  \
# 0                2318                2928        351312        101371
# 1                2029                2374        351312        101371
# 2                1735                2167        351312        101371
# 3                2361                3084        351312        101371
# 4                1844                2862        351312        101371
#
#    n_valid  n_features_after_fe_te  pitstop_pairwise_features_removed
# 0    87828                     226                               True
# 1    87828                     226                               True
# 2    87828                     226                               True
# 3    87828                     226                               True
# 4    87828                     226                               True
#    fold  seed_index  model_seed       auc  best_iteration  n_train  n_valid  \
# 0     1           1          42  0.952565            2628   452683    87828
# 1     1           2          43  0.952444            2318   452683    87828
# 2     1           3          44  0.952808            2343   452683    87828
# 3     1           4          45  0.952595            2928   452683    87828
# 4     1           5          46  0.952650            2512   452683    87828
#
#    n_features
# 0         226
# 1         226
# 2         226
# 3         226
# 4         226

# %%
# ============================================================
# Save Artifacts
# ============================================================

print_section("Save Artifacts")

np.save(CFG.OUTDIR / f"oof_{CFG.EXP_ID}.npy", oof_preds)
np.save(CFG.OUTDIR / f"pred_{CFG.EXP_ID}.npy", test_preds)

oof_csv = pd.DataFrame({
    CFG.ID_COL: train_ids.values,
    TARGET: train[TARGET].values,
    "pred": oof_preds,
})
oof_csv.to_csv(CFG.OUTDIR / f"oof_{CFG.EXP_ID}.csv", index=False)

sub = sample_submission.copy()
sub[TARGET] = clip_pred(test_preds)

sub_path = CFG.OUTDIR / f"submission_{CFG.EXP_ID}.csv"
sub.to_csv(sub_path, index=False)

fold_df.to_csv(CFG.OUTDIR / "fold_scores.csv", index=False)
seed_df.to_csv(CFG.OUTDIR / "seed_scores.csv", index=False)

if all_feature_cols_after_fe_te is None:
    all_feature_cols_after_fe_te = FEATURES

pitstop_pairwise_cols = [
    c for c in all_feature_cols_after_fe_te
    if ("__PitStop" in c or "PitStop__" in c)
]

feature_df = pd.DataFrame({
    "feature": all_feature_cols_after_fe_te,
    "is_base": [c in BASE for c in all_feature_cols_after_fe_te],
    "is_num_as_cat": [c in NUM_as_CAT for c in all_feature_cols_after_fe_te],
    "is_digit": [c in DIGIT_FEATURES for c in all_feature_cols_after_fe_te],
    "is_laptime_delta_035": [c in LAPTIME_DELTA_FEATURES_035 for c in all_feature_cols_after_fe_te],
    "is_frequency": [c.startswith("fe__") or c.startswith("fe2__") for c in all_feature_cols_after_fe_te],
    "is_target_encoding": [c.startswith("te_") or c.startswith("te2__") for c in all_feature_cols_after_fe_te],
    "is_pairwise_frequency": [c.startswith("fe2__") for c in all_feature_cols_after_fe_te],
    "is_pairwise_target_encoding": [c.startswith("te2__") for c in all_feature_cols_after_fe_te],
    "contains_year": ["Year" in c for c in all_feature_cols_after_fe_te],
    "contains_race": ["Race" in c for c in all_feature_cols_after_fe_te],
    "contains_driver": ["Driver" in c for c in all_feature_cols_after_fe_te],
    "contains_pitstop": ["PitStop" in c for c in all_feature_cols_after_fe_te],
    "is_pitstop_pairwise_fe_te": [
        ("__PitStop" in c or "PitStop__" in c)
        for c in all_feature_cols_after_fe_te
    ],
})
feature_df.to_csv(CFG.OUTDIR / "feature_columns.csv", index=False)

pd.Series(FEATURES, name="base_feature").to_csv(CFG.OUTDIR / "base_features.csv", index=False)
pd.Series(NUM_as_CAT, name="num_as_cat_feature").to_csv(CFG.OUTDIR / "num_as_cat_features.csv", index=False)
pd.Series(DIGIT_FEATURES, name="digit_feature").to_csv(CFG.OUTDIR / "digit_features.csv", index=False)
pd.Series(LAPTIME_DELTA_FEATURES_035, name="laptime_delta_feature_035").to_csv(CFG.OUTDIR / "laptime_delta_features_035.csv", index=False)

bigram_df = pd.DataFrame({
    "col1": [a for a, b in BIGRAM_SPECS],
    "col2": [b for a, b in BIGRAM_SPECS],
    "fe_feature": ["fe2__" + "__".join((a, b)) for a, b in BIGRAM_SPECS],
    "te_feature": ["te2__" + "__".join((a, b)) for a, b in BIGRAM_SPECS],
    "contains_pitstop": [
        ("PitStop" in (a, b))
        for a, b in BIGRAM_SPECS
    ],
})
bigram_df.to_csv(CFG.OUTDIR / "bigram_specs.csv", index=False)

pd.DataFrame({
    "removed_from_pairwise_source": CFG.DROP_FROM_PAIRWISE_FE_TE,
    "reason": [
        "017 ablation: keep PitStop as base feature but remove PitStop-containing pairwise FE/TE"
        for _ in CFG.DROP_FROM_PAIRWISE_FE_TE
    ],
}).to_csv(CFG.OUTDIR / "removed_pairwise_sources_017.csv", index=False)

# Guardrails
assert "PitStop" in FEATURES
assert len(pitstop_pairwise_cols) == 0
assert not bigram_df["contains_pitstop"].any()
assert not feature_df["is_pitstop_pairwise_fe_te"].any()
# Out:
# ==========================================================================================
# Save Artifacts
# ==========================================================================================

# %%
# ============================================================
# Save cv_result.json
# ============================================================

result = {
    "experiment": {
        "id": CFG.EXP_ID,
        "competition": CFG.COMPETITION,
        "metric": CFG.METRIC,
        "created_at": "2026-05-18",
    },
    "source": {
        "shared_code": "shared_005",
        "base_experiment": "exp_20260509_017_xgb_shared005_no_pitstop_pairte_min",
        "conversion": "017 XGBoost FE/TE seed ensemble + safe LapTime_Delta nonlinear features",
        "note": [
            "035 is based on 017.",
            "PitStop is kept as base feature.",
            "PitStop is removed only from pairwise FE/TE source columns.",
            "Added only safe LapTime_Delta nonlinear features from EDA.",
            "No Driver TE extension is added.",
            "No Normalized_TyreLife or proxy is used.",
            "Original rows are appended to each fold train side only.",
            "Competition validation rows only are used for OOF.",
            "OOF/pred npy files are saved for blend."
        ],
    },
    "data": {
        "train_shape": list(train.shape),
        "test_shape": list(test.shape),
        "original_available": orig is not None,
        "original_shape_after_drop": list(orig.shape) if orig is not None else None,
        "target": CFG.TARGET,
        "id_col": CFG.ID_COL,
        "danger_col": CFG.DANGER_COL,
        "danger_col_used": False,
        "use_original_rows": CFG.USE_ORIGINAL,
        "competition_target_mean": float(train[CFG.TARGET].mean()),
        "original_target_mean": float(orig[CFG.TARGET].mean()) if orig is not None else None,
    },
    "cv": {
        "scheme": "StratifiedKFold",
        "n_splits": CFG.N_SPLITS,
        "shuffle": True,
        "random_state": CFG.SEED,
        "target_encoding_inner_folds": CFG.N_TE_FOLDS,
        "target_encoding_smooth": CFG.TE_SMOOTH,
    },
    "features": {
        "base_feature_count_before_fe_te": int(len(FEATURES)),
        "final_feature_count_after_fe_te": int(len(all_feature_cols_after_fe_te)),
        "num_as_cat_count": int(len(NUM_as_CAT)),
        "digit_feature_count": int(len(DIGIT_FEATURES)),
        "laptime_delta_feature_count_035": int(len(LAPTIME_DELTA_FEATURES_035)),
        "laptime_delta_features_035": LAPTIME_DELTA_FEATURES_035,
        "bigram_spec_count": int(len(BIGRAM_SPECS)),
        "pitstop_in_base_features": "PitStop" in FEATURES,
        "pitstop_in_pairwise_source": "PitStop" in PAIRWISE_TE_BASE,
        "removed_from_pairwise_fe_te": CFG.DROP_FROM_PAIRWISE_FE_TE,
        "pitstop_pairwise_feature_count": int(len(pitstop_pairwise_cols)),
        "feature_blocks": [
            "original_baseline_features",
            "numeric_as_categorical_features",
            "digit_features",
            "laptime_delta_nonlinear_features_035",
            "single_column_frequency_encoding",
            "pairwise_joint_frequency_encoding_without_pitstop_pairs",
            "single_column_target_encoding",
            "pairwise_target_encoding_without_pitstop_pairs",
        ],
        "risk_features_to_watch": [
            "Year",
            "Race",
            "Race-Year interactions via pairwise FE/TE",
            "PitStop as base feature",
            "LapNumber/TyreLife/RaceProgress pairwise FE/TE",
        ],
        "normalized_tyrelife_policy": [
            "Normalized_TyreLife is dropped.",
            "Direct use is forbidden.",
            "Intentional proxy reconstruction is not added.",
        ],
    },
    "model": {
        "family": "XGBoost",
        "estimator": "XGBClassifier",
        "outer_folds": CFG.N_SPLITS,
        "seeds_per_fold": len(CFG.SEEDS),
        "total_models": int(CFG.N_SPLITS * len(CFG.SEEDS)),
        "seeds": CFG.SEEDS,
        "params": CFG.XGB_PARAMS,
    },
    "result": {
        "cv_auc": float(cv_auc),
        "cv_logloss": float(cv_logloss),
        "fold_auc_mean": float(fold_df["auc"].mean()),
        "fold_auc_std": float(fold_df["auc"].std()),
        "fold_scores": fold_records,
        "seed_auc_mean": float(seed_df["auc"].mean()),
        "seed_auc_std": float(seed_df["auc"].std()),
    },
    "artifacts": {
        "outdir": str(CFG.OUTDIR),
        "oof_npy": str(CFG.OUTDIR / f"oof_{CFG.EXP_ID}.npy"),
        "pred_npy": str(CFG.OUTDIR / f"pred_{CFG.EXP_ID}.npy"),
        "oof_csv": str(CFG.OUTDIR / f"oof_{CFG.EXP_ID}.csv"),
        "submission": str(sub_path),
        "fold_scores": str(CFG.OUTDIR / "fold_scores.csv"),
        "seed_scores": str(CFG.OUTDIR / "seed_scores.csv"),
        "feature_columns": str(CFG.OUTDIR / "feature_columns.csv"),
        "base_features": str(CFG.OUTDIR / "base_features.csv"),
        "num_as_cat_features": str(CFG.OUTDIR / "num_as_cat_features.csv"),
        "digit_features": str(CFG.OUTDIR / "digit_features.csv"),
        "laptime_delta_features_035": str(CFG.OUTDIR / "laptime_delta_features_035.csv"),
        "bigram_specs": str(CFG.OUTDIR / "bigram_specs.csv"),
        "removed_pairwise_sources_017": str(CFG.OUTDIR / "removed_pairwise_sources_017.csv"),
        "cv_result": str(CFG.OUTDIR / "cv_result.json"),
    },
    "decision_policy": {
        "single_model": [
            "Compare against 017 first.",
            "If CV/LB remain close to 017, LapTime_Delta nonlinear is not useful for XGB.",
            "If CV/LB improve, consider a CatBoost version only after blend confirmation.",
            "If CV/LB drop or blend weight is near zero, stop this EDA feature direction."
        ],
        "blend": [
            "Add 035 to the current clean stack.",
            "Evaluate avg / HC / NM / SLSQP / Ridge / LogReg using 033-based simplified blend code.",
            "Check correlation against 016/017/034 and whether 035 replaces 016/017.",
            "If 035 receives meaningful weight and improves LB/CV, keep as XGB branch candidate.",
            "Otherwise stop LapTime_Delta nonlinear horizontal expansion."
        ],
    },
}

with open(CFG.OUTDIR / "cv_result.json", "w", encoding="utf-8") as f:
    json.dump(result, f, ensure_ascii=False, indent=2)

print("Saved to:", CFG.OUTDIR)
print("Submission:", sub_path)
print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# Saved to: /kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min
# Submission: /kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/submission_exp_20260518_035_xgb_laptime_delta_nonlinear_min.csv
# {
#   "experiment": {
#     "id": "exp_20260518_035_xgb_laptime_delta_nonlinear_min",
#     "competition": "PS S6E5 Predicting F1 Pit Stops",
#     "metric": "AUC",
#     "created_at": "2026-05-18"
#   },
#   "source": {
#     "shared_code": "shared_005",
#     "base_experiment": "exp_20260509_017_xgb_shared005_no_pitstop_pairte_min",
#     "conversion": "017 XGBoost FE/TE seed ensemble + safe LapTime_Delta nonlinear features",
#     "note": [
#       "035 is based on 017.",
#       "PitStop is kept as base feature.",
#       "PitStop is removed only from pairwise FE/TE source columns.",
#       "Added only safe LapTime_Delta nonlinear features from EDA.",
#       "No Driver TE extension is added.",
#       "No Normalized_TyreLife or proxy is used.",
#       "Original rows are appended to each fold train side only.",
#       "Competition validation rows only are used for OOF.",
#       "OOF/pred npy files are saved for blend."
#     ]
#   },
#   "data": {
#     "train_shape": [
#       439140,
#       113
#     ],
#     "test_shape": [
#       188165,
#       112
#     ],
#     "original_available": true,
#     "original_shape_after_drop": [
#       101371,
#       112
#     ],
#     "target": "PitNextLap",
#     "id_col": "id",
#     "danger_col": "Normalized_TyreLife",
#     "danger_col_used": false,
#     "use_original_rows": true,
#     "competition_target_mean": 0.19898210137996994,
#     "original_target_mean": 0.25479673673930414
#   },
#   "cv": {
#     "scheme": "StratifiedKFold",
#     "n_splits": 5,
#     "shuffle": true,
#     "random_state": 42,
#     "target_encoding_inner_folds": 5,
#     "target_encoding_smooth": 20
#   },
#   "features": {
#     "base_feature_count_before_fe_te": 111,
#     "final_feature_count_after_fe_te": 226,
#     "num_as_cat_count": 23,
#     "digit_feature_count": 67,
#     "laptime_delta_feature_count_035": 7,
#     "laptime_delta_features_035": [
#       "LapTime_Delta_abs_035",
#       "LapTime_Delta_sq_035",
#       "LapTime_Delta_sign_035",
#       "LapTime_Delta_abs_x_TyreLife_035",
#       "LapTime_Delta_abs_x_RaceProgress_035",
#       "LapTime_Delta_abs_x_Cumulative_Degradation_abs_035",
#       "LapTime_Delta_abs_bin20_035"
#     ],
#     "bigram_spec_count": 45,
#     "pitstop_in_base_features": true,
#     "pitstop_in_pairwise_source": false,
#     "removed_from_pairwise_fe_te": [
#       "PitStop"
#     ],
#     "pitstop_pairwise_feature_count": 0,
#     "feature_blocks": [
#       "original_baseline_features",
#       "numeric_as_categorical_features",
#       "digit_features",
#       "laptime_delta_nonlinear_features_035",
#       "single_column_frequency_encoding",
#       "pairwise_joint_frequency_encoding_without_pitstop_pairs",
#       "single_column_target_encoding",
#       "pairwise_target_encoding_without_pitstop_pairs"
#     ],
#     "risk_features_to_watch": [
#       "Year",
#       "Race",
#       "Race-Year interactions via pairwise FE/TE",
#       "PitStop as base feature",
#       "LapNumber/TyreLife/RaceProgress pairwise FE/TE"
#     ],
#     "normalized_tyrelife_policy": [
#       "Normalized_TyreLife is dropped.",
#       "Direct use is forbidden.",
#       "Intentional proxy reconstruction is not added."
#     ]
#   },
#   "model": {
#     "family": "XGBoost",
#     "estimator": "XGBClassifier",
#     "outer_folds": 5,
#     "seeds_per_fold": 5,
#     "total_models": 25,
#     "seeds": [
#       42,
#       43,
#       44,
#       45,
#       46
#     ],
#     "params": {
#       "n_estimators": 10000,
#       "learning_rate": 0.03,
#       "grow_policy": "lossguide",
#       "max_depth": 0,
#       "max_leaves": 64,
#       "min_child_weight": 5,
#       "subsample": 0.8,
#       "colsample_bytree": 0.8,
#       "reg_alpha": 0.0,
#       "reg_lambda": 2.0,
#       "objective": "binary:logistic",
#       "eval_metric": "auc",
#       "tree_method": "hist",
#       "device": "cuda",
#       "n_jobs": -1,
#       "enable_categorical": true,
#       "early_stopping_rounds": 200
#     }
#   },
#   "result": {
#     "cv_auc": 0.951919781919443,
#     "cv_logloss": 0.21971128599770598,
#     "fold_auc_mean": 0.9519265396745282,
#     "fold_auc_std": 0.0008758924377205993,
#     "fold_scores": [
#       {
#         "fold": 1,
#         "auc": 0.9531136045498021,
#         "logloss": 0.2170720697876003,
#         "seed_auc_mean": 0.9526124697317625,
#         "seed_auc_std": 0.00011885400982599055,
#         "seed_best_iter_mean": 2545.8,
#         "seed_best_iter_min": 2318,
#         "seed_best_iter_max": 2928,
#         "n_train_comp": 351312,
#         "n_train_orig": 101371,
#         "n_valid": 87828,
#         "n_features_after_fe_te": 226,
#         "pitstop_pairwise_features_removed": true
#       },
#       {
#         "fold": 2,
#         "auc": 0.9509374695153581,
#         "logloss": 0.22196895462078592,
#         "seed_auc_mean": 0.9504860031930207,
#         "seed_auc_std": 8.948894827780751e-05,
#         "seed_best_iter_mean": 2151.0,
#         "seed_best_iter_min": 2029,
#         "seed_best_iter_max": 2374,
#         "n_train_comp": 351312,
#         "n_train_orig": 101371,
#         "n_valid": 87828,
#         "n_features_after_fe_te": 226,
#         "pitstop_pairwise_features_removed": true
#       },
#       {
#         "fold": 3,
#         "auc": 0.9515916481327418,
#         "logloss": 0.22013631421268137,
#         "seed_auc_mean": 0.9511697144986077,
#         "seed_auc_std": 3.447435897304661e-05,
#         "seed_best_iter_mean": 1939.4,
#         "seed_best_iter_min": 1735,
#         "seed_best_iter_max": 2167,
#         "n_train_comp": 351312,
#         "n_train_orig": 101371,
#         "n_valid": 87828,
#         "n_features_after_fe_te": 226,
#         "pitstop_pairwise_features_removed": true
#       },
#       {
#         "fold": 4,
#         "auc": 0.951465911185231,
#         "logloss": 0.22098248787966085,
#         "seed_auc_mean": 0.9509707181089784,
#         "seed_auc_std": 8.589654628645043e-05,
#         "seed_best_iter_mean": 2675.0,
#         "seed_best_iter_min": 2361,
#         "seed_best_iter_max": 3084,
#         "n_train_comp": 351312,
#         "n_train_orig": 101371,
#         "n_valid": 87828,
#         "n_features_after_fe_te": 226,
#         "pitstop_pairwise_features_removed": true
#       },
#       {
#         "fold": 5,
#         "auc": 0.9525240649895086,
#         "logloss": 0.21839660348780104,
#         "seed_auc_mean": 0.952041992265633,
#         "seed_auc_std": 6.470203248324899e-05,
#         "seed_best_iter_mean": 2395.6,
#         "seed_best_iter_min": 1844,
#         "seed_best_iter_max": 2862,
#         "n_train_comp": 351312,
#         "n_train_orig": 101371,
#         "n_valid": 87828,
#         "n_features_after_fe_te": 226,
#         "pitstop_pairwise_features_removed": true
#       }
#     ],
#     "seed_auc_mean": 0.9514561795596005,
#     "seed_auc_std": 0.0007871425539148242
#   },
#   "artifacts": {
#     "outdir": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min",
#     "oof_npy": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/oof_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy",
#     "pred_npy": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/pred_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy",
#     "oof_csv": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/oof_exp_20260518_035_xgb_laptime_delta_nonlinear_min.csv",
#     "submission": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/submission_exp_20260518_035_xgb_laptime_delta_nonlinear_min.csv",
#     "fold_scores": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/fold_scores.csv",
#     "seed_scores": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/seed_scores.csv",
#     "feature_columns": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/feature_columns.csv",
#     "base_features": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/base_features.csv",
#     "num_as_cat_features": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/num_as_cat_features.csv",
#     "digit_features": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/digit_features.csv",
#     "laptime_delta_features_035": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/laptime_delta_features_035.csv",
#     "bigram_specs": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/bigram_specs.csv",
#     "removed_pairwise_sources_017": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/removed_pairwise_sources_017.csv",
#     "cv_result": "/kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/cv_result.json"
#   },
#   "decision_policy": {
#     "single_model": [
#       "Compare against 017 first.",
#       "If CV/LB remain close to 017, LapTime_Delta nonlinear is not useful for XGB.",
#       "If CV/LB improve, consider a CatBoost version only after blend confirmation.",
#       "If CV/LB drop or blend weight is near zero, stop this EDA feature direction."
#     ],
#     "blend": [
#       "Add 035 to the current clean stack.",
#       "Evaluate avg / HC / NM / SLSQP / Ridge / LogReg using 033-based simplified blend code.",
#       "Check correlation against 016/017/034 and whether 035 replaces 016/017.",
#       "If 035 receives meaningful weight and improves LB/CV, keep as XGB branch candidate.",
#       "Otherwise stop LapTime_Delta nonlinear horizontal expansion."
#     ]
#   }
# }

# %%
# ============================================================
# memo draft
# ============================================================

memo_yml = f"""experiment:
  id: exp_20260518_035_xgb_laptime_delta_nonlinear_min
  title: XGB shared005 no PitStop pairTE + LapTime_Delta nonlinear
  competition: PS S6E5 Predicting F1 Pit Stops
  metric: AUC
  status: completed

objective:
  summary: >
    017 XGB shared005 no_PitStop_pairTE をbaseとして維持し、
    EDA由来の安全な LapTime_Delta 非線形特徴量だけを追加する。
    034 LGB版で効果が弱かったため、XGB branchでも同方向が効くかを1本だけ確認する。
  base_experiment: exp_20260509_017_xgb_shared005_no_pitstop_pairte_min
  intended_role: xgb_branch_replacement_or_auxiliary_candidate

implementation_check:
  base_code: ps-s6e5-017-xgb-shared005-no-pitstop-pairte-min.ipynb
  preserved_from_017:
    - shared005_XGB_FE_TE_seed_ensemble
    - PitStop_kept_as_base_feature
    - PitStop_removed_from_pairwise_FE_TE_source_columns
    - original_rows_appended_to_each_fold_train
    - 5_outer_folds
    - 5_seed_ensemble
    - cuML_TargetEncoder
    - XGB_params_from_017
    - OOF_pred_artifact_format
  added_in_035:
    - LapTime_Delta_abs_035
    - LapTime_Delta_sq_035
    - LapTime_Delta_sign_035
    - LapTime_Delta_abs_x_TyreLife_035
    - LapTime_Delta_abs_x_RaceProgress_035
    - LapTime_Delta_abs_x_Cumulative_Degradation_abs_035
    - LapTime_Delta_abs_bin20_035
  not_added:
    - Driver_TE_extension
    - Weather_x_target_TE
    - Normalized_TyreLife
    - Normalized_TyreLife_proxy
    - TyreLife_div_compound_median_stint
    - final_stint_length_or_future_endpoint_proxy

data:
  competition_path: {str(COMP_PATH)}
  original_path: {str(original_path) if original_path is not None else null}
  target: {CFG.TARGET}
  danger_col:
    name: {CFG.DANGER_COL}
    used: false
    note: >
      originalのNormalized_TyreLifeはdropし、proxy再構成も行わない。

model:
  family: XGBoost
  seeds: {CFG.SEEDS}
  folds: {CFG.N_SPLITS}
  use_original_rows: {CFG.USE_ORIGINAL}
  params: {CFG.XGB_PARAMS}

features:
  base_feature_count_before_fe_te: {len(FEATURES)}
  final_feature_count_after_fe_te: {len(all_feature_cols_after_fe_te)}
  num_as_cat_count: {len(NUM_as_CAT)}
  digit_feature_count: {len(DIGIT_FEATURES)}
  bigram_spec_count: {len(BIGRAM_SPECS)}
  laptime_delta_features_035: {LAPTIME_DELTA_FEATURES_035}
  pitstop_in_base_features: {"PitStop" in FEATURES}
  pitstop_in_pairwise_source: {"PitStop" in PAIRWISE_TE_BASE}
  removed_from_pairwise_fe_te: {CFG.DROP_FROM_PAIRWISE_FE_TE}

result:
  cv_auc: {float(cv_auc)}
  cv_logloss: {float(cv_logloss)}
  public_lb: null
  fold_auc_mean: {float(fold_df["auc"].mean())}
  fold_auc_std: {float(fold_df["auc"].std())}
  seed_auc_mean: {float(seed_df["auc"].mean())}
  seed_auc_std: {float(seed_df["auc"].std())}
  compared_to_017:
    cv_auc: 0.9519393682635370
    public_lb: 0.95164
  compared_to_016:
    cv_auc: 0.9519855866173828
    public_lb: 0.95164

artifacts:
  notebook: ps-s6e5-035-xgb-laptime-delta-nonlinear-min.ipynb
  oof: oof_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy
  pred: pred_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy
  submission: submission_exp_20260518_035_xgb_laptime_delta_nonlinear_min.csv
  cv_result: cv_result.json
  feature_columns: feature_columns.csv
  laptime_delta_features_035: laptime_delta_features_035.csv

blend_policy:
  benchmark_code: 033_based_simplified
  add_to_stack:
    - "014"
    - "015"
    - "016"
    - "017"
    - "021"
    - "028"
    - "029"
    - "032"
    - "034"
    - "035"
  decision_focus:
    - corr_vs_016
    - corr_vs_017
    - corr_vs_034
    - corr_vs_029
    - corr_vs_032
    - nm_hc_slsqp_weight
    - whether_035_replaces_016_or_017
    - logreg_cv
    - public_lb_if_submitted
  keep_rule: >
    Keep if 035 receives meaningful blend weight, improves LogReg, or replaces 016/017 with equal/better CV/LB.
  drop_rule: >
    Drop if 035 is highly correlated with 016/017 and receives near-zero blend weight.

judgement:
  status: pending
  summary: >
    CV/LB/correlation/blend weight確認後に keep / hold / drop を判断する。
"""

memo_path = CFG.OUTDIR / "memo_draft.yml"
with open(memo_path, "w", encoding="utf-8") as f:
    f.write(memo_yml)

print(memo_yml)
print("memo:", memo_path)
# Out:
# experiment:
#   id: exp_20260518_035_xgb_laptime_delta_nonlinear_min
#   title: XGB shared005 no PitStop pairTE + LapTime_Delta nonlinear
#   competition: PS S6E5 Predicting F1 Pit Stops
#   metric: AUC
#   status: completed
#
# objective:
#   summary: >
#     017 XGB shared005 no_PitStop_pairTE をbaseとして維持し、
#     EDA由来の安全な LapTime_Delta 非線形特徴量だけを追加する。
#     034 LGB版で効果が弱かったため、XGB branchでも同方向が効くかを1本だけ確認する。
#   base_experiment: exp_20260509_017_xgb_shared005_no_pitstop_pairte_min
#   intended_role: xgb_branch_replacement_or_auxiliary_candidate
#
# implementation_check:
#   base_code: ps-s6e5-017-xgb-shared005-no-pitstop-pairte-min.ipynb
#   preserved_from_017:
#     - shared005_XGB_FE_TE_seed_ensemble
#     - PitStop_kept_as_base_feature
#     - PitStop_removed_from_pairwise_FE_TE_source_columns
#     - original_rows_appended_to_each_fold_train
#     - 5_outer_folds
#     - 5_seed_ensemble
#     - cuML_TargetEncoder
#     - XGB_params_from_017
#     - OOF_pred_artifact_format
#   added_in_035:
#     - LapTime_Delta_abs_035
#     - LapTime_Delta_sq_035
#     - LapTime_Delta_sign_035
#     - LapTime_Delta_abs_x_TyreLife_035
#     - LapTime_Delta_abs_x_RaceProgress_035
#     - LapTime_Delta_abs_x_Cumulative_Degradation_abs_035
#     - LapTime_Delta_abs_bin20_035
#   not_added:
#     - Driver_TE_extension
#     - Weather_x_target_TE
#     - Normalized_TyreLife
#     - Normalized_TyreLife_proxy
#     - TyreLife_div_compound_median_stint
#     - final_stint_length_or_future_endpoint_proxy
#
# data:
#   competition_path: /kaggle/input/competitions/playground-series-s6e5
#   original_path: /kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/f1_strategy_dataset_v4.csv
#   target: PitNextLap
#   danger_col:
#     name: Normalized_TyreLife
#     used: false
#     note: >
#       originalのNormalized_TyreLifeはdropし、proxy再構成も行わない。
#
# model:
#   family: XGBoost
#   seeds: [42, 43, 44, 45, 46]
#   folds: 5
#   use_original_rows: True
#   params: {'n_estimators': 10000, 'learning_rate': 0.03, 'grow_policy': 'lossguide', 'max_depth': 0, 'max_leaves': 64, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0.0, 'reg_lambda': 2.0, 'objective': 'binary:logistic', 'eval_metric': 'auc', 'tree_method': 'hist', 'device': 'cuda', 'n_jobs': -1, 'enable_categorical': True, 'early_stopping_rounds': 200}
#
# features:
#   base_feature_count_before_fe_te: 111
#   final_feature_count_after_fe_te: 226
#   num_as_cat_count: 23
#   digit_feature_count: 67
#   bigram_spec_count: 45
#   laptime_delta_features_035: ['LapTime_Delta_abs_035', 'LapTime_Delta_sq_035', 'LapTime_Delta_sign_035', 'LapTime_Delta_abs_x_TyreLife_035', 'LapTime_Delta_abs_x_RaceProgress_035', 'LapTime_Delta_abs_x_Cumulative_Degradation_abs_035', 'LapTime_Delta_abs_bin20_035']
#   pitstop_in_base_features: True
#   pitstop_in_pairwise_source: False
#   removed_from_pairwise_fe_te: ['PitStop']
#
# result:
#   cv_auc: 0.951919781919443
#   cv_logloss: 0.21971128599770598
#   public_lb: null
#   fold_auc_mean: 0.9519265396745282
#   fold_auc_std: 0.0008758924377205993
#   seed_auc_mean: 0.9514561795596005
#   seed_auc_std: 0.0007871425539148242
#   compared_to_017:
#     cv_auc: 0.9519393682635370
#     public_lb: 0.95164
#   compared_to_016:
#     cv_auc: 0.9519855866173828
#     public_lb: 0.95164
#
# artifacts:
#   notebook: ps-s6e5-035-xgb-laptime-delta-nonlinear-min.ipynb
#   oof: oof_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy
#   pred: pred_exp_20260518_035_xgb_laptime_delta_nonlinear_min.npy
#   submission: submission_exp_20260518_035_xgb_laptime_delta_nonlinear_min.csv
#   cv_result: cv_result.json
#   feature_columns: feature_columns.csv
#   laptime_delta_features_035: laptime_delta_features_035.csv
#
# blend_policy:
#   benchmark_code: 033_based_simplified
#   add_to_stack:
#     - "014"
#     - "015"
#     - "016"
#     - "017"
#     - "021"
#     - "028"
#     - "029"
#     - "032"
#     - "034"
#     - "035"
#   decision_focus:
#     - corr_vs_016
#     - corr_vs_017
#     - corr_vs_034
#     - corr_vs_029
#     - corr_vs_032
#     - nm_hc_slsqp_weight
#     - whether_035_replaces_016_or_017
#     - logreg_cv
#     - public_lb_if_submitted
#   keep_rule: >
#     Keep if 035 receives meaningful blend weight, improves LogReg, or replaces 016/017 with equal/better CV/LB.
#   drop_rule: >
#     Drop if 035 is highly correlated with 016/017 and receives near-zero blend weight.
#
# judgement:
#   status: pending
#   summary: >
#     CV/LB/correlation/blend weight確認後に keep / hold / drop を判断する。
#
# memo: /kaggle/working/exp_20260518_035_xgb_laptime_delta_nonlinear_min/memo_draft.yml

# %%
# ============================================================
# Preview
# ============================================================

print_section("OOF Preview")
display(oof_csv.head())

print_section("Submission Preview")
display(sub.head())

print_section("Feature Columns Preview")
display(feature_df.head(30))

print_section("Bigram Specs Check")
display(bigram_df.head())
print("Any PitStop bigram:", bool(bigram_df["contains_pitstop"].any()))
# Out:
# ==========================================================================================
# OOF Preview
# ==========================================================================================
#    id  PitNextLap      pred
# 0   0         1.0  0.840412
# 1   1         0.0  0.490670
# 2   2         1.0  0.520854
# 3   3         0.0  0.001182
# 4   4         0.0  0.194083
# ==========================================================================================
# Submission Preview
# ==========================================================================================
#        id  PitNextLap
# 0  439140    0.003292
# 1  439141    0.011633
# 2  439142    0.003692
# 3  439143    0.395675
# 4  439144    0.792538
# ==========================================================================================
# Feature Columns Preview
# ==========================================================================================
#                               feature  is_base  is_num_as_cat  is_digit  \
# 0                              Driver     True          False     False
# 1                            Compound     True          False     False
# 2                                Race     True          False     False
# 3                                Year     True          False     False
# 4                             PitStop     True          False     False
# 5                           LapNumber     True          False     False
# 6                               Stint     True          False     False
# 7                            TyreLife     True          False     False
# 8                            Position     True          False     False
# 9                         LapTime (s)     True          False     False
# 10                      LapTime_Delta     True          False     False
# 11             Cumulative_Degradation     True          False     False
# 12                       RaceProgress     True          False     False
# 13                    Position_Change     True          False     False
# 14                    LapTime (s)_cat    False           True     False
# 15                  LapTime_Delta_cat    False           True     False
# 16         Cumulative_Degradation_cat    False           True     False
# 17             LapTime (s)_round1_cat    False           True     False
# 18             LapTime (s)_round0_cat    False           True     False
# 19     LapTime (s)_round_step_0p5_cat    False           True     False
# 20     LapTime (s)_round_step_1p0_cat    False           True     False
# 21     LapTime (s)_round_step_2p0_cat    False           True     False
# 22     LapTime (s)_round_step_5p0_cat    False           True     False
# 23           LapTime_Delta_round1_cat    False           True     False
# 24           LapTime_Delta_round0_cat    False           True     False
# 25   LapTime_Delta_round_step_0p5_cat    False           True     False
# 26   LapTime_Delta_round_step_1p0_cat    False           True     False
# 27   LapTime_Delta_round_step_2p0_cat    False           True     False
# 28   LapTime_Delta_round_step_5p0_cat    False           True     False
# 29  LapTime_Delta_round_step_10p0_cat    False           True     False
#
#     is_laptime_delta_035  is_frequency  is_target_encoding  \
# 0                  False         False               False
# 1                  False         False               False
# 2                  False         False               False
# 3                  False         False               False
# 4                  False         False               False
# 5                  False         False               False
# 6                  False         False               False
# 7                  False         False               False
# 8                  False         False               False
# 9                  False         False               False
# 10                 False         False               False
# 11                 False         False               False
# 12                 False         False               False
# 13                 False         False               False
# 14                 False         False               False
# 15                 False         False               False
# 16                 False         False               False
# 17                 False         False               False
# 18                 False         False               False
# 19                 False         False               False
# 20                 False         False               False
# 21                 False         False               False
# 22                 False         False               False
# 23                 False         False               False
# 24                 False         False               False
# 25                 False         False               False
# 26                 False         False               False
# 27                 False         False               False
# 28                 False         False               False
# 29                 False         False               False
#
#     is_pairwise_frequency  is_pairwise_target_encoding  contains_year  \
# 0                   False                        False          False
# 1                   False                        False          False
# 2                   False                        False          False
# 3                   False                        False           True
# 4                   False                        False          False
# 5                   False                        False          False
# 6                   False                        False          False
# 7                   False                        False          False
# 8                   False                        False          False
# 9                   False                        False          False
# 10                  False                        False          False
# 11                  False                        False          False
# 12                  False                        False          False
# 13                  False                        False          False
# 14                  False                        False          False
# 15                  False                        False          False
# 16                  False                        False          False
# 17                  False                        False          False
# 18                  False                        False          False
# 19                  False                        False          False
# 20                  False                        False          False
# 21                  False                        False          False
# 22                  False                        False          False
# 23                  False                        False          False
# 24                  False                        False          False
# 25                  False                        False          False
# 26                  False                        False          False
# 27                  False                        False          False
# 28                  False                        False          False
# 29                  False                        False          False
#
#     contains_race  contains_driver  contains_pitstop  \
# 0           False             True             False
# 1           False            False             False
# 2            True            False             False
# 3           False            False             False
# 4           False            False              True
# 5           False            False             False
# 6           False            False             False
# 7           False            False             False
# 8           False            False             False
# 9           False            False             False
# 10          False            False             False
# 11          False            False             False
# 12           True            False             False
# 13          False            False             False
# 14          False            False             False
# 15          False            False             False
# 16          False            False             False
# 17          False            False             False
# 18          False            False             False
# 19          False            False             False
# 20          False            False             False
# 21          False            False             False
# 22          False            False             False
# 23          False            False             False
# 24          False            False             False
# 25          False            False             False
# 26          False            False             False
# 27          False            False             False
# 28          False            False             False
# 29          False            False             False
#
#     is_pitstop_pairwise_fe_te
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                      False
# 13                      False
# 14                      False
# 15                      False
# 16                      False
# 17                      False
# 18                      False
# 19                      False
# 20                      False
# 21                      False
# 22                      False
# 23                      False
# 24                      False
# 25                      False
# 26                      False
# 27                      False
# 28                      False
# 29                      False
# ==========================================================================================
# Bigram Specs Check
# ==========================================================================================
#      col1       col2              fe_feature              te_feature  \
# 0  Driver   Compound   fe2__Driver__Compound   te2__Driver__Compound
# 1  Driver       Race       fe2__Driver__Race       te2__Driver__Race
# 2  Driver       Year       fe2__Driver__Year       te2__Driver__Year
# 3  Driver  LapNumber  fe2__Driver__LapNumber  te2__Driver__LapNumber
# 4  Driver      Stint      fe2__Driver__Stint      te2__Driver__Stint
#
#    contains_pitstop
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# Any PitStop bigram: False
