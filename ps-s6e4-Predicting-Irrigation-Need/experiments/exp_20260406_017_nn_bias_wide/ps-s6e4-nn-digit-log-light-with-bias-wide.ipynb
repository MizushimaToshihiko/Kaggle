# %% [markdown]
# # PS S6E4 - NN bias wide
#
# 目的:
# - 016_nn_digit_log_light を土台に、後処理の class bias wide search を追加する
# - モデル本体は変えず、OOF / test probability に対して bias を適用する
# - NN で bias wide が有効かを切り分ける

# %% [markdown]
# ## 1. Imports / config

# %%
import os
import gc
import json
import math
import random
import warnings
from pathlib import Path
from itertools import product

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

warnings.filterwarnings("ignore")


class CFG:
    COMP_NAME = "playground-series-s6e4"
    TARGET_COL = "Irrigation_Need"
    ID_COL = "id"

    EXP_NAME = "nn_bias_wide"
    SAVE_DIR = Path("/kaggle/working/exp_20260406_017_nn_bias_wide")
    SAVE_DIR.mkdir(parents=True, exist_ok=True)

    SEED = 42
    N_SPLITS = 5

    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    NUM_WORKERS = 2

    EPOCHS = 30
    BATCH_SIZE = 1024
    LR = 1e-3
    WEIGHT_DECAY = 1e-5
    PATIENCE = 5

    NUM_COLS = [
        "Soil_pH",
        "Soil_Moisture",
        "Organic_Carbon",
        "Electrical_Conductivity",
        "Temperature_C",
        "Humidity",
        "Rainfall_mm",
        "Sunlight_Hours",
        "Wind_Speed_kmh",
        "Field_Area_hectare",
        "Previous_Irrigation_mm",
    ]

    CAT_COLS = [
        "Soil_Type",
        "Crop_Type",
        "Crop_Growth_Stage",
        "Season",
        "Irrigation_Type",
        "Water_Source",
        "Region",
        "Mulching_Used",
    ]

    LIGHT_NUM_TARGETS = [
        "Soil_Moisture",
        "Organic_Carbon",
        "Electrical_Conductivity",
        "Rainfall_mm",
        "Sunlight_Hours",
        "Wind_Speed_kmh",
        "Field_Area_hectare",
        "Previous_Irrigation_mm",
    ]

    TARGET_CLASSES = ["Low", "Medium", "High"]
    TARGET_TO_IDX = {v: i for i, v in enumerate(TARGET_CLASSES)}
    IDX_TO_TARGET = {i: v for i, v in enumerate(TARGET_CLASSES)}

    # bias wide search
    BIAS_GRID = np.round(np.arange(-0.30, 0.301, 0.02), 2)
    EPS = 1e-12


def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


seed_everything(CFG.SEED)
print("device:", CFG.DEVICE)
print("save_dir:", CFG.SAVE_DIR)
# Out:
# device: cpu
# save_dir: /kaggle/working/exp_20260406_017_nn_bias_wide

# %% [markdown]
# ## 2. Load data

# %%
INPUT_DIR = Path(f"/kaggle/input/competitions/{CFG.COMP_NAME}")

train = pd.read_csv(INPUT_DIR / "train.csv")
test = pd.read_csv(INPUT_DIR / "test.csv")

print(train.shape, test.shape)
display(train.head())
print(train[CFG.TARGET_COL].value_counts(dropna=False))
# Out:
# (630000, 21) (270000, 20)
#    id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0   0     Loamy     4.92          32.58            1.01
# 1   1      Clay     7.08          56.61            0.44
# 2   2      Clay     5.69          27.71            0.81
# 3   3     Sandy     5.65          13.32            1.33
# 4   4      Clay     7.96          59.14            0.38
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     3.05          15.01     50.61       725.99
# 1                     2.00          22.92     67.86       985.66
# 2                     2.83          26.97     92.22      2201.70
# 3                     0.87          13.32     61.57      1357.33
# 4                     0.96          20.22     91.11      1538.20
#
#    Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0            5.90  ...  Sugarcane            Sowing    Zaid            Drip
# 1            6.98  ...      Wheat        Vegetative  Kharif         Rainfed
# 2            6.05  ...       Rice        Vegetative  Kharif       Sprinkler
# 3            9.12  ...      Wheat         Flowering  Kharif           Canal
# 4            6.95  ...      Wheat            Sowing    Rabi           Canal
#
#   Water_Source Field_Area_hectare  Mulching_Used Previous_Irrigation_mm  \
# 0    Rainwater               0.82             No                 112.16
# 1        River               5.27            Yes                  47.16
# 2    Reservoir               8.24            Yes                 110.38
# 3        River               8.32            Yes                  53.85
# 4        River               7.37             No                  93.19
#
#    Region Irrigation_Need
# 0    East             Low
# 1   South             Low
# 2   North             Low
# 3   South          Medium
# 4   South             Low
#
# [5 rows x 21 columns]
# Irrigation_Need
# Low       369917
# Medium    239074
# High       21009
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Feature engineering helpers

# %%
def safe_log1p(x: pd.Series) -> pd.Series:
    return np.log1p(np.clip(x, a_min=0, a_max=None))


def safe_sqrt(x: pd.Series) -> pd.Series:
    return np.sqrt(np.clip(x, a_min=0, a_max=None))


def build_digit_log_light_features(df: pd.DataFrame, num_targets: list[str]) -> pd.DataFrame:
    out = df.copy()

    for col in num_targets:
        s = out[col].astype(float)

        integer_part = np.floor(s)
        frac_part = s - integer_part

        out[f"{col}__log1p"] = safe_log1p(s)
        out[f"{col}__sqrt"] = safe_sqrt(s)
        out[f"{col}__is_zero"] = (s == 0).astype(np.float32)

        out[f"{col}__integer_part"] = integer_part.astype(np.float32)
        out[f"{col}__frac_part"] = frac_part.astype(np.float32)

        out[f"{col}__first_decimal"] = np.floor(frac_part * 10).astype(np.float32)
        out[f"{col}__second_decimal"] = np.floor((frac_part * 100) % 10).astype(np.float32)

        out[f"{col}__integer_like_flag"] = (np.isclose(frac_part, 0.0)).astype(np.float32)

    return out

# %% [markdown]
# ## 4. Category / target helpers

# %%
def fit_category_maps(train_df, cat_cols):
    cat_maps = {}
    cat_dims = {}
    for col in cat_cols:
        values = train_df[col].astype(str).fillna("__MISSING__")
        uniq = sorted(values.unique().tolist())
        mapping = {v: i + 1 for i, v in enumerate(uniq)}
        cat_maps[col] = mapping
        cat_dims[col] = len(mapping) + 1
    return cat_maps, cat_dims


def transform_categories(df, cat_cols, cat_maps):
    out = pd.DataFrame(index=df.index)
    for col in cat_cols:
        values = df[col].astype(str).fillna("__MISSING__")
        out[col] = values.map(cat_maps[col]).fillna(0).astype(np.int64)
    return out


def transform_target(y):
    return y.map(CFG.TARGET_TO_IDX).astype(np.int64).values


def make_embedding_dim(cardinality: int) -> int:
    return min(32, max(4, int(math.sqrt(cardinality)) + 1))

# %% [markdown]
# ## 5. Dataset

# %%
class TabularDataset(Dataset):
    def __init__(self, X_num, X_cat, y=None):
        self.X_num = torch.tensor(X_num, dtype=torch.float32)
        self.X_cat = torch.tensor(X_cat, dtype=torch.long)
        self.y = None if y is None else torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X_num)

    def __getitem__(self, idx):
        if self.y is None:
            return self.X_num[idx], self.X_cat[idx]
        return self.X_num[idx], self.X_cat[idx], self.y[idx]

# %% [markdown]
# ## 6. Model

# %%
class TabularMLP(nn.Module):
    def __init__(self, num_dim, cat_cardinalities, n_classes):
        super().__init__()

        self.embeddings = nn.ModuleList()
        emb_total_dim = 0
        for card in cat_cardinalities:
            emb_dim = make_embedding_dim(card)
            self.embeddings.append(nn.Embedding(card, emb_dim))
            emb_total_dim += emb_dim

        in_dim = num_dim + emb_total_dim

        self.mlp = nn.Sequential(
            nn.Linear(in_dim, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.1),

            nn.Linear(64, n_classes),
        )

    def forward(self, x_num, x_cat):
        embs = []
        for i, emb in enumerate(self.embeddings):
            embs.append(emb(x_cat[:, i]))
        x = torch.cat([x_num] + embs, dim=1)
        return self.mlp(x)

# %% [markdown]
# ## 7. Train / predict helpers

# %%
def run_epoch(model, loader, optimizer=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    loss_fn = nn.CrossEntropyLoss()
    losses = []
    preds = []
    trues = []

    for batch in loader:
        x_num, x_cat, y = batch

        x_num = x_num.to(CFG.DEVICE)
        x_cat = x_cat.to(CFG.DEVICE)
        y = y.to(CFG.DEVICE)

        with torch.set_grad_enabled(is_train):
            logits = model(x_num, x_cat)
            loss = loss_fn(logits, y)

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        losses.append(loss.item())
        preds.append(torch.argmax(logits, dim=1).detach().cpu().numpy())
        trues.append(y.detach().cpu().numpy())

    preds = np.concatenate(preds)
    trues = np.concatenate(trues)
    score = balanced_accuracy_score(trues, preds)

    return float(np.mean(losses)), score, preds, trues


@torch.no_grad()
def predict_proba(model, loader):
    model.eval()
    probs = []

    for batch in loader:
        if len(batch) == 3:
            x_num, x_cat, _ = batch
        else:
            x_num, x_cat = batch

        x_num = x_num.to(CFG.DEVICE)
        x_cat = x_cat.to(CFG.DEVICE)

        logits = model(x_num, x_cat)
        prob = torch.softmax(logits, dim=1).cpu().numpy()
        probs.append(prob)

    return np.concatenate(probs, axis=0)

# %% [markdown]
# ## 8. CV training

# %%
def fit_nn_cv(train_df, test_df):
    train_feat = build_digit_log_light_features(train_df, CFG.LIGHT_NUM_TARGETS)
    test_feat = build_digit_log_light_features(test_df, CFG.LIGHT_NUM_TARGETS)

    num_feature_cols = [c for c in train_feat.columns if c in CFG.NUM_COLS or "__" in c]

    oof_proba = np.zeros((len(train_df), len(CFG.TARGET_CLASSES)), dtype=np.float32)
    test_proba = np.zeros((len(test_df), len(CFG.TARGET_CLASSES)), dtype=np.float32)
    fold_scores = []

    y_all = train_df[CFG.TARGET_COL].copy()
    X_num_test_base = test_feat[num_feature_cols].copy()
    X_cat_test_base = test_feat[CFG.CAT_COLS].copy()

    skf = StratifiedKFold(n_splits=CFG.N_SPLITS, shuffle=True, random_state=CFG.SEED)

    for fold, (tr_idx, va_idx) in enumerate(skf.split(train_feat, y_all), 1):
        tr_df = train_feat.iloc[tr_idx].reset_index(drop=True)
        va_df = train_feat.iloc[va_idx].reset_index(drop=True)

        scaler = StandardScaler()
        X_num_tr = scaler.fit_transform(tr_df[num_feature_cols])
        X_num_va = scaler.transform(va_df[num_feature_cols])
        X_num_te = scaler.transform(X_num_test_base)

        cat_maps, cat_dims = fit_category_maps(tr_df, CFG.CAT_COLS)
        X_cat_tr = transform_categories(tr_df, CFG.CAT_COLS, cat_maps).values
        X_cat_va = transform_categories(va_df, CFG.CAT_COLS, cat_maps).values
        X_cat_te = transform_categories(X_cat_test_base, CFG.CAT_COLS, cat_maps).values

        y_tr = transform_target(tr_df[CFG.TARGET_COL])
        y_va = transform_target(va_df[CFG.TARGET_COL])

        train_ds = TabularDataset(X_num_tr, X_cat_tr, y_tr)
        valid_ds = TabularDataset(X_num_va, X_cat_va, y_va)
        test_ds = TabularDataset(X_num_te, X_cat_te, None)

        train_loader = DataLoader(
            train_ds, batch_size=CFG.BATCH_SIZE, shuffle=True,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )
        valid_loader = DataLoader(
            valid_ds, batch_size=CFG.BATCH_SIZE, shuffle=False,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )
        test_loader = DataLoader(
            test_ds, batch_size=CFG.BATCH_SIZE, shuffle=False,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )

        model = TabularMLP(
            num_dim=len(num_feature_cols),
            cat_cardinalities=[cat_dims[c] for c in CFG.CAT_COLS],
            n_classes=len(CFG.TARGET_CLASSES),
        ).to(CFG.DEVICE)

        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=CFG.LR,
            weight_decay=CFG.WEIGHT_DECAY,
        )

        best_score = -1.0
        best_state = None
        patience_count = 0

        for epoch in range(1, CFG.EPOCHS + 1):
            train_loss, train_score, _, _ = run_epoch(model, train_loader, optimizer)
            valid_loss, valid_score, _, _ = run_epoch(model, valid_loader, None)

            print(
                f"fold={fold} epoch={epoch} "
                f"train_loss={train_loss:.6f} train_bacc={train_score:.6f} "
                f"valid_loss={valid_loss:.6f} valid_bacc={valid_score:.6f}"
            )

            if valid_score > best_score:
                best_score = valid_score
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                patience_count = 0
            else:
                patience_count += 1
                if patience_count >= CFG.PATIENCE:
                    print(f"fold={fold} early stopping at epoch={epoch}")
                    break

        model.load_state_dict(best_state)

        valid_proba = predict_proba(model, valid_loader)
        test_fold_proba = predict_proba(model, test_loader)

        oof_proba[va_idx] = valid_proba
        test_proba += test_fold_proba / CFG.N_SPLITS
        fold_scores.append(best_score)

        print(f"fold {fold} best balanced_accuracy = {best_score:.6f}")

        del model, optimizer, scaler, train_loader, valid_loader, test_loader
        del train_ds, valid_ds, test_ds
        gc.collect()
        torch.cuda.empty_cache()

    cv_score = float(np.mean(fold_scores))
    return oof_proba, test_proba, fold_scores, cv_score, num_feature_cols

# %% [markdown]
# ## 9. Bias helpers

# %%
def apply_class_bias(proba: np.ndarray, bias: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    logp = np.log(np.clip(proba, eps, 1.0))
    biased = logp + bias.reshape(1, -1)
    return np.argmax(biased, axis=1)


def search_best_bias(y_true_idx: np.ndarray, oof_proba: np.ndarray, bias_grid: np.ndarray):
    best_score = -1.0
    best_bias = None

    for b0, b1, b2 in product(bias_grid, bias_grid, bias_grid):
        bias = np.array([b0, b1, b2], dtype=np.float32)
        pred_idx = apply_class_bias(oof_proba, bias, eps=CFG.EPS)
        score = balanced_accuracy_score(y_true_idx, pred_idx)

        if score > best_score:
            best_score = score
            best_bias = bias.copy()

    return best_bias, float(best_score)

# %% [markdown]
# ## 10. Run CV

# %%
oof_proba, test_proba, fold_scores, cv_score_raw, num_feature_cols = fit_nn_cv(train, test)

y_true_idx = transform_target(train[CFG.TARGET_COL])
best_bias, cv_score_biased = search_best_bias(y_true_idx, oof_proba, CFG.BIAS_GRID)

print("fold_scores =", fold_scores)
print("cv_score_raw =", cv_score_raw)
print("best_bias =", best_bias.tolist())
print("cv_score_biased =", cv_score_biased)
print("n_num_features =", len(num_feature_cols))
# Out:
# fold=1 epoch=1 train_loss=0.253418 train_bacc=0.796898 valid_loss=0.118459 valid_bacc=0.904825
# fold=1 epoch=2 train_loss=0.123162 train_bacc=0.907073 valid_loss=0.093508 valid_bacc=0.942413
# fold=1 epoch=3 train_loss=0.100859 train_bacc=0.929292 valid_loss=0.082037 valid_bacc=0.948719
# fold=1 epoch=4 train_loss=0.090923 train_bacc=0.938046 valid_loss=0.076072 valid_bacc=0.952066
# fold=1 epoch=5 train_loss=0.084841 train_bacc=0.942961 valid_loss=0.073791 valid_bacc=0.953569
# fold=1 epoch=6 train_loss=0.079968 train_bacc=0.947588 valid_loss=0.070388 valid_bacc=0.951471
# fold=1 epoch=7 train_loss=0.077294 train_bacc=0.949578 valid_loss=0.068837 valid_bacc=0.951713
# fold=1 epoch=8 train_loss=0.075218 train_bacc=0.951227 valid_loss=0.067484 valid_bacc=0.956547
# fold=1 epoch=9 train_loss=0.074510 train_bacc=0.951650 valid_loss=0.066356 valid_bacc=0.956264
# fold=1 epoch=10 train_loss=0.071930 train_bacc=0.953846 valid_loss=0.065305 valid_bacc=0.959068
# fold=1 epoch=11 train_loss=0.071802 train_bacc=0.954035 valid_loss=0.065602 valid_bacc=0.957850
# fold=1 epoch=12 train_loss=0.070232 train_bacc=0.955235 valid_loss=0.067409 valid_bacc=0.954718
# fold=1 epoch=13 train_loss=0.069333 train_bacc=0.955101 valid_loss=0.064528 valid_bacc=0.960671
# fold=1 epoch=14 train_loss=0.068760 train_bacc=0.956098 valid_loss=0.065183 valid_bacc=0.960373
# fold=1 epoch=15 train_loss=0.067800 train_bacc=0.957010 valid_loss=0.066895 valid_bacc=0.957176
# fold=1 epoch=16 train_loss=0.067005 train_bacc=0.956916 valid_loss=0.065994 valid_bacc=0.956760
# fold=1 epoch=17 train_loss=0.066528 train_bacc=0.957019 valid_loss=0.064909 valid_bacc=0.960103
# fold=5 epoch=4 train_loss=0.091155 train_bacc=0.940721 valid_loss=0.073090 valid_bacc=0.955350
# fold=5 epoch=5 train_loss=0.084819 train_bacc=0.946089 valid_loss=0.072926 valid_bacc=0.956190
# fold=5 epoch=6 train_loss=0.080838 train_bacc=0.948748 valid_loss=0.069408 valid_bacc=0.954844
# fold=5 epoch=7 train_loss=0.077840 train_bacc=0.950975 valid_loss=0.066841 valid_bacc=0.959893
# fold=5 epoch=8 train_loss=0.075724 train_bacc=0.952717 valid_loss=0.067053 valid_bacc=0.958919
# fold=5 epoch=9 train_loss=0.074237 train_bacc=0.953734 valid_loss=0.064675 valid_bacc=0.959668
# fold=5 epoch=10 train_loss=0.072983 train_bacc=0.954737 valid_loss=0.064032 valid_bacc=0.959876
# fold=5 epoch=11 train_loss=0.072241 train_bacc=0.954961 valid_loss=0.065079 valid_bacc=0.954888
# fold=5 epoch=12 train_loss=0.070938 train_bacc=0.955121 valid_loss=0.063007 valid_bacc=0.960854
# fold=5 epoch=13 train_loss=0.070589 train_bacc=0.955683 valid_loss=0.063234 valid_bacc=0.958435
# fold=5 epoch=14 train_loss=0.069780 train_bacc=0.955863 valid_loss=0.063607 valid_bacc=0.957140
# fold=5 epoch=15 train_loss=0.069099 train_bacc=0.957291 valid_loss=0.063520 valid_bacc=0.960991
# fold=5 epoch=16 train_loss=0.068241 train_bacc=0.957149 valid_loss=0.063233 valid_bacc=0.961279
# fold=5 epoch=17 train_loss=0.067754 train_bacc=0.957547 valid_loss=0.062779 valid_bacc=0.960110
# fold=5 epoch=18 train_loss=0.067465 train_bacc=0.958152 valid_loss=0.062663 valid_bacc=0.958716
# fold=5 epoch=19 train_loss=0.067194 train_bacc=0.957327 valid_loss=0.062199 valid_bacc=0.960176
# fold=5 epoch=20 train_loss=0.066434 train_bacc=0.958060 valid_loss=0.063239 valid_bacc=0.960228
# fold=5 epoch=21 train_loss=0.065579 train_bacc=0.958289 valid_loss=0.062396 valid_bacc=0.958615
# fold=5 early stopping at epoch=21
# fold 5 best balanced_accuracy = 0.961279
# fold_scores = [np.float64(0.9606708162703755), np.float64(0.9620438448153213), np.float64(0.96094252244266), np.float64(0.9610492794123052), np.float64(0.9612791099479834)]
# cv_score_raw = 0.9611971145777292
# best_bias = [-0.30000001192092896, -0.30000001192092896, 0.30000001192092896]
# cv_score_biased = 0.962927985965484
# n_num_features = 75

# %% [markdown]
# ## 11. Save artifacts

# %%
np.save(CFG.SAVE_DIR / f"oof_{CFG.EXP_NAME}_proba.npy", oof_proba)
np.save(CFG.SAVE_DIR / f"pred_{CFG.EXP_NAME}_proba.npy", test_proba)
np.save(CFG.SAVE_DIR / "best_class_bias.npy", best_bias)

oof_pred_idx_raw = oof_proba.argmax(axis=1)
oof_pred_idx_biased = apply_class_bias(oof_proba, best_bias, eps=CFG.EPS)

oof_df = pd.DataFrame({
    CFG.ID_COL: train[CFG.ID_COL],
    "y_true": train[CFG.TARGET_COL],
    "y_pred_raw": pd.Series(oof_pred_idx_raw).map(CFG.IDX_TO_TARGET),
    "y_pred_bias": pd.Series(oof_pred_idx_biased).map(CFG.IDX_TO_TARGET),
})
oof_df.to_csv(CFG.SAVE_DIR / f"oof_{CFG.EXP_NAME}_labels.csv", index=False)

test_pred_idx_biased = apply_class_bias(test_proba, best_bias, eps=CFG.EPS)
sub = pd.DataFrame({
    CFG.ID_COL: test[CFG.ID_COL],
    CFG.TARGET_COL: pd.Series(test_pred_idx_biased).map(CFG.IDX_TO_TARGET),
})
sub.to_csv(CFG.SAVE_DIR / f"submission_{CFG.EXP_NAME}.csv", index=False)

feature_columns_df = pd.DataFrame({
    "feature": num_feature_cols + CFG.CAT_COLS,
    "type": ["num"] * len(num_feature_cols) + ["cat"] * len(CFG.CAT_COLS),
    "is_engineered_num": [c not in CFG.NUM_COLS for c in num_feature_cols] + [False] * len(CFG.CAT_COLS),
})
feature_columns_df.to_csv(CFG.SAVE_DIR / "feature_columns.csv", index=False)

with open(CFG.SAVE_DIR / "cv_result.json", "w", encoding="utf-8") as f:
    json.dump(
        {
            "cv_score_raw": cv_score_raw,
            "cv_score_biased": cv_score_biased,
            "fold_scores": fold_scores,
            "best_bias": best_bias.tolist(),
            "n_raw_num_cols": len(CFG.NUM_COLS),
            "n_final_num_cols": len(num_feature_cols),
            "n_cat_cols": len(CFG.CAT_COLS),
            "n_total_features": len(num_feature_cols) + len(CFG.CAT_COLS),
            "light_num_targets": CFG.LIGHT_NUM_TARGETS,
            "bias_grid_min": float(CFG.BIAS_GRID.min()),
            "bias_grid_max": float(CFG.BIAS_GRID.max()),
            "bias_grid_step": float(CFG.BIAS_GRID[1] - CFG.BIAS_GRID[0]),
            "epochs": CFG.EPOCHS,
            "batch_size": CFG.BATCH_SIZE,
            "lr": CFG.LR,
            "weight_decay": CFG.WEIGHT_DECAY,
            "patience": CFG.PATIENCE,
            "device": CFG.DEVICE,
        },
        f,
        ensure_ascii=False,
        indent=2,
    )

print("saved to:", CFG.SAVE_DIR)
# Out:
# saved to: /kaggle/working/exp_20260406_017_nn_bias_wide

# %% [markdown]
# ## 12. Quick summary

# %%
summary_df = pd.DataFrame({
    "item": [
        "cv_score_raw",
        "cv_score_biased",
        "bias_low",
        "bias_medium",
        "bias_high",
        "n_raw_num_cols",
        "n_final_num_cols",
        "n_cat_cols",
        "n_total_features",
    ],
    "value": [
        cv_score_raw,
        cv_score_biased,
        best_bias[0],
        best_bias[1],
        best_bias[2],
        len(CFG.NUM_COLS),
        len(num_feature_cols),
        len(CFG.CAT_COLS),
        len(num_feature_cols) + len(CFG.CAT_COLS),
    ],
})
display(summary_df)
# Out:
#                item      value
# 0      cv_score_raw   0.961197
# 1   cv_score_biased   0.962928
# 2          bias_low  -0.300000
# 3       bias_medium  -0.300000
# 4         bias_high   0.300000
# 5    n_raw_num_cols  11.000000
# 6  n_final_num_cols  75.000000
# 7        n_cat_cols   8.000000
# 8  n_total_features  83.000000
