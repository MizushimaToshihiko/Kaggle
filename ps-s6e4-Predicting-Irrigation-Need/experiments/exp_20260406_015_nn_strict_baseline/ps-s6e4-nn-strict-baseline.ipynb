# %% [markdown]
# # PS S6E4 - NN strict baseline
#
# 目的:
# - NN系の素の基準線を作る
# - 数値11列 + カテゴリ8列のみ
# - digit/log/CATNUM/TE はまだ入れない
# - まずは MLP + categorical embedding の最小版で確認する

# %% [markdown]
# ## 1. Imports / config

# %%
import os
import gc
import json
import math
import random
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

warnings.filterwarnings("ignore")


class CFG:
    COMP_NAME = "playground-series-s6e4"
    TARGET_COL = "Irrigation_Need"
    ID_COL = "id"

    EXP_NAME = "nn_strict_baseline"
    SAVE_DIR = Path("/kaggle/working/exp_20260406_015_nn_strict_baseline")
    SAVE_DIR.mkdir(parents=True, exist_ok=True)

    SEED = 42
    N_SPLITS = 5

    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    NUM_WORKERS = 2

    EPOCHS = 30
    BATCH_SIZE = 1024
    LR = 1e-3
    WEIGHT_DECAY = 1e-5
    PATIENCE = 5

    NUM_COLS = [
        "Soil_pH",
        "Soil_Moisture",
        "Organic_Carbon",
        "Electrical_Conductivity",
        "Temperature_C",
        "Humidity",
        "Rainfall_mm",
        "Sunlight_Hours",
        "Wind_Speed_kmh",
        "Field_Area_hectare",
        "Previous_Irrigation_mm",
    ]

    CAT_COLS = [
        "Soil_Type",
        "Crop_Type",
        "Crop_Growth_Stage",
        "Season",
        "Irrigation_Type",
        "Water_Source",
        "Region",
        "Mulching_Used",
    ]

    TARGET_CLASSES = ["Low", "Medium", "High"]
    TARGET_TO_IDX = {v: i for i, v in enumerate(TARGET_CLASSES)}
    IDX_TO_TARGET = {i: v for i, v in enumerate(TARGET_CLASSES)}


def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


seed_everything(CFG.SEED)
print("device:", CFG.DEVICE)
print("save_dir:", CFG.SAVE_DIR)
# Out:
# device: cuda
# save_dir: /kaggle/working/exp_20260406_015_nn_strict_baseline

# %% [markdown]
# ## 2. Load data

# %%
INPUT_DIR = Path(f"/kaggle/input/competitions/{CFG.COMP_NAME}")

train = pd.read_csv(INPUT_DIR / "train.csv")
test = pd.read_csv(INPUT_DIR / "test.csv")

print(train.shape, test.shape)
display(train.head())
print(train[CFG.TARGET_COL].value_counts(dropna=False))
# Out:
# (630000, 21) (270000, 20)
#    id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0   0     Loamy     4.92          32.58            1.01
# 1   1      Clay     7.08          56.61            0.44
# 2   2      Clay     5.69          27.71            0.81
# 3   3     Sandy     5.65          13.32            1.33
# 4   4      Clay     7.96          59.14            0.38
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     3.05          15.01     50.61       725.99
# 1                     2.00          22.92     67.86       985.66
# 2                     2.83          26.97     92.22      2201.70
# 3                     0.87          13.32     61.57      1357.33
# 4                     0.96          20.22     91.11      1538.20
#
#    Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0            5.90  ...  Sugarcane            Sowing    Zaid            Drip
# 1            6.98  ...      Wheat        Vegetative  Kharif         Rainfed
# 2            6.05  ...       Rice        Vegetative  Kharif       Sprinkler
# 3            9.12  ...      Wheat         Flowering  Kharif           Canal
# 4            6.95  ...      Wheat            Sowing    Rabi           Canal
#
#   Water_Source Field_Area_hectare  Mulching_Used Previous_Irrigation_mm  \
# 0    Rainwater               0.82             No                 112.16
# 1        River               5.27            Yes                  47.16
# 2    Reservoir               8.24            Yes                 110.38
# 3        River               8.32            Yes                  53.85
# 4        River               7.37             No                  93.19
#
#    Region Irrigation_Need
# 0    East             Low
# 1   South             Low
# 2   North             Low
# 3   South          Medium
# 4   South             Low
#
# [5 rows x 21 columns]
# Irrigation_Need
# Low       369917
# Medium    239074
# High       21009
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Preprocess helpers

# %%
def fit_category_maps(train_df, cat_cols):
    cat_maps = {}
    cat_dims = {}
    for col in cat_cols:
        values = train_df[col].astype(str).fillna("__MISSING__")
        uniq = sorted(values.unique().tolist())
        mapping = {v: i + 1 for i, v in enumerate(uniq)}  # 0 は unknown/reserved
        cat_maps[col] = mapping
        cat_dims[col] = len(mapping) + 1
    return cat_maps, cat_dims


def transform_categories(df, cat_cols, cat_maps):
    out = pd.DataFrame(index=df.index)
    for col in cat_cols:
        values = df[col].astype(str).fillna("__MISSING__")
        out[col] = values.map(cat_maps[col]).fillna(0).astype(np.int64)
    return out


def transform_target(y):
    return y.map(CFG.TARGET_TO_IDX).astype(np.int64).values


def make_embedding_dim(cardinality: int) -> int:
    return min(32, max(4, int(math.sqrt(cardinality)) + 1))

# %% [markdown]
# ## 4. Dataset

# %%
class TabularDataset(Dataset):
    def __init__(self, X_num, X_cat, y=None):
        self.X_num = torch.tensor(X_num, dtype=torch.float32)
        self.X_cat = torch.tensor(X_cat, dtype=torch.long)
        self.y = None if y is None else torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X_num)

    def __getitem__(self, idx):
        if self.y is None:
            return self.X_num[idx], self.X_cat[idx]
        return self.X_num[idx], self.X_cat[idx], self.y[idx]

# %% [markdown]
# ## 5. Model

# %%
class TabularMLP(nn.Module):
    def __init__(self, num_dim, cat_cardinalities, n_classes):
        super().__init__()

        self.embeddings = nn.ModuleList()
        emb_total_dim = 0
        for card in cat_cardinalities:
            emb_dim = make_embedding_dim(card)
            self.embeddings.append(nn.Embedding(card, emb_dim))
            emb_total_dim += emb_dim

        in_dim = num_dim + emb_total_dim

        self.mlp = nn.Sequential(
            nn.Linear(in_dim, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.1),

            nn.Linear(64, n_classes),
        )

    def forward(self, x_num, x_cat):
        embs = []
        for i, emb in enumerate(self.embeddings):
            embs.append(emb(x_cat[:, i]))
        x = torch.cat([x_num] + embs, dim=1)
        return self.mlp(x)

# %% [markdown]
# ## 6. Train / valid helpers

# %%
def run_epoch(model, loader, optimizer=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    loss_fn = nn.CrossEntropyLoss()
    losses = []
    preds = []
    trues = []

    for batch in loader:
        if is_train:
            x_num, x_cat, y = batch
        else:
            x_num, x_cat, y = batch

        x_num = x_num.to(CFG.DEVICE)
        x_cat = x_cat.to(CFG.DEVICE)
        y = y.to(CFG.DEVICE)

        with torch.set_grad_enabled(is_train):
            logits = model(x_num, x_cat)
            loss = loss_fn(logits, y)

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        losses.append(loss.item())
        preds.append(torch.argmax(logits, dim=1).detach().cpu().numpy())
        trues.append(y.detach().cpu().numpy())

    preds = np.concatenate(preds)
    trues = np.concatenate(trues)
    score = balanced_accuracy_score(trues, preds)

    return float(np.mean(losses)), score, preds, trues


@torch.no_grad()
def predict_proba(model, loader):
    model.eval()
    probs = []

    for batch in loader:
        if len(batch) == 3:
            x_num, x_cat, _ = batch
        else:
            x_num, x_cat = batch

        x_num = x_num.to(CFG.DEVICE)
        x_cat = x_cat.to(CFG.DEVICE)

        logits = model(x_num, x_cat)
        prob = torch.softmax(logits, dim=1).cpu().numpy()
        probs.append(prob)

    return np.concatenate(probs, axis=0)

# %% [markdown]
# ## 7. CV training

# %%
def fit_nn_cv(train_df, test_df):
    oof_proba = np.zeros((len(train_df), len(CFG.TARGET_CLASSES)), dtype=np.float32)
    test_proba = np.zeros((len(test_df), len(CFG.TARGET_CLASSES)), dtype=np.float32)
    fold_scores = []

    X_num_all = train_df[CFG.NUM_COLS].copy()
    X_cat_all = train_df[CFG.CAT_COLS].copy()
    y_all = train_df[CFG.TARGET_COL].copy()

    X_num_test_base = test_df[CFG.NUM_COLS].copy()
    X_cat_test_base = test_df[CFG.CAT_COLS].copy()

    skf = StratifiedKFold(n_splits=CFG.N_SPLITS, shuffle=True, random_state=CFG.SEED)

    for fold, (tr_idx, va_idx) in enumerate(skf.split(train_df, y_all), 1):
        tr_df = train_df.iloc[tr_idx].reset_index(drop=True)
        va_df = train_df.iloc[va_idx].reset_index(drop=True)

        scaler = StandardScaler()
        X_num_tr = scaler.fit_transform(tr_df[CFG.NUM_COLS])
        X_num_va = scaler.transform(va_df[CFG.NUM_COLS])
        X_num_te = scaler.transform(X_num_test_base)

        cat_maps, cat_dims = fit_category_maps(tr_df, CFG.CAT_COLS)
        X_cat_tr = transform_categories(tr_df, CFG.CAT_COLS, cat_maps).values
        X_cat_va = transform_categories(va_df, CFG.CAT_COLS, cat_maps).values
        X_cat_te = transform_categories(X_cat_test_base, CFG.CAT_COLS, cat_maps).values

        y_tr = transform_target(tr_df[CFG.TARGET_COL])
        y_va = transform_target(va_df[CFG.TARGET_COL])

        train_ds = TabularDataset(X_num_tr, X_cat_tr, y_tr)
        valid_ds = TabularDataset(X_num_va, X_cat_va, y_va)
        test_ds = TabularDataset(X_num_te, X_cat_te, None)

        train_loader = DataLoader(
            train_ds, batch_size=CFG.BATCH_SIZE, shuffle=True,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )
        valid_loader = DataLoader(
            valid_ds, batch_size=CFG.BATCH_SIZE, shuffle=False,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )
        test_loader = DataLoader(
            test_ds, batch_size=CFG.BATCH_SIZE, shuffle=False,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )

        model = TabularMLP(
            num_dim=len(CFG.NUM_COLS),
            cat_cardinalities=[cat_dims[c] for c in CFG.CAT_COLS],
            n_classes=len(CFG.TARGET_CLASSES),
        ).to(CFG.DEVICE)

        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=CFG.LR,
            weight_decay=CFG.WEIGHT_DECAY,
        )

        best_score = -1.0
        best_state = None
        patience_count = 0

        for epoch in range(1, CFG.EPOCHS + 1):
            train_loss, train_score, _, _ = run_epoch(model, train_loader, optimizer)
            valid_loss, valid_score, _, _ = run_epoch(model, valid_loader, None)

            print(
                f"fold={fold} epoch={epoch} "
                f"train_loss={train_loss:.6f} train_bacc={train_score:.6f} "
                f"valid_loss={valid_loss:.6f} valid_bacc={valid_score:.6f}"
            )

            if valid_score > best_score:
                best_score = valid_score
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                patience_count = 0
            else:
                patience_count += 1
                if patience_count >= CFG.PATIENCE:
                    print(f"fold={fold} early stopping at epoch={epoch}")
                    break

        model.load_state_dict(best_state)

        valid_proba = predict_proba(model, valid_loader)
        test_fold_proba = predict_proba(model, test_loader)

        oof_proba[va_idx] = valid_proba
        test_proba += test_fold_proba / CFG.N_SPLITS
        fold_scores.append(best_score)

        print(f"fold {fold} best balanced_accuracy = {best_score:.6f}")

        del model, optimizer, scaler, train_loader, valid_loader, test_loader
        del train_ds, valid_ds, test_ds
        gc.collect()
        torch.cuda.empty_cache()

    cv_score = float(np.mean(fold_scores))
    return oof_proba, test_proba, fold_scores, cv_score

# %% [markdown]
# ## 8. Run CV

# %%
oof_proba, test_proba, fold_scores, cv_score = fit_nn_cv(train, test)

print("fold_scores =", fold_scores)
print("cv_score =", cv_score)
# Out:
# fold=1 epoch=1 train_loss=0.249944 train_bacc=0.799630 valid_loss=0.117223 valid_bacc=0.895336
# fold=1 epoch=2 train_loss=0.127061 train_bacc=0.897348 valid_loss=0.091819 valid_bacc=0.936048
# fold=1 epoch=3 train_loss=0.106201 train_bacc=0.920622 valid_loss=0.082813 valid_bacc=0.948262
# fold=1 epoch=4 train_loss=0.096660 train_bacc=0.930171 valid_loss=0.079987 valid_bacc=0.949951
# fold=1 epoch=5 train_loss=0.090988 train_bacc=0.935282 valid_loss=0.077381 valid_bacc=0.950251
# fold=1 epoch=6 train_loss=0.087343 train_bacc=0.940260 valid_loss=0.074235 valid_bacc=0.955546
# fold=1 epoch=7 train_loss=0.084852 train_bacc=0.942435 valid_loss=0.072280 valid_bacc=0.955626
# fold=1 epoch=8 train_loss=0.082466 train_bacc=0.944138 valid_loss=0.073245 valid_bacc=0.956184
# fold=1 epoch=9 train_loss=0.081157 train_bacc=0.945582 valid_loss=0.072888 valid_bacc=0.954781
# fold=1 epoch=10 train_loss=0.079701 train_bacc=0.947437 valid_loss=0.070855 valid_bacc=0.952975
# fold=1 epoch=11 train_loss=0.079072 train_bacc=0.948596 valid_loss=0.070595 valid_bacc=0.958837
# fold=1 epoch=12 train_loss=0.077557 train_bacc=0.948757 valid_loss=0.070277 valid_bacc=0.956036
# fold=1 epoch=13 train_loss=0.076874 train_bacc=0.949907 valid_loss=0.069803 valid_bacc=0.952337
# fold=1 epoch=14 train_loss=0.076312 train_bacc=0.950216 valid_loss=0.069010 valid_bacc=0.955234
# fold=1 epoch=15 train_loss=0.076004 train_bacc=0.951359 valid_loss=0.070343 valid_bacc=0.953910
# fold=1 epoch=16 train_loss=0.074761 train_bacc=0.951697 valid_loss=0.070481 valid_bacc=0.949703
# fold=1 early stopping at epoch=16
# fold 1 best balanced_accuracy = 0.958837
# fold=2 epoch=1 train_loss=0.256941 train_bacc=0.800906 valid_loss=0.129135 valid_bacc=0.903073
# fold=2 epoch=2 train_loss=0.131297 train_bacc=0.894900 valid_loss=0.093716 valid_bacc=0.933757
# fold=2 epoch=3 train_loss=0.105788 train_bacc=0.921498 valid_loss=0.086794 valid_bacc=0.927966
# fold=2 epoch=4 train_loss=0.095104 train_bacc=0.931403 valid_loss=0.079247 valid_bacc=0.951482
# fold=2 epoch=5 train_loss=0.088687 train_bacc=0.938192 valid_loss=0.075886 valid_bacc=0.951471
# fold=2 epoch=6 train_loss=0.085627 train_bacc=0.942027 valid_loss=0.074248 valid_bacc=0.959388
# fold=2 epoch=7 train_loss=0.083386 train_bacc=0.944546 valid_loss=0.073108 valid_bacc=0.952729
# fold=2 epoch=8 train_loss=0.080981 train_bacc=0.946484 valid_loss=0.074348 valid_bacc=0.956980
# fold=2 epoch=9 train_loss=0.079845 train_bacc=0.948122 valid_loss=0.070591 valid_bacc=0.954656
# fold=2 epoch=10 train_loss=0.078383 train_bacc=0.949011 valid_loss=0.071287 valid_bacc=0.959703
# fold=2 epoch=11 train_loss=0.077355 train_bacc=0.949550 valid_loss=0.070316 valid_bacc=0.959298
# fold=2 epoch=12 train_loss=0.076640 train_bacc=0.950715 valid_loss=0.070581 valid_bacc=0.961474
# fold=2 epoch=13 train_loss=0.075866 train_bacc=0.950719 valid_loss=0.071041 valid_bacc=0.958840
# fold=2 epoch=14 train_loss=0.075041 train_bacc=0.951537 valid_loss=0.070154 valid_bacc=0.954449
# fold=2 epoch=15 train_loss=0.074735 train_bacc=0.951683 valid_loss=0.071243 valid_bacc=0.959739
# fold=2 epoch=16 train_loss=0.074454 train_bacc=0.951922 valid_loss=0.068587 valid_bacc=0.959320
# fold=2 epoch=17 train_loss=0.073773 train_bacc=0.952732 valid_loss=0.068013 valid_bacc=0.955036
# fold=2 early stopping at epoch=17
# fold 2 best balanced_accuracy = 0.961474
# fold=3 epoch=1 train_loss=0.256183 train_bacc=0.799782 valid_loss=0.130272 valid_bacc=0.895414
# fold=3 epoch=2 train_loss=0.133750 train_bacc=0.893498 valid_loss=0.099338 valid_bacc=0.923054
# fold=3 epoch=3 train_loss=0.109131 train_bacc=0.918644 valid_loss=0.088404 valid_bacc=0.939455
# fold=3 epoch=4 train_loss=0.098418 train_bacc=0.930304 valid_loss=0.084720 valid_bacc=0.951368
# fold=3 epoch=5 train_loss=0.092196 train_bacc=0.936603 valid_loss=0.085001 valid_bacc=0.947173
# fold=3 epoch=6 train_loss=0.088759 train_bacc=0.939223 valid_loss=0.077173 valid_bacc=0.956579
# fold=3 epoch=7 train_loss=0.085465 train_bacc=0.941978 valid_loss=0.075679 valid_bacc=0.955298
# fold=3 epoch=8 train_loss=0.083716 train_bacc=0.944650 valid_loss=0.074701 valid_bacc=0.949814
# fold=3 epoch=9 train_loss=0.081712 train_bacc=0.945743 valid_loss=0.073541 valid_bacc=0.950228
# fold=3 epoch=10 train_loss=0.079964 train_bacc=0.947639 valid_loss=0.073707 valid_bacc=0.955178
# fold=3 epoch=11 train_loss=0.078768 train_bacc=0.947424 valid_loss=0.071754 valid_bacc=0.955478
# fold=3 early stopping at epoch=11
# fold 3 best balanced_accuracy = 0.956579
# fold=4 epoch=1 train_loss=0.246484 train_bacc=0.802657 valid_loss=0.120930 valid_bacc=0.904187
# fold=4 epoch=2 train_loss=0.127714 train_bacc=0.898007 valid_loss=0.092784 valid_bacc=0.931933
# fold=4 epoch=3 train_loss=0.104933 train_bacc=0.921048 valid_loss=0.081816 valid_bacc=0.948783
# fold=4 epoch=4 train_loss=0.095485 train_bacc=0.932177 valid_loss=0.080439 valid_bacc=0.946480
# fold=4 epoch=5 train_loss=0.089887 train_bacc=0.936493 valid_loss=0.075394 valid_bacc=0.954822
# fold=4 epoch=6 train_loss=0.086494 train_bacc=0.941738 valid_loss=0.074475 valid_bacc=0.949494
# fold=4 epoch=7 train_loss=0.084083 train_bacc=0.943594 valid_loss=0.072385 valid_bacc=0.942822
# fold=4 epoch=8 train_loss=0.082681 train_bacc=0.944423 valid_loss=0.072183 valid_bacc=0.948239
# fold=4 epoch=9 train_loss=0.081073 train_bacc=0.946656 valid_loss=0.072337 valid_bacc=0.948346
# fold=4 epoch=10 train_loss=0.079932 train_bacc=0.947208 valid_loss=0.072004 valid_bacc=0.953587
# fold=4 early stopping at epoch=10
# fold 4 best balanced_accuracy = 0.954822
# fold=5 epoch=1 train_loss=0.260923 train_bacc=0.793628 valid_loss=0.121349 valid_bacc=0.893504
# fold=5 epoch=2 train_loss=0.129043 train_bacc=0.899040 valid_loss=0.094828 valid_bacc=0.935718
# fold=5 epoch=3 train_loss=0.107148 train_bacc=0.922329 valid_loss=0.083425 valid_bacc=0.943432
# fold=5 epoch=4 train_loss=0.097062 train_bacc=0.932692 valid_loss=0.080054 valid_bacc=0.946957
# fold=5 epoch=5 train_loss=0.091616 train_bacc=0.937518 valid_loss=0.077839 valid_bacc=0.949675
# fold=5 epoch=6 train_loss=0.088765 train_bacc=0.940356 valid_loss=0.074072 valid_bacc=0.951241
# fold=5 epoch=7 train_loss=0.085908 train_bacc=0.943312 valid_loss=0.072902 valid_bacc=0.951168
# fold=5 epoch=8 train_loss=0.083827 train_bacc=0.944835 valid_loss=0.072771 valid_bacc=0.953366
# fold=5 epoch=9 train_loss=0.081902 train_bacc=0.945479 valid_loss=0.072271 valid_bacc=0.951580
# fold=5 epoch=10 train_loss=0.081269 train_bacc=0.946614 valid_loss=0.070959 valid_bacc=0.955460
# fold=5 epoch=11 train_loss=0.080302 train_bacc=0.947306 valid_loss=0.073027 valid_bacc=0.950977
# fold=5 epoch=12 train_loss=0.078997 train_bacc=0.948226 valid_loss=0.071485 valid_bacc=0.953482
# fold=5 epoch=13 train_loss=0.078970 train_bacc=0.949249 valid_loss=0.070027 valid_bacc=0.951904
# fold=5 epoch=14 train_loss=0.077965 train_bacc=0.949071 valid_loss=0.068978 valid_bacc=0.951827
# fold=5 epoch=15 train_loss=0.077323 train_bacc=0.949478 valid_loss=0.068771 valid_bacc=0.955791
# fold=5 epoch=16 train_loss=0.076637 train_bacc=0.950720 valid_loss=0.071978 valid_bacc=0.949896
# fold=5 epoch=17 train_loss=0.076283 train_bacc=0.950956 valid_loss=0.068943 valid_bacc=0.956886
# fold=5 epoch=18 train_loss=0.075229 train_bacc=0.950735 valid_loss=0.069445 valid_bacc=0.958045
# fold=5 epoch=19 train_loss=0.075088 train_bacc=0.951289 valid_loss=0.067601 valid_bacc=0.956406
# fold=5 epoch=20 train_loss=0.074341 train_bacc=0.951570 valid_loss=0.067364 valid_bacc=0.958733
# fold=5 epoch=21 train_loss=0.074211 train_bacc=0.952213 valid_loss=0.066533 valid_bacc=0.954469
# fold=5 epoch=22 train_loss=0.074147 train_bacc=0.951850 valid_loss=0.068404 valid_bacc=0.958071
# fold=5 epoch=23 train_loss=0.073447 train_bacc=0.952060 valid_loss=0.067841 valid_bacc=0.958030
# fold=5 epoch=24 train_loss=0.073054 train_bacc=0.952784 valid_loss=0.068486 valid_bacc=0.953361
# fold=5 epoch=25 train_loss=0.073081 train_bacc=0.952581 valid_loss=0.066115 valid_bacc=0.956724
# fold=5 early stopping at epoch=25
# fold 5 best balanced_accuracy = 0.958733
# fold_scores = [np.float64(0.9588365230631926), np.float64(0.9614739407131961), np.float64(0.9565792813846946), np.float64(0.9548218908637028), np.float64(0.9587333180147374)]
# cv_score = 0.9580889908079048

# %% [markdown]
# ## 9. Save artifacts

# %%
np.save(CFG.SAVE_DIR / f"oof_{CFG.EXP_NAME}_proba.npy", oof_proba)
np.save(CFG.SAVE_DIR / f"pred_{CFG.EXP_NAME}_proba.npy", test_proba)

oof_pred_idx = oof_proba.argmax(axis=1)
oof_pred_label = pd.Series(oof_pred_idx).map(CFG.IDX_TO_TARGET)

oof_df = pd.DataFrame({
    CFG.ID_COL: train[CFG.ID_COL],
    "y_true": train[CFG.TARGET_COL],
    "y_pred": oof_pred_label,
})
oof_df.to_csv(CFG.SAVE_DIR / f"oof_{CFG.EXP_NAME}_labels.csv", index=False)

sub = pd.DataFrame({
    CFG.ID_COL: test[CFG.ID_COL],
    CFG.TARGET_COL: pd.Series(test_proba.argmax(axis=1)).map(CFG.IDX_TO_TARGET),
})
sub.to_csv(CFG.SAVE_DIR / f"submission_{CFG.EXP_NAME}.csv", index=False)

feature_columns_df = pd.DataFrame({
    "feature": CFG.NUM_COLS + CFG.CAT_COLS,
    "type": ["num"] * len(CFG.NUM_COLS) + ["cat"] * len(CFG.CAT_COLS),
})
feature_columns_df.to_csv(CFG.SAVE_DIR / "feature_columns.csv", index=False)

with open(CFG.SAVE_DIR / "cv_result.json", "w", encoding="utf-8") as f:
    json.dump(
        {
            "cv_score": cv_score,
            "fold_scores": fold_scores,
            "n_num_cols": len(CFG.NUM_COLS),
            "n_cat_cols": len(CFG.CAT_COLS),
            "n_total_features": len(CFG.NUM_COLS) + len(CFG.CAT_COLS),
            "epochs": CFG.EPOCHS,
            "batch_size": CFG.BATCH_SIZE,
            "lr": CFG.LR,
            "weight_decay": CFG.WEIGHT_DECAY,
            "patience": CFG.PATIENCE,
            "device": CFG.DEVICE,
        },
        f,
        ensure_ascii=False,
        indent=2,
    )

print("saved to:", CFG.SAVE_DIR)
# Out:
# saved to: /kaggle/working/exp_20260406_015_nn_strict_baseline

# %% [markdown]
# ## 10. Quick summary

# %%
summary_df = pd.DataFrame({
    "item": [
        "cv_score",
        "n_num_cols",
        "n_cat_cols",
        "n_total_features",
        "epochs",
        "batch_size",
    ],
    "value": [
        cv_score,
        len(CFG.NUM_COLS),
        len(CFG.CAT_COLS),
        len(CFG.NUM_COLS) + len(CFG.CAT_COLS),
        CFG.EPOCHS,
        CFG.BATCH_SIZE,
    ],
})
display(summary_df)
# Out:
#                item        value
# 0          cv_score     0.958089
# 1        n_num_cols    11.000000
# 2        n_cat_cols     8.000000
# 3  n_total_features    19.000000
# 4            epochs    30.000000
# 5        batch_size  1024.000000
