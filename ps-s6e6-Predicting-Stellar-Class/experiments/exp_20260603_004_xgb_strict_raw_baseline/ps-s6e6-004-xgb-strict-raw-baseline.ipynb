# %% [markdown]
# # PS S6E6 - 004 XGBoost strict raw baseline
#
# Experiment: `exp_20260603_004_xgb_strict_raw_baseline`
#
# Purpose:
# - Build the first strict raw XGBoost baseline.
# - Use only competition train/test.
# - Do not use original dataset.
# - Do not add feature engineering, color indices, original priors, snap features, or bias search.
# - Save OOF / test prediction / CV result / submission / memo / registry.
# - Compare with:
#   - `exp_20260601_002_lgb_strict_raw_baseline`
#   - `exp_20260601_003_cat_strict_raw_baseline`
#
# Metric:
# - `balanced_accuracy_score`
#
# CV:
# - `StratifiedKFold(n_splits=5, shuffle=True, random_state=42)`
#
# Date:
# - 2026-06-03

# %%
# ============================================================
# 0. Imports / Config
# ============================================================

import os
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

warnings.filterwarnings("ignore")

try:
    import yaml
except Exception:
    yaml = None

try:
    import xgboost as xgb
    from xgboost import XGBClassifier
except Exception as e:
    raise ImportError("XGBoost import failed. On Kaggle, xgboost should be available by default.") from e


COMPETITION = "PS S6E6 Predicting Stellar Class"
EXP_ID = "exp_20260603_004_xgb_strict_raw_baseline"
SEED = 42
N_SPLITS = 5

TRAIN_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/train.csv")
TEST_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/test.csv")
SAMPLE_SUB_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/sample_submission.csv")

WORKDIR = Path("/kaggle/working")
OUTDIR = WORKDIR / EXP_ID
OUTDIR.mkdir(parents=True, exist_ok=True)

print("XGBoost version:", xgb.__version__)
print("OUTDIR:", OUTDIR)
# Out:
# XGBoost version: 3.2.0
# OUTDIR: /kaggle/working/exp_20260603_004_xgb_strict_raw_baseline

# %%
# ============================================================
# 1. Load data
# ============================================================

for p in [TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH]:
    if not p.exists():
        raise FileNotFoundError(p)

train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_SUB_PATH)

print("train:", train.shape)
print("test :", test.shape)
print("sample:", sample.shape)
print("train columns:", train.columns.tolist())
print("test columns :", test.columns.tolist())
print("sample columns:", sample.columns.tolist())

display(train.head())
display(test.head())
display(sample.head())
# Out:
# train: (577347, 12)
# test : (247435, 11)
# sample: (247435, 2)
# train columns: ['id', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population', 'class']
# test columns : ['id', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population']
# sample columns: ['id', 'class']
#    id       alpha      delta          u          g          r          i  \
# 0   0  147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   1  127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   2  179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   3  225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   4  141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#            z  redshift spectral_type galaxy_population   class
# 0  18.621057  0.408982             M      Red_Sequence  GALAXY
# 1  16.786433  0.157976             M      Red_Sequence  GALAXY
# 2  20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3  17.914952  0.536099             M      Red_Sequence  GALAXY
# 4  17.616185  0.555761             M      Red_Sequence  GALAXY
#        id       alpha      delta          u          g          r          i  \
# 0  577347  120.719779  23.924249  23.668066  21.951680  21.086183  20.180032
# 1  577348  219.414419  42.171651  24.902933  22.338822  20.732163  19.860330
# 2  577349  173.568731  -1.756400  19.427591  18.474633  17.551314  16.570674
# 3  577350  184.903993  -1.411074  23.121029  21.526855  20.670159  20.417633
# 4  577351  222.487816  15.381403  25.094282  22.643981  21.123173  19.439500
#
#            z  redshift spectral_type galaxy_population
# 0  19.202124  0.429042           G/K      Red_Sequence
# 1  19.687691  0.867305             M      Red_Sequence
# 2  16.176765  0.224234           G/K        Blue_Cloud
# 3  20.699095  0.066507           G/K      Red_Sequence
# 4  19.094158  0.977218             M      Red_Sequence
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350  GALAXY
# 4  577351  GALAXY

# %%
# ============================================================
# 2. Schema fixed from 001
# ============================================================

ID_COL = "id"
TARGET_COL = "class"

NUMERIC_COLS = [
    "alpha", "delta", "u", "g", "r", "i", "z", "redshift"
]

CATEGORICAL_COLS = [
    "spectral_type",
    "galaxy_population",
]

FEATURE_COLS = NUMERIC_COLS + CATEGORICAL_COLS

assert ID_COL in train.columns
assert TARGET_COL in train.columns
assert ID_COL in test.columns
assert TARGET_COL not in test.columns
assert set(FEATURE_COLS).issubset(train.columns)
assert set(FEATURE_COLS).issubset(test.columns)

print("FEATURE_COLS:", FEATURE_COLS)
print("NUMERIC_COLS:", NUMERIC_COLS)
print("CATEGORICAL_COLS:", CATEGORICAL_COLS)

print("\nTarget distribution:")
target_dist = train[TARGET_COL].value_counts().to_frame("count")
target_dist["rate"] = train[TARGET_COL].value_counts(normalize=True)
display(target_dist)
# Out:
# FEATURE_COLS: ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population']
# NUMERIC_COLS: ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift']
# CATEGORICAL_COLS: ['spectral_type', 'galaxy_population']
#
# Target distribution:
#          count      rate
# class
# GALAXY  377480  0.653818
# QSO     117143  0.202899
# STAR     82724  0.143283

# %%
# ============================================================
# 3. Strict raw preprocessing
# ============================================================

def prepare_strict_raw(train_df: pd.DataFrame, test_df: pd.DataFrame):
    X = train_df[FEATURE_COLS].copy()
    X_test = test_df[FEATURE_COLS].copy()

    # XGBoost sklearn API is most stable with numeric matrix.
    # Strict raw means no FE, but categorical columns need minimal encoding.
    # Fit mapping on train+test to avoid unseen category mismatch.
    cat_maps = {}
    for col in CATEGORICAL_COLS:
        all_values = pd.concat([X[col], X_test[col]], axis=0).astype("string").fillna("__NA__")
        categories = sorted(all_values.unique().tolist())
        mapping = {v: i for i, v in enumerate(categories)}
        cat_maps[col] = mapping

        X[col] = X[col].astype("string").fillna("__NA__").map(mapping).astype("int32")
        X_test[col] = X_test[col].astype("string").fillna("__NA__").map(mapping).astype("int32")

    for col in NUMERIC_COLS:
        X[col] = X[col].astype("float32")
        X_test[col] = X_test[col].astype("float32")

    return X, X_test, cat_maps

X, X_test, cat_maps = prepare_strict_raw(train, test)

le = LabelEncoder()
y = le.fit_transform(train[TARGET_COL].astype(str))
class_names = le.classes_.tolist()
n_classes = len(class_names)

print("class_names:", class_names)
print("n_classes:", n_classes)
print("cat_maps:", cat_maps)
print("X dtypes:")
display(X.dtypes.to_frame("dtype"))

print("\nEncoded target distribution:")
display(pd.Series(y).value_counts().sort_index().rename(index={i: c for i, c in enumerate(class_names)}).to_frame("count"))
# Out:
# class_names: ['GALAXY', 'QSO', 'STAR']
# n_classes: 3
# cat_maps: {'spectral_type': {'A/F': 0, 'G/K': 1, 'M': 2, 'O/B': 3}, 'galaxy_population': {'Blue_Cloud': 0, 'Red_Sequence': 1}}
# X dtypes:
#                      dtype
# alpha              float32
# delta              float32
# u                  float32
# g                  float32
# r                  float32
# i                  float32
# z                  float32
# redshift           float32
# spectral_type        int32
# galaxy_population    int32
# Encoded target distribution:
#          count
# GALAXY  377480
# QSO     117143
# STAR     82724

# %%
# ============================================================
# 4. Model params
# ============================================================

# Strict raw XGBoost baseline params.
# Do not tune yet. Keep simple, stable, and reproducible.
#
# Notes:
# - tree_method="hist" for stable CPU execution.
# - objective="multi:softprob" because submission needs final class labels
#   and OOF/pred probabilities are useful for later blend/bias search.
# - eval_metric="mlogloss" is for early stopping only.
#   Final adoption metric is sklearn balanced_accuracy_score on OOF argmax.

XGB_PARAMS = dict(
    objective="multi:softprob",
    num_class=n_classes,
    n_estimators=5000,
    learning_rate=0.03,
    max_depth=6,
    min_child_weight=5.0,
    subsample=0.85,
    colsample_bytree=0.85,
    reg_alpha=0.0,
    reg_lambda=1.0,
    gamma=0.0,
    tree_method="hist",
    max_bin=256,
    random_state=SEED,
    n_jobs=-1,
    eval_metric="mlogloss",
)

EARLY_STOPPING_ROUNDS = 150

print(json.dumps(XGB_PARAMS, indent=2))
# Out:
# {
#   "objective": "multi:softprob",
#   "num_class": 3,
#   "n_estimators": 5000,
#   "learning_rate": 0.03,
#   "max_depth": 6,
#   "min_child_weight": 5.0,
#   "subsample": 0.85,
#   "colsample_bytree": 0.85,
#   "reg_alpha": 0.0,
#   "reg_lambda": 1.0,
#   "gamma": 0.0,
#   "tree_method": "hist",
#   "max_bin": 256,
#   "random_state": 42,
#   "n_jobs": -1,
#   "eval_metric": "mlogloss"
# }

# %%
# ============================================================
# 5. CV training
# ============================================================

skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

oof_proba = np.zeros((len(train), n_classes), dtype=np.float32)
test_proba = np.zeros((len(test), n_classes), dtype=np.float32)

fold_rows = []
feature_importance_rows = []
models = []

for fold, (tr_idx, va_idx) in enumerate(skf.split(X, y), start=1):
    print(f"\n========== Fold {fold}/{N_SPLITS} ==========")

    X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
    y_tr, y_va = y[tr_idx], y[va_idx]

    model = XGBClassifier(
        **XGB_PARAMS,
        early_stopping_rounds=EARLY_STOPPING_ROUNDS,
    )

    model.fit(
        X_tr,
        y_tr,
        eval_set=[(X_va, y_va)],
        verbose=200,
    )

    best_iter = int(getattr(model, "best_iteration", None) or XGB_PARAMS["n_estimators"])

    va_proba = model.predict_proba(X_va)
    te_proba = model.predict_proba(X_test)

    oof_proba[va_idx] = va_proba.astype(np.float32)
    test_proba += te_proba.astype(np.float32) / N_SPLITS

    va_pred = va_proba.argmax(axis=1)
    fold_score = balanced_accuracy_score(y_va, va_pred)

    fold_rows.append({
        "fold": fold,
        "balanced_accuracy": float(fold_score),
        "best_iteration": int(best_iter),
        "n_train": int(len(tr_idx)),
        "n_valid": int(len(va_idx)),
    })

    booster = model.get_booster()
    score_gain = booster.get_score(importance_type="gain")
    score_weight = booster.get_score(importance_type="weight")
    fi = pd.DataFrame({
        "feature": FEATURE_COLS,
        "importance_gain": [score_gain.get(f, 0.0) for f in FEATURE_COLS],
        "importance_weight": [score_weight.get(f, 0.0) for f in FEATURE_COLS],
        "fold": fold,
    })
    feature_importance_rows.append(fi)

    print("fold balanced_accuracy:", fold_score)
    print("best_iteration:", best_iter)
    print("confusion matrix:")
    print(confusion_matrix(y_va, va_pred))

    models.append(model)

fold_scores = pd.DataFrame(fold_rows)
feature_importance = pd.concat(feature_importance_rows, ignore_index=True)

oof_pred = oof_proba.argmax(axis=1)
cv_score = balanced_accuracy_score(y, oof_pred)

print("\n========== CV result ==========")
display(fold_scores)
print("OOF balanced_accuracy:", cv_score)
print("\nClassification report:")
print(classification_report(y, oof_pred, target_names=class_names))
# Out:
# ========== Fold 1/5 ==========
# [0]	validation_0-mlogloss:0.84496
# [200]	validation_0-mlogloss:0.12024
# [400]	validation_0-mlogloss:0.10422
# [600]	validation_0-mlogloss:0.09802
# [800]	validation_0-mlogloss:0.09470
# [1000]	validation_0-mlogloss:0.09272
# [1200]	validation_0-mlogloss:0.09138
# [1400]	validation_0-mlogloss:0.09054
# [1600]	validation_0-mlogloss:0.08996
# [1800]	validation_0-mlogloss:0.08957
# [2000]	validation_0-mlogloss:0.08938
# [2200]	validation_0-mlogloss:0.08922
# [2400]	validation_0-mlogloss:0.08909
# [2600]	validation_0-mlogloss:0.08899
# [2800]	validation_0-mlogloss:0.08895
# [2868]	validation_0-mlogloss:0.08894
# fold balanced_accuracy: 0.954939860808643
# best_iteration: 2718
# confusion matrix:
# [[73937   672   887]
#  [  649 22554   226]
#  [ 1161   116 15268]]
#
# ========== Fold 2/5 ==========
# [0]	validation_0-mlogloss:0.84493
# [200]	validation_0-mlogloss:0.12032
# [400]	validation_0-mlogloss:0.10423
# [600]	validation_0-mlogloss:0.09827
# [800]	validation_0-mlogloss:0.09498
# [1000]	validation_0-mlogloss:0.09296
# [1200]	validation_0-mlogloss:0.09172
# [1400]	validation_0-mlogloss:0.09095
# [1600]	validation_0-mlogloss:0.09039
# [1800]	validation_0-mlogloss:0.09000
# [2000]	validation_0-mlogloss:0.08975
# [2200]	validation_0-mlogloss:0.08957
# [2400]	validation_0-mlogloss:0.08945
# [2600]	validation_0-mlogloss:0.08940
# [2800]	validation_0-mlogloss:0.08934
# [3000]	validation_0-mlogloss:0.08932
# [3056]	validation_0-mlogloss:0.08934
# fold balanced_accuracy: 0.9569373797403102
# best_iteration: 2906
# confusion matrix:
# [[73878   655   963]
#  [  600 22615   214]
#  [ 1089   119 15337]]
#
# ========== Fold 3/5 ==========
# [0]	validation_0-mlogloss:0.84498
# [200]	validation_0-mlogloss:0.12243
# [400]	validation_0-mlogloss:0.10616
# [600]	validation_0-mlogloss:0.10002
# [800]	validation_0-mlogloss:0.09657
# [1000]	validation_0-mlogloss:0.09462
# [1200]	validation_0-mlogloss:0.09334
# [1400]	validation_0-mlogloss:0.09235
# [1600]	validation_0-mlogloss:0.09175
# [1800]	validation_0-mlogloss:0.09129
# [2000]	validation_0-mlogloss:0.09103
# [2200]	validation_0-mlogloss:0.09081
# [2400]	validation_0-mlogloss:0.09066
# [2600]	validation_0-mlogloss:0.09052
# [2800]	validation_0-mlogloss:0.09052
# [3000]	validation_0-mlogloss:0.09051
# [3200]	validation_0-mlogloss:0.09047
# [3339]	validation_0-mlogloss:0.09049
# fold balanced_accuracy: 0.9559590148402394
# best_iteration: 3189
# confusion matrix:
# [[73816   674  1006]
#  [  640 22550   239]
#  [ 1085   112 15347]]
#
# ========== Fold 4/5 ==========
# [0]	validation_0-mlogloss:0.84490
# [200]	validation_0-mlogloss:0.12027
# [400]	validation_0-mlogloss:0.10451
# [600]	validation_0-mlogloss:0.09862
# [800]	validation_0-mlogloss:0.09514
# [1000]	validation_0-mlogloss:0.09312
# [1200]	validation_0-mlogloss:0.09192
# [1400]	validation_0-mlogloss:0.09110
# [1600]	validation_0-mlogloss:0.09045
# [1800]	validation_0-mlogloss:0.09008
# [2000]	validation_0-mlogloss:0.08981
# [2200]	validation_0-mlogloss:0.08963
# [2400]	validation_0-mlogloss:0.08953
# [2600]	validation_0-mlogloss:0.08945
# [2800]	validation_0-mlogloss:0.08938
# [3000]	validation_0-mlogloss:0.08941
# [3015]	validation_0-mlogloss:0.08940
# fold balanced_accuracy: 0.9550796948407984
# best_iteration: 2865
# confusion matrix:
# [[73936   621   939]
#  [  639 22583   206]
#  [ 1169   122 15254]]
#
# ========== Fold 5/5 ==========
# [0]	validation_0-mlogloss:0.84488
# [200]	validation_0-mlogloss:0.12134
# [400]	validation_0-mlogloss:0.10530
# [600]	validation_0-mlogloss:0.09933
# [800]	validation_0-mlogloss:0.09580
# [1000]	validation_0-mlogloss:0.09374
# [1200]	validation_0-mlogloss:0.09234
# [1400]	validation_0-mlogloss:0.09150
# [1600]	validation_0-mlogloss:0.09091
# [1800]	validation_0-mlogloss:0.09050
# [2000]	validation_0-mlogloss:0.09014
# [2200]	validation_0-mlogloss:0.08995
# [2400]	validation_0-mlogloss:0.08983
# [2600]	validation_0-mlogloss:0.08976
# [2800]	validation_0-mlogloss:0.08967
# [3000]	validation_0-mlogloss:0.08964
# [3118]	validation_0-mlogloss:0.08963
# fold balanced_accuracy: 0.9560022229454782
# best_iteration: 2968
# confusion matrix:
# [[73828   667  1001]
#  [  665 22544   219]
#  [ 1029   165 15351]]
#
# ========== CV result ==========
#    fold  balanced_accuracy  best_iteration  n_train  n_valid
# 0     1           0.954940            2718   461877   115470
# 1     2           0.956937            2906   461877   115470
# 2     3           0.955959            3189   461878   115469
# 3     4           0.955080            2865   461878   115469
# 4     5           0.956002            2968   461878   115469
# OOF balanced_accuracy: 0.9557836270283273
#
# Classification report:
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98    377480
#          QSO       0.97      0.96      0.96    117143
#         STAR       0.93      0.93      0.93     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.96      0.96      0.96    577347
# weighted avg       0.97      0.97      0.97    577347

# %%
# ============================================================
# 6. Submission
# ============================================================

test_pred = test_proba.argmax(axis=1)
test_labels = le.inverse_transform(test_pred)

submission = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    TARGET_COL: test_labels,
})

# Validate submission schema
assert submission.shape[0] == sample.shape[0]
assert submission.columns.tolist() == sample.columns.tolist()
assert submission[ID_COL].equals(sample[ID_COL])

print(submission[TARGET_COL].value_counts(normalize=True))
display(submission.head())

submission_path = OUTDIR / "submission_xgb_strict_raw_baseline.csv"
submission.to_csv(submission_path, index=False)
print("saved:", submission_path)
# Out:
# class
# GALAXY    0.655388
# QSO       0.202251
# STAR      0.142361
# Name: proportion, dtype: float64
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: /kaggle/working/exp_20260603_004_xgb_strict_raw_baseline/submission_xgb_strict_raw_baseline.csv

# %%
# ============================================================
# 7. Save artifacts
# ============================================================

np.save(OUTDIR / "oof_xgb_strict_raw_proba.npy", oof_proba)
np.save(OUTDIR / "pred_xgb_strict_raw_proba.npy", test_proba)

oof_df = pd.DataFrame({
    ID_COL: train[ID_COL].values,
    "y_true": train[TARGET_COL].astype(str).values,
    "y_pred": le.inverse_transform(oof_pred),
})
for i, cls in enumerate(class_names):
    oof_df[f"proba_{cls}"] = oof_proba[:, i]
oof_df.to_csv(OUTDIR / "oof_xgb_strict_raw.csv", index=False)

pred_df = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    "pred_label": test_labels,
})
for i, cls in enumerate(class_names):
    pred_df[f"proba_{cls}"] = test_proba[:, i]
pred_df.to_csv(OUTDIR / "pred_xgb_strict_raw.csv", index=False)

fold_scores.to_csv(OUTDIR / "fold_scores.csv", index=False)

feature_importance_summary = (
    feature_importance
    .groupby("feature", as_index=False)[["importance_gain", "importance_weight"]]
    .mean()
    .sort_values("importance_gain", ascending=False)
)
feature_importance.to_csv(OUTDIR / "feature_importance_by_fold.csv", index=False)
feature_importance_summary.to_csv(OUTDIR / "feature_importance.csv", index=False)

cv_result = {
    "competition": COMPETITION,
    "exp_id": EXP_ID,
    "model": "XGBoost",
    "status": "completed",
    "metric": "balanced_accuracy_score",
    "cv_score": float(cv_score),
    "fold_scores": fold_scores.to_dict(orient="records"),
    "class_names": class_names,
    "label_mapping": {str(cls): int(i) for i, cls in enumerate(class_names)},
    "feature_cols": FEATURE_COLS,
    "numeric_cols": NUMERIC_COLS,
    "categorical_cols": CATEGORICAL_COLS,
    "cat_maps": cat_maps,
    "params": XGB_PARAMS,
    "early_stopping_rounds": EARLY_STOPPING_ROUNDS,
    "use_original": False,
    "use_fe": False,
    "use_bias_search": False,
    "submission_path": str(submission_path),
}

with open(OUTDIR / "cv_result.json", "w", encoding="utf-8") as f:
    json.dump(cv_result, f, indent=2, ensure_ascii=False, default=str)

print("Artifacts saved to:", OUTDIR)
for p in sorted(OUTDIR.glob("*")):
    print(" -", p.name)
# Out:
# Artifacts saved to: /kaggle/working/exp_20260603_004_xgb_strict_raw_baseline
#  - cv_result.json
#  - feature_importance.csv
#  - feature_importance_by_fold.csv
#  - fold_scores.csv
#  - oof_xgb_strict_raw.csv
#  - oof_xgb_strict_raw_proba.npy
#  - pred_xgb_strict_raw.csv
#  - pred_xgb_strict_raw_proba.npy
#  - submission_xgb_strict_raw_baseline.csv

# %%
# ============================================================
# 8. Initialize / update oof_registry.csv
# ============================================================

registry_path = WORKDIR / "oof_registry.csv"

registry_row = {
    "exp_id": EXP_ID,
    "model_family": "XGBoost",
    "feature_family": "strict_raw",
    "cv_metric": "balanced_accuracy_score",
    "cv_score": float(cv_score),
    "fold_std": float(fold_scores["balanced_accuracy"].std(ddof=0)),
    "public_lb": np.nan,
    "use_original": False,
    "use_fe": False,
    "use_bias_search": False,
    "oof_path": str(OUTDIR / "oof_xgb_strict_raw_proba.npy"),
    "pred_path": str(OUTDIR / "pred_xgb_strict_raw_proba.npy"),
    "submission_path": str(submission_path),
    "role": "strict_raw_baseline",
    "status": "completed",
    "keep_hold_drop": "keep_reference",
    "notes": "First XGBoost strict raw baseline. No original, no FE, no bias search.",
}

if registry_path.exists():
    registry = pd.read_csv(registry_path)
    registry = registry[registry["exp_id"] != EXP_ID]
    registry = pd.concat([registry, pd.DataFrame([registry_row])], ignore_index=True)
else:
    registry = pd.DataFrame([registry_row])

registry.to_csv(registry_path, index=False)
registry.to_csv(OUTDIR / "oof_registry.csv", index=False)

display(registry.tail())
print("registry saved:", registry_path)
# Out:
#                                      exp_id model_family feature_family  \
# 0  exp_20260603_004_xgb_strict_raw_baseline      XGBoost     strict_raw
#
#                  cv_metric  cv_score  fold_std  public_lb  use_original  \
# 0  balanced_accuracy_score  0.955784  0.000723        NaN         False
#
#    use_fe  use_bias_search                                           oof_path  \
# 0   False            False  /kaggle/working/exp_20260603_004_xgb_strict_ra...
#
#                                            pred_path  \
# 0  /kaggle/working/exp_20260603_004_xgb_strict_ra...
#
#                                      submission_path                 role  \
# 0  /kaggle/working/exp_20260603_004_xgb_strict_ra...  strict_raw_baseline
#
#       status  keep_hold_drop  \
# 0  completed  keep_reference
#
#                                                notes
# 0  First XGBoost strict raw baseline. No original...
# registry saved: /kaggle/working/oof_registry.csv

# %%
# ============================================================
# 9. memo.yml
# ============================================================

memo = {
    "experiment": {
        "id": EXP_ID,
        "title": "XGBoost strict raw baseline",
        "competition": COMPETITION,
        "status": "completed",
        "metric": "balanced_accuracy_score",
        "model": "XGBoost",
        "created_at": "2026-06-03",
    },
    "objective": {
        "summary": (
            "Build the first strict raw XGBoost baseline using only competition train/test. "
            "No original dataset, no feature engineering, no color indices, no bias search. "
            "Categorical columns are minimally ordinal-encoded for XGBoost input."
        ),
        "success_criteria": [
            "save oof proba",
            "save test pred proba",
            "save cv_result",
            "save submission",
            "save feature importance",
            "update oof_registry",
        ],
    },
    "data": {
        "train_path": str(TRAIN_PATH),
        "test_path": str(TEST_PATH),
        "sample_submission_path": str(SAMPLE_SUB_PATH),
        "train_shape": list(train.shape),
        "test_shape": list(test.shape),
        "target_col": TARGET_COL,
        "id_col": ID_COL,
        "use_original": False,
    },
    "features": {
        "feature_family": "strict_raw",
        "feature_cols": FEATURE_COLS,
        "numeric_cols": NUMERIC_COLS,
        "categorical_cols": CATEGORICAL_COLS,
        "categorical_encoding": "train+test fitted ordinal encoding",
        "cat_maps": cat_maps,
        "notes": "Raw competition columns only. Categorical columns are encoded only because XGBoost requires numeric input.",
    },
    "cv": {
        "scheme": "StratifiedKFold",
        "n_splits": N_SPLITS,
        "shuffle": True,
        "random_state": SEED,
        "score": float(cv_score),
        "fold_scores": fold_scores.to_dict(orient="records"),
        "fold_std": float(fold_scores["balanced_accuracy"].std(ddof=0)),
    },
    "params": XGB_PARAMS,
    "early_stopping_rounds": EARLY_STOPPING_ROUNDS,
    "outputs": {
        "oof_proba": "oof_xgb_strict_raw_proba.npy",
        "pred_proba": "pred_xgb_strict_raw_proba.npy",
        "oof_csv": "oof_xgb_strict_raw.csv",
        "pred_csv": "pred_xgb_strict_raw.csv",
        "submission": "submission_xgb_strict_raw_baseline.csv",
        "cv_result": "cv_result.json",
        "feature_importance": "feature_importance.csv",
        "registry": "oof_registry.csv",
    },
    "judgement": {
        "status": "keep_reference",
        "reason": (
            "This is the first strict raw XGBoost baseline and should be kept as the reference "
            "for raw baseline family comparison and later FE/original/bias-search experiments."
        ),
        "next_action": [
            "Compare 002/003/004 OOF correlation, fold stability, CV, and Public LB",
            "Decide first main raw family after 002/003/004 comparison",
            "Only after raw baselines, test FE such as color indices or redshift bins",
        ],
    },
}

memo_path = OUTDIR / "memo.yml"
if yaml is not None:
    with open(memo_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(memo, f, allow_unicode=True, sort_keys=False)
else:
    with open(memo_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(memo, indent=2, ensure_ascii=False, default=str))

print("memo saved:", memo_path)
# Out:
# memo saved: /kaggle/working/exp_20260603_004_xgb_strict_raw_baseline/memo.yml
