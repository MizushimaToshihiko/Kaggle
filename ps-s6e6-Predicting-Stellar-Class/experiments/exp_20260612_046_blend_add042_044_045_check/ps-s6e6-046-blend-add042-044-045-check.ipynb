# %% [markdown]
# # 046 Blend Add042 + 044 + 045 Check
#
# Blend/correlation check

# %%
# ============================================================
# 0. Imports / Config
# ============================================================

import json
import warnings
from pathlib import Path
from itertools import combinations

import numpy as np
import pandas as pd
from scipy.optimize import minimize
from scipy.stats import spearmanr

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score
from sklearn.linear_model import LogisticRegression, RidgeClassifier, Ridge, ElasticNet

warnings.filterwarnings("ignore")

try:
    import yaml
except Exception:
    yaml = None

COMPETITION = "PS S6E6 Predicting Stellar Class"
EXP_ID = "exp_20260612_046_blend_add042_044_045_check"
SEED = 42

TRAIN_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/train.csv")
TEST_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/test.csv")
SAMPLE_SUB_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/sample_submission.csv")

# Primary location. The loader below also scans /kaggle/input if a file is not found here.
NPY_DIR = Path("/kaggle/input/datasets/mizushimatoshihiko/npy-files")
INPUT_ROOT = Path("/kaggle/input")

OUTDIR = Path("/kaggle/working") / EXP_ID
OUTDIR.mkdir(parents=True, exist_ok=True)

ID_COL = "id"
TARGET_COL = "class"

MODEL_SPECS = [
    {"key": "015_realmlp_seed42", "exp_id": "exp_20260605_015_shared001_realmlp_as_is", "family": "RealMLP", "role": "stable_single_realmlp_backup", "oof": "oof_exp_20260605_015_shared001_realmlp_as_is_proba.npy", "pred": "pred_exp_20260605_015_shared001_realmlp_as_is_proba.npy", "cv": 0.9681693449222352, "public_lb": 0.96977},
    {"key": "017_realmlp_bias", "exp_id": "exp_20260606_017_bias_search_on_015_realmlp", "family": "RealMLP", "role": "previous_best_realmlp_bias_backup", "oof": "oof_exp_20260606_017_bias_search_on_015_realmlp_proba.npy", "pred": "pred_exp_20260606_017_bias_search_on_015_realmlp_proba.npy", "cv": 0.9683022653955233, "public_lb": 0.96985},
    {"key": "018_xgb_shared003", "exp_id": "exp_20260606_018_shared003_xgb_as_is", "family": "XGBoost", "role": "effective_blend_material", "oof": "oof_exp_20260606_018_shared003_xgb_as_is_proba.npy", "pred": "pred_exp_20260606_018_shared003_xgb_as_is_proba.npy", "cv": 0.965207986418628, "public_lb": 0.96578},
    {"key": "019_blend_best", "exp_id": "exp_20260607_019_blend_add018_xgb_check", "family": "Blend", "role": "previous_public_confirmed_best", "oof": "oof_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy", "pred": "pred_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy", "cv": 0.968872315017554, "public_lb": 0.97000},
    {"key": "020_blend_bias", "exp_id": "exp_20260607_020_bias_search_on_019_best_blend", "family": "Blend", "role": "cv_trusted_attack_reference", "oof": "oof_exp_20260607_020_bias_search_on_019_best_blend_proba.npy", "pred": "pred_exp_20260607_020_bias_search_on_019_best_blend_proba.npy", "cv": 0.9692240443617589, "public_lb": 0.96969},
    {"key": "024_seed_ensemble_blend", "exp_id": "exp_20260608_024_seed_ensemble_and_blend_check", "family": "Blend", "role": "seed_ensemble_blend_reference", "oof": "oof_exp_20260608_024_seed_ensemble_and_blend_check_best_blend_proba.npy", "pred": "pred_exp_20260608_024_seed_ensemble_and_blend_check_best_blend_proba.npy", "cv": 0.9694803109983217, "public_lb": 0.96958},
    {"key": "026_realmlp_v5", "exp_id": "exp_20260608_026_realmlp_v5_as_is", "family": "RealMLP", "role": "realmlp_v5_single_model_candidate", "oof": "oof_exp_20260608_026_realmlp_v5_as_is_proba.npy", "pred": "pred_exp_20260608_026_realmlp_v5_as_is_proba.npy", "cv": 0.9690389777981231, "public_lb": 0.96979},
    {"key": "027_blend_add026", "exp_id": "exp_20260608_027_blend_add026_realmlp_v5_check", "family": "Blend", "role": "previous_cv_trusted_slot", "oof": "oof_exp_20260608_027_blend_add026_realmlp_v5_check_best_blend_proba.npy", "pred": "pred_exp_20260608_027_blend_add026_realmlp_v5_check_best_blend_proba.npy", "cv": 0.9695425457477898, "public_lb": 0.96975},
    {"key": "028_cat_v3", "exp_id": "exp_20260608_028_cat_v3_as_is", "family": "CatBoost", "role": "catboost_v3_family_aux_material", "oof": "oof_exp_20260608_028_cat_v3_as_is_proba.npy", "pred": "pred_exp_20260608_028_cat_v3_as_is_proba.npy", "cv": 0.9688146470512534, "public_lb": 0.96969},
    {"key": "029_blend_add028", "exp_id": "exp_20260608_029_blend_add028_cat_v3_check", "family": "Blend", "role": "previous_best_backup", "oof": "oof_exp_20260608_029_blend_add028_cat_v3_check_best_blend_proba.npy", "pred": "pred_exp_20260608_029_blend_add028_cat_v3_check_best_blend_proba.npy", "cv": 0.9700023026377228, "public_lb": 0.970036},
    {"key": "030_ovr_xgb", "exp_id": "exp_20260608_030_ovr_xgb_as_is", "family": "XGBoost", "role": "low_weight_auxiliary_xgb_ovr_material", "oof": "oof_exp_20260608_030_ovr_xgb_as_is_proba.npy", "pred": "pred_exp_20260608_030_ovr_xgb_as_is_proba.npy", "cv": 0.9609971296999271, "public_lb": 0.96118},
    {"key": "031_blend_add030", "exp_id": "exp_20260608_031_blend_add030_ovr_xgb_check", "family": "Blend", "role": "public_confirmed_current_best_before_033", "oof": "oof_exp_20260608_031_blend_add030_ovr_xgb_check_best_blend_proba.npy", "pred": "pred_exp_20260608_031_blend_add030_ovr_xgb_check_best_blend_proba.npy", "cv": 0.9700333620193362, "public_lb": 0.97043},
    {"key": "032_ovr_tabm", "exp_id": "exp_20260609_032_ovr_tabm_as_is", "family": "TabM", "role": "tabm_ovr_family_aux_material", "oof": "oof_exp_20260609_032_ovr_tabm_as_is_proba.npy", "pred": "pred_exp_20260609_032_ovr_tabm_as_is_proba.npy", "cv": 0.9610105651284856, "public_lb": 0.96106, "tuned_cv": 0.9686168281485955, "public_lb_biased": 0.96895},
    {"key": "033_blend_add032", "exp_id": "exp_20260609_033_blend_add032_tabm_check", "family": "Blend", "role": "previous_public_confirmed_best_backup", "oof": "oof_exp_20260609_033_blend_add032_tabm_check_best_blend_proba.npy", "pred": "pred_exp_20260609_033_blend_add032_tabm_check_best_blend_proba.npy", "cv": 0.9700400336552478, "public_lb": 0.97043},
    {"key": "034_gpu_logreg_default", "exp_id": "exp_20260609_034_gpu_logreg_stacker_own", "family": "GPU_LogisticRegression_Stacker", "role": "stacker_backup_default", "oof": "oof_exp_20260609_034_gpu_logreg_stacker_own_proba.npy", "pred": "pred_exp_20260609_034_gpu_logreg_stacker_own_proba.npy", "cv": 0.9700373069292101, "public_lb": 0.97022, "raw_cv": 0.9699389938897909, "public_lb_raw": 0.97027},
    {"key": "035_shared001_updated", "exp_id": "exp_20260610_035_shared001_updated_realmlp_pytorch_as_is", "family": "RealMLP", "role": "updated_shared001_realmlp_aux_material", "oof": "oof_exp_20260610_035_shared001_updated_realmlp_pytorch_as_is_proba.npy", "pred": "pred_exp_20260610_035_shared001_updated_realmlp_pytorch_as_is_proba.npy", "cv": 0.9687410900866934, "public_lb": 0.97012},
    {"key": "036_gpu_logreg_add035", "exp_id": "exp_20260610_036_gpu_logreg_stacker_add035_own", "family": "GPU_LogisticRegression_Stacker", "role": "improved_stacker_backup_add035", "oof": "oof_exp_20260610_036_gpu_logreg_stacker_add035_own_proba.npy", "pred": "pred_exp_20260610_036_gpu_logreg_stacker_add035_own_proba.npy", "cv": 0.9700674063284508, "public_lb": 0.97037},
    {"key": "036_blend_add035", "exp_id": "exp_20260610_036_blend_add035_shared001_check", "family": "Blend", "role": "cv_best_but_public_weak_add035_blend", "oof": "oof_exp_20260610_036_blend_add035_shared001_check_best_blend_proba.npy", "pred": "pred_exp_20260610_036_blend_add035_shared001_check_best_blend_proba.npy", "cv": 0.9700727843277738, "public_lb": 0.97023},
    {"key": "037_tabicl_v2", "exp_id": "exp_20260610_037_tabicl_v2_as_is", "family": "TabICL", "role": "weak_tabicl_family_material_optional_corr", "oof": "oof_exp_20260610_037_tabicl_v2_as_is_proba.npy", "pred": "pred_exp_20260610_037_tabicl_v2_as_is_proba.npy", "cv": 0.9580770153777599, "public_lb": 0.95920},
    {"key": "038_gpu_logreg_add037", "exp_id": "exp_20260610_038_gpu_logreg_stacker_add037_own", "family": "GPU_LogisticRegression_Stacker", "role": "previous_stacker_best_before_040", "oof": "oof_exp_20260610_038_gpu_logreg_stacker_add037_own_proba.npy", "pred": "pred_exp_20260610_038_gpu_logreg_stacker_add037_own_proba.npy", "cv": 0.9701353365798572, "public_lb": 0.97060},
    {"key": "039_cat_v3_seed2026_qbin_variant", "exp_id": "exp_20260611_039_cat_v3_seed2026_qbin_variant", "family": "CatBoost", "role": "catboost_v3_lower_correlation_variant_material", "oof": "oof_exp_20260611_039_cat_v3_seed2026_qbin_variant_proba.npy", "pred": "pred_exp_20260611_039_cat_v3_seed2026_qbin_variant_proba.npy", "cv": 0.9687053023092482, "public_lb": 0.96984},
    {"key": "040_gpu_logreg_add039", "exp_id": "exp_20260611_040_gpu_logreg_stacker_add039_own", "family": "GPU_LogisticRegression_Stacker", "role": "current_best_after_add039", "oof": "oof_exp_20260611_040_gpu_logreg_stacker_add039_own_proba.npy", "pred": "pred_exp_20260611_040_gpu_logreg_stacker_add039_own_proba.npy", "cv": 0.9702017877238539, "public_lb": 0.97069},
    {"key": "042_realmlp_v5_seed2026_foldvariant", "exp_id": "exp_20260611_042_realmlp_v5_seed2026_foldvariant", "family": "RealMLP", "role": "realmlp_v5_seed_fold_variant_material", "oof": "oof_exp_20260611_042_realmlp_v5_seed2026_foldvariant_proba.npy", "pred": "pred_exp_20260611_042_realmlp_v5_seed2026_foldvariant_proba.npy", "cv": 0.9689482884928097, "public_lb": 0.96943},
    {"key": "044_shared001_updated_seed2027_foldvariant", "exp_id": "exp_20260612_044_shared001_updated_seed2027_foldvariant", "family": "RealMLP", "role": "shared001_updated_seed_fold_variant_material", "oof": "oof_exp_20260612_044_shared001_updated_seed2027_foldvariant_proba.npy", "pred": "pred_exp_20260612_044_shared001_updated_seed2027_foldvariant_proba.npy", "cv": 0.9686035095582338, "public_lb": 0.97000},
    {"key": "045_gpu_logreg_add044", "exp_id": "exp_20260612_045_gpu_logreg_stacker_add044_own", "family": "GPU_LogisticRegression_Stacker", "role": "cv_best_but_public_weak_stacker_add044", "oof": "oof_exp_20260612_045_gpu_logreg_stacker_add044_own_proba.npy", "pred": "pred_exp_20260612_045_gpu_logreg_stacker_add044_own_proba.npy", "cv": 0.9702445493383917, "public_lb": 0.97040, "raw_cv": 0.9701651297689362, "tuned_cv": 0.9702445493383917},
]

TRACK_KEYS = {
    "045": "045_gpu_logreg_add044",
    "044": "044_shared001_updated_seed2027_foldvariant",
    "042": "042_realmlp_v5_seed2026_foldvariant",
    "040": "040_gpu_logreg_add039",
    "039": "039_cat_v3_seed2026_qbin_variant",
    "038": "038_gpu_logreg_add037",
    "037": "037_tabicl_v2",
    "036_gpu": "036_gpu_logreg_add035",
    "036_blend": "036_blend_add035",
    "035": "035_shared001_updated",
    "034": "034_gpu_logreg_default",
    "033": "033_blend_add032",
    "032": "032_ovr_tabm",
    "031": "031_blend_add030",
    "030": "030_ovr_xgb",
    "029": "029_blend_add028",
    "028": "028_cat_v3",
}

FOCUS_MODEL_KEYS = {
    "045": "045_gpu_logreg_add044",
    "044": "044_shared001_updated_seed2027_foldvariant",
    "042": "042_realmlp_v5_seed2026_foldvariant",
    "040": "040_gpu_logreg_add039",
    "039": "039_cat_v3_seed2026_qbin_variant",
    "038": "038_gpu_logreg_add037",
    "037": "037_tabicl_v2",
    "036_gpu": "036_gpu_logreg_add035",
    "036_blend": "036_blend_add035",
    "033": "033_blend_add032",
    "031": "031_blend_add030",
    "028": "028_cat_v3",
}

# 041 should answer:
# - Does 039 help simple probability blending after it improved the GPU LogReg stacker?
# - Can 040 be improved by direct safe blending with 033/038/039/036 variants?
# - Which candidates should remain as final submission slots or backups?
BLEND_SETS = {
    # Singles / current references
    "A_045_only": ["045_gpu_logreg_add044"],
    "B_040_only": ["040_gpu_logreg_add039"],
    "C_041_proxy_best_public_context_038_only": ["038_gpu_logreg_add037"],
    "D_033_only": ["033_blend_add032"],
    "E_044_only": ["044_shared001_updated_seed2027_foldvariant"],
    "F_042_only": ["042_realmlp_v5_seed2026_foldvariant"],
    "G_039_only": ["039_cat_v3_seed2026_qbin_variant"],
    "H_036_gpu_only": ["036_gpu_logreg_add035"],
    "I_036_blend_only": ["036_blend_add035"],
    "J_037_only": ["037_tabicl_v2"],
    "K_031_only": ["031_blend_add030"],

    # Direct 045 checks: 045 has highest OOF CV but weaker LB, so confirm whether safe probability blend can rescue LB-oriented behavior.
    "L_045_040": ["045_gpu_logreg_add044", "040_gpu_logreg_add039"],
    "M_045_033": ["045_gpu_logreg_add044", "033_blend_add032"],
    "N_045_038": ["045_gpu_logreg_add044", "038_gpu_logreg_add037"],
    "O_045_039": ["045_gpu_logreg_add044", "039_cat_v3_seed2026_qbin_variant"],
    "P_045_044": ["045_gpu_logreg_add044", "044_shared001_updated_seed2027_foldvariant"],
    "Q_045_042": ["045_gpu_logreg_add044", "042_realmlp_v5_seed2026_foldvariant"],

    # Direct 040 checks with new single-model materials.
    "R_040_044": ["040_gpu_logreg_add039", "044_shared001_updated_seed2027_foldvariant"],
    "S_040_042": ["040_gpu_logreg_add039", "042_realmlp_v5_seed2026_foldvariant"],
    "T_040_044_042": ["040_gpu_logreg_add039", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant"],
    "U_040_033_044": ["040_gpu_logreg_add039", "033_blend_add032", "044_shared001_updated_seed2027_foldvariant"],
    "V_040_033_042": ["040_gpu_logreg_add039", "033_blend_add032", "042_realmlp_v5_seed2026_foldvariant"],

    # 041-like core sets, now with 042/044/045.
    "W_045_040_033": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "033_blend_add032"],
    "X_045_040_038": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "038_gpu_logreg_add037"],
    "Y_045_040_033_038": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037"],
    "Z1_045_040_033_038_044_042": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant"],
    "Z2_045_040_033_038_036gpu_036blend": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037", "036_gpu_logreg_add035", "036_blend_add035"],
    "Z3_045_040_033_038_036gpu_036blend_044_042": ["045_gpu_logreg_add044", "040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037", "036_gpu_logreg_add035", "036_blend_add035", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant"],
    "Z4_041_old_best_like_plus_new": ["040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037", "036_gpu_logreg_add035", "036_blend_add035", "039_cat_v3_seed2026_qbin_variant", "037_tabicl_v2", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant", "045_gpu_logreg_add044"],
    "Z5_040_033_038_036gpu_036blend_039_044_042": ["040_gpu_logreg_add039", "033_blend_add032", "038_gpu_logreg_add037", "036_gpu_logreg_add035", "036_blend_add035", "039_cat_v3_seed2026_qbin_variant", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant"],
    "Z6_045_033_038_036gpu_036blend_039_044_042": ["045_gpu_logreg_add044", "033_blend_add032", "038_gpu_logreg_add037", "036_gpu_logreg_add035", "036_blend_add035", "039_cat_v3_seed2026_qbin_variant", "044_shared001_updated_seed2027_foldvariant", "042_realmlp_v5_seed2026_foldvariant"],

    # Component diagnostics. Interpret weights carefully because composite blends and components coexist.
    "Z7_component_diagnostics_with_new": ["027_blend_add026", "026_realmlp_v5", "028_cat_v3", "039_cat_v3_seed2026_qbin_variant", "030_ovr_xgb", "032_ovr_tabm", "035_shared001_updated", "037_tabicl_v2", "042_realmlp_v5_seed2026_foldvariant", "044_shared001_updated_seed2027_foldvariant"],
    "Z8_full_all_loaded": [
        "015_realmlp_seed42", "017_realmlp_bias", "018_xgb_shared003",
        "019_blend_best", "020_blend_bias", "024_seed_ensemble_blend",
        "026_realmlp_v5", "027_blend_add026", "028_cat_v3",
        "029_blend_add028", "030_ovr_xgb", "031_blend_add030",
        "032_ovr_tabm", "033_blend_add032", "034_gpu_logreg_default",
        "035_shared001_updated", "036_gpu_logreg_add035", "036_blend_add035",
        "037_tabicl_v2", "038_gpu_logreg_add037", "039_cat_v3_seed2026_qbin_variant",
        "040_gpu_logreg_add039", "042_realmlp_v5_seed2026_foldvariant",
        "044_shared001_updated_seed2027_foldvariant", "045_gpu_logreg_add044",
    ],
}

print("EXP_ID:", EXP_ID)
print("OUTDIR:", OUTDIR)
print("NPY_DIR:", NPY_DIR)
print("n_models:", len(MODEL_SPECS))
print("n_blend_sets:", len(BLEND_SETS))
# Out:
# EXP_ID: exp_20260612_046_blend_add042_044_045_check
# OUTDIR: /kaggle/working/exp_20260612_046_blend_add042_044_045_check
# NPY_DIR: /kaggle/input/datasets/mizushimatoshihiko/npy-files
# n_models: 25
# n_blend_sets: 33

# %%
# ============================================================
# 1. Utilities
# ============================================================

def save_json(obj, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False, default=str)

def resolve_npy(filename):
    """Resolve an npy path. Prefer NPY_DIR, then scan /kaggle/input.

    This is intentionally more robust than 027 because 028 may be uploaded as a
    separate dataset from older npy files.
    """
    p = NPY_DIR / filename
    if p.exists():
        return p
    matches = list(INPUT_ROOT.rglob(filename)) if INPUT_ROOT.exists() else []
    if len(matches) == 1:
        return matches[0]
    if len(matches) > 1:
        print(f"[WARN] multiple matches for {filename}. Using first:")
        for m in matches[:10]:
            print("  ", m)
        return matches[0]
    raise FileNotFoundError(f"Missing npy file: {filename}. Checked {NPY_DIR} and scanned {INPUT_ROOT}.")

def validate_proba(name, arr, n_rows, n_classes):
    assert arr.shape == (n_rows, n_classes), (name, arr.shape)
    assert np.isfinite(arr).all(), name
    assert np.allclose(arr.sum(axis=1), 1.0, atol=1e-4), name
    assert arr.min() >= -1e-7, (name, arr.min())
    assert arr.max() <= 1.0 + 1e-7, (name, arr.max())

def normalize_rows(p, eps=1e-12):
    p = np.asarray(p, dtype=np.float64)
    p = np.clip(p, eps, None)
    return p / p.sum(axis=1, keepdims=True)

def softmax_np(x, axis=1):
    x = np.asarray(x, dtype=np.float64)
    x = x - np.max(x, axis=axis, keepdims=True)
    ex = np.exp(x)
    return ex / np.sum(ex, axis=axis, keepdims=True)

def proba_to_pred(p):
    return np.argmax(p, axis=1)

def flatten_proba(p):
    return np.asarray(p, dtype=float).reshape(-1)

def corr_pearson(a, b):
    a, b = flatten_proba(a), flatten_proba(b)
    if np.std(a) == 0 or np.std(b) == 0:
        return float("nan")
    return float(np.corrcoef(a, b)[0, 1])

def corr_spearman(a, b):
    a, b = flatten_proba(a), flatten_proba(b)
    if np.std(a) == 0 or np.std(b) == 0:
        return float("nan")
    return float(spearmanr(a, b).correlation)

def class_recalls(y_true, y_pred, class_names):
    out = {}
    for i, cls in enumerate(class_names):
        m = y_true == i
        out[f"recall_{cls}"] = float((y_pred[m] == i).mean()) if m.any() else float("nan")
    return out

def evaluate_proba(y_true, p, class_names):
    pred = proba_to_pred(p)
    res = {"balanced_accuracy": float(balanced_accuracy_score(y_true, pred))}
    res.update(class_recalls(y_true, pred, class_names))
    return res

def rank_normalize_matrix(p):
    out = np.zeros_like(p, dtype=np.float64)
    n = p.shape[0]
    for j in range(p.shape[1]):
        r = pd.Series(p[:, j]).rank(method="average").to_numpy()
        out[:, j] = (r - 1) / max(n - 1, 1)
    return normalize_rows(out)

def logit_transform(p, eps=1e-15):
    p = np.clip(p, eps, 1.0 - eps)
    return np.log(p / (1.0 - p))

def build_meta_features(keys, proba_dict, mode):
    mats = []
    for k in keys:
        p = proba_dict[k]
        if mode == "raw":
            mats.append(p)
        elif mode == "rank":
            mats.append(rank_normalize_matrix(p))
        elif mode == "logit":
            mats.append(logit_transform(p))
        elif mode == "raw_logit":
            mats += [p, logit_transform(p)]
        elif mode == "raw_rank_logit":
            mats += [p, rank_normalize_matrix(p), logit_transform(p)]
        else:
            raise ValueError(mode)
    return np.concatenate(mats, axis=1)

def average_proba(keys, oof_dict, pred_dict=None):
    oof_avg = normalize_rows(np.mean([oof_dict[k] for k in keys], axis=0))
    pred_avg = None
    if pred_dict is not None:
        pred_avg = normalize_rows(np.mean([pred_dict[k] for k in keys], axis=0))
    return oof_avg, pred_avg

def onehot_y(y, n_classes):
    out = np.zeros((len(y), n_classes), dtype=np.float64)
    out[np.arange(len(y)), y] = 1.0
    return out

def hill_climb_weights(y_true, probas, steps=(0.1, 0.05, 0.02, 0.01, 0.005, 0.002), max_iter=300):
    n = len(probas)
    w = np.ones(n, dtype=float) / n
    cur_score = balanced_accuracy_score(y_true, normalize_rows(sum(w[i] * probas[i] for i in range(n))).argmax(axis=1))
    hist = [{"iter": 0, "score": float(cur_score), "weights": w.copy().tolist()}]
    for step in steps:
        improved = True
        it = 0
        while improved and it < max_iter:
            improved = False
            it += 1
            best_score, best_w = cur_score, w.copy()
            for i in range(n):
                for direction in [-1, 1]:
                    cand_w = w.copy()
                    cand_w[i] += direction * step
                    cand_w = np.clip(cand_w, 0.0, None)
                    if cand_w.sum() <= 0:
                        continue
                    cand_w /= cand_w.sum()
                    cand = normalize_rows(sum(cand_w[j] * probas[j] for j in range(n)))
                    score = balanced_accuracy_score(y_true, cand.argmax(axis=1))
                    if score > best_score + 1e-15:
                        best_score, best_w = score, cand_w.copy()
            if best_score > cur_score + 1e-15:
                cur_score, w = best_score, best_w
                improved = True
                hist.append({"iter": len(hist), "step": step, "score": float(cur_score), "weights": w.copy().tolist()})
    return w, float(cur_score), hist

def nm_softmax_weights(y_true, probas, n_restarts=5, maxiter=2500):
    probas = [np.asarray(p, dtype=np.float64) for p in probas]
    n = len(probas)

    def eval_from_theta(theta):
        w = np.exp(theta - np.max(theta))
        w = w / w.sum()
        p = normalize_rows(sum(w[i] * probas[i] for i in range(n)))
        return balanced_accuracy_score(y_true, p.argmax(axis=1)), w

    def objective(theta):
        score, _ = eval_from_theta(theta)
        return -score

    inits = [np.zeros(n)]
    rng = np.random.default_rng(SEED)
    for _ in range(n_restarts - 1):
        inits.append(rng.normal(0, 0.25, size=n))

    best_score, best_w, best_res = -1, None, None
    for init in inits:
        res = minimize(objective, init, method="Nelder-Mead", options={"maxiter": maxiter, "xatol": 1e-8, "fatol": 1e-12})
        score, w = eval_from_theta(res.x)
        if score > best_score:
            best_score, best_w, best_res = score, w, res
    return best_w, float(best_score), best_res

def disagreement_and_error_overlap(y_true, p1, p2):
    pred1 = p1.argmax(axis=1)
    pred2 = p2.argmax(axis=1)
    wrong1 = pred1 != y_true
    wrong2 = pred2 != y_true
    both_wrong = wrong1 & wrong2
    either_wrong = wrong1 | wrong2
    return {
        "disagreement_rate": float((pred1 != pred2).mean()),
        "wrong_rate_left": float(wrong1.mean()),
        "wrong_rate_right": float(wrong2.mean()),
        "both_wrong_rate": float(both_wrong.mean()),
        "error_overlap_jaccard": float(both_wrong.sum() / max(either_wrong.sum(), 1)),
        "left_wrong_right_correct_rate": float((wrong1 & ~wrong2).mean()),
        "right_wrong_left_correct_rate": float((wrong2 & ~wrong1).mean()),
    }

# %%
# ============================================================
# 2. Load data and OOF/pred
# ============================================================

for p in [TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH]:
    if not p.exists():
        raise FileNotFoundError(p)

train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_SUB_PATH)

le = LabelEncoder()
y = le.fit_transform(train[TARGET_COL].astype(str))
class_names = le.classes_.tolist()
n_classes = len(class_names)
assert class_names == ["GALAXY", "QSO", "STAR"], class_names

oof, pred, resolved_specs = {}, {}, []
for spec in MODEL_SPECS:
    key = spec["key"]
    oof_path = resolve_npy(spec["oof"])
    pred_path = resolve_npy(spec["pred"])
    oof_arr = np.load(oof_path)
    pred_arr = np.load(pred_path)
    validate_proba(f"oof:{key}", oof_arr, len(train), n_classes)
    validate_proba(f"pred:{key}", pred_arr, len(test), n_classes)
    oof[key] = oof_arr.astype(np.float64)
    pred[key] = pred_arr.astype(np.float64)
    s = spec.copy()
    s["resolved_oof_path"] = str(oof_path)
    s["resolved_pred_path"] = str(pred_path)
    resolved_specs.append(s)
    print(f"loaded {key}: {oof_arr.shape} / {pred_arr.shape}")

model_keys = [s["key"] for s in resolved_specs]
print("class_names:", class_names)
print("loaded keys:", model_keys)
# Out:
# loaded 015_realmlp_seed42: (577347, 3) / (247435, 3)
# loaded 017_realmlp_bias: (577347, 3) / (247435, 3)
# loaded 018_xgb_shared003: (577347, 3) / (247435, 3)
# loaded 019_blend_best: (577347, 3) / (247435, 3)
# loaded 020_blend_bias: (577347, 3) / (247435, 3)
# loaded 024_seed_ensemble_blend: (577347, 3) / (247435, 3)
# loaded 026_realmlp_v5: (577347, 3) / (247435, 3)
# loaded 027_blend_add026: (577347, 3) / (247435, 3)
# loaded 028_cat_v3: (577347, 3) / (247435, 3)
# loaded 029_blend_add028: (577347, 3) / (247435, 3)
# loaded 030_ovr_xgb: (577347, 3) / (247435, 3)
# loaded 031_blend_add030: (577347, 3) / (247435, 3)
# loaded 032_ovr_tabm: (577347, 3) / (247435, 3)
# loaded 033_blend_add032: (577347, 3) / (247435, 3)
# loaded 034_gpu_logreg_default: (577347, 3) / (247435, 3)
# loaded 035_shared001_updated: (577347, 3) / (247435, 3)
# loaded 036_gpu_logreg_add035: (577347, 3) / (247435, 3)
# loaded 036_blend_add035: (577347, 3) / (247435, 3)
# loaded 037_tabicl_v2: (577347, 3) / (247435, 3)
# loaded 038_gpu_logreg_add037: (577347, 3) / (247435, 3)
# loaded 039_cat_v3_seed2026_qbin_variant: (577347, 3) / (247435, 3)
# loaded 040_gpu_logreg_add039: (577347, 3) / (247435, 3)
# loaded 042_realmlp_v5_seed2026_foldvariant: (577347, 3) / (247435, 3)
# loaded 044_shared001_updated_seed2027_foldvariant: (577347, 3) / (247435, 3)
# loaded 045_gpu_logreg_add044: (577347, 3) / (247435, 3)
# class_names: ['GALAXY', 'QSO', 'STAR']
# loaded keys: ['015_realmlp_seed42', '017_realmlp_bias', '018_xgb_shared003', '019_blend_best', '020_blend_bias', '024_seed_ensemble_blend', '026_realmlp_v5', '027_blend_add026', '028_cat_v3', '029_blend_add028', '030_ovr_xgb', '031_blend_add030', '032_ovr_tabm', '033_blend_add032', '034_gpu_logreg_default', '035_shared001_updated', '036_gpu_logreg_add035', '036_blend_add035', '037_tabicl_v2', '038_gpu_logreg_add037', '039_cat_v3_seed2026_qbin_variant', '040_gpu_logreg_add039', '042_realmlp_v5_seed2026_foldvariant', '044_shared001_updated_seed2027_foldvariant', '045_gpu_logreg_add044']

# %%
# ============================================================
# 3. Individual scores and pairwise diagnostics
# ============================================================

rows = []
for spec in resolved_specs:
    key = spec["key"]
    p = oof[key]
    y_pred = proba_to_pred(p)
    score = balanced_accuracy_score(y, y_pred)
    row = {
        "key": key,
        "exp_id": spec["exp_id"],
        "family": spec["family"],
        "role": spec["role"],
        "cv_from_memo": spec.get("cv", np.nan),
        "public_lb": spec.get("public_lb", np.nan),
        "public_lb_biased": spec.get("public_lb_biased", np.nan),
        "tuned_cv": spec.get("tuned_cv", np.nan),
        "recomputed_oof_cv": float(score),
        "delta_recomputed_minus_memo": float(score - spec.get("cv", score)),
    }
    row.update(class_recalls(y, y_pred, class_names))
    rows.append(row)

individual_df = pd.DataFrame(rows).sort_values("recomputed_oof_cv", ascending=False).reset_index(drop=True)
display(individual_df)
individual_df.to_csv(OUTDIR / "individual_scores.csv", index=False)

pair_rows = []
for a, b in combinations(model_keys, 2):
    diag = disagreement_and_error_overlap(y, oof[a], oof[b])
    pair_rows.append({
        "left": a,
        "right": b,
        "pearson_flat_proba": corr_pearson(oof[a], oof[b]),
        "spearman_flat_proba": corr_spearman(oof[a], oof[b]),
        **diag,
    })

pairwise_df = pd.DataFrame(pair_rows)
pairwise_df = pairwise_df.sort_values(["pearson_flat_proba", "error_overlap_jaccard"], ascending=[True, True]).reset_index(drop=True)
display(pairwise_df)
pairwise_df.to_csv(OUTDIR / "pairwise_oof_correlation.csv", index=False)

# Focus tables for newly added / current reference models.
def focus_pairwise(key, filename):
    df = pairwise_df[(pairwise_df["left"] == key) | (pairwise_df["right"] == key)].copy()
    df = df.sort_values("pearson_flat_proba").reset_index(drop=True)
    display(df)
    df.to_csv(OUTDIR / filename, index=False)
    return df

focus_pairwise_tables = {}
for short_name, key in FOCUS_MODEL_KEYS.items():
    if key in model_keys:
        focus_pairwise_tables[short_name] = focus_pairwise(key, f"pairwise_oof_correlation_focus_{short_name}.csv")

# Backward-compatible variables for easy notebook inspection.
focus_040_df = focus_pairwise_tables.get("040", pd.DataFrame())
focus_039_df = focus_pairwise_tables.get("039", pd.DataFrame())
focus_038_df = focus_pairwise_tables.get("038", pd.DataFrame())
focus_037_df = focus_pairwise_tables.get("037", pd.DataFrame())
focus_033_df = focus_pairwise_tables.get("033", pd.DataFrame())
# Out:
#                                            key  \
# 0                        045_gpu_logreg_add044
# 1                        040_gpu_logreg_add039
# 2                        038_gpu_logreg_add037
# 3                             036_blend_add035
# 4                        036_gpu_logreg_add035
# 5                             033_blend_add032
# 6                       034_gpu_logreg_default
# 7                             031_blend_add030
# 8                             029_blend_add028
# 9                             027_blend_add026
# 10                     024_seed_ensemble_blend
# 11                              020_blend_bias
# 12                              026_realmlp_v5
# 13         042_realmlp_v5_seed2026_foldvariant
# 14                              019_blend_best
# 15                                  028_cat_v3
# 16                       035_shared001_updated
# 17            039_cat_v3_seed2026_qbin_variant
# 18  044_shared001_updated_seed2027_foldvariant
# 19                            017_realmlp_bias
# 20                          015_realmlp_seed42
# 21                           018_xgb_shared003
# 22                                032_ovr_tabm
# 23                                 030_ovr_xgb
# 24                               037_tabicl_v2
#
#                                                exp_id  \
# 0      exp_20260612_045_gpu_logreg_stacker_add044_own
# 1      exp_20260611_040_gpu_logreg_stacker_add039_own
# 2      exp_20260610_038_gpu_logreg_stacker_add037_own
# 3       exp_20260610_036_blend_add035_shared001_check
# 4      exp_20260610_036_gpu_logreg_stacker_add035_own
# 5            exp_20260609_033_blend_add032_tabm_check
# 6             exp_20260609_034_gpu_logreg_stacker_own
# 7         exp_20260608_031_blend_add030_ovr_xgb_check
# 8          exp_20260608_029_blend_add028_cat_v3_check
# 9      exp_20260608_027_blend_add026_realmlp_v5_check
# 10     exp_20260608_024_seed_ensemble_and_blend_check
# 11     exp_20260607_020_bias_search_on_019_best_blend
# 12                  exp_20260608_026_realmlp_v5_as_is
# 13   exp_20260611_042_realmlp_v5_seed2026_foldvariant
# 14            exp_20260607_019_blend_add018_xgb_check
# 15                      exp_20260608_028_cat_v3_as_is
# 16  exp_20260610_035_shared001_updated_realmlp_pyt...
# 17      exp_20260611_039_cat_v3_seed2026_qbin_variant
# 18  exp_20260612_044_shared001_updated_seed2027_fo...
# 19        exp_20260606_017_bias_search_on_015_realmlp
# 20           exp_20260605_015_shared001_realmlp_as_is
# 21               exp_20260606_018_shared003_xgb_as_is
# 22                    exp_20260609_032_ovr_tabm_as_is
# 23                     exp_20260608_030_ovr_xgb_as_is
# 24                   exp_20260610_037_tabicl_v2_as_is
#
#                             family  \
# 0   GPU_LogisticRegression_Stacker
# 1   GPU_LogisticRegression_Stacker
# 2   GPU_LogisticRegression_Stacker
# 3                            Blend
# 4   GPU_LogisticRegression_Stacker
# 5                            Blend
# 6   GPU_LogisticRegression_Stacker
# 7                            Blend
# 8                            Blend
# 9                            Blend
# 10                           Blend
# 11                           Blend
# 12                         RealMLP
# 13                         RealMLP
# 14                           Blend
# 15                        CatBoost
# 16                         RealMLP
# 17                        CatBoost
# 18                         RealMLP
# 19                         RealMLP
# 20                         RealMLP
# 21                         XGBoost
# 22                            TabM
# 23                         XGBoost
# 24                          TabICL
#
#                                               role  cv_from_memo  public_lb  \
# 0           cv_best_but_public_weak_stacker_add044      0.970245   0.970400
# 1                        current_best_after_add039      0.970202   0.970690
# 2                 previous_stacker_best_before_040      0.970135   0.970600
# 3             cv_best_but_public_weak_add035_blend      0.970073   0.970230
# 4                   improved_stacker_backup_add035      0.970067   0.970370
# 5            previous_public_confirmed_best_backup      0.970040   0.970430
# 6                           stacker_backup_default      0.970037   0.970220
# 7         public_confirmed_current_best_before_033      0.970033   0.970430
# 8                             previous_best_backup      0.970002   0.970036
# 9                         previous_cv_trusted_slot      0.969543   0.969750
# 10                   seed_ensemble_blend_reference      0.969480   0.969580
# 11                     cv_trusted_attack_reference      0.969224   0.969690
# 12               realmlp_v5_single_model_candidate      0.969039   0.969790
# 13           realmlp_v5_seed_fold_variant_material      0.968948   0.969430
# 14                  previous_public_confirmed_best      0.968872   0.970000
# 15                 catboost_v3_family_aux_material      0.968815   0.969690
# 16          updated_shared001_realmlp_aux_material      0.968741   0.970120
# 17  catboost_v3_lower_correlation_variant_material      0.968705   0.969840
# 18    shared001_updated_seed_fold_variant_material      0.968604   0.970000
# 19               previous_best_realmlp_bias_backup      0.968302   0.969850
# 20                    stable_single_realmlp_backup      0.968169   0.969770
# 21                        effective_blend_material      0.965208   0.965780
# 22                    tabm_ovr_family_aux_material      0.961011   0.961060
# 23           low_weight_auxiliary_xgb_ovr_material      0.960997   0.961180
# 24       weak_tabicl_family_material_optional_corr      0.958077   0.959200
#
#     public_lb_biased  tuned_cv  recomputed_oof_cv  \
# 0                NaN  0.970245           0.970245
# 1                NaN       NaN           0.970202
# 2                NaN       NaN           0.970135
# 3                NaN       NaN           0.970073
# 4                NaN       NaN           0.970067
# 5                NaN       NaN           0.970040
# 6                NaN       NaN           0.970037
# 7                NaN       NaN           0.970033
# 8                NaN       NaN           0.970002
# 9                NaN       NaN           0.969543
# 10               NaN       NaN           0.969480
# 11               NaN       NaN           0.969224
# 12               NaN       NaN           0.969039
# 13               NaN       NaN           0.968948
# 14               NaN       NaN           0.968872
# 15               NaN       NaN           0.968815
# 16               NaN       NaN           0.968741
# 17               NaN       NaN           0.968705
# 18               NaN       NaN           0.968604
# 19               NaN       NaN           0.968302
# 20               NaN       NaN           0.968169
# 21               NaN       NaN           0.965208
# 22           0.96895  0.968617           0.961011
# 23               NaN       NaN           0.960997
# 24               NaN       NaN           0.958077
#
#     delta_recomputed_minus_memo  recall_GALAXY  recall_QSO  recall_STAR
# 0                           0.0       0.960096    0.977148     0.973490
# 1                           0.0       0.959500    0.976866     0.974240
# 2                           0.0       0.958120    0.977950     0.974336
# 3                           0.0       0.960777    0.976943     0.972499
# 4                           0.0       0.958313    0.978701     0.973188
# 5                           0.0       0.961775    0.975773     0.972571
# 6                           0.0       0.959794    0.977771     0.972547
# 7                           0.0       0.961738    0.975790     0.972571
# 8                           0.0       0.961315    0.975867     0.972825
# 9                           0.0       0.961479    0.976439     0.970710
# 10                          0.0       0.961956    0.976174     0.970311
# 11                          0.0       0.961137    0.976200     0.970335
# 12                          0.0       0.959505    0.976431     0.971181
# 13                          0.0       0.958469    0.976541     0.971834
# 14                          0.0       0.965479    0.974441     0.966696
# 15                          0.0       0.960099    0.974826     0.971520
# 16                          0.0       0.960591    0.976046     0.969586
# 17                          0.0       0.959571    0.974928     0.971616
# 18                          0.0       0.959079    0.975756     0.970976
# 19                          0.0       0.959889    0.975867     0.969150
# 20                          0.0       0.962234    0.976098     0.966177
# 21                          0.0       0.966870    0.972043     0.956711
# 22                          0.0       0.979880    0.965939     0.937213
# 23                          0.0       0.980163    0.965410     0.937418
# 24                          0.0       0.941422    0.970839     0.961970
#                        left                  right  pearson_flat_proba  \
# 0               030_ovr_xgb          037_tabicl_v2            0.974477
# 1              032_ovr_tabm          037_tabicl_v2            0.974850
# 2        015_realmlp_seed42          037_tabicl_v2            0.979561
# 3          017_realmlp_bias          037_tabicl_v2            0.980194
# 4     035_shared001_updated          037_tabicl_v2            0.981919
# ..                      ...                    ...                 ...
# 295  034_gpu_logreg_default  036_gpu_logreg_add035            0.999938
# 296   040_gpu_logreg_add039  045_gpu_logreg_add044            0.999966
# 297        029_blend_add028       033_blend_add032            0.999993
# 298        029_blend_add028       031_blend_add030            0.999993
# 299        031_blend_add030       033_blend_add032            1.000000
#
#      spearman_flat_proba  disagreement_rate  wrong_rate_left  \
# 0               0.953569           0.037044         0.028955
# 1               0.953750           0.037186         0.029062
# 2               0.910951           0.031806         0.034388
# 3               0.901659           0.031480         0.035542
# 4               0.878275           0.029999         0.034984
# ..                   ...                ...              ...
# 295             0.998882           0.001436         0.034731
# 296             0.999174           0.001102         0.034865
# 297             0.999794           0.000438         0.034083
# 298             0.999801           0.000421         0.034083
# 299             0.999999           0.000031         0.033858
#
#      wrong_rate_right  both_wrong_rate  error_overlap_jaccard  \
# 0            0.049665         0.020975               0.363871
# 1            0.049665         0.020963               0.362909
# 2            0.049665         0.026350               0.456641
# 3            0.049665         0.027077               0.465809
# 4            0.049665         0.027516               0.481598
# ..                ...              ...                    ...
# 295          0.035419         0.034366               0.960358
# 296          0.034525         0.034158               0.969520
# 297          0.033838         0.033749               0.987632
# 298          0.033858         0.033768               0.988140
# 299          0.033838         0.033832               0.999079
#
#      left_wrong_right_correct_rate  right_wrong_left_correct_rate
# 0                         0.007980                       0.028690
# 1                         0.008099                       0.028702
# 2                         0.008038                       0.023315
# 3                         0.008465                       0.022588
# 4                         0.007469                       0.022150
# ..                             ...                            ...
# 295                       0.000365                       0.001053
# 296                       0.000707                       0.000367
# 297                       0.000334                       0.000088
# 298                       0.000315                       0.000090
# 299                       0.000026                       0.000005
#
# [300 rows x 11 columns]
#                                           left                  right  \
# 0                                037_tabicl_v2  045_gpu_logreg_add044
# 1                                  030_ovr_xgb  045_gpu_logreg_add044
# 2                                 032_ovr_tabm  045_gpu_logreg_add044
# 3                            018_xgb_shared003  045_gpu_logreg_add044
# 4                           015_realmlp_seed42  045_gpu_logreg_add044
# 5                             017_realmlp_bias  045_gpu_logreg_add044
# 6          042_realmlp_v5_seed2026_foldvariant  045_gpu_logreg_add044
# 7   044_shared001_updated_seed2027_foldvariant  045_gpu_logreg_add044
# 8                               026_realmlp_v5  045_gpu_logreg_add044
# 9                        035_shared001_updated  045_gpu_logreg_add044
# 10            039_cat_v3_seed2026_qbin_variant  045_gpu_logreg_add044
# 11                                  028_cat_v3  045_gpu_logreg_add044
# 12                              019_blend_best  045_gpu_logreg_add044
# 13                              020_blend_bias  045_gpu_logreg_add044
# 14                     024_seed_ensemble_blend  045_gpu_logreg_add044
# 15                            027_blend_add026  045_gpu_logreg_add044
# 16                            031_blend_add030  045_gpu_logreg_add044
# 17                            033_blend_add032  045_gpu_logreg_add044
# 18                            029_blend_add028  045_gpu_logreg_add044
# 19                            036_blend_add035  045_gpu_logreg_add044
# 20                       036_gpu_logreg_add035  045_gpu_logreg_add044
# 21                      034_gpu_logreg_default  045_gpu_logreg_add044
# 22                       038_gpu_logreg_add037  045_gpu_logreg_add044
# 23                       040_gpu_logreg_add039  045_gpu_logreg_add044
#
#     pearson_flat_proba  spearman_flat_proba  disagreement_rate  \
# 0             0.984186             0.955351           0.027613
# 1             0.990156             0.942695           0.021306
# 2             0.990390             0.951425           0.021247
# 3             0.994284             0.965120           0.014118
# 4             0.996933             0.926308           0.010306
# 5             0.997038             0.923205           0.010356
# 6             0.997539             0.857610           0.008610
# 7             0.997719             0.892361           0.008721
# 8             0.997793             0.860130           0.008349
# 9             0.997819             0.901692           0.008534
# 10            0.998123             0.969399           0.008170
# 11            0.998216             0.970972           0.008068
# 12            0.998256             0.939575           0.007876
# 13            0.998630             0.945740           0.006992
# 14            0.998733             0.953208           0.006720
# 15            0.998862             0.918929           0.006377
# 16            0.999479             0.914232           0.003925
# 17            0.999479             0.914281           0.003928
# 18            0.999503             0.915659           0.003804
# 19            0.999789             0.959305           0.002583
# 20            0.999791             0.997941           0.002873
# 21            0.999859             0.998380           0.002298
# 22            0.999870             0.998229           0.002234
# 23            0.999966             0.999174           0.001102
#
#     wrong_rate_left  wrong_rate_right  both_wrong_rate  error_overlap_jaccard  \
# 0          0.049665          0.034525         0.028435               0.510003
# 1          0.028955          0.034525         0.021187               0.500942
# 2          0.029062          0.034525         0.021271               0.502681
# 3          0.033536          0.034525         0.027039               0.659137
# 4          0.034388          0.034525         0.029423               0.745044
# 5          0.035542          0.034525         0.029968               0.747354
# 6          0.035949          0.034525         0.031032               0.786756
# 7          0.035833          0.034525         0.030914               0.783735
# 8          0.035388          0.034525         0.030884               0.791328
# 9          0.034984          0.034525         0.030585               0.785743
# 10         0.035587          0.034525         0.031054               0.795078
# 11         0.035277          0.034525         0.030952               0.796701
# 12         0.032528          0.034525         0.029662               0.793265
# 13         0.034489          0.034525         0.031077               0.819157
# 14         0.033962          0.034525         0.030955               0.824773
# 15         0.034163          0.034525         0.031231               0.833765
# 16         0.033858          0.034525         0.032286               0.894391
# 17         0.033838          0.034525         0.032273               0.894270
# 18         0.034083          0.034525         0.032457               0.897806
# 19         0.034264          0.034525         0.033134               0.929317
# 20         0.035419          0.034525         0.033557               0.922220
# 21         0.034731          0.034525         0.033498               0.936789
# 22         0.035533          0.034525         0.033926               0.938929
# 23         0.034865          0.034525         0.034158               0.969520
#
#     left_wrong_right_correct_rate  right_wrong_left_correct_rate
# 0                        0.021230                       0.006090
# 1                        0.007768                       0.013339
# 2                        0.007791                       0.013254
# 3                        0.006497                       0.007486
# 4                        0.004966                       0.005103
# 5                        0.005574                       0.004557
# 6                        0.004917                       0.003494
# 7                        0.004919                       0.003611
# 8                        0.004503                       0.003641
# 9                        0.004399                       0.003940
# 10                       0.004533                       0.003471
# 11                       0.004325                       0.003573
# 12                       0.002867                       0.004864
# 13                       0.003412                       0.003449
# 14                       0.003007                       0.003570
# 15                       0.002932                       0.003294
# 16                       0.001573                       0.002240
# 17                       0.001564                       0.002252
# 18                       0.001626                       0.002068
# 19                       0.001129                       0.001391
# 20                       0.001862                       0.000968
# 21                       0.001233                       0.001027
# 22                       0.001607                       0.000599
# 23                       0.000707                       0.000367
#                                           left  \
# 0                                037_tabicl_v2
# 1                                  030_ovr_xgb
# 2                                 032_ovr_tabm
# 3                            018_xgb_shared003
# 4             039_cat_v3_seed2026_qbin_variant
# 5                                   028_cat_v3
# 6                           015_realmlp_seed42
# 7                             017_realmlp_bias
# 8                               019_blend_best
# 9                               020_blend_bias
# 10                              026_realmlp_v5
# 11         042_realmlp_v5_seed2026_foldvariant
# 12                       038_gpu_logreg_add037
# 13                       036_gpu_logreg_add035
# 14  044_shared001_updated_seed2027_foldvariant
# 15                       040_gpu_logreg_add039
# 16                      034_gpu_logreg_default
# 17                            031_blend_add030
# 18                            033_blend_add032
# 19                            029_blend_add028
# 20                     024_seed_ensemble_blend
# 21                            036_blend_add035
# 22                       035_shared001_updated
# 23                            027_blend_add026
#
#                                          right  pearson_flat_proba  \
# 0   044_shared001_updated_seed2027_foldvariant            0.983156
# 1   044_shared001_updated_seed2027_foldvariant            0.988672
# 2   044_shared001_updated_seed2027_foldvariant            0.989198
# 3   044_shared001_updated_seed2027_foldvariant            0.991347
# 4   044_shared001_updated_seed2027_foldvariant            0.995318
# 5   044_shared001_updated_seed2027_foldvariant            0.995321
# 6   044_shared001_updated_seed2027_foldvariant            0.996538
# 7   044_shared001_updated_seed2027_foldvariant            0.996663
# 8   044_shared001_updated_seed2027_foldvariant            0.996878
# 9   044_shared001_updated_seed2027_foldvariant            0.997250
# 10  044_shared001_updated_seed2027_foldvariant            0.997433
# 11  044_shared001_updated_seed2027_foldvariant            0.997586
# 12  044_shared001_updated_seed2027_foldvariant            0.997696
# 13  044_shared001_updated_seed2027_foldvariant            0.997710
# 14                       045_gpu_logreg_add044            0.997719
# 15  044_shared001_updated_seed2027_foldvariant            0.997731
# 16  044_shared001_updated_seed2027_foldvariant            0.997763
# 17  044_shared001_updated_seed2027_foldvariant            0.997853
# 18  044_shared001_updated_seed2027_foldvariant            0.997856
# 19  044_shared001_updated_seed2027_foldvariant            0.997897
# 20  044_shared001_updated_seed2027_foldvariant            0.997940
# 21  044_shared001_updated_seed2027_foldvariant            0.998039
# 22  044_shared001_updated_seed2027_foldvariant            0.998062
# 23  044_shared001_updated_seed2027_foldvariant            0.998152
#
#     spearman_flat_proba  disagreement_rate  wrong_rate_left  wrong_rate_right  \
# 0              0.882472           0.029218         0.049665          0.035833
# 1              0.878785           0.022475         0.028955          0.035833
# 2              0.883758           0.022169         0.029062          0.035833
# 3              0.884525           0.017563         0.033536          0.035833
# 4              0.892239           0.012985         0.035587          0.035833
# 5              0.892453           0.013127         0.035277          0.035833
# 6              0.876838           0.010829         0.034388          0.035833
# 7              0.875192           0.010869         0.035542          0.035833
# 8              0.884204           0.010387         0.032528          0.035833
# 9              0.884472           0.009850         0.034489          0.035833
# 10             0.816686           0.008925         0.035388          0.035833
# 11             0.816522           0.008565         0.035949          0.035833
# 12             0.892139           0.008839         0.035533          0.035833
# 13             0.892276           0.008820         0.035419          0.035833
# 14             0.892361           0.008721         0.035833          0.034525
# 15             0.893517           0.008676         0.034865          0.035833
# 16             0.893069           0.008634         0.034731          0.035833
# 17             0.858744           0.008487         0.033858          0.035833
# 18             0.858801           0.008497         0.033838          0.035833
# 19             0.859606           0.008387         0.034083          0.035833
# 20             0.891240           0.008589         0.033962          0.035833
# 21             0.879508           0.008146         0.034264          0.035833
# 22             0.870384           0.008078         0.034984          0.035833
# 23             0.864096           0.008073         0.034163          0.035833
#
#     both_wrong_rate  error_overlap_jaccard  left_wrong_right_correct_rate  \
# 0          0.028319               0.495274                       0.021346
# 1          0.021294               0.489586                       0.007661
# 2          0.021491               0.495151                       0.007571
# 3          0.026031               0.600655                       0.007505
# 4          0.029345               0.697431                       0.006242
# 5          0.029130               0.693898                       0.006147
# 6          0.029802               0.737316                       0.004586
# 7          0.030353               0.739909                       0.005189
# 8          0.029074               0.740058                       0.003454
# 9          0.030327               0.758261                       0.004162
# 10         0.031236               0.781200                       0.004152
# 11         0.031693               0.790581                       0.004256
# 12         0.031369               0.784298                       0.004164
# 13         0.031317               0.784221                       0.004102
# 14         0.030914               0.783735                       0.004919
# 15         0.031110               0.785833                       0.003755
# 16         0.031066               0.786529                       0.003665
# 17         0.030692               0.786996                       0.003166
# 18         0.030677               0.786701                       0.003161
# 19         0.030850               0.789670                       0.003234
# 20         0.030678               0.784272                       0.003284
# 21         0.031065               0.795873                       0.003199
# 22         0.031446               0.798689                       0.003539
# 23         0.031035               0.796568                       0.003128
#
#     right_wrong_left_correct_rate
# 0                        0.007514
# 1                        0.014539
# 2                        0.014341
# 3                        0.009802
# 4                        0.006488
# 5                        0.006703
# 6                        0.006031
# 7                        0.005480
# 8                        0.006759
# 9                        0.005506
# 10                       0.004597
# 11                       0.004140
# 12                       0.004464
# 13                       0.004515
# 14                       0.003611
# 15                       0.004723
# 16                       0.004767
# 17                       0.005141
# 18                       0.005156
# 19                       0.004983
# 20                       0.005155
# 21                       0.004768
# 22                       0.004387
# 23                       0.004798
#                                    left  \
# 0                         037_tabicl_v2
# 1                           030_ovr_xgb
# 2                          032_ovr_tabm
# 3                     018_xgb_shared003
# 4                            028_cat_v3
# 5      039_cat_v3_seed2026_qbin_variant
# 6                    015_realmlp_seed42
# 7                      017_realmlp_bias
# 8                        019_blend_best
# 9                        020_blend_bias
# 10                035_shared001_updated
# 11                036_gpu_logreg_add035
# 12               034_gpu_logreg_default
# 13  042_realmlp_v5_seed2026_foldvariant
# 14                038_gpu_logreg_add037
# 15                040_gpu_logreg_add039
# 16  042_realmlp_v5_seed2026_foldvariant
# 17              024_seed_ensemble_blend
# 18                     031_blend_add030
# 19                     033_blend_add032
# 20                     029_blend_add028
# 21                     036_blend_add035
# 22                       026_realmlp_v5
# 23                     027_blend_add026
#
#                                          right  pearson_flat_proba  \
# 0          042_realmlp_v5_seed2026_foldvariant            0.982745
# 1          042_realmlp_v5_seed2026_foldvariant            0.987105
# 2          042_realmlp_v5_seed2026_foldvariant            0.987614
# 3          042_realmlp_v5_seed2026_foldvariant            0.990835
# 4          042_realmlp_v5_seed2026_foldvariant            0.994809
# 5          042_realmlp_v5_seed2026_foldvariant            0.995016
# 6          042_realmlp_v5_seed2026_foldvariant            0.996174
# 7          042_realmlp_v5_seed2026_foldvariant            0.996396
# 8          042_realmlp_v5_seed2026_foldvariant            0.996426
# 9          042_realmlp_v5_seed2026_foldvariant            0.996972
# 10         042_realmlp_v5_seed2026_foldvariant            0.997450
# 11         042_realmlp_v5_seed2026_foldvariant            0.997532
# 12         042_realmlp_v5_seed2026_foldvariant            0.997536
# 13                       045_gpu_logreg_add044            0.997539
# 14         042_realmlp_v5_seed2026_foldvariant            0.997556
# 15         042_realmlp_v5_seed2026_foldvariant            0.997561
# 16  044_shared001_updated_seed2027_foldvariant            0.997586
# 17         042_realmlp_v5_seed2026_foldvariant            0.997713
# 18         042_realmlp_v5_seed2026_foldvariant            0.997786
# 19         042_realmlp_v5_seed2026_foldvariant            0.997788
# 20         042_realmlp_v5_seed2026_foldvariant            0.997844
# 21         042_realmlp_v5_seed2026_foldvariant            0.997856
# 22         042_realmlp_v5_seed2026_foldvariant            0.998107
# 23         042_realmlp_v5_seed2026_foldvariant            0.998153
#
#     spearman_flat_proba  disagreement_rate  wrong_rate_left  wrong_rate_right  \
# 0              0.808008           0.029559         0.049665          0.035949
# 1              0.749468           0.023140         0.028955          0.035949
# 2              0.759791           0.022775         0.029062          0.035949
# 3              0.795267           0.017691         0.033536          0.035949
# 4              0.806349           0.013633         0.035277          0.035949
# 5              0.804879           0.013191         0.035587          0.035949
# 6              0.813865           0.011006         0.034388          0.035949
# 7              0.832858           0.010867         0.035542          0.035949
# 8              0.819799           0.010605         0.032528          0.035949
# 9              0.845963           0.009750         0.034489          0.035949
# 10             0.816058           0.008688         0.034984          0.035949
# 11             0.864218           0.008771         0.035419          0.035949
# 12             0.861834           0.008634         0.034731          0.035949
# 13             0.857610           0.008610         0.035949          0.034525
# 14             0.865760           0.008653         0.035533          0.035949
# 15             0.859032           0.008543         0.034865          0.035949
# 16             0.816522           0.008565         0.035949          0.035833
# 17             0.837943           0.008258         0.033962          0.035949
# 18             0.944782           0.008584         0.033858          0.035949
# 19             0.944717           0.008588         0.033838          0.035949
# 20             0.944824           0.008454         0.034083          0.035949
# 21             0.923022           0.008200         0.034264          0.035949
# 22             0.959599           0.007857         0.035388          0.035949
# 23             0.938075           0.007548         0.034163          0.035949
#
#     both_wrong_rate  error_overlap_jaccard  left_wrong_right_correct_rate  \
# 0          0.028224               0.491791                       0.021441
# 1          0.021019               0.478944                       0.007936
# 2          0.021237               0.485142                       0.007825
# 3          0.026028               0.598924                       0.007508
# 4          0.028948               0.684706                       0.006329
# 5          0.029310               0.694122                       0.006277
# 6          0.029778               0.734167                       0.004611
# 7          0.030420               0.740680                       0.005122
# 8          0.029017               0.735361                       0.003511
# 9          0.030427               0.760476                       0.004062
# 10         0.031217               0.786001                       0.003767
# 11         0.031397               0.785501                       0.004022
# 12         0.031118               0.786568                       0.003613
# 13         0.031032               0.786756                       0.004917
# 14         0.031518               0.788671                       0.004015
# 15         0.031236               0.789234                       0.003629
# 16         0.031693               0.790581                       0.004256
# 17         0.030893               0.791761                       0.003069
# 18         0.030704               0.785214                       0.003154
# 19         0.030692               0.785078                       0.003145
# 20         0.030877               0.788596                       0.003206
# 21         0.031092               0.794784                       0.003171
# 22         0.031816               0.805058                       0.003572
# 23         0.031349               0.808713                       0.002815
#
#     right_wrong_left_correct_rate
# 0                        0.007725
# 1                        0.014930
# 2                        0.014712
# 3                        0.009921
# 4                        0.007001
# 5                        0.006639
# 6                        0.006171
# 7                        0.005529
# 8                        0.006932
# 9                        0.005522
# 10                       0.004732
# 11                       0.004552
# 12                       0.004831
# 13                       0.003494
# 14                       0.004431
# 15                       0.004713
# 16                       0.004140
# 17                       0.005056
# 18                       0.005245
# 19                       0.005257
# 20                       0.005071
# 21                       0.004857
# 22                       0.004133
# 23                       0.004600
#                                 left  \
# 0                      037_tabicl_v2
# 1                        030_ovr_xgb
# 2                       032_ovr_tabm
# 3                  018_xgb_shared003
# 4                 015_realmlp_seed42
# 5                   017_realmlp_bias
# 6              040_gpu_logreg_add039
# 7              040_gpu_logreg_add039
# 8                     026_realmlp_v5
# 9              035_shared001_updated
# 10  039_cat_v3_seed2026_qbin_variant
# 11                    019_blend_best
# 12                        028_cat_v3
# 13                    020_blend_bias
# 14           024_seed_ensemble_blend
# 15                  027_blend_add026
# 16                  033_blend_add032
# 17                  031_blend_add030
# 18                  029_blend_add028
# 19                  036_blend_add035
# 20             036_gpu_logreg_add035
# 21            034_gpu_logreg_default
# 22             038_gpu_logreg_add037
# 23             040_gpu_logreg_add039
#
#                                          right  pearson_flat_proba  \
# 0                        040_gpu_logreg_add039            0.984338
# 1                        040_gpu_logreg_add039            0.989809
# 2                        040_gpu_logreg_add039            0.990036
# 3                        040_gpu_logreg_add039            0.994166
# 4                        040_gpu_logreg_add039            0.996843
# 5                        040_gpu_logreg_add039            0.996997
# 6          042_realmlp_v5_seed2026_foldvariant            0.997561
# 7   044_shared001_updated_seed2027_foldvariant            0.997731
# 8                        040_gpu_logreg_add039            0.997798
# 9                        040_gpu_logreg_add039            0.997811
# 10                       040_gpu_logreg_add039            0.998130
# 11                       040_gpu_logreg_add039            0.998178
# 12                       040_gpu_logreg_add039            0.998209
# 13                       040_gpu_logreg_add039            0.998610
# 14                       040_gpu_logreg_add039            0.998693
# 15                       040_gpu_logreg_add039            0.998835
# 16                       040_gpu_logreg_add039            0.999463
# 17                       040_gpu_logreg_add039            0.999463
# 18                       040_gpu_logreg_add039            0.999494
# 19                       040_gpu_logreg_add039            0.999775
# 20                       040_gpu_logreg_add039            0.999789
# 21                       040_gpu_logreg_add039            0.999845
# 22                       040_gpu_logreg_add039            0.999884
# 23                       045_gpu_logreg_add044            0.999966
#
#     spearman_flat_proba  disagreement_rate  wrong_rate_left  wrong_rate_right  \
# 0              0.953540           0.027484         0.049665          0.034865
# 1              0.940546           0.021798         0.028955          0.034865
# 2              0.949985           0.021753         0.029062          0.034865
# 3              0.963306           0.014267         0.033536          0.034865
# 4              0.927797           0.010510         0.034388          0.034865
# 5              0.925200           0.010458         0.035542          0.034865
# 6              0.859032           0.008543         0.034865          0.035949
# 7              0.893517           0.008676         0.034865          0.035833
# 8              0.861649           0.008385         0.035388          0.034865
# 9              0.902374           0.008593         0.034984          0.034865
# 10             0.968624           0.008123         0.035587          0.034865
# 11             0.940981           0.008153         0.032528          0.034865
# 12             0.969897           0.008044         0.035277          0.034865
# 13             0.947194           0.007093         0.034489          0.034865
# 14             0.953361           0.006907         0.033962          0.034865
# 15             0.920134           0.006502         0.034163          0.034865
# 16             0.915413           0.004006         0.033838          0.034865
# 17             0.915366           0.003996         0.033858          0.034865
# 18             0.916822           0.003845         0.034083          0.034865
# 19             0.960206           0.002673         0.034264          0.034865
# 20             0.997822           0.002906         0.035419          0.034865
# 21             0.998313           0.002418         0.034731          0.034865
# 22             0.998178           0.002068         0.035533          0.034865
# 23             0.999174           0.001102         0.034865          0.034525
#
#     both_wrong_rate  error_overlap_jaccard  left_wrong_right_correct_rate  \
# 0          0.028666               0.513131                       0.021000
# 1          0.021114               0.494403                       0.007841
# 2          0.021195               0.496007                       0.007867
# 3          0.027134               0.657545                       0.006402
# 4          0.029495               0.741875                       0.004893
# 5          0.030093               0.746466                       0.005449
# 6          0.031236               0.789234                       0.003629
# 7          0.031110               0.785833                       0.003755
# 8          0.031044               0.791757                       0.004344
# 9          0.030728               0.785487                       0.004256
# 10         0.031245               0.796916                       0.004342
# 11         0.029693               0.787605                       0.002835
# 12         0.031127               0.797825                       0.004150
# 13         0.031194               0.817484                       0.003294
# 14         0.031035               0.821211                       0.002927
# 15         0.031343               0.831732                       0.002820
# 16         0.032402               0.892595                       0.001436
# 17         0.032417               0.892896                       0.001441
# 18         0.032604               0.897107                       0.001479
# 19         0.033257               0.927137                       0.001006
# 20         0.033713               0.921853                       0.001706
# 21         0.033607               0.933824                       0.001124
# 22         0.034180               0.943759                       0.001353
# 23         0.034158               0.969520                       0.000707
#
#     right_wrong_left_correct_rate
# 0                        0.006199
# 1                        0.013751
# 2                        0.013669
# 3                        0.007730
# 4                        0.005369
# 5                        0.004772
# 6                        0.004713
# 7                        0.004723
# 8                        0.003821
# 9                        0.004136
# 10                       0.003620
# 11                       0.005172
# 12                       0.003738
# 13                       0.003670
# 14                       0.003830
# 15                       0.003521
# 16                       0.002463
# 17                       0.002447
# 18                       0.002260
# 19                       0.001607
# 20                       0.001152
# 21                       0.001257
# 22                       0.000684
# 23                       0.000367
#                                 left  \
# 0                      037_tabicl_v2
# 1                        030_ovr_xgb
# 2                       032_ovr_tabm
# 3                  018_xgb_shared003
# 4                 015_realmlp_seed42
# 5                   017_realmlp_bias
# 6                     026_realmlp_v5
# 7              035_shared001_updated
# 8   039_cat_v3_seed2026_qbin_variant
# 9   039_cat_v3_seed2026_qbin_variant
# 10                    019_blend_best
# 11                    020_blend_bias
# 12           024_seed_ensemble_blend
# 13                  027_blend_add026
# 14             038_gpu_logreg_add037
# 15             036_gpu_logreg_add035
# 16            034_gpu_logreg_default
# 17                  036_blend_add035
# 18                  029_blend_add028
# 19                  033_blend_add032
# 20                  031_blend_add030
# 21  039_cat_v3_seed2026_qbin_variant
# 22  039_cat_v3_seed2026_qbin_variant
# 23                        028_cat_v3
#
#                                          right  pearson_flat_proba  \
# 0             039_cat_v3_seed2026_qbin_variant            0.984865
# 1             039_cat_v3_seed2026_qbin_variant            0.988783
# 2             039_cat_v3_seed2026_qbin_variant            0.988993
# 3             039_cat_v3_seed2026_qbin_variant            0.992109
# 4             039_cat_v3_seed2026_qbin_variant            0.993330
# 5             039_cat_v3_seed2026_qbin_variant            0.993395
# 6             039_cat_v3_seed2026_qbin_variant            0.994581
# 7             039_cat_v3_seed2026_qbin_variant            0.994848
# 8          042_realmlp_v5_seed2026_foldvariant            0.995016
# 9   044_shared001_updated_seed2027_foldvariant            0.995318
# 10            039_cat_v3_seed2026_qbin_variant            0.995390
# 11            039_cat_v3_seed2026_qbin_variant            0.995649
# 12            039_cat_v3_seed2026_qbin_variant            0.995756
# 13            039_cat_v3_seed2026_qbin_variant            0.995823
# 14            039_cat_v3_seed2026_qbin_variant            0.997587
# 15            039_cat_v3_seed2026_qbin_variant            0.997605
# 16            039_cat_v3_seed2026_qbin_variant            0.997713
# 17            039_cat_v3_seed2026_qbin_variant            0.997845
# 18            039_cat_v3_seed2026_qbin_variant            0.997901
# 19            039_cat_v3_seed2026_qbin_variant            0.997930
# 20            039_cat_v3_seed2026_qbin_variant            0.997933
# 21                       045_gpu_logreg_add044            0.998123
# 22                       040_gpu_logreg_add039            0.998130
# 23            039_cat_v3_seed2026_qbin_variant            0.998463
#
#     spearman_flat_proba  disagreement_rate  wrong_rate_left  wrong_rate_right  \
# 0              0.961404           0.027367         0.049665          0.035587
# 1              0.964342           0.022205         0.028955          0.035587
# 2              0.962610           0.022210         0.029062          0.035587
# 3              0.967151           0.016841         0.033536          0.035587
# 4              0.916658           0.015687         0.034388          0.035587
# 5              0.907284           0.015802         0.035542          0.035587
# 6              0.804236           0.014011         0.035388          0.035587
# 7              0.898905           0.013708         0.034984          0.035587
# 8              0.804879           0.013191         0.035587          0.035949
# 9              0.892239           0.012985         0.035587          0.035833
# 10             0.929347           0.013067         0.032528          0.035587
# 11             0.926949           0.012982         0.034489          0.035587
# 12             0.936612           0.012850         0.033962          0.035587
# 13             0.871286           0.012699         0.034163          0.035587
# 14             0.963981           0.009395         0.035533          0.035587
# 15             0.963800           0.009374         0.035419          0.035587
# 16             0.964405           0.009036         0.034731          0.035587
# 17             0.912962           0.008929         0.034264          0.035587
# 18             0.872301           0.008771         0.034083          0.035587
# 19             0.870715           0.008723         0.033838          0.035587
# 20             0.870672           0.008719         0.033858          0.035587
# 21             0.969399           0.008170         0.035587          0.034525
# 22             0.968624           0.008123         0.035587          0.034865
# 23             0.993034           0.007263         0.035277          0.035587
#
#     both_wrong_rate  error_overlap_jaccard  left_wrong_right_correct_rate  \
# 0          0.029088               0.517918                       0.020577
# 1          0.021308               0.492849                       0.007647
# 2          0.021362               0.493478                       0.007701
# 3          0.026253               0.612379                       0.007283
# 4          0.027315               0.640276                       0.007074
# ...
# 1                        0.007611                       0.012493
# 2                        0.007616                       0.012391
# 3                        0.007024                       0.007325
# 4                        0.005033                       0.004483
# 5                        0.005714                       0.004010
# 6                        0.003145                       0.005257
# 7                        0.003161                       0.005156
# 8                        0.003398                       0.005148
# 9                        0.003284                       0.004431
# 10                       0.003050                       0.004360
# 11                       0.003897                       0.003246
# 12                       0.004230                       0.002679
# 13                       0.004131                       0.002692
# 14                       0.003372                       0.003248
# 15                       0.003114                       0.002789
# 16                       0.001370                       0.002951
# 17                       0.001323                       0.003019
# 18                       0.001436                       0.002463
# 19                       0.001564                       0.002252
# 20                       0.001311                       0.002205
# 21                       0.000800                       0.001226
# 22                       0.000334                       0.000088
# 23                       0.000026                       0.000005
#                        left                                       right  \
# 0          031_blend_add030                               037_tabicl_v2
# 1               030_ovr_xgb                            031_blend_add030
# 2          031_blend_add030                                032_ovr_tabm
# 3         018_xgb_shared003                            031_blend_add030
# 4        015_realmlp_seed42                            031_blend_add030
# 5          017_realmlp_bias                            031_blend_add030
# 6          031_blend_add030         042_realmlp_v5_seed2026_foldvariant
# 7          031_blend_add030  044_shared001_updated_seed2027_foldvariant
# 8          031_blend_add030            039_cat_v3_seed2026_qbin_variant
# 9          031_blend_add030                       035_shared001_updated
# 10           019_blend_best                            031_blend_add030
# 11           020_blend_bias                            031_blend_add030
# 12           026_realmlp_v5                            031_blend_add030
# 13  024_seed_ensemble_blend                            031_blend_add030
# 14               028_cat_v3                            031_blend_add030
# 15         027_blend_add026                            031_blend_add030
# 16         031_blend_add030                       036_gpu_logreg_add035
# 17         031_blend_add030                       038_gpu_logreg_add037
# 18         031_blend_add030                       040_gpu_logreg_add039
# 19         031_blend_add030                       045_gpu_logreg_add044
# 20         031_blend_add030                      034_gpu_logreg_default
# 21         031_blend_add030                            036_blend_add035
# 22         029_blend_add028                            031_blend_add030
# 23         031_blend_add030                            033_blend_add032
#
#     pearson_flat_proba  spearman_flat_proba  disagreement_rate  \
# 0             0.984873             0.865479           0.027770
# 1             0.990536             0.821836           0.020385
# 2             0.990777             0.830573           0.020262
# 3             0.993874             0.858577           0.014553
# 4             0.997199             0.868061           0.009734
# 5             0.997253             0.881326           0.009913
# 6             0.997786             0.944782           0.008584
# 7             0.997853             0.858744           0.008487
# 8             0.997933             0.870672           0.008719
# 9             0.998123             0.841979           0.007883
# 10            0.998293             0.878896           0.007571
# 11            0.998538             0.899859           0.007276
# 12            0.998540             0.976821           0.007079
# 13            0.998741             0.900716           0.006753
# 14            0.998742             0.872885           0.006942
# 15            0.999055             0.992043           0.006038
# 16            0.999415             0.919475           0.004420
# 17            0.999422             0.920266           0.004441
# 18            0.999463             0.915366           0.003996
# 19            0.999479             0.914232           0.003925
# 20            0.999534             0.918851           0.003608
# 21            0.999862             0.983076           0.002077
# 22            0.999993             0.999801           0.000421
# 23            1.000000             0.999999           0.000031
#
#     wrong_rate_left  wrong_rate_right  both_wrong_rate  error_overlap_jaccard  \
# 0          0.033858          0.049665         0.028026               0.505009
# 1          0.028955          0.033858         0.021341               0.514576
# 2          0.033858          0.029062         0.021441               0.516912
# 3          0.033536          0.033858         0.026518               0.648729
# 4          0.034388          0.033858         0.029364               0.755178
# 5          0.035542          0.033858         0.029842               0.754368
# 6          0.033858          0.035949         0.030704               0.785214
# 7          0.033858          0.035833         0.030692               0.786996
# 8          0.033858          0.035587         0.030451               0.780927
# 9          0.033858          0.034984         0.030566               0.798543
# 10         0.032528          0.033858         0.029480               0.798761
# 11         0.034489          0.033858         0.030600               0.810673
# 12         0.035388          0.033858         0.031162               0.818219
# 13         0.033962          0.033858         0.030599               0.822057
# 14         0.035277          0.033858         0.031167               0.820857
# 15         0.034163          0.033858         0.031054               0.840041
# 16         0.033858          0.035419         0.032487               0.883009
# 17         0.033858          0.035533         0.032533               0.882660
# 18         0.033858          0.034865         0.032417               0.892896
# 19         0.033858          0.034525         0.032286               0.894391
# 20         0.033858          0.034731         0.032542               0.902748
# 21         0.033858          0.034264         0.033051               0.942414
# 22         0.034083          0.033858         0.033768               0.988140
# 23         0.033858          0.033838         0.033832               0.999079
#
#     left_wrong_right_correct_rate  right_wrong_left_correct_rate
# 0                        0.005832                       0.021639
# 1                        0.007614                       0.012518
# 2                        0.012417                       0.007621
# 3                        0.007018                       0.007340
# 4                        0.005025                       0.004495
# 5                        0.005700                       0.004017
# 6                        0.003154                       0.005245
# 7                        0.003166                       0.005141
# 8                        0.003407                       0.005136
# 9                        0.003293                       0.004418
# 10                       0.003048                       0.004379
# 11                       0.003888                       0.003258
# 12                       0.004226                       0.002697
# 13                       0.003364                       0.003260
# 14                       0.004110                       0.002692
# 15                       0.003109                       0.002804
# 16                       0.001372                       0.002932
# 17                       0.001325                       0.003000
# 18                       0.001441                       0.002447
# 19                       0.001573                       0.002240
# 20                       0.001316                       0.002189
# 21                       0.000807                       0.001212
# 22                       0.000315                       0.000090
# 23                       0.000026                       0.000005
#                        left                                       right  \
# 0                028_cat_v3                               037_tabicl_v2
# 1                028_cat_v3                                 030_ovr_xgb
# 2                028_cat_v3                                032_ovr_tabm
# 3         018_xgb_shared003                                  028_cat_v3
# 4        015_realmlp_seed42                                  028_cat_v3
# 5          017_realmlp_bias                                  028_cat_v3
# 6            026_realmlp_v5                                  028_cat_v3
# 7                028_cat_v3         042_realmlp_v5_seed2026_foldvariant
# 8                028_cat_v3                       035_shared001_updated
# 9                028_cat_v3  044_shared001_updated_seed2027_foldvariant
# 10           019_blend_best                                  028_cat_v3
# 11  024_seed_ensemble_blend                                  028_cat_v3
# 12           020_blend_bias                                  028_cat_v3
# 13         027_blend_add026                                  028_cat_v3
# 14               028_cat_v3                       036_gpu_logreg_add035
# 15               028_cat_v3                       038_gpu_logreg_add037
# 16               028_cat_v3                       040_gpu_logreg_add039
# 17               028_cat_v3                       045_gpu_logreg_add044
# 18               028_cat_v3                      034_gpu_logreg_default
# 19               028_cat_v3            039_cat_v3_seed2026_qbin_variant
# 20               028_cat_v3                            036_blend_add035
# 21               028_cat_v3                            029_blend_add028
# 22               028_cat_v3                            033_blend_add032
# 23               028_cat_v3                            031_blend_add030
#
#     pearson_flat_proba  spearman_flat_proba  disagreement_rate  \
# 0             0.984692             0.962312           0.027529
# 1             0.988941             0.965161           0.021862
# 2             0.989126             0.963762           0.021803
# 3             0.992356             0.969802           0.016441
# 4             0.993619             0.913554           0.015279
# 5             0.993673             0.904245           0.015462
# 6             0.994791             0.804927           0.013787
# 7             0.994809             0.806349           0.013633
# 8             0.995089             0.900310           0.013491
# 9             0.995321             0.892453           0.013127
# 10            0.995654             0.926925           0.012703
# 11            0.995894             0.936706           0.012668
# 12            0.995895             0.925055           0.012687
# 13            0.995986             0.871535           0.012578
# 14            0.998128             0.967264           0.008394
# 15            0.998150             0.967380           0.008354
# 16            0.998209             0.969897           0.008044
# 17            0.998216             0.970972           0.008068
# 18            0.998248             0.967845           0.007921
# 19            0.998463             0.993034           0.007263
# 20            0.998477             0.915623           0.007612
# 21            0.998697             0.874527           0.007069
# 22            0.998737             0.872920           0.006963
# 23            0.998742             0.872885           0.006942
#
#     wrong_rate_left  wrong_rate_right  both_wrong_rate  error_overlap_jaccard  \
# 0          0.035277          0.049665         0.028853               0.514406
# 1          0.035277          0.028955         0.021330               0.497194
# 2          0.035277          0.029062         0.021407               0.498608
# 3          0.033536          0.035277         0.026291               0.618289
# 4          0.034388          0.035277         0.027358               0.646647
# 5          0.035542          0.035277         0.027832               0.647474
# 6          0.035388          0.035277         0.028589               0.679483
# 7          0.035277          0.035949         0.028948               0.684706
# 8          0.035277          0.034984         0.028527               0.683544
# 9          0.035277          0.035833         0.029130               0.693898
# 10         0.032528          0.035277         0.027673               0.689555
# 11         0.033962          0.035277         0.028413               0.695940
# 12         0.034489          0.035277         0.028659               0.697173
# 13         0.034163          0.035277         0.028563               0.698771
# 14         0.035277          0.035419         0.031239               0.791747
# 15         0.035277          0.035533         0.031314               0.792834
# 16         0.035277          0.034865         0.031127               0.797825
# 17         0.035277          0.034525         0.030952               0.796701
# 18         0.035277          0.034731         0.031125               0.800481
# 19         0.035277          0.035587         0.031858               0.816741
# 20         0.035277          0.034264         0.031045               0.806479
# 21         0.035277          0.034083         0.031224               0.818739
# 22         0.035277          0.033838         0.031146               0.820309
# 23         0.035277          0.033858         0.031167               0.820857
#
#     left_wrong_right_correct_rate  right_wrong_left_correct_rate
# 0                        0.006424                       0.020812
# 1                        0.013947                       0.007625
# 2                        0.013870                       0.007656
# 3                        0.007245                       0.008986
# 4                        0.007030                       0.007919
# 5                        0.007709                       0.007444
# 6                        0.006798                       0.006687
# 7                        0.006329                       0.007001
# 8                        0.006750                       0.006457
# 9                        0.006147                       0.006703
# 10                       0.004855                       0.007604
# 11                       0.005550                       0.006864
# 12                       0.005830                       0.006618
# 13                       0.005600                       0.006713
# 14                       0.004037                       0.004179
# 15                       0.003963                       0.004219
# 16                       0.004150                       0.003738
# 17                       0.004325                       0.003573
# 18                       0.004152                       0.003606
# 19                       0.003419                       0.003729
# 20                       0.004231                       0.003218
# 21                       0.004053                       0.002860
# 22                       0.004131                       0.002692
# 23                       0.004110                       0.002692

# %%
# ============================================================
# 4. Blend diagnostics
# ============================================================

blend_rows = {}
blend_probas = {}

def _weight_of(keys, weights, target_key):
    if weights is None or target_key not in keys:
        return None
    return float(dict(zip(keys, weights)).get(target_key, 0.0))

def record_blend(set_name, method, keys, oof_p, test_p=None, weights=None, extra=None):
    ev = evaluate_proba(y, oof_p, class_names)
    row = {
        "set_name": set_name,
        "method": method,
        "keys": ",".join(keys),
        "n_models": len(keys),
        "balanced_accuracy": ev["balanced_accuracy"],
        "weights_json": json.dumps({k: float(w) for k, w in zip(keys, weights)}, ensure_ascii=False) if weights is not None else None,
    }
    for short_name, target_key in TRACK_KEYS.items():
        row[f"includes_{short_name}"] = target_key in keys
        row[f"weight_{short_name}"] = _weight_of(keys, weights, target_key)
    row.update({k: v for k, v in ev.items() if k != "balanced_accuracy"})
    if extra:
        row.update(extra)
    blend_rows[(set_name, method)] = row
    if test_p is not None:
        blend_probas[(set_name, method)] = (normalize_rows(oof_p), normalize_rows(test_p))

for set_name, keys in BLEND_SETS.items():
    print("\n===", set_name, keys, "===")

    # 1) Simple average.
    avg_oof, avg_pred = average_proba(keys, oof, pred)
    record_blend(set_name, "avg", keys, avg_oof, avg_pred)

    # 2) Hill climb nonnegative raw probabilities.
    try:
        w, score, hist = hill_climb_weights(y, [oof[k] for k in keys])
        hc_oof = normalize_rows(sum(w[i] * oof[keys[i]] for i in range(len(keys))))
        hc_pred = normalize_rows(sum(w[i] * pred[keys[i]] for i in range(len(keys))))
        record_blend(set_name, "hc_nonnegative_raw", keys, hc_oof, hc_pred, weights=w, extra={"hc_score_internal": score, "hc_n_steps": len(hist)})
    except Exception as e:
        print(f"[WARN] HC failed: {set_name}: {e}")

    # 3) Nelder-Mead softmax weights.
    try:
        w, score, res = nm_softmax_weights(y, [oof[k] for k in keys])
        nm_oof = normalize_rows(sum(w[i] * oof[keys[i]] for i in range(len(keys))))
        nm_pred = normalize_rows(sum(w[i] * pred[keys[i]] for i in range(len(keys))))
        record_blend(set_name, "nm_softmax_raw", keys, nm_oof, nm_pred, weights=w, extra={"nm_score_internal": score, "nm_success": bool(res.success), "nm_message": str(res.message)})
    except Exception as e:
        print(f"[WARN] NM failed: {set_name}: {e}")

    # 4) In-sample meta models. Diagnostic only; do not use as final candidates.
    for mode in ["raw", "rank", "logit", "raw_logit", "raw_rank_logit"]:
        X_meta = build_meta_features(keys, oof, mode)
        X_test_meta = build_meta_features(keys, pred, mode)
        try:
            lr = LogisticRegression(C=0.05, multi_class="multinomial", solver="lbfgs", max_iter=2000, random_state=SEED)
            lr.fit(X_meta, y)
            record_blend(set_name, f"logreg_{mode}", keys, lr.predict_proba(X_meta), lr.predict_proba(X_test_meta), extra={"C": 0.05, "risk": "in_sample_meta_screening"})
        except Exception as e:
            print(f"[WARN] logreg failed: {set_name} {mode}: {e}")
        try:
            rc = RidgeClassifier(alpha=10.0, random_state=SEED)
            rc.fit(X_meta, y)
            record_blend(set_name, f"ridgeclf_{mode}", keys, softmax_np(rc.decision_function(X_meta)), softmax_np(rc.decision_function(X_test_meta)), extra={"alpha": 10.0, "risk": "in_sample_meta_screening"})
        except Exception as e:
            print(f"[WARN] ridgeclf failed: {set_name} {mode}: {e}")
        try:
            y_oh = onehot_y(y, n_classes)
            rr = Ridge(alpha=10.0, random_state=SEED)
            rr.fit(X_meta, y_oh)
            record_blend(set_name, f"ridge_reg_{mode}", keys, normalize_rows(np.clip(rr.predict(X_meta), 1e-12, None)), normalize_rows(np.clip(rr.predict(X_test_meta), 1e-12, None)), extra={"alpha": 10.0, "risk": "in_sample_meta_screening"})
        except Exception as e:
            print(f"[WARN] ridge_reg failed: {set_name} {mode}: {e}")
        try:
            y_oh = onehot_y(y, n_classes)
            oof_cols, test_cols = [], []
            for c in range(n_classes):
                en = ElasticNet(alpha=0.0005, l1_ratio=0.05, random_state=SEED, max_iter=2000)
                en.fit(X_meta, y_oh[:, c])
                oof_cols.append(en.predict(X_meta))
                test_cols.append(en.predict(X_test_meta))
            en_oof = normalize_rows(np.clip(np.vstack(oof_cols).T, 1e-12, None))
            en_pred = normalize_rows(np.clip(np.vstack(test_cols).T, 1e-12, None))
            record_blend(set_name, f"elasticnet_reg_{mode}", keys, en_oof, en_pred, extra={"alpha": 0.0005, "l1_ratio": 0.05, "risk": "in_sample_meta_screening"})
        except Exception as e:
            print(f"[WARN] elasticnet_reg failed: {set_name} {mode}: {e}")

blend_df = pd.DataFrame(list(blend_rows.values())).sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)
display(blend_df.head(200))
blend_df.to_csv(OUTDIR / "blend_diagnostics.csv", index=False)

safe_methods = ["avg", "hc_nonnegative_raw", "nm_softmax_raw"]
safe_blend_df = blend_df[blend_df["method"].isin(safe_methods)].copy().sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)
display(safe_blend_df.head(100))
safe_blend_df.to_csv(OUTDIR / "safe_blend_diagnostics.csv", index=False)

focus_blend_tables = {}
for short_name, target_key in TRACK_KEYS.items():
    include_col = f"includes_{short_name}"
    if include_col in safe_blend_df.columns:
        df = safe_blend_df[safe_blend_df[include_col]].copy().sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)
        focus_blend_tables[short_name] = df
        display(df.head(80))
        df.to_csv(OUTDIR / f"safe_blend_diagnostics_focus_{short_name}.csv", index=False)

# Backward-compatible variables for easy notebook inspection.
focus_040_blend_df = focus_blend_tables.get("040", pd.DataFrame())
focus_039_blend_df = focus_blend_tables.get("039", pd.DataFrame())
focus_038_blend_df = focus_blend_tables.get("038", pd.DataFrame())
focus_037_blend_df = focus_blend_tables.get("037", pd.DataFrame())
focus_033_blend_df = focus_blend_tables.get("033", pd.DataFrame())
# Out:
# === A_045_only ['045_gpu_logreg_add044'] ===
#
# === B_040_only ['040_gpu_logreg_add039'] ===
#
# === C_041_proxy_best_public_context_038_only ['038_gpu_logreg_add037'] ===
#
# === D_033_only ['033_blend_add032'] ===
#
# === E_044_only ['044_shared001_updated_seed2027_foldvariant'] ===
#
# === F_042_only ['042_realmlp_v5_seed2026_foldvariant'] ===
#
# === G_039_only ['039_cat_v3_seed2026_qbin_variant'] ===
#
# === H_036_gpu_only ['036_gpu_logreg_add035'] ===
#
# === I_036_blend_only ['036_blend_add035'] ===
#
# === J_037_only ['037_tabicl_v2'] ===
#
# === K_031_only ['031_blend_add030'] ===
#
# === L_045_040 ['045_gpu_logreg_add044', '040_gpu_logreg_add039'] ===
#
# === M_045_033 ['045_gpu_logreg_add044', '033_blend_add032'] ===
#
# === N_045_038 ['045_gpu_logreg_add044', '038_gpu_logreg_add037'] ===
#
# === O_045_039 ['045_gpu_logreg_add044', '039_cat_v3_seed2026_qbin_variant'] ===
#
# === P_045_044 ['045_gpu_logreg_add044', '044_shared001_updated_seed2027_foldvariant'] ===
#
# === Q_045_042 ['045_gpu_logreg_add044', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === R_040_044 ['040_gpu_logreg_add039', '044_shared001_updated_seed2027_foldvariant'] ===
#
# === S_040_042 ['040_gpu_logreg_add039', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === T_040_044_042 ['040_gpu_logreg_add039', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === U_040_033_044 ['040_gpu_logreg_add039', '033_blend_add032', '044_shared001_updated_seed2027_foldvariant'] ===
#
# === V_040_033_042 ['040_gpu_logreg_add039', '033_blend_add032', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === W_045_040_033 ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '033_blend_add032'] ===
#
# === X_045_040_038 ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '038_gpu_logreg_add037'] ===
#
# === Y_045_040_033_038 ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037'] ===
#
# === Z1_045_040_033_038_044_042 ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === Z2_045_040_033_038_036gpu_036blend ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037', '036_gpu_logreg_add035', '036_blend_add035'] ===
#
# === Z3_045_040_033_038_036gpu_036blend_044_042 ['045_gpu_logreg_add044', '040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037', '036_gpu_logreg_add035', '036_blend_add035', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === Z4_041_old_best_like_plus_new ['040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037', '036_gpu_logreg_add035', '036_blend_add035', '039_cat_v3_seed2026_qbin_variant', '037_tabicl_v2', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant', '045_gpu_logreg_add044'] ===
#
# === Z5_040_033_038_036gpu_036blend_039_044_042 ['040_gpu_logreg_add039', '033_blend_add032', '038_gpu_logreg_add037', '036_gpu_logreg_add035', '036_blend_add035', '039_cat_v3_seed2026_qbin_variant', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === Z6_045_033_038_036gpu_036blend_039_044_042 ['045_gpu_logreg_add044', '033_blend_add032', '038_gpu_logreg_add037', '036_gpu_logreg_add035', '036_blend_add035', '039_cat_v3_seed2026_qbin_variant', '044_shared001_updated_seed2027_foldvariant', '042_realmlp_v5_seed2026_foldvariant'] ===
#
# === Z7_component_diagnostics_with_new ['027_blend_add026', '026_realmlp_v5', '028_cat_v3', '039_cat_v3_seed2026_qbin_variant', '030_ovr_xgb', '032_ovr_tabm', '035_shared001_updated', '037_tabicl_v2', '042_realmlp_v5_seed2026_foldvariant', '044_shared001_updated_seed2027_foldvariant'] ===
#
# === Z8_full_all_loaded ['015_realmlp_seed42', '017_realmlp_bias', '018_xgb_shared003', '019_blend_best', '020_blend_bias', '024_seed_ensemble_blend', '026_realmlp_v5', '027_blend_add026', '028_cat_v3', '029_blend_add028', '030_ovr_xgb', '031_blend_add030', '032_ovr_tabm', '033_blend_add032', '034_gpu_logreg_default', '035_shared001_updated', '036_gpu_logreg_add035', '036_blend_add035', '037_tabicl_v2', '038_gpu_logreg_add037', '039_cat_v3_seed2026_qbin_variant', '040_gpu_logreg_add039', '042_realmlp_v5_seed2026_foldvariant', '044_shared001_updated_seed2027_foldvariant', '045_gpu_logreg_add044'] ===
#                                set_name                    method  \
# 0                         X_045_040_038        hc_nonnegative_raw
# 1                             P_045_044        hc_nonnegative_raw
# 2                             P_045_044            nm_softmax_raw
# 3                     Y_045_040_033_038        hc_nonnegative_raw
# 4    Z2_045_040_033_038_036gpu_036blend        hc_nonnegative_raw
# ..                                  ...                       ...
# 195                           L_045_040  ridge_reg_raw_rank_logit
# 196                           L_045_040   ridgeclf_raw_rank_logit
# 197                           R_040_044  elasticnet_reg_raw_logit
# 198                          K_031_only        ridgeclf_raw_logit
# 199                          K_031_only       ridge_reg_raw_logit
#
#                                                   keys  n_models  \
# 0    045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 1    045_gpu_logreg_add044,044_shared001_updated_se...         2
# 2    045_gpu_logreg_add044,044_shared001_updated_se...         2
# 3    045_gpu_logreg_add044,040_gpu_logreg_add039,03...         4
# 4    045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# ..                                                 ...       ...
# 195        045_gpu_logreg_add044,040_gpu_logreg_add039         2
# 196        045_gpu_logreg_add044,040_gpu_logreg_add039         2
# 197  040_gpu_logreg_add039,044_shared001_updated_se...         2
# 198                                   031_blend_add030         1
# 199                                   031_blend_add030         1
#
#      balanced_accuracy                                       weights_json  \
# 0             0.970253  {"045_gpu_logreg_add044": 0.5144616346780971, ...
# 1             0.970252  {"045_gpu_logreg_add044": 0.9498746867167919, ...
# 2             0.970252  {"045_gpu_logreg_add044": 0.9518786383465581, ...
# 3             0.970252  {"045_gpu_logreg_add044": 0.32558062578057534,...
# 4             0.970248  {"045_gpu_logreg_add044": 0.05736489655841356,...
# ..                 ...                                                ...
# 195           0.969050                                               None
# 196           0.969050                                               None
# 197           0.969037                                               None
# 198           0.969000                                               None
# 199           0.969000                                               None
#
#      includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0            True    0.514462         False         NaN  ...     0.973937
# 1            True    0.949875          True    0.050125  ...     0.973526
# 2            True    0.951879          True    0.048121  ...     0.973526
# 3            True    0.325581         False         NaN  ...     0.974022
# 4            True    0.057365         False         NaN  ...     0.973599
# ..            ...         ...           ...         ...  ...          ...
# 195          True         NaN         False         NaN  ...     0.963203
# 196          True         NaN         False         NaN  ...     0.963203
# 197         False         NaN          True         NaN  ...     0.963650
# 198         False         NaN         False         NaN  ...     0.964811
# 199         False         NaN         False         NaN  ...     0.964811
#
#      hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0             0.970253         9.0                NaN         NaN
# 1             0.970252        10.0                NaN         NaN
# 2                  NaN         NaN           0.970252        True
# 3             0.970252         9.0                NaN         NaN
# 4             0.970248         8.0                NaN         NaN
# ..                 ...         ...                ...         ...
# 195                NaN         NaN                NaN         NaN
# 196                NaN         NaN                NaN         NaN
# 197                NaN         NaN                NaN         NaN
# 198                NaN         NaN                NaN         NaN
# 199                NaN         NaN                NaN         NaN
#
#                                 nm_message   C                      risk  \
# 0                                      NaN NaN                       NaN
# 1                                      NaN NaN                       NaN
# 2    Optimization terminated successfully. NaN                       NaN
# 3                                      NaN NaN                       NaN
# 4                                      NaN NaN                       NaN
# ..                                     ...  ..                       ...
# 195                                    NaN NaN  in_sample_meta_screening
# 196                                    NaN NaN  in_sample_meta_screening
# 197                                    NaN NaN  in_sample_meta_screening
# 198                                    NaN NaN  in_sample_meta_screening
# 199                                    NaN NaN  in_sample_meta_screening
#
#        alpha  l1_ratio
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# ..       ...       ...
# 195  10.0000       NaN
# 196  10.0000       NaN
# 197   0.0005      0.05
# 198  10.0000       NaN
# 199  10.0000       NaN
#
# [200 rows x 52 columns]
#                               set_name              method  \
# 0                        X_045_040_038  hc_nonnegative_raw
# 1                            P_045_044  hc_nonnegative_raw
# 2                            P_045_044      nm_softmax_raw
# 3                    Y_045_040_033_038  hc_nonnegative_raw
# 4   Z2_045_040_033_038_036gpu_036blend  hc_nonnegative_raw
# ..                                 ...                 ...
# 94                          E_044_only      nm_softmax_raw
# 95                          E_044_only                 avg
# 96                          J_037_only      nm_softmax_raw
# 97                          J_037_only  hc_nonnegative_raw
# 98                          J_037_only                 avg
#
#                                                  keys  n_models  \
# 0   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 1   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 2   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 3   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         4
# 4   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# ..                                                ...       ...
# 94         044_shared001_updated_seed2027_foldvariant         1
# 95         044_shared001_updated_seed2027_foldvariant         1
# 96                                      037_tabicl_v2         1
# 97                                      037_tabicl_v2         1
# 98                                      037_tabicl_v2         1
#
#     balanced_accuracy                                       weights_json  \
# 0            0.970253  {"045_gpu_logreg_add044": 0.5144616346780971, ...
# 1            0.970252  {"045_gpu_logreg_add044": 0.9498746867167919, ...
# 2            0.970252  {"045_gpu_logreg_add044": 0.9518786383465581, ...
# 3            0.970252  {"045_gpu_logreg_add044": 0.32558062578057534,...
# 4            0.970248  {"045_gpu_logreg_add044": 0.05736489655841356,...
# ..                ...                                                ...
# 94           0.968604  {"044_shared001_updated_seed2027_foldvariant":...
# 95           0.968604                                               None
# 96           0.958077                             {"037_tabicl_v2": 1.0}
# 97           0.958077                             {"037_tabicl_v2": 1.0}
# 98           0.958077                                               None
#
#     includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0           True    0.514462         False         NaN  ...     0.973937
# 1           True    0.949875          True    0.050125  ...     0.973526
# 2           True    0.951879          True    0.048121  ...     0.973526
# 3           True    0.325581         False         NaN  ...     0.974022
# 4           True    0.057365         False         NaN  ...     0.973599
# ..           ...         ...           ...         ...  ...          ...
# 94         False         NaN          True    1.000000  ...     0.970976
# 95         False         NaN          True         NaN  ...     0.970976
# 96         False         NaN         False         NaN  ...     0.961970
# 97         False         NaN         False         NaN  ...     0.961970
# 98         False         NaN         False         NaN  ...     0.961970
#
#     hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0            0.970253         9.0                NaN         NaN
# 1            0.970252        10.0                NaN         NaN
# 2                 NaN         NaN           0.970252        True
# 3            0.970252         9.0                NaN         NaN
# 4            0.970248         8.0                NaN         NaN
# ..                ...         ...                ...         ...
# 94                NaN         NaN           0.968604        True
# 95                NaN         NaN                NaN         NaN
# 96                NaN         NaN           0.958077        True
# 97           0.958077         1.0                NaN         NaN
# 98                NaN         NaN                NaN         NaN
#
#                                nm_message   C  risk  alpha  l1_ratio
# 0                                     NaN NaN   NaN    NaN       NaN
# 1                                     NaN NaN   NaN    NaN       NaN
# 2   Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                     NaN NaN   NaN    NaN       NaN
# 4                                     NaN NaN   NaN    NaN       NaN
# ..                                    ...  ..   ...    ...       ...
# 94  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 95                                    NaN NaN   NaN    NaN       NaN
# 96  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 97                                    NaN NaN   NaN    NaN       NaN
# 98                                    NaN NaN   NaN    NaN       NaN
#
# [99 rows x 52 columns]
#                                       set_name              method  \
# 0                                X_045_040_038  hc_nonnegative_raw
# 1                                    P_045_044  hc_nonnegative_raw
# 2                                    P_045_044      nm_softmax_raw
# 3                            Y_045_040_033_038  hc_nonnegative_raw
# 4           Z2_045_040_033_038_036gpu_036blend  hc_nonnegative_raw
# 5                   Z1_045_040_033_038_044_042  hc_nonnegative_raw
# 6                                   A_045_only      nm_softmax_raw
# 7                                    O_045_039  hc_nonnegative_raw
# 8                                   A_045_only                 avg
# 9                                   A_045_only  hc_nonnegative_raw
# 10  Z3_045_040_033_038_036gpu_036blend_044_042  hc_nonnegative_raw
# 11                               W_045_040_033  hc_nonnegative_raw
# 12                               X_045_040_038      nm_softmax_raw
# 13                               X_045_040_038                 avg
# 14          Z2_045_040_033_038_036gpu_036blend      nm_softmax_raw
# 15               Z4_041_old_best_like_plus_new  hc_nonnegative_raw
# 16                                   M_045_033  hc_nonnegative_raw
# 17                                   L_045_040      nm_softmax_raw
# 18                                   L_045_040  hc_nonnegative_raw
# 19                                   Q_045_042  hc_nonnegative_raw
# 20                                   Q_045_042      nm_softmax_raw
# 21          Z2_045_040_033_038_036gpu_036blend                 avg
# 22                                   L_045_040                 avg
# 23  Z6_045_033_038_036gpu_036blend_039_044_042  hc_nonnegative_raw
# 24                               W_045_040_033      nm_softmax_raw
# 25                                   M_045_033      nm_softmax_raw
# 26                                   N_045_038  hc_nonnegative_raw
# 27                                   N_045_038      nm_softmax_raw
# 28                           Y_045_040_033_038                 avg
# 29                           Y_045_040_033_038      nm_softmax_raw
# 30  Z6_045_033_038_036gpu_036blend_039_044_042      nm_softmax_raw
# 31                                   N_045_038                 avg
# 32                               W_045_040_033                 avg
# 33                                   M_045_033                 avg
# 34                  Z1_045_040_033_038_044_042      nm_softmax_raw
# 35                          Z8_full_all_loaded  hc_nonnegative_raw
# 36  Z6_045_033_038_036gpu_036blend_039_044_042                 avg
# 37  Z3_045_040_033_038_036gpu_036blend_044_042      nm_softmax_raw
# 38                  Z1_045_040_033_038_044_042                 avg
# 39  Z3_045_040_033_038_036gpu_036blend_044_042                 avg
# 40               Z4_041_old_best_like_plus_new      nm_softmax_raw
# 41               Z4_041_old_best_like_plus_new                 avg
# 42                                   Q_045_042                 avg
# 43                          Z8_full_all_loaded      nm_softmax_raw
# 44                          Z8_full_all_loaded                 avg
# 45                                   O_045_039      nm_softmax_raw
# 46                                   P_045_044                 avg
# 47                                   O_045_039                 avg
#
#                                                  keys  n_models  \
# 0   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 1   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 2   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 3   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         4
# 4   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 5   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 6                               045_gpu_logreg_add044         1
# 7   045_gpu_logreg_add044,039_cat_v3_seed2026_qbin...         2
# 8                               045_gpu_logreg_add044         1
# 9                               045_gpu_logreg_add044         1
# 10  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 11  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 12  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 13  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 14  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 15  040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 16             045_gpu_logreg_add044,033_blend_add032         2
# 17        045_gpu_logreg_add044,040_gpu_logreg_add039         2
# 18        045_gpu_logreg_add044,040_gpu_logreg_add039         2
# 19  045_gpu_logreg_add044,042_realmlp_v5_seed2026_...         2
# 20  045_gpu_logreg_add044,042_realmlp_v5_seed2026_...         2
# 21  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 22        045_gpu_logreg_add044,040_gpu_logreg_add039         2
# 23  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 24  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 25             045_gpu_logreg_add044,033_blend_add032         2
# 26        045_gpu_logreg_add044,038_gpu_logreg_add037         2
# 27        045_gpu_logreg_add044,038_gpu_logreg_add037         2
# 28  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         4
# 29  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         4
# 30  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 31        045_gpu_logreg_add044,038_gpu_logreg_add037         2
# 32  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         3
# 33             045_gpu_logreg_add044,033_blend_add032         2
# 34  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 35  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 36  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 37  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 38  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 39  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 40  040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 41  040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 42  045_gpu_logreg_add044,042_realmlp_v5_seed2026_...         2
# 43  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 44  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 45  045_gpu_logreg_add044,039_cat_v3_seed2026_qbin...         2
# 46  045_gpu_logreg_add044,044_shared001_updated_se...         2
# 47  045_gpu_logreg_add044,039_cat_v3_seed2026_qbin...         2
#
#     balanced_accuracy                                       weights_json  \
# 0            0.970253  {"045_gpu_logreg_add044": 0.5144616346780971, ...
# 1            0.970252  {"045_gpu_logreg_add044": 0.9498746867167919, ...
# 2            0.970252  {"045_gpu_logreg_add044": 0.9518786383465581, ...
# 3            0.970252  {"045_gpu_logreg_add044": 0.32558062578057534,...
# 4            0.970248  {"045_gpu_logreg_add044": 0.05736489655841356,...
# 5            0.970246  {"045_gpu_logreg_add044": 0.1953383167534802, ...
# 6            0.970245                     {"045_gpu_logreg_add044": 1.0}
# 7            0.970245  {"045_gpu_logreg_add044": 1.0, "039_cat_v3_see...
# 8            0.970245                                               None
# 9            0.970245                     {"045_gpu_logreg_add044": 1.0}
# 10           0.970242  {"045_gpu_logreg_add044": 0.20442407183347813,...
# 11           0.970222  {"045_gpu_logreg_add044": 0.4599494724621861, ...
# 12           0.970218  {"045_gpu_logreg_add044": 0.48768090588066687,...
# 13           0.970207                                               None
# 14           0.970202  {"045_gpu_logreg_add044": 0.16530270047047682,...
# 15           0.970201  {"040_gpu_logreg_add039": 0.10901800829964889,...
# 16           0.970200  {"045_gpu_logreg_add044": 0.5555555555555556, ...
# 17           0.970200  {"045_gpu_logreg_add044": 0.6045504088187327, ...
# 18           0.970200  {"045_gpu_logreg_add044": 0.6060606060606061, ...
# 19           0.970199  {"045_gpu_logreg_add044": 0.7992306571323092, ...
# 20           0.970198  {"045_gpu_logreg_add044": 0.7943761685465539, ...
# 21           0.970197                                               None
# 22           0.970188                                               None
# 23           0.970184  {"045_gpu_logreg_add044": 0.20067153972335602,...
# 24           0.970183  {"045_gpu_logreg_add044": 0.355181163811397, "...
# 25           0.970179  {"045_gpu_logreg_add044": 0.586417528006666, "...
# 26           0.970169  {"045_gpu_logreg_add044": 0.5532997191371984, ...
# 27           0.970166  {"045_gpu_logreg_add044": 0.528318852485257, "...
# 28           0.970164                                               None
# 29           0.970164  {"045_gpu_logreg_add044": 0.25, "040_gpu_logre...
# 30           0.970163  {"045_gpu_logreg_add044": 0.11648976637539903,...
# 31           0.970156                                               None
# 32           0.970155                                               None
# 33           0.970149                                               None
# 34           0.970145  {"045_gpu_logreg_add044": 0.19161509400530638,...
# 35           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 36           0.970127                                               None
# 37           0.970120  {"045_gpu_logreg_add044": 0.1412583716403924, ...
# 38           0.970117                                               None
# 39           0.970107                                               None
# 40           0.970008  {"040_gpu_logreg_add039": 0.09167680702748734,...
# 41           0.969995                                               None
# 42           0.969940                                               None
# 43           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 44           0.969822                                               None
# 45           0.969790  {"045_gpu_logreg_add044": 0.5810254687953933, ...
# 46           0.969785                                               None
# 47           0.969657                                               None
#
#     includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0           True    0.514462         False         NaN  ...     0.973937
# 1           True    0.949875          True    0.050125  ...     0.973526
# 2           True    0.951879          True    0.048121  ...     0.973526
# 3           True    0.325581         False         NaN  ...     0.974022
# 4           True    0.057365         False         NaN  ...     0.973599
# 5           True    0.195338          True    0.195338  ...     0.974252
# 6           True    1.000000         False         NaN  ...     0.973490
# 7           True    1.000000         False         NaN  ...     0.973490
# 8           True         NaN         False         NaN  ...     0.973490
# 9           True    1.000000         False         NaN  ...     0.973490
# 10          True    0.204424          True    0.022592  ...     0.973599
# 11          True    0.459949         False         NaN  ...     0.973804
# 12          True    0.487681         False         NaN  ...     0.973937
# 13          True         NaN         False         NaN  ...     0.974046
# 14          True    0.165303         False         NaN  ...     0.973502
# 15          True    0.101101          True    0.000000  ...     0.973430
# 16          True    0.555556         False         NaN  ...     0.973103
# 17          True    0.604550         False         NaN  ...     0.973768
# 18          True    0.606061         False         NaN  ...     0.973768
# 19          True    0.799231         False         NaN  ...     0.973297
# 20          True    0.794376         False         NaN  ...     0.973273
# 21          True         NaN         False         NaN  ...     0.973442
# 22          True         NaN         False         NaN  ...     0.973829
# 23          True    0.200672          True    0.026858  ...     0.973478
# 24          True    0.355181         False         NaN  ...     0.973285
# 25          True    0.586418         False         NaN  ...     0.973091
# 26          True    0.553300         False         NaN  ...     0.973804
# 27          True    0.528319         False         NaN  ...     0.973817
# 28          True         NaN         False         NaN  ...     0.973611
# 29          True    0.250000         False         NaN  ...     0.973611
# 30          True    0.116490          True    0.130928  ...     0.973587
# 31          True         NaN         False         NaN  ...     0.973841
# 32          True         NaN         False         NaN  ...     0.973297
# 33          True         NaN         False         NaN  ...     0.972970
# 34          True    0.191615          True    0.108463  ...     0.973611
# 35          True    0.206471          True    0.028269  ...     0.972088
# 36          True         NaN          True         NaN  ...     0.973430
# 37          True    0.141258          True    0.135321  ...     0.973514
# 38          True         NaN          True         NaN  ...     0.973732
# 39          True         NaN          True         NaN  ...     0.973406
# 40          True    0.107351          True    0.105546  ...     0.974022
# 41          True         NaN          True         NaN  ...     0.973829
# 42          True         NaN         False         NaN  ...     0.973152
# 43          True    0.037943          True    0.044244  ...     0.970601
# 44          True         NaN          True         NaN  ...     0.970529
# 45          True    0.581025         False         NaN  ...     0.972934
# 46          True         NaN          True         NaN  ...     0.972958
# 47          True         NaN         False         NaN  ...     0.972813
#
#     hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0            0.970253         9.0                NaN         NaN
# 1            0.970252        10.0                NaN         NaN
# 2                 NaN         NaN           0.970252        True
# 3            0.970252         9.0                NaN         NaN
# 4            0.970248         8.0                NaN         NaN
# 5            0.970246        10.0                NaN         NaN
# 6                 NaN         NaN           0.970245        True
# 7            0.970245         9.0                NaN         NaN
# 8                 NaN         NaN                NaN         NaN
# 9            0.970245         1.0                NaN         NaN
# 10           0.970242        13.0                NaN         NaN
# 11           0.970222         7.0                NaN         NaN
# 12                NaN         NaN           0.970218        True
# 13                NaN         NaN                NaN         NaN
# 14                NaN         NaN           0.970202        True
# 15           0.970201         9.0                NaN         NaN
# 16           0.970200         2.0                NaN         NaN
# 17                NaN         NaN           0.970200        True
# 18           0.970200         3.0                NaN         NaN
# 19           0.970199         9.0                NaN         NaN
# 20                NaN         NaN           0.970198        True
# 21                NaN         NaN                NaN         NaN
# 22                NaN         NaN                NaN         NaN
# 23           0.970184         8.0                NaN         NaN
# 24                NaN         NaN           0.970183        True
# 25                NaN         NaN           0.970179        True
# 26           0.970169         5.0                NaN         NaN
# 27                NaN         NaN           0.970166        True
# 28                NaN         NaN                NaN         NaN
# 29                NaN         NaN           0.970164        True
# 30                NaN         NaN           0.970163        True
# 31                NaN         NaN                NaN         NaN
# 32                NaN         NaN                NaN         NaN
# 33                NaN         NaN                NaN         NaN
# 34                NaN         NaN           0.970145        True
# 35           0.970139        10.0                NaN         NaN
# 36                NaN         NaN                NaN         NaN
# 37                NaN         NaN           0.970120        True
# 38                NaN         NaN                NaN         NaN
# 39                NaN         NaN                NaN         NaN
# 40                NaN         NaN           0.970008        True
# 41                NaN         NaN                NaN         NaN
# 42                NaN         NaN                NaN         NaN
# 43                NaN         NaN           0.969852        True
# 44                NaN         NaN                NaN         NaN
# 45                NaN         NaN           0.969790        True
# 46                NaN         NaN                NaN         NaN
# 47                NaN         NaN                NaN         NaN
#
#                                nm_message   C  risk  alpha  l1_ratio
# 0                                     NaN NaN   NaN    NaN       NaN
# 1                                     NaN NaN   NaN    NaN       NaN
# 2   Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                     NaN NaN   NaN    NaN       NaN
# 4                                     NaN NaN   NaN    NaN       NaN
# 5                                     NaN NaN   NaN    NaN       NaN
# 6   Optimization terminated successfully. NaN   NaN    NaN       NaN
# 7                                     NaN NaN   NaN    NaN       NaN
# 8                                     NaN NaN   NaN    NaN       NaN
# 9                                     NaN NaN   NaN    NaN       NaN
# 10                                    NaN NaN   NaN    NaN       NaN
# 11                                    NaN NaN   NaN    NaN       NaN
# 12  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 13                                    NaN NaN   NaN    NaN       NaN
# 14  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 15                                    NaN NaN   NaN    NaN       NaN
# 16                                    NaN NaN   NaN    NaN       NaN
# 17  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 18                                    NaN NaN   NaN    NaN       NaN
# 19                                    NaN NaN   NaN    NaN       NaN
# 20  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 21                                    NaN NaN   NaN    NaN       NaN
# 22                                    NaN NaN   NaN    NaN       NaN
# 23                                    NaN NaN   NaN    NaN       NaN
# 24  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 25  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 26                                    NaN NaN   NaN    NaN       NaN
# 27  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 28                                    NaN NaN   NaN    NaN       NaN
# 29  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 30  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 31                                    NaN NaN   NaN    NaN       NaN
# 32                                    NaN NaN   NaN    NaN       NaN
# 33                                    NaN NaN   NaN    NaN       NaN
# 34  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 35                                    NaN NaN   NaN    NaN       NaN
# 36                                    NaN NaN   NaN    NaN       NaN
# 37  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 38                                    NaN NaN   NaN    NaN       NaN
# 39                                    NaN NaN   NaN    NaN       NaN
# 40  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 41                                    NaN NaN   NaN    NaN       NaN
# 42                                    NaN NaN   NaN    NaN       NaN
# 43  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 44                                    NaN NaN   NaN    NaN       NaN
# 45  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 46                                    NaN NaN   NaN    NaN       NaN
# 47                                    NaN NaN   NaN    NaN       NaN
#
# [48 rows x 52 columns]
#                                       set_name              method  \
# 0                                    P_045_044  hc_nonnegative_raw
# 1                                    P_045_044      nm_softmax_raw
# 2                   Z1_045_040_033_038_044_042  hc_nonnegative_raw
# 3   Z3_045_040_033_038_036gpu_036blend_044_042  hc_nonnegative_raw
# 4                                T_040_044_042  hc_nonnegative_raw
# 5                                    R_040_044  hc_nonnegative_raw
# 6                                    R_040_044      nm_softmax_raw
# 7                Z4_041_old_best_like_plus_new  hc_nonnegative_raw
# 8                                U_040_033_044  hc_nonnegative_raw
# 9                                U_040_033_044      nm_softmax_raw
# 10  Z6_045_033_038_036gpu_036blend_039_044_042  hc_nonnegative_raw
# 11  Z5_040_033_038_036gpu_036blend_039_044_042  hc_nonnegative_raw
# 12  Z6_045_033_038_036gpu_036blend_039_044_042      nm_softmax_raw
# 13                  Z1_045_040_033_038_044_042      nm_softmax_raw
# 14  Z5_040_033_038_036gpu_036blend_039_044_042      nm_softmax_raw
# 15                          Z8_full_all_loaded  hc_nonnegative_raw
# 16  Z6_045_033_038_036gpu_036blend_039_044_042                 avg
# 17  Z3_045_040_033_038_036gpu_036blend_044_042      nm_softmax_raw
# 18                  Z1_045_040_033_038_044_042                 avg
# 19           Z7_component_diagnostics_with_new  hc_nonnegative_raw
# 20  Z3_045_040_033_038_036gpu_036blend_044_042                 avg
# 21  Z5_040_033_038_036gpu_036blend_039_044_042                 avg
# 22               Z4_041_old_best_like_plus_new      nm_softmax_raw
# 23               Z4_041_old_best_like_plus_new                 avg
# 24                               U_040_033_044                 avg
# 25                               T_040_044_042      nm_softmax_raw
# 26                          Z8_full_all_loaded      nm_softmax_raw
# 27                                   R_040_044                 avg
# 28                          Z8_full_all_loaded                 avg
# 29                                   P_045_044                 avg
# 30                               T_040_044_042                 avg
# 31           Z7_component_diagnostics_with_new      nm_softmax_raw
# 32           Z7_component_diagnostics_with_new                 avg
# 33                                  E_044_only  hc_nonnegative_raw
# 34                                  E_044_only      nm_softmax_raw
# 35                                  E_044_only                 avg
#
#                                                  keys  n_models  \
# 0   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 1   045_gpu_logreg_add044,044_shared001_updated_se...         2
# 2   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 3   045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 4   040_gpu_logreg_add039,044_shared001_updated_se...         3
# 5   040_gpu_logreg_add039,044_shared001_updated_se...         2
# 6   040_gpu_logreg_add039,044_shared001_updated_se...         2
# 7   040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 8   040_gpu_logreg_add039,033_blend_add032,044_sha...         3
# 9   040_gpu_logreg_add039,033_blend_add032,044_sha...         3
# 10  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 11  040_gpu_logreg_add039,033_blend_add032,038_gpu...         8
# 12  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 13  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 14  040_gpu_logreg_add039,033_blend_add032,038_gpu...         8
# 15  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 16  045_gpu_logreg_add044,033_blend_add032,038_gpu...         8
# 17  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 18  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         6
# 19  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 20  045_gpu_logreg_add044,040_gpu_logreg_add039,03...         8
# 21  040_gpu_logreg_add039,033_blend_add032,038_gpu...         8
# 22  040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 23  040_gpu_logreg_add039,033_blend_add032,038_gpu...        10
# 24  040_gpu_logreg_add039,033_blend_add032,044_sha...         3
# 25  040_gpu_logreg_add039,044_shared001_updated_se...         3
# 26  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 27  040_gpu_logreg_add039,044_shared001_updated_se...         2
# 28  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 29  045_gpu_logreg_add044,044_shared001_updated_se...         2
# 30  040_gpu_logreg_add039,044_shared001_updated_se...         3
# 31  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 32  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 33         044_shared001_updated_seed2027_foldvariant         1
# 34         044_shared001_updated_seed2027_foldvariant         1
# 35         044_shared001_updated_seed2027_foldvariant         1
#
#     balanced_accuracy                                       weights_json  \
# 0            0.970252  {"045_gpu_logreg_add044": 0.9498746867167919, ...
# 1            0.970252  {"045_gpu_logreg_add044": 0.9518786383465581, ...
# 2            0.970246  {"045_gpu_logreg_add044": 0.1953383167534802, ...
# 3            0.970242  {"045_gpu_logreg_add044": 0.20442407183347813,...
# 4            0.970226  {"040_gpu_logreg_add039": 0.8747895065800776, ...
# 5            0.970220  {"040_gpu_logreg_add039": 0.8829901829369541, ...
# 6            0.970218  {"040_gpu_logreg_add039": 0.8758994257518171, ...
# 7            0.970201  {"040_gpu_logreg_add039": 0.10901800829964889,...
# 8            0.970196  {"040_gpu_logreg_add039": 0.6082293785700359, ...
# 9            0.970191  {"040_gpu_logreg_add039": 0.7101566594750165, ...
# 10           0.970184  {"045_gpu_logreg_add044": 0.20067153972335602,...
# 11           0.970169  {"040_gpu_logreg_add039": 0.14412255051010178,...
# 12           0.970163  {"045_gpu_logreg_add044": 0.11648976637539903,...
# 13           0.970145  {"045_gpu_logreg_add044": 0.19161509400530638,...
# 14           0.970140  {"040_gpu_logreg_add039": 0.11648262430253267,...
# 15           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 16           0.970127                                               None
# 17           0.970120  {"045_gpu_logreg_add044": 0.1412583716403924, ...
# 18           0.970117                                               None
# 19           0.970117  {"027_blend_add026": 0.10536135606998472, "026...
# 20           0.970107                                               None
# 21           0.970080                                               None
# 22           0.970008  {"040_gpu_logreg_add039": 0.09167680702748734,...
# 23           0.969995                                               None
# 24           0.969988                                               None
# 25           0.969952  {"040_gpu_logreg_add039": 0.48605716649909886,...
# 26           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 27           0.969837                                               None
# 28           0.969822                                               None
# 29           0.969785                                               None
# 30           0.969634                                               None
# 31           0.969631  {"027_blend_add026": 0.11457916200264882, "026...
# 32           0.969472                                               None
# 33           0.968604  {"044_shared001_updated_seed2027_foldvariant":...
# 34           0.968604  {"044_shared001_updated_seed2027_foldvariant":...
# 35           0.968604                                               None
#
#     includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0           True    0.949875          True    0.050125  ...     0.973526
# 1           True    0.951879          True    0.048121  ...     0.973526
# 2           True    0.195338          True    0.195338  ...     0.974252
# 3           True    0.204424          True    0.022592  ...     0.973599
# 4          False         NaN          True    0.115359  ...     0.974264
# 5          False         NaN          True    0.117010  ...     0.974252
# 6          False         NaN          True    0.124101  ...     0.974240
# 7           True    0.101101          True    0.000000  ...     0.973430
# 8          False         NaN          True    0.029898  ...     0.973647
# 9          False         NaN          True    0.078723  ...     0.973865
# 10          True    0.200672          True    0.026858  ...     0.973478
# 11         False         NaN          True    0.024883  ...     0.973563
# 12          True    0.116490          True    0.130928  ...     0.973587
# 13          True    0.191615          True    0.108463  ...     0.973611
# 14         False         NaN          True    0.131475  ...     0.973671
# 15          True    0.206471          True    0.028269  ...     0.972088
# 16          True         NaN          True         NaN  ...     0.973430
# 17          True    0.141258          True    0.135321  ...     0.973514
# 18          True         NaN          True         NaN  ...     0.973732
# 19         False         NaN          True    0.000000  ...     0.973357
# 20          True         NaN          True         NaN  ...     0.973406
# 21         False         NaN          True         NaN  ...     0.973502
# 22          True    0.107351          True    0.105546  ...     0.974022
# 23          True         NaN          True         NaN  ...     0.973829
# 24         False         NaN          True         NaN  ...     0.973297
# 25         False         NaN          True    0.247744  ...     0.973671
# 26          True    0.037943          True    0.044244  ...     0.970601
# 27         False         NaN          True         NaN  ...     0.973526
# 28          True         NaN          True         NaN  ...     0.970529
# 29          True         NaN          True         NaN  ...     0.972958
# 30         False         NaN          True         NaN  ...     0.972704
# 31         False         NaN          True    0.085635  ...     0.970130
# 32         False         NaN          True         NaN  ...     0.968691
# 33         False         NaN          True    1.000000  ...     0.970976
# 34         False         NaN          True    1.000000  ...     0.970976
# 35         False         NaN          True         NaN  ...     0.970976
#
#     hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0            0.970252        10.0                NaN         NaN
# 1                 NaN         NaN           0.970252        True
# 2            0.970246        10.0                NaN         NaN
# 3            0.970242        13.0                NaN         NaN
# 4            0.970226        18.0                NaN         NaN
# 5            0.970220         9.0                NaN         NaN
# 6                 NaN         NaN           0.970218        True
# 7            0.970201         9.0                NaN         NaN
# 8            0.970196        13.0                NaN         NaN
# 9                 NaN         NaN           0.970191        True
# 10           0.970184         8.0                NaN         NaN
# 11           0.970169         6.0                NaN         NaN
# 12                NaN         NaN           0.970163        True
# 13                NaN         NaN           0.970145        True
# 14                NaN         NaN           0.970140        True
# 15           0.970139        10.0                NaN         NaN
# 16                NaN         NaN                NaN         NaN
# 17                NaN         NaN           0.970120        True
# ...
# 0                                     NaN NaN   NaN    NaN       NaN
# 1                                     NaN NaN   NaN    NaN       NaN
# 2                                     NaN NaN   NaN    NaN       NaN
# 3                                     NaN NaN   NaN    NaN       NaN
# 4                                     NaN NaN   NaN    NaN       NaN
# 5   Optimization terminated successfully. NaN   NaN    NaN       NaN
# 6                                     NaN NaN   NaN    NaN       NaN
# 7                                     NaN NaN   NaN    NaN       NaN
# 8                                     NaN NaN   NaN    NaN       NaN
# 9                                     NaN NaN   NaN    NaN       NaN
# 10  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 11                                    NaN NaN   NaN    NaN       NaN
# 12  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 13  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 14                                    NaN NaN   NaN    NaN       NaN
# 15                                    NaN NaN   NaN    NaN       NaN
# 16  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 17  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 18                                    NaN NaN   NaN    NaN       NaN
# 19                                    NaN NaN   NaN    NaN       NaN
# 20  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 21  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 22                                    NaN NaN   NaN    NaN       NaN
# 23                                    NaN NaN   NaN    NaN       NaN
# 24  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 25                                    NaN NaN   NaN    NaN       NaN
# 26  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 27                                    NaN NaN   NaN    NaN       NaN
# 28                                    NaN NaN   NaN    NaN       NaN
# 29                                    NaN NaN   NaN    NaN       NaN
# 30                                    NaN NaN   NaN    NaN       NaN
# 31  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 32                                    NaN NaN   NaN    NaN       NaN
# 33                                    NaN NaN   NaN    NaN       NaN
# 34  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 35                                    NaN NaN   NaN    NaN       NaN
# 36                                    NaN NaN   NaN    NaN       NaN
# 37  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 38                                    NaN NaN   NaN    NaN       NaN
#
# [39 rows x 52 columns]
#                             set_name              method  \
# 0                 Z8_full_all_loaded  hc_nonnegative_raw
# 1  Z7_component_diagnostics_with_new  hc_nonnegative_raw
# 2                 Z8_full_all_loaded      nm_softmax_raw
# 3                 Z8_full_all_loaded                 avg
# 4  Z7_component_diagnostics_with_new      nm_softmax_raw
# 5  Z7_component_diagnostics_with_new                 avg
#
#                                                 keys  n_models  \
# 0  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 1  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 2  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 3  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 4  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 5  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
#
#    balanced_accuracy                                       weights_json  \
# 0           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 1           0.970117  {"027_blend_add026": 0.10536135606998472, "026...
# 2           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 3           0.969822                                               None
# 4           0.969631  {"027_blend_add026": 0.11457916200264882, "026...
# 5           0.969472                                               None
#
#    includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0          True    0.206471          True    0.028269  ...     0.972088
# 1         False         NaN          True    0.000000  ...     0.973357
# 2          True    0.037943          True    0.044244  ...     0.970601
# 3          True         NaN          True         NaN  ...     0.970529
# 4         False         NaN          True    0.085635  ...     0.970130
# 5         False         NaN          True         NaN  ...     0.968691
#
#    hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0           0.970139        10.0                NaN         NaN
# 1           0.970117        17.0                NaN         NaN
# 2                NaN         NaN           0.969852        True
# 3                NaN         NaN                NaN         NaN
# 4                NaN         NaN           0.969631        True
# 5                NaN         NaN                NaN         NaN
#
#                               nm_message   C  risk  alpha  l1_ratio
# 0                                    NaN NaN   NaN    NaN       NaN
# 1                                    NaN NaN   NaN    NaN       NaN
# 2  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                    NaN NaN   NaN    NaN       NaN
# 4  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 5                                    NaN NaN   NaN    NaN       NaN
#
# [6 rows x 52 columns]
#              set_name              method  \
# 0  Z8_full_all_loaded  hc_nonnegative_raw
# 1          K_031_only                 avg
# 2          K_031_only      nm_softmax_raw
# 3          K_031_only  hc_nonnegative_raw
# 4  Z8_full_all_loaded      nm_softmax_raw
# 5  Z8_full_all_loaded                 avg
#
#                                                 keys  n_models  \
# 0  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 1                                   031_blend_add030         1
# 2                                   031_blend_add030         1
# 3                                   031_blend_add030         1
# 4  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 5  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
#
#    balanced_accuracy                                       weights_json  \
# 0           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 1           0.970033                                               None
# 2           0.970033                          {"031_blend_add030": 1.0}
# 3           0.970033                          {"031_blend_add030": 1.0}
# 4           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 5           0.969822                                               None
#
#    includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0          True    0.206471          True    0.028269  ...     0.972088
# 1         False         NaN         False         NaN  ...     0.972571
# 2         False         NaN         False         NaN  ...     0.972571
# 3         False         NaN         False         NaN  ...     0.972571
# 4          True    0.037943          True    0.044244  ...     0.970601
# 5          True         NaN          True         NaN  ...     0.970529
#
#    hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0           0.970139        10.0                NaN         NaN
# 1                NaN         NaN                NaN         NaN
# 2                NaN         NaN           0.970033        True
# 3           0.970033         1.0                NaN         NaN
# 4                NaN         NaN           0.969852        True
# 5                NaN         NaN                NaN         NaN
#
#                               nm_message   C  risk  alpha  l1_ratio
# 0                                    NaN NaN   NaN    NaN       NaN
# 1                                    NaN NaN   NaN    NaN       NaN
# 2  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                    NaN NaN   NaN    NaN       NaN
# 4  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 5                                    NaN NaN   NaN    NaN       NaN
#
# [6 rows x 52 columns]
#                             set_name              method  \
# 0                 Z8_full_all_loaded  hc_nonnegative_raw
# 1  Z7_component_diagnostics_with_new  hc_nonnegative_raw
# 2                 Z8_full_all_loaded      nm_softmax_raw
# 3                 Z8_full_all_loaded                 avg
# 4  Z7_component_diagnostics_with_new      nm_softmax_raw
# 5  Z7_component_diagnostics_with_new                 avg
#
#                                                 keys  n_models  \
# 0  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 1  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 2  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 3  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 4  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 5  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
#
#    balanced_accuracy                                       weights_json  \
# 0           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 1           0.970117  {"027_blend_add026": 0.10536135606998472, "026...
# 2           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 3           0.969822                                               None
# 4           0.969631  {"027_blend_add026": 0.11457916200264882, "026...
# 5           0.969472                                               None
#
#    includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0          True    0.206471          True    0.028269  ...     0.972088
# 1         False         NaN          True    0.000000  ...     0.973357
# 2          True    0.037943          True    0.044244  ...     0.970601
# 3          True         NaN          True         NaN  ...     0.970529
# 4         False         NaN          True    0.085635  ...     0.970130
# 5         False         NaN          True         NaN  ...     0.968691
#
#    hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0           0.970139        10.0                NaN         NaN
# 1           0.970117        17.0                NaN         NaN
# 2                NaN         NaN           0.969852        True
# 3                NaN         NaN                NaN         NaN
# 4                NaN         NaN           0.969631        True
# 5                NaN         NaN                NaN         NaN
#
#                               nm_message   C  risk  alpha  l1_ratio
# 0                                    NaN NaN   NaN    NaN       NaN
# 1                                    NaN NaN   NaN    NaN       NaN
# 2  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                    NaN NaN   NaN    NaN       NaN
# 4  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 5                                    NaN NaN   NaN    NaN       NaN
#
# [6 rows x 52 columns]
#              set_name              method  \
# 0  Z8_full_all_loaded  hc_nonnegative_raw
# 1  Z8_full_all_loaded      nm_softmax_raw
# 2  Z8_full_all_loaded                 avg
#
#                                                 keys  n_models  \
# 0  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 1  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 2  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
#
#    balanced_accuracy                                       weights_json  \
# 0           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 1           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 2           0.969822                                               None
#
#    includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0          True    0.206471          True    0.028269  ...     0.972088
# 1          True    0.037943          True    0.044244  ...     0.970601
# 2          True         NaN          True         NaN  ...     0.970529
#
#    hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0           0.970139        10.0                NaN         NaN
# 1                NaN         NaN           0.969852        True
# 2                NaN         NaN                NaN         NaN
#
#                               nm_message   C  risk  alpha  l1_ratio
# 0                                    NaN NaN   NaN    NaN       NaN
# 1  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 2                                    NaN NaN   NaN    NaN       NaN
#
# [3 rows x 52 columns]
#                             set_name              method  \
# 0                 Z8_full_all_loaded  hc_nonnegative_raw
# 1  Z7_component_diagnostics_with_new  hc_nonnegative_raw
# 2                 Z8_full_all_loaded      nm_softmax_raw
# 3                 Z8_full_all_loaded                 avg
# 4  Z7_component_diagnostics_with_new      nm_softmax_raw
# 5  Z7_component_diagnostics_with_new                 avg
#
#                                                 keys  n_models  \
# 0  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 1  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 2  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 3  015_realmlp_seed42,017_realmlp_bias,018_xgb_sh...        25
# 4  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
# 5  027_blend_add026,026_realmlp_v5,028_cat_v3,039...        10
#
#    balanced_accuracy                                       weights_json  \
# 0           0.970139  {"015_realmlp_seed42": 0.028268706931836803, "...
# 1           0.970117  {"027_blend_add026": 0.10536135606998472, "026...
# 2           0.969852  {"015_realmlp_seed42": 0.034145163809488205, "...
# 3           0.969822                                               None
# 4           0.969631  {"027_blend_add026": 0.11457916200264882, "026...
# 5           0.969472                                               None
#
#    includes_045  weight_045  includes_044  weight_044  ...  recall_STAR  \
# 0          True    0.206471          True    0.028269  ...     0.972088
# 1         False         NaN          True    0.000000  ...     0.973357
# 2          True    0.037943          True    0.044244  ...     0.970601
# 3          True         NaN          True         NaN  ...     0.970529
# 4         False         NaN          True    0.085635  ...     0.970130
# 5         False         NaN          True         NaN  ...     0.968691
#
#    hc_score_internal  hc_n_steps  nm_score_internal  nm_success  \
# 0           0.970139        10.0                NaN         NaN
# 1           0.970117        17.0                NaN         NaN
# 2                NaN         NaN           0.969852        True
# 3                NaN         NaN                NaN         NaN
# 4                NaN         NaN           0.969631        True
# 5                NaN         NaN                NaN         NaN
#
#                               nm_message   C  risk  alpha  l1_ratio
# 0                                    NaN NaN   NaN    NaN       NaN
# 1                                    NaN NaN   NaN    NaN       NaN
# 2  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 3                                    NaN NaN   NaN    NaN       NaN
# 4  Optimization terminated successfully. NaN   NaN    NaN       NaN
# 5                                    NaN NaN   NaN    NaN       NaN
#
# [6 rows x 52 columns]

# %%
# ============================================================
# 5. Save best safe blend
# ============================================================

safe_blend_df = safe_blend_df.sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)
best_row = safe_blend_df.iloc[0].to_dict()
best_set_name = best_row["set_name"]
best_method = best_row["method"]
best_keys = best_row["keys"].split(",")

print("Best safe blend:")
print(json.dumps(best_row, indent=2, ensure_ascii=False))

if best_method == "avg":
    best_oof_proba, best_pred_proba = average_proba(best_keys, oof, pred)
else:
    weights_json = json.loads(best_row["weights_json"])
    w = np.array([weights_json[k] for k in best_keys], dtype=float)
    best_oof_proba = normalize_rows(sum(w[i] * oof[best_keys[i]] for i in range(len(best_keys))))
    best_pred_proba = normalize_rows(sum(w[i] * pred[best_keys[i]] for i in range(len(best_keys))))

validate_proba("best_oof_proba", best_oof_proba, len(train), n_classes)
validate_proba("best_pred_proba", best_pred_proba, len(test), n_classes)

best_oof_score = balanced_accuracy_score(y, best_oof_proba.argmax(axis=1))
print("best_oof_score:", best_oof_score)

best_oof_npy = OUTDIR / f"oof_{EXP_ID}_best_blend_proba.npy"
best_pred_npy = OUTDIR / f"pred_{EXP_ID}_best_blend_proba.npy"
np.save(best_oof_npy, best_oof_proba.astype(np.float32))
np.save(best_pred_npy, best_pred_proba.astype(np.float32))

best_labels = le.inverse_transform(best_pred_proba.argmax(axis=1))
submission = pd.DataFrame({ID_COL: test[ID_COL].values, TARGET_COL: best_labels})
assert submission.shape[0] == sample.shape[0]
assert submission.columns.tolist() == sample.columns.tolist()
assert submission[ID_COL].equals(sample[ID_COL])

best_submission_path = OUTDIR / f"submission_{EXP_ID}_best_blend.csv"
submission.to_csv(best_submission_path, index=False)

best_info = {
    "exp_id": EXP_ID,
    "best_set_name": best_set_name,
    "best_method": best_method,
    "best_keys": best_keys,
    "cv_score": float(best_oof_score),
    "weights_json": best_row.get("weights_json"),
    "oof_path": str(best_oof_npy),
    "pred_path": str(best_pred_npy),
    "submission_path": str(best_submission_path),
    "row": best_row,
    "note": "Best safe blend excludes in-sample meta screening methods.",
}
for short_name, target_key in TRACK_KEYS.items():
    best_info[f"includes_{short_name}"] = target_key in best_keys
    best_info[f"weight_{short_name}"] = best_row.get(f"weight_{short_name}")

save_json(best_info, OUTDIR / "best_blend_info.json")

saved_submission_record = {
    "set_name": best_set_name,
    "method": best_method,
    "cv": float(best_oof_score),
    "keys": ",".join(best_keys),
    "weights_json": best_row.get("weights_json"),
    "submission": best_submission_path.name,
    "oof_proba": best_oof_npy.name,
    "pred_proba": best_pred_npy.name,
}
for short_name, target_key in TRACK_KEYS.items():
    saved_submission_record[f"includes_{short_name}"] = target_key in best_keys
    saved_submission_record[f"weight_{short_name}"] = best_row.get(f"weight_{short_name}")

saved_submission_df = pd.DataFrame([saved_submission_record])
display(saved_submission_df)
saved_submission_df.to_csv(OUTDIR / "saved_submission_candidates.csv", index=False)
# Out:
# Best safe blend:
# {
#   "set_name": "X_045_040_038",
#   "method": "hc_nonnegative_raw",
#   "keys": "045_gpu_logreg_add044,040_gpu_logreg_add039,038_gpu_logreg_add037",
#   "n_models": 3,
#   "balanced_accuracy": 0.9702533348410616,
#   "weights_json": "{\"045_gpu_logreg_add044\": 0.5144616346780971, \"040_gpu_logreg_add039\": 0.2949869322672667, \"038_gpu_logreg_add037\": 0.19055143305463623}",
#   "includes_045": true,
#   "weight_045": 0.5144616346780971,
#   "includes_044": false,
#   "weight_044": NaN,
#   "includes_042": false,
#   "weight_042": NaN,
#   "includes_040": true,
#   "weight_040": 0.2949869322672667,
#   "includes_039": false,
#   "weight_039": NaN,
#   "includes_038": true,
#   "weight_038": 0.19055143305463623,
#   "includes_037": false,
#   "weight_037": NaN,
#   "includes_036_gpu": false,
#   "weight_036_gpu": NaN,
#   "includes_036_blend": false,
#   "weight_036_blend": NaN,
#   "includes_035": false,
#   "weight_035": NaN,
#   "includes_034": false,
#   "weight_034": NaN,
#   "includes_033": false,
#   "weight_033": NaN,
#   "includes_032": false,
#   "weight_032": NaN,
#   "includes_031": false,
#   "weight_031": NaN,
#   "includes_030": false,
#   "weight_030": NaN,
#   "includes_029": false,
#   "weight_029": NaN,
#   "includes_028": false,
#   "weight_028": NaN,
#   "recall_GALAXY": 0.9595554731376497,
#   "recall_QSO": 0.9772671008937794,
#   "recall_STAR": 0.9739374304917557,
#   "hc_score_internal": 0.9702533348410616,
#   "hc_n_steps": 9.0,
#   "nm_score_internal": NaN,
#   "nm_success": NaN,
#   "nm_message": NaN,
#   "C": NaN,
#   "risk": NaN,
#   "alpha": NaN,
#   "l1_ratio": NaN
# }
# best_oof_score: 0.9702533348410616
#         set_name              method        cv  \
# 0  X_045_040_038  hc_nonnegative_raw  0.970253
#
#                                                 keys  \
# 0  045_gpu_logreg_add044,040_gpu_logreg_add039,03...
#
#                                         weights_json  \
# 0  {"045_gpu_logreg_add044": 0.5144616346780971, ...
#
#                                           submission  \
# 0  submission_exp_20260612_046_blend_add042_044_0...
#
#                                            oof_proba  \
# 0  oof_exp_20260612_046_blend_add042_044_045_chec...
#
#                                           pred_proba  includes_045  \
# 0  pred_exp_20260612_046_blend_add042_044_045_che...          True
#
#    weight_045  ...  includes_032  weight_032  includes_031  weight_031  \
# 0    0.514462  ...         False         NaN         False         NaN
#
#    includes_030  weight_030  includes_029  weight_029  includes_028  \
# 0         False         NaN         False         NaN         False
#
#    weight_028
# 0         NaN
#
# [1 rows x 42 columns]

# %%
# ============================================================
# 6. Save summary / memo
# ============================================================

reference_scores = {
    "045_gpu_logreg_add044_cv": 0.9702445493383917,
    "045_gpu_logreg_add044_public_lb": 0.97040,
    "044_shared001_updated_variant_cv": 0.9686035095582338,
    "044_shared001_updated_variant_public_lb": 0.97000,
    "043_gpu_logreg_add042_cv": 0.9701820598346598,
    "043_gpu_logreg_add042_public_lb": 0.97034,
    "042_realmlp_v5_variant_cv": 0.9689482884928097,
    "042_realmlp_v5_variant_public_lb": 0.96943,
    "041_blend_add039_gpu040_cv": 0.9702371689099357,
    "041_blend_add039_gpu040_public_lb": 0.97050,
    "040_gpu_logreg_add039_cv": 0.9702017877238539,
    "040_gpu_logreg_add039_public_lb": 0.97069,
    "038_gpu_logreg_add037_cv": 0.9701353365798572,
    "038_gpu_logreg_add037_public_lb": 0.97060,
    "033_cv": 0.9700400336552478,
    "033_public_lb": 0.97043,
    "036_gpu_logreg_add035_cv": 0.9700674063284508,
    "036_gpu_logreg_add035_public_lb": 0.97037,
    "036_blend_add035_cv": 0.9700727843277738,
    "036_blend_add035_public_lb": 0.97023,
    "039_cat_v3_variant_cv": 0.9687053023092482,
    "039_cat_v3_variant_public_lb": 0.96984,
    "028_cat_v3_cv": 0.9688146470512534,
    "028_cat_v3_public_lb": 0.96969,
    "037_cv": 0.9580770153777599,
    "037_public_lb": 0.95920,
}

best_focus_safe = {}
for short_name, df in focus_blend_tables.items():
    best_focus_safe[short_name] = None if len(df) == 0 else df.iloc[0].to_dict()

judgement = {
    "reference_scores": reference_scores,
    "individual_best": {
        "key": individual_df.iloc[0]["key"],
        "cv": float(individual_df.iloc[0]["recomputed_oof_cv"]),
        "public_lb": float(individual_df.iloc[0]["public_lb"]),
    },
    "best_safe_blend": best_info,
    "best_focus_safe": best_focus_safe,
    "main_questions": {
        "does_045_help_probability_blend": "Check focus_045 safe blends and weight_045.",
        "does_044_help_probability_blend": "Check focus_044 safe blends and weight_044.",
        "does_042_help_probability_blend": "Check focus_042 safe blends and weight_042.",
        "can_040_or_045_be_improved_by_simple_blend": "Check focus_040/focus_045 safe blends versus 040 and 045 references.",
        "does_033_still_work_as_diversity_backup": "Check 040+033 and broader sets containing 033.",
        "should_promote_046_best_blend": "Only if best safe blend improves CV and Public LB over 040 without being only an in-sample meta artifact.",
    },
    "automatic_view": {
        "best_safe_includes_045": bool(best_info.get("includes_045")),
        "best_safe_weight_045": best_info.get("weight_045"),
        "best_safe_includes_044": bool(best_info.get("includes_044")),
        "best_safe_weight_044": best_info.get("weight_044"),
        "best_safe_includes_042": bool(best_info.get("includes_042")),
        "best_safe_weight_042": best_info.get("weight_042"),
        "best_safe_includes_040": bool(best_info.get("includes_040")),
        "best_safe_weight_040": best_info.get("weight_040"),
        "best_safe_includes_039": bool(best_info.get("includes_039")),
        "best_safe_weight_039": best_info.get("weight_039"),
        "best_safe_includes_033": bool(best_info.get("includes_033")),
        "best_safe_weight_033": best_info.get("weight_033"),
        "best_safe_cv": float(best_info["cv_score"]),
        "040_reference_cv": reference_scores["040_gpu_logreg_add039_cv"],
        "040_reference_public_lb": reference_scores["040_gpu_logreg_add039_public_lb"],
        "045_reference_cv": reference_scores["045_gpu_logreg_add044_cv"],
        "045_reference_public_lb": reference_scores["045_gpu_logreg_add044_public_lb"],
        "promotion_rule": (
            "Promote 046 only if the best safe probability blend beats 040 on CV and also confirms on Public LB. "
            "Do not promote in-sample LogReg/Ridge/ElasticNet diagnostic rows."
        ),
    },
}
save_json(judgement, OUTDIR / "role_judgement.json")

summary = {
    "competition": COMPETITION,
    "exp_id": EXP_ID,
    "status": "completed",
    "purpose": "Blend/correlation check after adding 042, 044, and 045 to the 041 candidate pool",
    "npy_dir": str(NPY_DIR),
    "model_keys": model_keys,
    "class_names": class_names,
    "resolved_specs": resolved_specs,
    "individual_scores": individual_df.to_dict(orient="records"),
    "pairwise_oof_correlation": pairwise_df.to_dict(orient="records"),
    "pairwise_oof_correlation_focus": {k: v.to_dict(orient="records") for k, v in focus_pairwise_tables.items()},
    "blend_diagnostics": blend_df.to_dict(orient="records"),
    "safe_blend_diagnostics": safe_blend_df.to_dict(orient="records"),
    "safe_blend_diagnostics_focus": {k: v.to_dict(orient="records") for k, v in focus_blend_tables.items()},
    "best_blend_info": best_info,
    "saved_submission_candidates": saved_submission_df.to_dict(orient="records"),
    "role_judgement": judgement,
}
summary_path = OUTDIR / "blend_add042_044_045_summary.json"
save_json(summary, summary_path)

memo = {
    "experiment": {
        "id": EXP_ID,
        "title": "Blend check after adding 042/044/045 to 041 pool",
        "competition": COMPETITION,
        "status": "completed",
        "metric": "balanced_accuracy_score",
        "created_at": "2026-06-12",
    },
    "objective": {
        "summary": (
            "Load OOF/pred probabilities from npy-files, add 042 RealMLP v5 variant, 044 shared001 updated variant, and 045 GPU LogReg stacker, "
            "and decide whether a direct probability blend can improve over the current 040 best."
        ),
        "success_criteria": [
            "load existing OOF/pred npy files including 038/039/040/042/044/045",
            "recompute individual balanced accuracy",
            "compute pairwise OOF correlations with focus tables for 040/039/038/033",
            "evaluate add042/add044/add045 blend sets",
            "separate safe blends from in-sample meta screening",
            "save best safe blend OOF/pred npy",
            "save best safe blend submission",
        ],
    },
    "inputs": {"npy_dir": str(NPY_DIR), "models": resolved_specs, "blend_sets": BLEND_SETS},
    "outputs": {
        "individual_scores": "individual_scores.csv",
        "pairwise_oof_correlation": "pairwise_oof_correlation.csv",
        "pairwise_oof_correlation_focus_prefix": "pairwise_oof_correlation_focus_*.csv",
        "blend_diagnostics": "blend_diagnostics.csv",
        "safe_blend_diagnostics": "safe_blend_diagnostics.csv",
        "safe_blend_diagnostics_focus_prefix": "safe_blend_diagnostics_focus_*.csv",
        "best_blend_info": "best_blend_info.json",
        "best_oof_proba": best_oof_npy.name,
        "best_pred_proba": best_pred_npy.name,
        "best_submission": best_submission_path.name,
        "summary": summary_path.name,
    },
    "judgement": {
        "status": "completed_pending_manual_review",
        "initial_view": (
            "040 is current best. 041 should only replace it if safe probability blend improves CV and Public LB. "
            "039 may help as direct blend material or only through GPU LogReg stacker."
        ),
        "automatic_view": judgement["automatic_view"],
        "next_action": [
            "Review individual_scores.csv and confirm 040 recomputed OOF CV",
            "Review pairwise_oof_correlation_focus_045.csv, focus_044.csv, focus_042.csv, focus_040.csv",
            "Review safe_blend_diagnostics_focus_045.csv, focus_044.csv, focus_042.csv, focus_040.csv",
            "Submit only best safe blend, not in-sample meta rows",
            "Keep 040 as slot_1 unless 046 best safe blend confirms on Public LB",
        ],
    },
}

memo_path = OUTDIR / "memo.yml"
if yaml is not None:
    with open(memo_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(memo, f, allow_unicode=True, sort_keys=False)
else:
    with open(memo_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(memo, indent=2, ensure_ascii=False, default=str))

print("Saved files:")
for p in sorted(OUTDIR.glob("*")):
    print(" -", p.name)
# Out:
# Saved files:
#  - best_blend_info.json
#  - blend_add042_044_045_summary.json
#  - blend_diagnostics.csv
#  - individual_scores.csv
#  - memo.yml
#  - oof_exp_20260612_046_blend_add042_044_045_check_best_blend_proba.npy
#  - pairwise_oof_correlation.csv
#  - pairwise_oof_correlation_focus_028.csv
#  - pairwise_oof_correlation_focus_031.csv
#  - pairwise_oof_correlation_focus_033.csv
#  - pairwise_oof_correlation_focus_036_blend.csv
#  - pairwise_oof_correlation_focus_036_gpu.csv
#  - pairwise_oof_correlation_focus_037.csv
#  - pairwise_oof_correlation_focus_038.csv
#  - pairwise_oof_correlation_focus_039.csv
#  - pairwise_oof_correlation_focus_040.csv
#  - pairwise_oof_correlation_focus_042.csv
#  - pairwise_oof_correlation_focus_044.csv
#  - pairwise_oof_correlation_focus_045.csv
#  - pred_exp_20260612_046_blend_add042_044_045_check_best_blend_proba.npy
#  - role_judgement.json
#  - safe_blend_diagnostics.csv
#  - safe_blend_diagnostics_focus_028.csv
#  - safe_blend_diagnostics_focus_029.csv
#  - safe_blend_diagnostics_focus_030.csv
#  - safe_blend_diagnostics_focus_031.csv
#  - safe_blend_diagnostics_focus_032.csv
#  - safe_blend_diagnostics_focus_033.csv
#  - safe_blend_diagnostics_focus_034.csv
#  - safe_blend_diagnostics_focus_035.csv
#  - safe_blend_diagnostics_focus_036_blend.csv
#  - safe_blend_diagnostics_focus_036_gpu.csv
#  - safe_blend_diagnostics_focus_037.csv
#  - safe_blend_diagnostics_focus_038.csv
#  - safe_blend_diagnostics_focus_039.csv
#  - safe_blend_diagnostics_focus_040.csv
#  - safe_blend_diagnostics_focus_042.csv
#  - safe_blend_diagnostics_focus_044.csv
#  - safe_blend_diagnostics_focus_045.csv
#  - saved_submission_candidates.csv
#  - submission_exp_20260612_046_blend_add042_044_045_check_best_blend.csv
