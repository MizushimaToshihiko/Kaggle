# %% [markdown]
# # PS S6E6 - 020 Bias search on 019 best blend
#
# Experiment: `exp_20260607_020_bias_search_on_019_best_blend`
#
# Purpose:
# - Load 019 best blend OOF/test probabilities from `/kaggle/input/datasets/mizushimatoshihiko/npy-files`.
# - Run class-wise bias search on OOF to maximize `balanced_accuracy_score`.
# - Apply the best bias to both OOF and test predictions.
# - Save blend-ready adjusted OOF/test `.npy` files with the full `exp_*` id in filenames.
#
# Base:
# - `exp_20260607_019_blend_add018_xgb_check`
# - best blend: `F_014_017_018 / hc_nonnegative_raw`
# - CV: `0.968872315017554`
# - Public LB: `0.97000`
# - weights:
#   - `014_blend_bias`: `0.19335207956110856`
#   - `017_realmlp_bias`: `0.5031124737181557`
#   - `018_xgb_shared003`: `0.3035354467207357`
#
# This is an attack/postprocess candidate. Keep 017 and 015 as backups.

# %%
# ============================================================
# 0. Imports / Config
# ============================================================

import os
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

warnings.filterwarnings("ignore")

try:
    import yaml
except Exception:
    yaml = None

COMPETITION = "PS S6E6 Predicting Stellar Class"
EXP_ID = "exp_20260607_020_bias_search_on_019_best_blend"
SEED = 42

TRAIN_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/train.csv")
TEST_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/test.csv")
SAMPLE_SUB_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/sample_submission.csv")
NPY_DIR = Path("/kaggle/input/datasets/mizushimatoshihiko/npy-files")

WORKDIR = Path("/kaggle/working")
OUTDIR = WORKDIR / EXP_ID
OUTDIR.mkdir(parents=True, exist_ok=True)

ID_COL = "id"
TARGET_COL = "class"

REF_019_EXP_ID = "exp_20260607_019_blend_add018_xgb_check"
REF_019_MODEL = "F_014_017_018 / hc_nonnegative_raw"
REF_019_CV = 0.968872315017554
REF_019_PUBLIC_LB = 0.97000
REF_019_WEIGHTS = {
    "014_blend_bias": 0.19335207956110856,
    "017_realmlp_bias": 0.5031124737181557,
    "018_xgb_shared003": 0.3035354467207357,
}

OOF_019_FILENAME = "oof_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy"
PRED_019_FILENAME = "pred_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy"

OOF_019_PATH = NPY_DIR / OOF_019_FILENAME
PRED_019_PATH = NPY_DIR / PRED_019_FILENAME

OOF_BIASED_NPY = OUTDIR / "oof_exp_20260607_020_bias_search_on_019_best_blend_proba.npy"
PRED_BIASED_NPY = OUTDIR / "pred_exp_20260607_020_bias_search_on_019_best_blend_proba.npy"

print("EXP_ID:", EXP_ID)
print("OUTDIR:", OUTDIR)
print("NPY_DIR:", NPY_DIR)
print("OOF_019_PATH:", OOF_019_PATH)
print("PRED_019_PATH:", PRED_019_PATH)
# Out:
# EXP_ID: exp_20260607_020_bias_search_on_019_best_blend
# OUTDIR: /kaggle/working/exp_20260607_020_bias_search_on_019_best_blend
# NPY_DIR: /kaggle/input/datasets/mizushimatoshihiko/npy-files
# OOF_019_PATH: /kaggle/input/datasets/mizushimatoshihiko/npy-files/oof_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy
# PRED_019_PATH: /kaggle/input/datasets/mizushimatoshihiko/npy-files/pred_exp_20260607_019_blend_add018_xgb_check_best_blend_proba.npy

# %%
# ============================================================
# 1. Utilities
# ============================================================

def save_json(obj, path: Path) -> None:
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False, default=str)


def proba_to_logp(proba: np.ndarray, eps: float = 1e-15) -> np.ndarray:
    return np.log(np.clip(proba, eps, 1.0))


def softmax_np(x: np.ndarray, axis: int = 1) -> np.ndarray:
    x = x - np.max(x, axis=axis, keepdims=True)
    ex = np.exp(x)
    return ex / np.sum(ex, axis=axis, keepdims=True)


def apply_bias_to_proba(proba: np.ndarray, bias: np.ndarray) -> np.ndarray:
    logp = proba_to_logp(proba)
    return softmax_np(logp + bias.reshape(1, -1), axis=1)


def predict_with_bias(logp: np.ndarray, bias: np.ndarray) -> np.ndarray:
    return np.argmax(logp + bias.reshape(1, -1), axis=1)


def class_recalls(y_true: np.ndarray, y_pred: np.ndarray, class_names: list[str]) -> dict:
    out = {}
    for i, cls in enumerate(class_names):
        mask = y_true == i
        out[f"recall_{cls}"] = float((y_pred[mask] == i).mean()) if mask.any() else float("nan")
    return out


def eval_pred(y_true: np.ndarray, y_pred: np.ndarray, class_names: list[str]) -> dict:
    res = {"balanced_accuracy": float(balanced_accuracy_score(y_true, y_pred))}
    res.update(class_recalls(y_true, y_pred, class_names))
    return res


def validate_proba(name: str, arr: np.ndarray, n_rows: int, n_classes: int) -> None:
    assert arr.shape == (n_rows, n_classes), (name, arr.shape, n_rows, n_classes)
    assert np.isfinite(arr).all(), name
    row_sum = arr.sum(axis=1)
    assert np.allclose(row_sum, 1.0, atol=1e-4), (name, row_sum.min(), row_sum.max())
    assert arr.min() >= -1e-7, (name, arr.min())
    assert arr.max() <= 1.0 + 1e-7, (name, arr.max())

# %%
# ============================================================
# 2. Load train/test/sample and 019 best blend predictions
# ============================================================

for p in [TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH, NPY_DIR, OOF_019_PATH, PRED_019_PATH]:
    if not p.exists():
        raise FileNotFoundError(p)

train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_SUB_PATH)

le = LabelEncoder()
y = le.fit_transform(train[TARGET_COL].astype(str))
class_names = le.classes_.tolist()
n_classes = len(class_names)

assert class_names == ["GALAXY", "QSO", "STAR"], class_names

oof_proba_raw = np.load(OOF_019_PATH).astype(np.float32)
test_proba_raw = np.load(PRED_019_PATH).astype(np.float32)

validate_proba("oof_proba_raw", oof_proba_raw, len(train), n_classes)
validate_proba("test_proba_raw", test_proba_raw, len(test), n_classes)

oof_logp = proba_to_logp(oof_proba_raw)
test_logp = proba_to_logp(test_proba_raw)

print("train:", train.shape)
print("test:", test.shape)
print("class_names:", class_names)
print("oof_proba_raw:", oof_proba_raw.shape)
print("test_proba_raw:", test_proba_raw.shape)
# Out:
# train: (577347, 12)
# test: (247435, 11)
# class_names: ['GALAXY', 'QSO', 'STAR']
# oof_proba_raw: (577347, 3)
# test_proba_raw: (247435, 3)

# %%
# ============================================================
# 3. Raw 019 best blend confirmation
# ============================================================

raw_bias = np.zeros(n_classes, dtype=np.float64)
raw_pred = predict_with_bias(oof_logp, raw_bias)
raw_eval = eval_pred(y, raw_pred, class_names)

print("Raw 019 best blend:")
print(json.dumps(raw_eval, indent=2, ensure_ascii=False))
print("delta vs REF_019_CV:", raw_eval["balanced_accuracy"] - REF_019_CV)
print(confusion_matrix(y, raw_pred))
print(classification_report(y, raw_pred, target_names=class_names))
# Out:
# Raw 019 best blend:
# {
#   "balanced_accuracy": 0.968872315017554,
#   "recall_GALAXY": 0.9654789657730211,
#   "recall_QSO": 0.9744414945835432,
#   "recall_STAR": 0.9666964846960978
# }
# delta vs REF_019_CV: 0.0
# [[364449   4751   8280]
#  [  1943 114149   1051]
#  [  2355    400  79969]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.97      0.98    377480
#          QSO       0.96      0.97      0.97    117143
#         STAR       0.90      0.97      0.93     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.95      0.97      0.96    577347
# weighted avg       0.97      0.97      0.97    577347

# %%
# ============================================================
# 4. Bias search
# ============================================================

def grid_search_bias_2d(logp, y_true, qso_values, star_values, stage_name):
    rows = []
    best_score = -1.0
    best_bias = None

    for bq in qso_values:
        for bs in star_values:
            bias = np.array([0.0, float(bq), float(bs)], dtype=np.float64)
            pred = predict_with_bias(logp, bias)
            score = float(balanced_accuracy_score(y_true, pred))

            rows.append({
                "stage": stage_name,
                "bias_GALAXY": 0.0,
                "bias_QSO": float(bq),
                "bias_STAR": float(bs),
                "balanced_accuracy": score,
            })

            if score > best_score:
                best_score = score
                best_bias = bias.copy()

        print(f"{stage_name}: bq={bq:.6f}, best={best_score:.9f}, bias={best_bias}")

    return {"score": best_score, "bias": best_bias}, pd.DataFrame(rows)


coarse_qso = np.round(np.arange(-0.200, 0.200 + 1e-12, 0.010), 6)
coarse_star = np.round(np.arange(-0.200, 0.200 + 1e-12, 0.010), 6)
best_coarse, coarse_df = grid_search_bias_2d(oof_logp, y, coarse_qso, coarse_star, "coarse")

cq, cs = best_coarse["bias"][1], best_coarse["bias"][2]
local_qso = np.round(np.arange(cq - 0.020, cq + 0.020 + 1e-12, 0.002), 6)
local_star = np.round(np.arange(cs - 0.020, cs + 0.020 + 1e-12, 0.002), 6)
best_local, local_df = grid_search_bias_2d(oof_logp, y, local_qso, local_star, "local")

uq, us = best_local["bias"][1], best_local["bias"][2]
ultra_qso = np.round(np.arange(uq - 0.004, uq + 0.004 + 1e-12, 0.0005), 6)
ultra_star = np.round(np.arange(us - 0.004, us + 0.004 + 1e-12, 0.0005), 6)
best_ultra, ultra_df = grid_search_bias_2d(oof_logp, y, ultra_qso, ultra_star, "ultra_local")

search_df = pd.concat([coarse_df, local_df, ultra_df], ignore_index=True)
search_df = search_df.sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)

best_bias = best_ultra["bias"]
best_score = best_ultra["score"]

display(search_df.head(30))
print("raw_score:", raw_eval["balanced_accuracy"])
print("best_score:", best_score)
print("delta_vs_raw:", best_score - raw_eval["balanced_accuracy"])
print("best_bias:", best_bias)
# Out:
# coarse: bq=-0.200000, best=0.968672024, bias=[ 0.  -0.2  0.2]
# coarse: bq=-0.190000, best=0.968694542, bias=[ 0.   -0.19  0.12]
# coarse: bq=-0.180000, best=0.968708960, bias=[ 0.   -0.18  0.12]
# coarse: bq=-0.170000, best=0.968726610, bias=[ 0.   -0.17  0.12]
# coarse: bq=-0.160000, best=0.968727579, bias=[ 0.   -0.16  0.12]
# coarse: bq=-0.150000, best=0.968747994, bias=[ 0.   -0.15  0.2 ]
# coarse: bq=-0.140000, best=0.968755734, bias=[ 0.   -0.14  0.2 ]
# coarse: bq=-0.130000, best=0.968786532, bias=[ 0.   -0.13  0.2 ]
# coarse: bq=-0.120000, best=0.968800257, bias=[ 0.   -0.12  0.2 ]
# coarse: bq=-0.110000, best=0.968815447, bias=[ 0.   -0.11  0.2 ]
# coarse: bq=-0.100000, best=0.968827019, bias=[ 0.  -0.1  0.2]
# coarse: bq=-0.090000, best=0.968841530, bias=[ 0.   -0.09  0.2 ]
# coarse: bq=-0.080000, best=0.968842499, bias=[ 0.   -0.08  0.2 ]
# coarse: bq=-0.070000, best=0.968842499, bias=[ 0.   -0.08  0.2 ]
# coarse: bq=-0.060000, best=0.968842499, bias=[ 0.   -0.08  0.2 ]
# coarse: bq=-0.050000, best=0.968846257, bias=[ 0.   -0.05  0.2 ]
# coarse: bq=-0.040000, best=0.968846324, bias=[ 0.   -0.04  0.2 ]
# coarse: bq=-0.030000, best=0.968866224, bias=[ 0.   -0.03  0.2 ]
# coarse: bq=-0.020000, best=0.968876613, bias=[ 0.   -0.02  0.2 ]
# coarse: bq=-0.010000, best=0.968884850, bias=[ 0.   -0.01  0.2 ]
# coarse: bq=0.000000, best=0.968936064, bias=[0.  0.  0.2]
# coarse: bq=0.010000, best=0.968955467, bias=[0.   0.01 0.2 ]
# coarse: bq=0.020000, best=0.968959374, bias=[0.   0.02 0.2 ]
# coarse: bq=0.030000, best=0.968959374, bias=[0.   0.02 0.2 ]
# coarse: bq=0.040000, best=0.968966016, bias=[0.   0.04 0.2 ]
# coarse: bq=0.050000, best=0.968986498, bias=[0.   0.05 0.2 ]
# coarse: bq=0.060000, best=0.968986498, bias=[0.   0.05 0.2 ]
# coarse: bq=0.070000, best=0.968988914, bias=[0.   0.07 0.2 ]
# coarse: bq=0.080000, best=0.968992918, bias=[0.   0.08 0.2 ]
# coarse: bq=0.090000, best=0.969010476, bias=[0.   0.09 0.2 ]
# coarse: bq=0.100000, best=0.969029984, bias=[0.  0.1 0.2]
# coarse: bq=0.110000, best=0.969029984, bias=[0.  0.1 0.2]
# coarse: bq=0.120000, best=0.969038183, bias=[0.   0.12 0.2 ]
# coarse: bq=0.130000, best=0.969040451, bias=[0.   0.13 0.13]
# coarse: bq=0.140000, best=0.969072979, bias=[0.   0.14 0.2 ]
# coarse: bq=0.150000, best=0.969084840, bias=[0.   0.15 0.2 ]
# coarse: bq=0.160000, best=0.969104452, bias=[0.   0.16 0.2 ]
# coarse: bq=0.170000, best=0.969104452, bias=[0.   0.16 0.2 ]
# coarse: bq=0.180000, best=0.969111284, bias=[0.   0.18 0.2 ]
# coarse: bq=0.190000, best=0.969127167, bias=[0.   0.19 0.2 ]
# coarse: bq=0.200000, best=0.969130283, bias=[0.  0.2 0.2]
# local: bq=0.180000, best=0.969174358, bias=[0.    0.18  0.216]
# local: bq=0.182000, best=0.969174358, bias=[0.    0.18  0.216]
# local: bq=0.184000, best=0.969178656, bias=[0.    0.184 0.216]
# local: bq=0.186000, best=0.969178656, bias=[0.    0.184 0.216]
# local: bq=0.188000, best=0.969180907, bias=[0.    0.188 0.216]
# local: bq=0.190000, best=0.969185028, bias=[0.    0.19  0.216]
# local: bq=0.192000, best=0.969185028, bias=[0.    0.19  0.216]
# local: bq=0.194000, best=0.969185028, bias=[0.    0.19  0.216]
# local: bq=0.196000, best=0.969185028, bias=[0.    0.19  0.216]
# local: bq=0.198000, best=0.969193265, bias=[0.    0.198 0.216]
# local: bq=0.200000, best=0.969193265, bias=[0.    0.198 0.216]
# local: bq=0.202000, best=0.969198466, bias=[0.    0.202 0.216]
# local: bq=0.204000, best=0.969198466, bias=[0.    0.202 0.216]
# local: bq=0.206000, best=0.969200612, bias=[0.    0.206 0.216]
# local: bq=0.208000, best=0.969205014, bias=[0.    0.208 0.216]
# local: bq=0.210000, best=0.969207952, bias=[0.    0.21  0.216]
# local: bq=0.212000, best=0.969210994, bias=[0.    0.212 0.216]
# local: bq=0.214000, best=0.969214232, bias=[0.    0.214 0.216]
# local: bq=0.216000, best=0.969221094, bias=[0.    0.216 0.216]
# local: bq=0.218000, best=0.969221094, bias=[0.    0.216 0.216]
# local: bq=0.220000, best=0.969221094, bias=[0.    0.216 0.216]
# ultra_local: bq=0.212000, best=0.969210994, bias=[0.    0.212 0.216]
# ultra_local: bq=0.212500, best=0.969210994, bias=[0.    0.212 0.216]
# ultra_local: bq=0.213000, best=0.969212243, bias=[0.    0.213 0.214]
# ultra_local: bq=0.213500, best=0.969212243, bias=[0.    0.213 0.214]
# ultra_local: bq=0.214000, best=0.969215396, bias=[0.    0.214 0.215]
# ultra_local: bq=0.214500, best=0.969216973, bias=[0.     0.2145 0.2155]
# ultra_local: bq=0.215000, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.215500, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.216000, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.216500, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.217000, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.217500, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.218000, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.218500, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.219000, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.219500, best=0.969224044, bias=[0.    0.215 0.216]
# ultra_local: bq=0.220000, best=0.969224044, bias=[0.    0.215 0.216]
#           stage  bias_GALAXY  bias_QSO  bias_STAR  balanced_accuracy
# 0   ultra_local          0.0    0.2150     0.2160           0.969224
# 1   ultra_local          0.0    0.2165     0.2160           0.969223
# 2   ultra_local          0.0    0.2155     0.2160           0.969222
# 3         local          0.0    0.2160     0.2160           0.969221
# 4   ultra_local          0.0    0.2160     0.2160           0.969221
# 5   ultra_local          0.0    0.2170     0.2160           0.969220
# 6   ultra_local          0.0    0.2165     0.2155           0.969220
# 7   ultra_local          0.0    0.2150     0.2155           0.969220
# 8   ultra_local          0.0    0.2155     0.2155           0.969219
# 9   ultra_local          0.0    0.2165     0.2175           0.969219
# 10  ultra_local          0.0    0.2150     0.2150           0.969218
# 11  ultra_local          0.0    0.2150     0.2140           0.969218
# 12  ultra_local          0.0    0.2160     0.2155           0.969218
# 13  ultra_local          0.0    0.2155     0.2165           0.969218
# 14  ultra_local          0.0    0.2165     0.2165           0.969218
# 15  ultra_local          0.0    0.2155     0.2150           0.969217
# 16  ultra_local          0.0    0.2145     0.2155           0.969217
# 17  ultra_local          0.0    0.2150     0.2145           0.969217
# 18  ultra_local          0.0    0.2160     0.2150           0.969217
# 19  ultra_local          0.0    0.2180     0.2160           0.969216
# 20  ultra_local          0.0    0.2175     0.2160           0.969216
# 21        local          0.0    0.2180     0.2160           0.969216
# 22  ultra_local          0.0    0.2155     0.2145           0.969216
# 23  ultra_local          0.0    0.2165     0.2170           0.969216
# 24  ultra_local          0.0    0.2160     0.2165           0.969216
# 25  ultra_local          0.0    0.2170     0.2180           0.969216
# 26  ultra_local          0.0    0.2185     0.2160           0.969215
# 27  ultra_local          0.0    0.2140     0.2150           0.969215
# 28  ultra_local          0.0    0.2160     0.2170           0.969215
# 29  ultra_local          0.0    0.2175     0.2165           0.969215
# raw_score: 0.968872315017554
# best_score: 0.9692240443617589
# delta_vs_raw: 0.00035172934420490964
# best_bias: [0.    0.215 0.216]

# %%
# ============================================================
# 5. Build blend-ready biased OOF/test probabilities
# ============================================================

oof_proba_biased = apply_bias_to_proba(oof_proba_raw, best_bias).astype(np.float32)
test_proba_biased = apply_bias_to_proba(test_proba_raw, best_bias).astype(np.float32)

validate_proba("oof_proba_biased", oof_proba_biased, len(train), n_classes)
validate_proba("test_proba_biased", test_proba_biased, len(test), n_classes)

biased_oof_pred = oof_proba_biased.argmax(axis=1)
biased_eval = eval_pred(y, biased_oof_pred, class_names)

print("Biased 020:")
print(json.dumps(biased_eval, indent=2, ensure_ascii=False))
print("delta vs raw:", biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"])
print("delta vs REF_019_CV:", biased_eval["balanced_accuracy"] - REF_019_CV)
print(confusion_matrix(y, biased_oof_pred))
print(classification_report(y, biased_oof_pred, target_names=class_names))

compare_eval = pd.DataFrame([
    {"version": "raw_019_best_blend", **raw_eval},
    {"version": "biased_020", **biased_eval},
])
display(compare_eval)

print("OOF proba raw/biased diff abs mean:", float(np.mean(np.abs(oof_proba_biased - oof_proba_raw))))
print("TEST proba raw/biased diff abs mean:", float(np.mean(np.abs(test_proba_biased - test_proba_raw))))
# Out:
# Biased 020:
# {
#   "balanced_accuracy": 0.9692240443617589,
#   "recall_GALAXY": 0.9611370138815302,
#   "recall_QSO": 0.9762000290243549,
#   "recall_STAR": 0.9703350901793917
# }
# delta vs raw: 0.00035172934420490964
# delta vs REF_019_CV: 0.00035172934420490964
# [[362810   5223   9447]
#  [  1722 114355   1066]
#  [  2051    403  80270]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.98    377480
#          QSO       0.95      0.98      0.96    117143
#         STAR       0.88      0.97      0.93     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.94      0.97      0.95    577347
# weighted avg       0.97      0.97      0.97    577347
#               version  balanced_accuracy  recall_GALAXY  recall_QSO  \
# 0  raw_019_best_blend           0.968872       0.965479    0.974441
# 1          biased_020           0.969224       0.961137    0.976200
#
#    recall_STAR
# 0     0.966696
# 1     0.970335
# OOF proba raw/biased diff abs mean: 0.0033453989308327436
# TEST proba raw/biased diff abs mean: 0.0034072170965373516

# %%
# ============================================================
# 6. Biased submission
# ============================================================

biased_test_pred = test_proba_biased.argmax(axis=1)
biased_test_labels = le.inverse_transform(biased_test_pred)

submission = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    TARGET_COL: biased_test_labels,
})

assert submission.shape[0] == sample.shape[0]
assert submission.columns.tolist() == sample.columns.tolist()
assert submission[ID_COL].equals(sample[ID_COL])

print(submission[TARGET_COL].value_counts(normalize=True))
display(submission.head())

submission_path = OUTDIR / "submission_bias_search_on_019_best_blend.csv"
submission.to_csv(submission_path, index=False)
print("saved:", submission_path)
# Out:
# class
# GALAXY    0.635658
# QSO       0.207574
# STAR      0.156768
# Name: proportion, dtype: float64
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: /kaggle/working/exp_20260607_020_bias_search_on_019_best_blend/submission_bias_search_on_019_best_blend.csv

# %%
# ============================================================
# 7. Save artifacts
# ============================================================

np.save(OUTDIR / "bias_vector.npy", best_bias)

# Blend-ready .npy files with exp_* in filenames.
np.save(OOF_BIASED_NPY, oof_proba_biased)
np.save(PRED_BIASED_NPY, test_proba_biased)

# Optional raw copies with explicit exp name for audit.
np.save(OUTDIR / "oof_exp_20260607_020_bias_search_on_019_best_blend_raw019_best_blend_proba.npy", oof_proba_raw)
np.save(OUTDIR / "pred_exp_20260607_020_bias_search_on_019_best_blend_raw019_best_blend_proba.npy", test_proba_raw)

oof_df = pd.DataFrame({
    ID_COL: train[ID_COL].values,
    "y_true": train[TARGET_COL].astype(str).values,
    "raw_pred": le.inverse_transform(raw_pred),
    "biased_pred": le.inverse_transform(biased_oof_pred),
})
for i, cls in enumerate(class_names):
    oof_df[f"raw_proba_{cls}"] = oof_proba_raw[:, i]
    oof_df[f"biased_proba_{cls}"] = oof_proba_biased[:, i]
    oof_df[f"logp_{cls}"] = oof_logp[:, i]
oof_df.to_csv(OUTDIR / "oof_bias_search_on_019_best_blend.csv", index=False)

pred_df = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    "biased_pred_label": biased_test_labels,
})
for i, cls in enumerate(class_names):
    pred_df[f"raw_proba_{cls}"] = test_proba_raw[:, i]
    pred_df[f"biased_proba_{cls}"] = test_proba_biased[:, i]
    pred_df[f"logp_{cls}"] = test_logp[:, i]
pred_df.to_csv(OUTDIR / "pred_bias_search_on_019_best_blend.csv", index=False)

search_df.to_csv(OUTDIR / "bias_search_results.csv", index=False)
compare_eval.to_csv(OUTDIR / "raw_vs_biased_oof_eval.csv", index=False)

cv_result = {
    "competition": COMPETITION,
    "exp_id": EXP_ID,
    "model": "019 best blend postprocess",
    "status": "completed",
    "metric": "balanced_accuracy_score",
    "reference_exp_id": REF_019_EXP_ID,
    "reference_model": REF_019_MODEL,
    "reference_weights": REF_019_WEIGHTS,
    "raw_cv_score": float(raw_eval["balanced_accuracy"]),
    "biased_cv_score": float(biased_eval["balanced_accuracy"]),
    "delta_biased_minus_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
    "reference_019_public_lb": REF_019_PUBLIC_LB,
    "class_names": class_names,
    "label_mapping": {str(cls): int(i) for i, cls in enumerate(class_names)},
    "bias": {
        "GALAXY": float(best_bias[0]),
        "QSO": float(best_bias[1]),
        "STAR": float(best_bias[2]),
    },
    "raw_eval": raw_eval,
    "biased_eval": biased_eval,
    "use_original": False,
    "use_fe": True,
    "use_bias_search": True,
    "adjusted_probability_method": "softmax(log(raw_proba) + class_bias)",
    "search_ranges": {
        "coarse": {"min": -0.20, "max": 0.20, "step": 0.01},
        "local": {"around_best": 0.02, "step": 0.002},
        "ultra_local": {"around_best": 0.004, "step": 0.0005},
    },
    "submission_path": str(submission_path),
    "oof_path": str(OOF_BIASED_NPY),
    "pred_path": str(PRED_BIASED_NPY),
    "raw_019_oof_path": str(OOF_019_PATH),
    "raw_019_pred_path": str(PRED_019_PATH),
}
save_json(cv_result, OUTDIR / "cv_result.json")

print("Artifacts saved to:", OUTDIR)
for p in sorted(OUTDIR.glob("*")):
    print(" -", p.name)
# Out:
# Artifacts saved to: /kaggle/working/exp_20260607_020_bias_search_on_019_best_blend
#  - bias_search_results.csv
#  - bias_vector.npy
#  - cv_result.json
#  - oof_bias_search_on_019_best_blend.csv
#  - oof_exp_20260607_020_bias_search_on_019_best_blend_proba.npy
#  - oof_exp_20260607_020_bias_search_on_019_best_blend_raw019_best_blend_proba.npy
#  - pred_bias_search_on_019_best_blend.csv
#  - pred_exp_20260607_020_bias_search_on_019_best_blend_proba.npy
#  - pred_exp_20260607_020_bias_search_on_019_best_blend_raw019_best_blend_proba.npy
#  - raw_vs_biased_oof_eval.csv
#  - submission_bias_search_on_019_best_blend.csv

# %%
# ============================================================
# 8. Registry and memo
# ============================================================

registry_path = WORKDIR / "oof_registry.csv"

registry_row = {
    "exp_id": EXP_ID,
    "model_family": "Blend",
    "feature_family": "019_best_blend_postprocess",
    "cv_metric": "balanced_accuracy_score",
    "cv_score": float(biased_eval["balanced_accuracy"]),
    "raw_cv_score": float(raw_eval["balanced_accuracy"]),
    "cv_delta_vs_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
    "public_lb": np.nan,
    "use_original": False,
    "use_fe": True,
    "use_bias_search": True,
    "oof_path": str(OOF_BIASED_NPY),
    "pred_path": str(PRED_BIASED_NPY),
    "submission_path": str(submission_path),
    "role": "blend_bias_candidate",
    "status": "completed",
    "keep_hold_drop": "pending_public_lb",
    "notes": (
        "Class-wise bias search on 019 best blend. "
        "Input npy loaded from fixed npy-files dataset. "
        "Blend-ready adjusted OOF/pred proba saved with exp_* filenames. "
        "Keep 017 and 015 as backups due to postprocess/HC overfit risk."
    ),
}

if registry_path.exists():
    registry = pd.read_csv(registry_path)
    registry = registry[registry["exp_id"] != EXP_ID]
    registry = pd.concat([registry, pd.DataFrame([registry_row])], ignore_index=True)
else:
    registry = pd.DataFrame([registry_row])

registry.to_csv(registry_path, index=False)
registry.to_csv(OUTDIR / "oof_registry.csv", index=False)

memo = {
    "experiment": {
        "id": EXP_ID,
        "title": "Bias search on 019 best blend",
        "competition": COMPETITION,
        "status": "completed",
        "metric": "balanced_accuracy_score",
        "model": "019 best blend postprocess",
        "created_at": "2026-06-07",
    },
    "objective": {
        "summary": (
            "Apply class-wise bias search to 019 best blend OOF/test probabilities. "
            "Do not retrain. GALAXY bias is fixed to 0 and QSO/STAR biases are searched. "
            "Input npy files are read from /kaggle/input/datasets/mizushimatoshihiko/npy-files."
        ),
        "success_criteria": [
            "load 019 best blend OOF and test predictions from npy-files dataset",
            "confirm raw 019 best blend OOF score",
            "search class-wise bias on OOF",
            "save adjusted OOF proba as npy",
            "save adjusted test pred proba as npy",
            "save biased submission",
            "save bias vector and search results",
            "update oof_registry",
        ],
    },
    "data": {
        "train_path": str(TRAIN_PATH),
        "test_path": str(TEST_PATH),
        "sample_submission_path": str(SAMPLE_SUB_PATH),
        "target_col": TARGET_COL,
        "id_col": ID_COL,
        "npy_dir": str(NPY_DIR),
        "raw_019_oof_path": str(OOF_019_PATH),
        "raw_019_pred_path": str(PRED_019_PATH),
        "use_original": False,
    },
    "reference": {
        "exp_id": REF_019_EXP_ID,
        "model": REF_019_MODEL,
        "cv": REF_019_CV,
        "public_lb": REF_019_PUBLIC_LB,
        "weights": REF_019_WEIGHTS,
    },
    "bias_search": {
        "bias_space": {
            "GALAXY": "fixed_0",
            "QSO": "searched",
            "STAR": "searched",
        },
        "best_bias": {
            "GALAXY": float(best_bias[0]),
            "QSO": float(best_bias[1]),
            "STAR": float(best_bias[2]),
        },
        "raw_cv": float(raw_eval["balanced_accuracy"]),
        "biased_cv": float(biased_eval["balanced_accuracy"]),
        "delta_biased_minus_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
        "raw_eval": raw_eval,
        "biased_eval": biased_eval,
        "adjusted_probability_method": "softmax(log(raw_proba) + class_bias)",
    },
    "outputs": {
        "submission": "submission_bias_search_on_019_best_blend.csv",
        "bias_vector": "bias_vector.npy",
        "oof_proba": OOF_BIASED_NPY.name,
        "pred_proba": PRED_BIASED_NPY.name,
        "bias_search_results": "bias_search_results.csv",
        "raw_vs_biased_oof_eval": "raw_vs_biased_oof_eval.csv",
        "oof_csv": "oof_bias_search_on_019_best_blend.csv",
        "pred_csv": "pred_bias_search_on_019_best_blend.csv",
        "cv_result": "cv_result.json",
        "registry": "oof_registry.csv",
    },
    "judgement": {
        "status": "pending_public_lb",
        "reason": (
            "This is class-wise threshold tuning on the current best 019 HC blend. "
            "Adoption depends on whether Public LB improves over 019 best blend LB 0.97000. "
            "Even if it improves, 017 and 015 should remain backups."
        ),
        "next_action": [
            "Submit submission_bias_search_on_019_best_blend.csv",
            "Record Public LB",
            "If LB improves over 0.97000, promote 020 to current best attack candidate",
            "If LB drops, keep 019 as current best",
            "Keep 017 as previous best RealMLP bias backup",
            "Keep 015 as stable RealMLP single backup",
            "Add 020 OOF/pred to npy-files dataset if useful for final comparison",
        ],
    },
}

memo_path = OUTDIR / "memo.yml"
if yaml is not None:
    with open(memo_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(memo, f, allow_unicode=True, sort_keys=False)
else:
    with open(memo_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(memo, indent=2, ensure_ascii=False, default=str))

print("registry saved:", registry_path)
print("memo saved:", memo_path)
display(registry.tail())
# Out:
# registry saved: /kaggle/working/oof_registry.csv
# memo saved: /kaggle/working/exp_20260607_020_bias_search_on_019_best_blend/memo.yml
#                                            exp_id model_family  \
# 0  exp_20260607_020_bias_search_on_019_best_blend        Blend
#
#                feature_family                cv_metric  cv_score  \
# 0  019_best_blend_postprocess  balanced_accuracy_score  0.969224
#
#    raw_cv_score  cv_delta_vs_raw  public_lb  use_original  use_fe  \
# 0      0.968872         0.000352        NaN         False    True
#
#    use_bias_search                                           oof_path  \
# 0             True  /kaggle/working/exp_20260607_020_bias_search_o...
#
#                                            pred_path  \
# 0  /kaggle/working/exp_20260607_020_bias_search_o...
#
#                                      submission_path                  role  \
# 0  /kaggle/working/exp_20260607_020_bias_search_o...  blend_bias_candidate
#
#       status     keep_hold_drop  \
# 0  completed  pending_public_lb
#
#                                                notes
# 0  Class-wise bias search on 019 best blend. Inpu...
