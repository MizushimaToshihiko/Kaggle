# %% [markdown]
# # PS S6E6 - 003 CatBoost strict raw baseline
#
# Experiment: `exp_20260601_003_cat_strict_raw_baseline`
#
# Purpose:
# - Build the first strict raw CatBoost baseline.
# - Use only competition train/test.
# - Do not use original dataset.
# - Do not add feature engineering, color indices, original priors, snap features, or bias search.
# - Save OOF / test prediction / CV result / submission / memo / registry.
# - Compare later with 002 LightGBM and 004 XGBoost.
#
# Metric:
# - `balanced_accuracy_score`
#
# CV:
# - `StratifiedKFold(n_splits=5, shuffle=True, random_state=42)`
#
# CatBoost note:
# - `bootstrap_type`, `subsample`, and `border_count` are explicitly set to avoid CPU/GPU default ambiguity.

# %%
# ============================================================
# 0. Imports / Config
# ============================================================

import os
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

warnings.filterwarnings("ignore")

try:
    import yaml
except Exception:
    yaml = None

try:
    import catboost
    from catboost import CatBoostClassifier, Pool
except Exception as e:
    raise ImportError("CatBoost import failed. On Kaggle, catboost should be available by default.") from e


COMPETITION = "PS S6E6 Predicting Stellar Class"
EXP_ID = "exp_20260601_003_cat_strict_raw_baseline"
SEED = 42
N_SPLITS = 5

TRAIN_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/train.csv")
TEST_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/test.csv")
SAMPLE_SUB_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/sample_submission.csv")

WORKDIR = Path("/kaggle/working")
OUTDIR = WORKDIR / EXP_ID
OUTDIR.mkdir(parents=True, exist_ok=True)

# Keep CPU as default for reproducibility.
# If Kaggle GPU is enabled and you want speed, change to "GPU".
TASK_TYPE = "CPU"

print("CatBoost version:", catboost.__version__)
print("TASK_TYPE:", TASK_TYPE)
print("OUTDIR:", OUTDIR)
# Out:
# CatBoost version: 1.2.10
# TASK_TYPE: CPU
# OUTDIR: /kaggle/working/exp_20260601_003_cat_strict_raw_baseline

# %%
# ============================================================
# 1. Load data
# ============================================================

for p in [TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH]:
    if not p.exists():
        raise FileNotFoundError(p)

train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_SUB_PATH)

print("train:", train.shape)
print("test :", test.shape)
print("sample:", sample.shape)
print("train columns:", train.columns.tolist())
print("test columns :", test.columns.tolist())
print("sample columns:", sample.columns.tolist())

display(train.head())
display(test.head())
display(sample.head())
# Out:
# train: (577347, 12)
# test : (247435, 11)
# sample: (247435, 2)
# train columns: ['id', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population', 'class']
# test columns : ['id', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population']
# sample columns: ['id', 'class']
#    id       alpha      delta          u          g          r          i  \
# 0   0  147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   1  127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   2  179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   3  225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   4  141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#            z  redshift spectral_type galaxy_population   class
# 0  18.621057  0.408982             M      Red_Sequence  GALAXY
# 1  16.786433  0.157976             M      Red_Sequence  GALAXY
# 2  20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3  17.914952  0.536099             M      Red_Sequence  GALAXY
# 4  17.616185  0.555761             M      Red_Sequence  GALAXY
#        id       alpha      delta          u          g          r          i  \
# 0  577347  120.719779  23.924249  23.668066  21.951680  21.086183  20.180032
# 1  577348  219.414419  42.171651  24.902933  22.338822  20.732163  19.860330
# 2  577349  173.568731  -1.756400  19.427591  18.474633  17.551314  16.570674
# 3  577350  184.903993  -1.411074  23.121029  21.526855  20.670159  20.417633
# 4  577351  222.487816  15.381403  25.094282  22.643981  21.123173  19.439500
#
#            z  redshift spectral_type galaxy_population
# 0  19.202124  0.429042           G/K      Red_Sequence
# 1  19.687691  0.867305             M      Red_Sequence
# 2  16.176765  0.224234           G/K        Blue_Cloud
# 3  20.699095  0.066507           G/K      Red_Sequence
# 4  19.094158  0.977218             M      Red_Sequence
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350  GALAXY
# 4  577351  GALAXY

# %%
# ============================================================
# 2. Schema fixed from 001
# ============================================================

ID_COL = "id"
TARGET_COL = "class"

NUMERIC_COLS = [
    "alpha", "delta", "u", "g", "r", "i", "z", "redshift"
]

CATEGORICAL_COLS = [
    "spectral_type",
    "galaxy_population",
]

FEATURE_COLS = NUMERIC_COLS + CATEGORICAL_COLS

assert ID_COL in train.columns
assert TARGET_COL in train.columns
assert ID_COL in test.columns
assert TARGET_COL not in test.columns
assert set(FEATURE_COLS).issubset(train.columns)
assert set(FEATURE_COLS).issubset(test.columns)

print("FEATURE_COLS:", FEATURE_COLS)
print("NUMERIC_COLS:", NUMERIC_COLS)
print("CATEGORICAL_COLS:", CATEGORICAL_COLS)

print("\\nTarget distribution:")
target_dist = train[TARGET_COL].value_counts().to_frame("count")
target_dist["rate"] = train[TARGET_COL].value_counts(normalize=True)
display(target_dist)
# Out:
# FEATURE_COLS: ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'spectral_type', 'galaxy_population']
# NUMERIC_COLS: ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift']
# CATEGORICAL_COLS: ['spectral_type', 'galaxy_population']
# \nTarget distribution:
#          count      rate
# class
# GALAXY  377480  0.653818
# QSO     117143  0.202899
# STAR     82724  0.143283

# %%
# ============================================================
# 3. Strict raw preprocessing
# ============================================================

def prepare_strict_raw(train_df: pd.DataFrame, test_df: pd.DataFrame):
    X = train_df[FEATURE_COLS].copy()
    X_test = test_df[FEATURE_COLS].copy()

    # CatBoost handles categorical features as strings.
    # Missing is not expected from 001, but fill defensively.
    for col in CATEGORICAL_COLS:
        X[col] = X[col].astype("string").fillna("__NA__").astype(str)
        X_test[col] = X_test[col].astype("string").fillna("__NA__").astype(str)

    for col in NUMERIC_COLS:
        X[col] = X[col].astype("float32")
        X_test[col] = X_test[col].astype("float32")

    return X, X_test

X, X_test = prepare_strict_raw(train, test)

le = LabelEncoder()
y = le.fit_transform(train[TARGET_COL].astype(str))
class_names = le.classes_.tolist()
n_classes = len(class_names)

cat_features = CATEGORICAL_COLS

print("class_names:", class_names)
print("n_classes:", n_classes)
print("cat_features:", cat_features)
print("X dtypes:")
display(X.dtypes.to_frame("dtype"))

print("\\nEncoded target distribution:")
display(pd.Series(y).value_counts().sort_index().rename(index={i: c for i, c in enumerate(class_names)}).to_frame("count"))
# Out:
# class_names: ['GALAXY', 'QSO', 'STAR']
# n_classes: 3
# cat_features: ['spectral_type', 'galaxy_population']
# X dtypes:
#                      dtype
# alpha              float32
# delta              float32
# u                  float32
# g                  float32
# r                  float32
# i                  float32
# z                  float32
# redshift           float32
# spectral_type       object
# galaxy_population   object
# \nEncoded target distribution:
#          count
# GALAXY  377480
# QSO     117143
# STAR     82724

# %%
# ============================================================
# 4. Model params
# ============================================================

# Strict raw CatBoost baseline params.
# Do not tune yet. Keep simple, stable, and reproducible.
#
# Explicit CPU/GPU-sensitive parameters:
# - bootstrap_type
# - subsample
# - border_count
#
# eval_metric is TotalF1 macro for early stopping alignment with balanced multiclass classification.
# Final adoption metric is still sklearn balanced_accuracy_score on OOF argmax.

CAT_PARAMS = dict(
    loss_function="MultiClass",
    eval_metric="TotalF1:average=Macro",
    iterations=5000,
    learning_rate=0.03,
    depth=8,
    l2_leaf_reg=3.0,
    random_seed=SEED,
    task_type=TASK_TYPE,
    bootstrap_type="Bernoulli",
    subsample=0.8,
    border_count=254,
    grow_policy="SymmetricTree",
    od_type="Iter",
    od_wait=150,
    allow_writing_files=False,
    verbose=200,
)

print(json.dumps(CAT_PARAMS, indent=2))
# Out:
# {
#   "loss_function": "MultiClass",
#   "eval_metric": "TotalF1:average=Macro",
#   "iterations": 5000,
#   "learning_rate": 0.03,
#   "depth": 8,
#   "l2_leaf_reg": 3.0,
#   "random_seed": 42,
#   "task_type": "CPU",
#   "bootstrap_type": "Bernoulli",
#   "subsample": 0.8,
#   "border_count": 254,
#   "grow_policy": "SymmetricTree",
#   "od_type": "Iter",
#   "od_wait": 150,
#   "allow_writing_files": false,
#   "verbose": 200
# }

# %%
# ============================================================
# 5. CV training
# ============================================================

skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

oof_proba = np.zeros((len(train), n_classes), dtype=np.float32)
test_proba = np.zeros((len(test), n_classes), dtype=np.float32)

fold_rows = []
feature_importance_rows = []
models = []

test_pool = Pool(X_test, cat_features=cat_features)

for fold, (tr_idx, va_idx) in enumerate(skf.split(X, y), start=1):
    print(f"\n========== Fold {fold}/{N_SPLITS} ==========")

    X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
    y_tr, y_va = y[tr_idx], y[va_idx]

    train_pool = Pool(X_tr, y_tr, cat_features=cat_features)
    valid_pool = Pool(X_va, y_va, cat_features=cat_features)

    model = CatBoostClassifier(**CAT_PARAMS)

    model.fit(
        train_pool,
        eval_set=valid_pool,
        use_best_model=True,
    )

    best_iter = int(model.get_best_iteration() or CAT_PARAMS["iterations"])

    va_proba = model.predict_proba(valid_pool)
    te_proba = model.predict_proba(test_pool)

    oof_proba[va_idx] = va_proba.astype(np.float32)
    test_proba += te_proba.astype(np.float32) / N_SPLITS

    va_pred = va_proba.argmax(axis=1)
    fold_score = balanced_accuracy_score(y_va, va_pred)

    fold_rows.append({
        "fold": fold,
        "balanced_accuracy": float(fold_score),
        "best_iteration": int(best_iter),
        "n_train": int(len(tr_idx)),
        "n_valid": int(len(va_idx)),
    })

    fi = pd.DataFrame({
        "feature": FEATURE_COLS,
        "importance": model.get_feature_importance(type="FeatureImportance"),
        "fold": fold,
    })
    feature_importance_rows.append(fi)

    print("fold balanced_accuracy:", fold_score)
    print("best_iteration:", best_iter)
    print("confusion matrix:")
    print(confusion_matrix(y_va, va_pred))

    models.append(model)

fold_scores = pd.DataFrame(fold_rows)
feature_importance = pd.concat(feature_importance_rows, ignore_index=True)

oof_pred = oof_proba.argmax(axis=1)
cv_score = balanced_accuracy_score(y, oof_pred)

print("\n========== CV result ==========")
display(fold_scores)
print("OOF balanced_accuracy:", cv_score)
print("\nClassification report:")
print(classification_report(y, oof_pred, target_names=class_names))
# Out:
# ========== Fold 1/5 ==========
# 0:	learn: 0.8860716	test: 0.8865198	best: 0.8865198 (0)	total: 767ms	remaining: 1h 3m 56s
# 200:	learn: 0.9307077	test: 0.9309135	best: 0.9309135 (200)	total: 2m 4s	remaining: 49m 32s
# 400:	learn: 0.9411395	test: 0.9404044	best: 0.9404044 (400)	total: 4m 10s	remaining: 47m 57s
# 600:	learn: 0.9464768	test: 0.9451647	best: 0.9452282 (597)	total: 6m 18s	remaining: 46m 12s
# 800:	learn: 0.9495154	test: 0.9480039	best: 0.9480589 (795)	total: 8m 25s	remaining: 44m 8s
# 1000:	learn: 0.9514808	test: 0.9492021	best: 0.9492856 (991)	total: 10m 31s	remaining: 42m 1s
# 1200:	learn: 0.9529088	test: 0.9504284	best: 0.9504470 (1199)	total: 12m 36s	remaining: 39m 53s
# 1400:	learn: 0.9541308	test: 0.9512132	best: 0.9512199 (1388)	total: 14m 42s	remaining: 37m 47s
# 1600:	learn: 0.9552504	test: 0.9520150	best: 0.9520150 (1599)	total: 16m 48s	remaining: 35m 40s
# 1800:	learn: 0.9563350	test: 0.9529169	best: 0.9529514 (1798)	total: 18m 54s	remaining: 33m 35s
# 2000:	learn: 0.9571270	test: 0.9531499	best: 0.9531668 (1995)	total: 21m	remaining: 31m 29s
# 2200:	learn: 0.9579671	test: 0.9535061	best: 0.9535116 (2194)	total: 23m 7s	remaining: 29m 24s
# 2400:	learn: 0.9588213	test: 0.9535931	best: 0.9536494 (2388)	total: 25m 12s	remaining: 27m 17s
# 2600:	learn: 0.9594585	test: 0.9537905	best: 0.9537905 (2598)	total: 27m 17s	remaining: 25m 10s
# 2800:	learn: 0.9601650	test: 0.9539303	best: 0.9539303 (2800)	total: 29m 23s	remaining: 23m 4s
# 3000:	learn: 0.9608883	test: 0.9539738	best: 0.9541014 (2948)	total: 31m 29s	remaining: 20m 58s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.954101383
# bestIteration = 2948
#
# Shrink model to first 2949 iterations.
# fold balanced_accuracy: 0.9521612100002829
# best_iteration: 2948
# confusion matrix:
# [[73863   699   934]
#  [  617 22570   242]
#  [ 1308   102 15135]]
#
# ========== Fold 2/5 ==========
# 0:	learn: 0.8833726	test: 0.8842316	best: 0.8842316 (0)	total: 683ms	remaining: 56m 52s
# 200:	learn: 0.9308854	test: 0.9313789	best: 0.9313789 (200)	total: 2m 4s	remaining: 49m 35s
# 400:	learn: 0.9409874	test: 0.9418246	best: 0.9418246 (400)	total: 4m 10s	remaining: 47m 51s
# 600:	learn: 0.9463208	test: 0.9466321	best: 0.9466377 (597)	total: 6m 17s	remaining: 46m
# 800:	learn: 0.9493245	test: 0.9489064	best: 0.9489258 (792)	total: 8m 22s	remaining: 43m 54s
# 1000:	learn: 0.9514496	test: 0.9505096	best: 0.9505799 (997)	total: 10m 27s	remaining: 41m 48s
# 1200:	learn: 0.9528285	test: 0.9516389	best: 0.9517259 (1197)	total: 12m 30s	remaining: 39m 33s
# 1400:	learn: 0.9541293	test: 0.9524096	best: 0.9524239 (1377)	total: 14m 32s	remaining: 37m 21s
# 1600:	learn: 0.9552972	test: 0.9528272	best: 0.9529178 (1558)	total: 16m 34s	remaining: 35m 11s
# 1800:	learn: 0.9561646	test: 0.9532726	best: 0.9533456 (1792)	total: 18m 36s	remaining: 33m 3s
# 2000:	learn: 0.9570499	test: 0.9536638	best: 0.9536689 (1997)	total: 20m 39s	remaining: 30m 58s
# 2200:	learn: 0.9579748	test: 0.9538220	best: 0.9539616 (2097)	total: 22m 42s	remaining: 28m 52s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.9539616072
# bestIteration = 2097
#
# Shrink model to first 2098 iterations.
# fold balanced_accuracy: 0.9527751164058013
# best_iteration: 2097
# confusion matrix:
# [[73794   676  1026]
#  [  622 22585   222]
#  [ 1267   108 15170]]
#
# ========== Fold 3/5 ==========
# 0:	learn: 0.8863927	test: 0.8842572	best: 0.8842572 (0)	total: 747ms	remaining: 1h 2m 13s
# 200:	learn: 0.9306294	test: 0.9289599	best: 0.9289599 (200)	total: 2m 5s	remaining: 49m 48s
# 400:	learn: 0.9414262	test: 0.9387160	best: 0.9387297 (399)	total: 4m 11s	remaining: 48m 7s
# 600:	learn: 0.9466698	test: 0.9440070	best: 0.9440385 (598)	total: 6m 18s	remaining: 46m 9s
# 800:	learn: 0.9496281	test: 0.9467416	best: 0.9467416 (800)	total: 8m 24s	remaining: 44m 3s
# 1000:	learn: 0.9516185	test: 0.9482636	best: 0.9482636 (1000)	total: 10m 30s	remaining: 41m 58s
# 1200:	learn: 0.9531656	test: 0.9495810	best: 0.9496441 (1196)	total: 12m 35s	remaining: 39m 50s
# 1400:	learn: 0.9542843	test: 0.9504539	best: 0.9504716 (1392)	total: 14m 41s	remaining: 37m 43s
# 1600:	learn: 0.9552406	test: 0.9509462	best: 0.9509497 (1598)	total: 16m 46s	remaining: 35m 36s
# 1800:	learn: 0.9563615	test: 0.9515401	best: 0.9515409 (1778)	total: 18m 51s	remaining: 33m 29s
# 2000:	learn: 0.9572705	test: 0.9519754	best: 0.9520340 (1976)	total: 20m 57s	remaining: 31m 24s
# 2200:	learn: 0.9581619	test: 0.9524497	best: 0.9524628 (2195)	total: 23m 3s	remaining: 29m 19s
# 2400:	learn: 0.9589201	test: 0.9524639	best: 0.9525444 (2378)	total: 25m 10s	remaining: 27m 14s
# 2600:	learn: 0.9596089	test: 0.9526128	best: 0.9526876 (2526)	total: 27m 17s	remaining: 25m 10s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.9526876434
# bestIteration = 2526
#
# Shrink model to first 2527 iterations.
# fold balanced_accuracy: 0.9520008117137116
# best_iteration: 2526
# confusion matrix:
# [[73717   695  1084]
#  [  613 22573   243]
#  [ 1281   107 15156]]
#
# ========== Fold 4/5 ==========
# 0:	learn: 0.8837151	test: 0.8837978	best: 0.8837978 (0)	total: 747ms	remaining: 1h 2m 14s
# 200:	learn: 0.9308987	test: 0.9297930	best: 0.9297930 (200)	total: 2m 6s	remaining: 50m 19s
# 400:	learn: 0.9412463	test: 0.9402036	best: 0.9402036 (400)	total: 4m 13s	remaining: 48m 24s
# 600:	learn: 0.9464517	test: 0.9450282	best: 0.9450415 (599)	total: 6m 20s	remaining: 46m 28s
# 800:	learn: 0.9496432	test: 0.9479033	best: 0.9479033 (800)	total: 8m 28s	remaining: 44m 23s
# 1000:	learn: 0.9516873	test: 0.9492357	best: 0.9492438 (999)	total: 10m 35s	remaining: 42m 18s
# 1200:	learn: 0.9531482	test: 0.9505714	best: 0.9506247 (1193)	total: 12m 41s	remaining: 40m 9s
# 1400:	learn: 0.9544242	test: 0.9514009	best: 0.9514236 (1397)	total: 14m 46s	remaining: 37m 58s
# 1600:	learn: 0.9553817	test: 0.9519816	best: 0.9519816 (1600)	total: 16m 51s	remaining: 35m 46s
# 1800:	learn: 0.9562299	test: 0.9525753	best: 0.9526952 (1757)	total: 18m 53s	remaining: 33m 33s
# 2000:	learn: 0.9569962	test: 0.9531124	best: 0.9531308 (1978)	total: 20m 56s	remaining: 31m 22s
# 2200:	learn: 0.9578353	test: 0.9532833	best: 0.9533032 (2189)	total: 22m 59s	remaining: 29m 13s
# 2400:	learn: 0.9585698	test: 0.9535276	best: 0.9535930 (2395)	total: 25m 2s	remaining: 27m 6s
# 2600:	learn: 0.9592540	test: 0.9536507	best: 0.9537450 (2564)	total: 27m 6s	remaining: 25m
# 2800:	learn: 0.9599652	test: 0.9539325	best: 0.9539530 (2774)	total: 29m 9s	remaining: 22m 53s
# 3000:	learn: 0.9605181	test: 0.9541260	best: 0.9541967 (2940)	total: 31m 15s	remaining: 20m 49s
# 3200:	learn: 0.9611069	test: 0.9543204	best: 0.9544237 (3095)	total: 33m 20s	remaining: 18m 44s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.9544236578
# bestIteration = 3095
#
# Shrink model to first 3096 iterations.
# fold balanced_accuracy: 0.9527844116663017
# best_iteration: 3095
# confusion matrix:
# [[73855   633  1008]
#  [  627 22587   214]
#  [ 1276   114 15155]]
#
# ========== Fold 5/5 ==========
# 0:	learn: 0.8829563	test: 0.8832961	best: 0.8832961 (0)	total: 695ms	remaining: 57m 56s
# 200:	learn: 0.9304337	test: 0.9302318	best: 0.9302318 (200)	total: 2m 5s	remaining: 49m 49s
# 400:	learn: 0.9413060	test: 0.9394219	best: 0.9394219 (400)	total: 4m 12s	remaining: 48m 20s
# 600:	learn: 0.9463452	test: 0.9441558	best: 0.9441558 (600)	total: 6m 21s	remaining: 46m 31s
# 800:	learn: 0.9495657	test: 0.9462912	best: 0.9462912 (800)	total: 8m 29s	remaining: 44m 28s
# 1000:	learn: 0.9519097	test: 0.9479106	best: 0.9479106 (1000)	total: 10m 37s	remaining: 42m 24s
# 1200:	learn: 0.9534825	test: 0.9487357	best: 0.9488226 (1190)	total: 12m 44s	remaining: 40m 17s
# 1400:	learn: 0.9546929	test: 0.9495208	best: 0.9495652 (1392)	total: 14m 51s	remaining: 38m 9s
# 1600:	learn: 0.9557494	test: 0.9501870	best: 0.9502197 (1595)	total: 16m 58s	remaining: 36m 2s
# 1800:	learn: 0.9566967	test: 0.9507564	best: 0.9507937 (1766)	total: 19m 5s	remaining: 33m 55s
# 2000:	learn: 0.9575930	test: 0.9512850	best: 0.9513745 (1949)	total: 21m 13s	remaining: 31m 48s
# 2200:	learn: 0.9584403	test: 0.9518988	best: 0.9518988 (2199)	total: 23m 19s	remaining: 29m 40s
# 2400:	learn: 0.9592338	test: 0.9522340	best: 0.9522340 (2400)	total: 25m 26s	remaining: 27m 32s
# 2600:	learn: 0.9599483	test: 0.9524510	best: 0.9525141 (2514)	total: 27m 33s	remaining: 25m 25s
# 2800:	learn: 0.9605753	test: 0.9527154	best: 0.9527353 (2796)	total: 29m 40s	remaining: 23m 17s
# 3000:	learn: 0.9611238	test: 0.9528927	best: 0.9528950 (2984)	total: 31m 47s	remaining: 21m 10s
# 3200:	learn: 0.9617052	test: 0.9530266	best: 0.9530617 (3173)	total: 33m 54s	remaining: 19m 3s
# 3400:	learn: 0.9622571	test: 0.9529872	best: 0.9531007 (3327)	total: 36m 1s	remaining: 16m 56s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.953100708
# bestIteration = 3327
#
# Shrink model to first 3328 iterations.
# fold balanced_accuracy: 0.9525693869301138
# best_iteration: 3327
# confusion matrix:
# [[73732   687  1077]
#  [  647 22552   229]
#  [ 1208   141 15196]]
#
# ========== CV result ==========
#    fold  balanced_accuracy  best_iteration  n_train  n_valid
# 0     1           0.952161            2948   461877   115470
# 1     2           0.952775            2097   461877   115470
# 2     3           0.952001            2526   461878   115469
# 3     4           0.952784            3095   461878   115469
# 4     5           0.952569            3327   461878   115469
# OOF balanced_accuracy: 0.9524581895303758
#
# Classification report:
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.98      0.98    377480
#          QSO       0.97      0.96      0.96    117143
#         STAR       0.92      0.92      0.92     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.95      0.95      0.95    577347
# weighted avg       0.97      0.97      0.97    577347

# %%
# ============================================================
# 6. Submission
# ============================================================

test_pred = test_proba.argmax(axis=1)
test_labels = le.inverse_transform(test_pred)

submission = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    TARGET_COL: test_labels,
})

# Validate submission schema
assert submission.shape[0] == sample.shape[0]
assert submission.columns.tolist() == sample.columns.tolist()
assert submission[ID_COL].equals(sample[ID_COL])

print(submission[TARGET_COL].value_counts(normalize=True))
display(submission.head())

submission_path = OUTDIR / "submission_cat_strict_raw_baseline.csv"
submission.to_csv(submission_path, index=False)
print("saved:", submission_path)
# Out:
# class
# GALAXY    0.655995
# QSO       0.202102
# STAR      0.141904
# Name: proportion, dtype: float64
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: /kaggle/working/exp_20260601_003_cat_strict_raw_baseline/submission_cat_strict_raw_baseline.csv

# %%
# ============================================================
# 7. Save artifacts
# ============================================================

np.save(OUTDIR / "oof_cat_strict_raw_proba.npy", oof_proba)
np.save(OUTDIR / "pred_cat_strict_raw_proba.npy", test_proba)

oof_df = pd.DataFrame({
    ID_COL: train[ID_COL].values,
    "y_true": train[TARGET_COL].astype(str).values,
    "y_pred": le.inverse_transform(oof_pred),
})
for i, cls in enumerate(class_names):
    oof_df[f"proba_{cls}"] = oof_proba[:, i]
oof_df.to_csv(OUTDIR / "oof_cat_strict_raw.csv", index=False)

pred_df = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    "pred_label": test_labels,
})
for i, cls in enumerate(class_names):
    pred_df[f"proba_{cls}"] = test_proba[:, i]
pred_df.to_csv(OUTDIR / "pred_cat_strict_raw.csv", index=False)

fold_scores.to_csv(OUTDIR / "fold_scores.csv", index=False)

feature_importance_summary = (
    feature_importance
    .groupby("feature", as_index=False)[["importance"]]
    .mean()
    .sort_values("importance", ascending=False)
)
feature_importance.to_csv(OUTDIR / "feature_importance_by_fold.csv", index=False)
feature_importance_summary.to_csv(OUTDIR / "feature_importance.csv", index=False)

cv_result = {
    "competition": COMPETITION,
    "exp_id": EXP_ID,
    "model": "CatBoost",
    "status": "completed",
    "metric": "balanced_accuracy_score",
    "cv_score": float(cv_score),
    "fold_scores": fold_scores.to_dict(orient="records"),
    "class_names": class_names,
    "label_mapping": {str(cls): int(i) for i, cls in enumerate(class_names)},
    "feature_cols": FEATURE_COLS,
    "numeric_cols": NUMERIC_COLS,
    "categorical_cols": CATEGORICAL_COLS,
    "params": CAT_PARAMS,
    "use_original": False,
    "use_fe": False,
    "use_bias_search": False,
    "submission_path": str(submission_path),
}

with open(OUTDIR / "cv_result.json", "w", encoding="utf-8") as f:
    json.dump(cv_result, f, indent=2, ensure_ascii=False, default=str)

print("Artifacts saved to:", OUTDIR)
for p in sorted(OUTDIR.glob("*")):
    print(" -", p.name)
# Out:
# Artifacts saved to: /kaggle/working/exp_20260601_003_cat_strict_raw_baseline
#  - cv_result.json
#  - feature_importance.csv
#  - feature_importance_by_fold.csv
#  - fold_scores.csv
#  - oof_cat_strict_raw.csv
#  - oof_cat_strict_raw_proba.npy
#  - pred_cat_strict_raw.csv
#  - pred_cat_strict_raw_proba.npy
#  - submission_cat_strict_raw_baseline.csv

# %%
# ============================================================
# 8. Initialize / update oof_registry.csv
# ============================================================

registry_path = WORKDIR / "oof_registry.csv"

registry_row = {
    "exp_id": EXP_ID,
    "model_family": "CatBoost",
    "feature_family": "strict_raw",
    "cv_metric": "balanced_accuracy_score",
    "cv_score": float(cv_score),
    "fold_std": float(fold_scores["balanced_accuracy"].std(ddof=0)),
    "public_lb": np.nan,
    "use_original": False,
    "use_fe": False,
    "use_bias_search": False,
    "oof_path": str(OUTDIR / "oof_cat_strict_raw_proba.npy"),
    "pred_path": str(OUTDIR / "pred_cat_strict_raw_proba.npy"),
    "submission_path": str(submission_path),
    "role": "strict_raw_baseline",
    "status": "completed",
    "keep_hold_drop": "keep_reference",
    "notes": "First CatBoost strict raw baseline. No original, no FE, no bias search. CPU/GPU-sensitive params explicitly set.",
}

if registry_path.exists():
    registry = pd.read_csv(registry_path)
    registry = registry[registry["exp_id"] != EXP_ID]
    registry = pd.concat([registry, pd.DataFrame([registry_row])], ignore_index=True)
else:
    registry = pd.DataFrame([registry_row])

registry.to_csv(registry_path, index=False)
registry.to_csv(OUTDIR / "oof_registry.csv", index=False)

display(registry.tail())
print("registry saved:", registry_path)
# Out:
#                                      exp_id model_family feature_family  \
# 0  exp_20260601_003_cat_strict_raw_baseline     CatBoost     strict_raw
#
#                  cv_metric  cv_score  fold_std  public_lb  use_original  \
# 0  balanced_accuracy_score  0.952458  0.000321        NaN         False
#
#    use_fe  use_bias_search                                           oof_path  \
# 0   False            False  /kaggle/working/exp_20260601_003_cat_strict_ra...
#
#                                            pred_path  \
# 0  /kaggle/working/exp_20260601_003_cat_strict_ra...
#
#                                      submission_path                 role  \
# 0  /kaggle/working/exp_20260601_003_cat_strict_ra...  strict_raw_baseline
#
#       status  keep_hold_drop  \
# 0  completed  keep_reference
#
#                                                notes
# 0  First CatBoost strict raw baseline. No origina...
# registry saved: /kaggle/working/oof_registry.csv

# %%
# ============================================================
# 9. memo.yml
# ============================================================

memo = {
    "experiment": {
        "id": EXP_ID,
        "title": "CatBoost strict raw baseline",
        "competition": COMPETITION,
        "status": "completed",
        "metric": "balanced_accuracy_score",
        "model": "CatBoost",
    },
    "objective": {
        "summary": (
            "Build the first strict raw CatBoost baseline using only competition train/test. "
            "No original dataset, no feature engineering, no color indices, no bias search. "
            "Explicitly set bootstrap_type, subsample, and border_count to avoid CPU/GPU default ambiguity."
        ),
        "success_criteria": [
            "save oof proba",
            "save test pred proba",
            "save cv_result",
            "save submission",
            "save feature importance",
            "update oof_registry",
        ],
    },
    "data": {
        "train_path": str(TRAIN_PATH),
        "test_path": str(TEST_PATH),
        "sample_submission_path": str(SAMPLE_SUB_PATH),
        "train_shape": list(train.shape),
        "test_shape": list(test.shape),
        "target_col": TARGET_COL,
        "id_col": ID_COL,
        "use_original": False,
    },
    "features": {
        "feature_family": "strict_raw",
        "feature_cols": FEATURE_COLS,
        "numeric_cols": NUMERIC_COLS,
        "categorical_cols": CATEGORICAL_COLS,
        "notes": "Raw competition columns only.",
    },
    "cv": {
        "scheme": "StratifiedKFold",
        "n_splits": N_SPLITS,
        "shuffle": True,
        "random_state": SEED,
        "score": float(cv_score),
        "fold_scores": fold_scores.to_dict(orient="records"),
        "fold_std": float(fold_scores["balanced_accuracy"].std(ddof=0)),
    },
    "params": CAT_PARAMS,
    "outputs": {
        "oof_proba": "oof_cat_strict_raw_proba.npy",
        "pred_proba": "pred_cat_strict_raw_proba.npy",
        "oof_csv": "oof_cat_strict_raw.csv",
        "pred_csv": "pred_cat_strict_raw.csv",
        "submission": "submission_cat_strict_raw_baseline.csv",
        "cv_result": "cv_result.json",
        "feature_importance": "feature_importance.csv",
        "registry": "oof_registry.csv",
    },
    "judgement": {
        "status": "keep_reference",
        "reason": (
            "This is the first strict raw CatBoost baseline and should be kept as the reference "
            "for LightGBM/XGBoost baselines and later FE/original/bias-search experiments."
        ),
        "next_action": [
            "Run exp_20260601_004_xgb_strict_raw_baseline",
            "Compare 002/003/004 OOF correlation, fold stability, CV, and Public LB",
            "Only after raw baselines, test FE such as color indices or redshift bins",
        ],
    },
}

memo_path = OUTDIR / "memo.yml"
if yaml is not None:
    with open(memo_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(memo, f, allow_unicode=True, sort_keys=False)
else:
    with open(memo_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(memo, indent=2, ensure_ascii=False, default=str))

print("memo saved:", memo_path)
# Out:
# memo saved: /kaggle/working/exp_20260601_003_cat_strict_raw_baseline/memo.yml
