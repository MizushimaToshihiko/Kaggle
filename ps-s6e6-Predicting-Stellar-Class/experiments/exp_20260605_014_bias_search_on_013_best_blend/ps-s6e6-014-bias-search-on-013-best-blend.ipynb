# %% [markdown]
# # PS S6E6 - 014 Bias search on 013 best blend
#
# Experiment: `exp_20260605_014_bias_search_on_013_best_blend`
#
# Purpose:
# - Load 013 best blend OOF/test probabilities from `/kaggle/input/datasets/mizushimatoshihiko/npy-files`.
# - Run class-wise bias search on OOF to maximize `balanced_accuracy_score`.
# - Apply the best bias to both OOF and test predictions.
# - Save blend-ready adjusted OOF/test `.npy` files with the full `exp_*` id in filenames.
#
# Base:
# - `exp_20260605_013_blend_add012_lgb010_bias_check`
# - best blend: `C_keep_010_012_007_004_006 / hc_nonnegative_raw`
# - CV: `0.9648069017992585`
# - Public LB: `0.96562`

# %%
# ============================================================
# 0. Imports / Config
# ============================================================

import os
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

warnings.filterwarnings("ignore")

try:
    import yaml
except Exception:
    yaml = None

COMPETITION = "PS S6E6 Predicting Stellar Class"
EXP_ID = "exp_20260605_014_bias_search_on_013_best_blend"
SEED = 42

TRAIN_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/train.csv")
TEST_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/test.csv")
SAMPLE_SUB_PATH = Path("/kaggle/input/competitions/playground-series-s6e6/sample_submission.csv")

NPY_DIR = Path("/kaggle/input/datasets/mizushimatoshihiko/npy-files")

WORKDIR = Path("/kaggle/working")
OUTDIR = WORKDIR / EXP_ID
OUTDIR.mkdir(parents=True, exist_ok=True)

ID_COL = "id"
TARGET_COL = "class"

REF_013_EXP_ID = "exp_20260605_013_blend_add012_lgb010_bias_check"
REF_013_BEST_SET = "C_keep_010_012_007_004_006"
REF_013_BEST_METHOD = "hc_nonnegative_raw"
REF_013_CV = 0.9648069017992585
REF_013_PUBLIC_LB = 0.96562

OOF_013_FILENAME = "oof_exp_20260605_013_blend_add012_lgb010_bias_check_best_blend_proba.npy"
PRED_013_FILENAME = "pred_exp_20260605_013_blend_add012_lgb010_bias_check_best_blend_proba.npy"

OOF_013_PATH = NPY_DIR / OOF_013_FILENAME
PRED_013_PATH = NPY_DIR / PRED_013_FILENAME

OOF_BIASED_NPY = OUTDIR / "oof_exp_20260605_014_bias_search_on_013_best_blend_proba.npy"
PRED_BIASED_NPY = OUTDIR / "pred_exp_20260605_014_bias_search_on_013_best_blend_proba.npy"

print("OUTDIR:", OUTDIR)
print("NPY_DIR:", NPY_DIR)
print("OOF_013_PATH:", OOF_013_PATH)
print("PRED_013_PATH:", PRED_013_PATH)
print("OOF_BIASED_NPY:", OOF_BIASED_NPY)
print("PRED_BIASED_NPY:", PRED_BIASED_NPY)
# Out:
# OUTDIR: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend
# NPY_DIR: /kaggle/input/datasets/mizushimatoshihiko/npy-files
# OOF_013_PATH: /kaggle/input/datasets/mizushimatoshihiko/npy-files/oof_exp_20260605_013_blend_add012_lgb010_bias_check_best_blend_proba.npy
# PRED_013_PATH: /kaggle/input/datasets/mizushimatoshihiko/npy-files/pred_exp_20260605_013_blend_add012_lgb010_bias_check_best_blend_proba.npy
# OOF_BIASED_NPY: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend/oof_exp_20260605_014_bias_search_on_013_best_blend_proba.npy
# PRED_BIASED_NPY: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend/pred_exp_20260605_014_bias_search_on_013_best_blend_proba.npy

# %%
# ============================================================
# 1. Utilities
# ============================================================

def save_json(obj, path: Path) -> None:
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False, default=str)


def proba_to_logp(proba: np.ndarray, eps: float = 1e-15) -> np.ndarray:
    return np.log(np.clip(proba, eps, 1.0))


def softmax_np(x: np.ndarray, axis: int = 1) -> np.ndarray:
    x = x - np.max(x, axis=axis, keepdims=True)
    ex = np.exp(x)
    return ex / np.sum(ex, axis=axis, keepdims=True)


def apply_bias_to_proba(proba: np.ndarray, bias: np.ndarray) -> np.ndarray:
    logp = proba_to_logp(proba)
    return softmax_np(logp + bias.reshape(1, -1), axis=1)


def predict_with_bias(logp: np.ndarray, bias: np.ndarray) -> np.ndarray:
    return np.argmax(logp + bias.reshape(1, -1), axis=1)


def class_recalls(y_true: np.ndarray, y_pred: np.ndarray, class_names: list[str]) -> dict:
    out = {}
    for i, cls in enumerate(class_names):
        mask = y_true == i
        out[f"recall_{cls}"] = float((y_pred[mask] == i).mean()) if mask.any() else float("nan")
    return out


def eval_pred(y_true: np.ndarray, y_pred: np.ndarray, class_names: list[str]) -> dict:
    res = {"balanced_accuracy": float(balanced_accuracy_score(y_true, y_pred))}
    res.update(class_recalls(y_true, y_pred, class_names))
    return res


def validate_proba(name: str, arr: np.ndarray, n_rows: int, n_classes: int) -> None:
    assert arr.shape == (n_rows, n_classes), (name, arr.shape, n_rows, n_classes)
    assert np.isfinite(arr).all(), name
    row_sum = arr.sum(axis=1)
    assert np.allclose(row_sum, 1.0, atol=1e-4), (name, row_sum.min(), row_sum.max())
    assert arr.min() >= -1e-7, (name, arr.min())
    assert arr.max() <= 1.0 + 1e-7, (name, arr.max())

# %%
# ============================================================
# 2. Load train/test/sample and 013 best blend predictions
# ============================================================

for p in [TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH, NPY_DIR, OOF_013_PATH, PRED_013_PATH]:
    if not p.exists():
        raise FileNotFoundError(p)

train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_SUB_PATH)

le = LabelEncoder()
y = le.fit_transform(train[TARGET_COL].astype(str))
class_names = le.classes_.tolist()
n_classes = len(class_names)

assert class_names == ["GALAXY", "QSO", "STAR"], class_names

oof_proba_raw = np.load(OOF_013_PATH).astype(np.float32)
test_proba_raw = np.load(PRED_013_PATH).astype(np.float32)

validate_proba("oof_proba_raw", oof_proba_raw, len(train), n_classes)
validate_proba("test_proba_raw", test_proba_raw, len(test), n_classes)

oof_logp = proba_to_logp(oof_proba_raw)
test_logp = proba_to_logp(test_proba_raw)

print("train:", train.shape)
print("test:", test.shape)
print("class_names:", class_names)
print("oof_proba_raw:", oof_proba_raw.shape)
print("test_proba_raw:", test_proba_raw.shape)
# Out:
# train: (577347, 12)
# test: (247435, 11)
# class_names: ['GALAXY', 'QSO', 'STAR']
# oof_proba_raw: (577347, 3)
# test_proba_raw: (247435, 3)

# %%
# ============================================================
# 3. Raw 013 best blend confirmation
# ============================================================

raw_bias = np.zeros(n_classes, dtype=np.float64)
raw_pred = predict_with_bias(oof_logp, raw_bias)
raw_eval = eval_pred(y, raw_pred, class_names)

print("Raw 013 best blend:")
print(json.dumps(raw_eval, indent=2, ensure_ascii=False))
print("delta vs REF_013_CV:", raw_eval["balanced_accuracy"] - REF_013_CV)
print(confusion_matrix(y, raw_pred))
print(classification_report(y, raw_pred, target_names=class_names))
# Out:
# Raw 013 best blend:
# {
#   "balanced_accuracy": 0.9648069017992585,
#   "recall_GALAXY": 0.9717653915439228,
#   "recall_QSO": 0.9688329648378478,
#   "recall_STAR": 0.953822349016005
# }
# delta vs REF_013_CV: 0.0
# [[366822   4106   6552]
#  [  2395 113492   1256]
#  [  3470    350  78904]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.97      0.98    377480
#          QSO       0.96      0.97      0.97    117143
#         STAR       0.91      0.95      0.93     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.95      0.96      0.96    577347
# weighted avg       0.97      0.97      0.97    577347

# %%
# ============================================================
# 4. Bias search
# ============================================================

def grid_search_bias_2d(logp, y_true, qso_values, star_values, stage_name):
    rows = []
    best_score = -1.0
    best_bias = None

    for bq in qso_values:
        for bs in star_values:
            bias = np.array([0.0, float(bq), float(bs)], dtype=np.float64)
            pred = predict_with_bias(logp, bias)
            score = float(balanced_accuracy_score(y_true, pred))

            rows.append({
                "stage": stage_name,
                "bias_GALAXY": 0.0,
                "bias_QSO": float(bq),
                "bias_STAR": float(bs),
                "balanced_accuracy": score,
            })

            if score > best_score:
                best_score = score
                best_bias = bias.copy()

        print(f"{stage_name}: bq={bq:.6f}, best={best_score:.9f}, bias={best_bias}")

    return {"score": best_score, "bias": best_bias}, pd.DataFrame(rows)


coarse_qso = np.round(np.arange(-0.200, 0.200 + 1e-12, 0.010), 6)
coarse_star = np.round(np.arange(-0.200, 0.200 + 1e-12, 0.010), 6)
best_coarse, coarse_df = grid_search_bias_2d(oof_logp, y, coarse_qso, coarse_star, "coarse")

cq, cs = best_coarse["bias"][1], best_coarse["bias"][2]
local_qso = np.round(np.arange(cq - 0.020, cq + 0.020 + 1e-12, 0.002), 6)
local_star = np.round(np.arange(cs - 0.020, cs + 0.020 + 1e-12, 0.002), 6)
best_local, local_df = grid_search_bias_2d(oof_logp, y, local_qso, local_star, "local")

uq, us = best_local["bias"][1], best_local["bias"][2]
ultra_qso = np.round(np.arange(uq - 0.004, uq + 0.004 + 1e-12, 0.0005), 6)
ultra_star = np.round(np.arange(us - 0.004, us + 0.004 + 1e-12, 0.0005), 6)
best_ultra, ultra_df = grid_search_bias_2d(oof_logp, y, ultra_qso, ultra_star, "ultra_local")

search_df = pd.concat([coarse_df, local_df, ultra_df], ignore_index=True)
search_df = search_df.sort_values("balanced_accuracy", ascending=False).reset_index(drop=True)

best_bias = best_ultra["bias"]
best_score = best_ultra["score"]

display(search_df.head(30))
print("raw_score:", raw_eval["balanced_accuracy"])
print("best_score:", best_score)
print("delta_vs_raw:", best_score - raw_eval["balanced_accuracy"])
print("best_bias:", best_bias)
# Out:
# coarse: bq=-0.200000, best=0.965249641, bias=[ 0.  -0.2  0.2]
# coarse: bq=-0.190000, best=0.965285933, bias=[ 0.   -0.19  0.2 ]
# coarse: bq=-0.180000, best=0.965292293, bias=[ 0.   -0.18  0.2 ]
# coarse: bq=-0.170000, best=0.965301013, bias=[ 0.   -0.17  0.2 ]
# coarse: bq=-0.160000, best=0.965324654, bias=[ 0.   -0.16  0.2 ]
# coarse: bq=-0.150000, best=0.965354962, bias=[ 0.   -0.15  0.2 ]
# coarse: bq=-0.140000, best=0.965370453, bias=[ 0.   -0.14  0.2 ]
# coarse: bq=-0.130000, best=0.965398313, bias=[ 0.   -0.13  0.2 ]
# coarse: bq=-0.120000, best=0.965412234, bias=[ 0.   -0.12  0.2 ]
# coarse: bq=-0.110000, best=0.965428804, bias=[ 0.   -0.11  0.2 ]
# coarse: bq=-0.100000, best=0.965459903, bias=[ 0.  -0.1  0.2]
# coarse: bq=-0.090000, best=0.965501200, bias=[ 0.   -0.09  0.2 ]
# coarse: bq=-0.080000, best=0.965527687, bias=[ 0.   -0.08  0.2 ]
# coarse: bq=-0.070000, best=0.965549955, bias=[ 0.   -0.07  0.2 ]
# coarse: bq=-0.060000, best=0.965568966, bias=[ 0.   -0.06  0.2 ]
# coarse: bq=-0.050000, best=0.965577889, bias=[ 0.   -0.05  0.2 ]
# coarse: bq=-0.040000, best=0.965580023, bias=[ 0.   -0.04  0.2 ]
# coarse: bq=-0.030000, best=0.965583249, bias=[ 0.   -0.03  0.2 ]
# coarse: bq=-0.020000, best=0.965592257, bias=[ 0.   -0.02  0.2 ]
# coarse: bq=-0.010000, best=0.965592257, bias=[ 0.   -0.02  0.2 ]
# coarse: bq=0.000000, best=0.965631265, bias=[0.  0.  0.2]
# coarse: bq=0.010000, best=0.965631265, bias=[0.  0.  0.2]
# coarse: bq=0.020000, best=0.965657060, bias=[0.   0.02 0.2 ]
# coarse: bq=0.030000, best=0.965673245, bias=[0.   0.03 0.2 ]
# coarse: bq=0.040000, best=0.965673245, bias=[0.   0.03 0.2 ]
# coarse: bq=0.050000, best=0.965686245, bias=[0.   0.05 0.2 ]
# coarse: bq=0.060000, best=0.965705641, bias=[0.   0.06 0.2 ]
# coarse: bq=0.070000, best=0.965720340, bias=[0.   0.07 0.2 ]
# coarse: bq=0.080000, best=0.965752310, bias=[0.   0.08 0.2 ]
# coarse: bq=0.090000, best=0.965773760, bias=[0.   0.09 0.2 ]
# coarse: bq=0.100000, best=0.965773760, bias=[0.   0.09 0.2 ]
# coarse: bq=0.110000, best=0.965813096, bias=[0.   0.11 0.2 ]
# coarse: bq=0.120000, best=0.965846157, bias=[0.   0.12 0.2 ]
# coarse: bq=0.130000, best=0.965860556, bias=[0.   0.13 0.2 ]
# coarse: bq=0.140000, best=0.965884871, bias=[0.   0.14 0.2 ]
# coarse: bq=0.150000, best=0.965899675, bias=[0.   0.15 0.2 ]
# coarse: bq=0.160000, best=0.965899675, bias=[0.   0.15 0.2 ]
# coarse: bq=0.170000, best=0.965899675, bias=[0.   0.15 0.2 ]
# coarse: bq=0.180000, best=0.965922900, bias=[0.   0.18 0.2 ]
# coarse: bq=0.190000, best=0.965922900, bias=[0.   0.18 0.2 ]
# coarse: bq=0.200000, best=0.965934271, bias=[0.  0.2 0.2]
# local: bq=0.180000, best=0.965980741, bias=[0.    0.18  0.216]
# local: bq=0.182000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.184000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.186000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.188000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.190000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.192000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.194000, best=0.965981820, bias=[0.    0.182 0.216]
# local: bq=0.196000, best=0.965987003, bias=[0.    0.196 0.216]
# local: bq=0.198000, best=0.965988665, bias=[0.    0.198 0.216]
# local: bq=0.200000, best=0.965989744, bias=[0.    0.2   0.216]
# local: bq=0.202000, best=0.965995690, bias=[0.    0.202 0.212]
# local: bq=0.204000, best=0.965999641, bias=[0.    0.204 0.214]
# local: bq=0.206000, best=0.966002795, bias=[0.    0.206 0.216]
# local: bq=0.208000, best=0.966002795, bias=[0.    0.206 0.216]
# local: bq=0.210000, best=0.966002795, bias=[0.    0.206 0.216]
# local: bq=0.212000, best=0.966002795, bias=[0.    0.206 0.216]
# local: bq=0.214000, best=0.966006602, bias=[0.    0.214 0.214]
# local: bq=0.216000, best=0.966006602, bias=[0.    0.214 0.214]
# local: bq=0.218000, best=0.966006602, bias=[0.    0.214 0.214]
# local: bq=0.220000, best=0.966006813, bias=[0.    0.22  0.216]
# ultra_local: bq=0.216000, best=0.966006027, bias=[0.    0.216 0.215]
# ultra_local: bq=0.216500, best=0.966006027, bias=[0.    0.216 0.215]
# ultra_local: bq=0.217000, best=0.966006027, bias=[0.    0.216 0.215]
# ultra_local: bq=0.217500, best=0.966006027, bias=[0.    0.216 0.215]
# ultra_local: bq=0.218000, best=0.966006027, bias=[0.    0.216 0.215]
# ultra_local: bq=0.218500, best=0.966007499, bias=[0.     0.2185 0.215 ]
# ultra_local: bq=0.219000, best=0.966007499, bias=[0.     0.2185 0.215 ]
# ultra_local: bq=0.219500, best=0.966007499, bias=[0.     0.2185 0.215 ]
# ultra_local: bq=0.220000, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.220500, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.221000, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.221500, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.222000, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.222500, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.223000, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.223500, best=0.966008579, bias=[0.    0.22  0.215]
# ultra_local: bq=0.224000, best=0.966008579, bias=[0.    0.22  0.215]
#           stage  bias_GALAXY  bias_QSO  bias_STAR  balanced_accuracy
# 0   ultra_local          0.0    0.2200     0.2150           0.966009
# 1   ultra_local          0.0    0.2200     0.2155           0.966009
# 2   ultra_local          0.0    0.2200     0.2135           0.966008
# 3   ultra_local          0.0    0.2200     0.2145           0.966008
# 4   ultra_local          0.0    0.2205     0.2155           0.966008
# 5   ultra_local          0.0    0.2210     0.2150           0.966008
# 6   ultra_local          0.0    0.2210     0.2155           0.966008
# 7   ultra_local          0.0    0.2205     0.2150           0.966008
# 8   ultra_local          0.0    0.2185     0.2155           0.966007
# 9   ultra_local          0.0    0.2185     0.2150           0.966007
# 10  ultra_local          0.0    0.2185     0.2135           0.966007
# 11  ultra_local          0.0    0.2205     0.2145           0.966007
# 12  ultra_local          0.0    0.2210     0.2145           0.966007
# 13  ultra_local          0.0    0.2185     0.2145           0.966007
# 14  ultra_local          0.0    0.2215     0.2150           0.966007
# 15  ultra_local          0.0    0.2215     0.2155           0.966007
# 16        local          0.0    0.2200     0.2160           0.966007
# 17  ultra_local          0.0    0.2200     0.2160           0.966007
# 18  ultra_local          0.0    0.2200     0.2140           0.966007
# 19        local          0.0    0.2200     0.2140           0.966007
# 20        local          0.0    0.2140     0.2140           0.966007
# 21  ultra_local          0.0    0.2160     0.2155           0.966006
# 22  ultra_local          0.0    0.2160     0.2150           0.966006
# 23  ultra_local          0.0    0.2210     0.2160           0.966006
# 24  ultra_local          0.0    0.2205     0.2160           0.966006
# 25  ultra_local          0.0    0.2160     0.2135           0.966006
# 26  ultra_local          0.0    0.2205     0.2140           0.966006
# 27  ultra_local          0.0    0.2195     0.2155           0.966006
# 28  ultra_local          0.0    0.2190     0.2150           0.966006
# 29  ultra_local          0.0    0.2190     0.2155           0.966006
# raw_score: 0.9648069017992585
# best_score: 0.9660085788215015
# delta_vs_raw: 0.0012016770222429418
# best_bias: [0.    0.22  0.215]

# %%
# ============================================================
# 5. Build blend-ready biased OOF/test probabilities
# ============================================================

oof_proba_biased = apply_bias_to_proba(oof_proba_raw, best_bias).astype(np.float32)
test_proba_biased = apply_bias_to_proba(test_proba_raw, best_bias).astype(np.float32)

validate_proba("oof_proba_biased", oof_proba_biased, len(train), n_classes)
validate_proba("test_proba_biased", test_proba_biased, len(test), n_classes)

biased_oof_pred = oof_proba_biased.argmax(axis=1)
biased_eval = eval_pred(y, biased_oof_pred, class_names)

print("Biased 014:")
print(json.dumps(biased_eval, indent=2, ensure_ascii=False))
print("delta vs raw:", biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"])
print("delta vs REF_013_CV:", biased_eval["balanced_accuracy"] - REF_013_CV)
print(confusion_matrix(y, biased_oof_pred))
print(classification_report(y, biased_oof_pred, target_names=class_names))

compare_eval = pd.DataFrame([
    {"version": "raw_013_best", **raw_eval},
    {"version": "biased_014", **biased_eval},
])
display(compare_eval)

print("OOF proba raw/biased diff abs mean:", float(np.mean(np.abs(oof_proba_biased - oof_proba_raw))))
print("TEST proba raw/biased diff abs mean:", float(np.mean(np.abs(test_proba_biased - test_proba_raw))))
# Out:
# Biased 014:
# {
#   "balanced_accuracy": 0.9660085788215015,
#   "recall_GALAXY": 0.9680618840733284,
#   "recall_QSO": 0.9706171090035256,
#   "recall_STAR": 0.9593467433876505
# }
# delta vs raw: 0.0012016770222429418
# delta vs REF_013_CV: 0.0012016770222429418
# [[365424   4518   7538]
#  [  2177 113701   1265]
#  [  3008    355  79361]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.97      0.98    377480
#          QSO       0.96      0.97      0.96    117143
#         STAR       0.90      0.96      0.93     82724
#
#     accuracy                           0.97    577347
#    macro avg       0.95      0.97      0.96    577347
# weighted avg       0.97      0.97      0.97    577347
#         version  balanced_accuracy  recall_GALAXY  recall_QSO  recall_STAR
# 0  raw_013_best           0.964807       0.971765    0.968833     0.953822
# 1    biased_014           0.966009       0.968062    0.970617     0.959347
# OOF proba raw/biased diff abs mean: 0.003154890378937125
# TEST proba raw/biased diff abs mean: 0.003213754389435053

# %%
# ============================================================
# 6. Biased submission
# ============================================================

biased_test_pred = test_proba_biased.argmax(axis=1)
biased_test_labels = le.inverse_transform(biased_test_pred)

submission = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    TARGET_COL: biased_test_labels,
})

assert submission.shape[0] == sample.shape[0]
assert submission.columns.tolist() == sample.columns.tolist()
assert submission[ID_COL].equals(sample[ID_COL])

print(submission[TARGET_COL].value_counts(normalize=True))
display(submission.head())

submission_path = OUTDIR / "submission_bias_search_on_013_best_blend.csv"
submission.to_csv(submission_path, index=False)
print("saved:", submission_path)
# Out:
# class
# GALAXY    0.642775
# QSO       0.205189
# STAR      0.152036
# Name: proportion, dtype: float64
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend/submission_bias_search_on_013_best_blend.csv

# %%
# ============================================================
# 7. Save artifacts
# ============================================================

np.save(OUTDIR / "bias_vector.npy", best_bias)
np.save(OOF_BIASED_NPY, oof_proba_biased)
np.save(PRED_BIASED_NPY, test_proba_biased)

np.save(OUTDIR / "oof_exp_20260605_014_bias_search_on_013_best_blend_raw013_best_blend_proba.npy", oof_proba_raw)
np.save(OUTDIR / "pred_exp_20260605_014_bias_search_on_013_best_blend_raw013_best_blend_proba.npy", test_proba_raw)

oof_df = pd.DataFrame({
    ID_COL: train[ID_COL].values,
    "y_true": train[TARGET_COL].astype(str).values,
    "raw_pred": le.inverse_transform(raw_pred),
    "biased_pred": le.inverse_transform(biased_oof_pred),
})
for i, cls in enumerate(class_names):
    oof_df[f"raw_proba_{cls}"] = oof_proba_raw[:, i]
    oof_df[f"biased_proba_{cls}"] = oof_proba_biased[:, i]
    oof_df[f"logp_{cls}"] = oof_logp[:, i]
oof_df.to_csv(OUTDIR / "oof_bias_search_on_013_best_blend.csv", index=False)

pred_df = pd.DataFrame({
    ID_COL: test[ID_COL].values,
    "biased_pred_label": biased_test_labels,
})
for i, cls in enumerate(class_names):
    pred_df[f"raw_proba_{cls}"] = test_proba_raw[:, i]
    pred_df[f"biased_proba_{cls}"] = test_proba_biased[:, i]
    pred_df[f"logp_{cls}"] = test_logp[:, i]
pred_df.to_csv(OUTDIR / "pred_bias_search_on_013_best_blend.csv", index=False)

search_df.to_csv(OUTDIR / "bias_search_results.csv", index=False)
compare_eval.to_csv(OUTDIR / "raw_vs_biased_oof_eval.csv", index=False)

cv_result = {
    "competition": COMPETITION,
    "exp_id": EXP_ID,
    "model": "013 best blend postprocess",
    "status": "completed",
    "metric": "balanced_accuracy_score",
    "reference_exp_id": REF_013_EXP_ID,
    "reference_best_set": REF_013_BEST_SET,
    "reference_best_method": REF_013_BEST_METHOD,
    "raw_cv_score": float(raw_eval["balanced_accuracy"]),
    "biased_cv_score": float(biased_eval["balanced_accuracy"]),
    "delta_biased_minus_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
    "reference_013_public_lb": REF_013_PUBLIC_LB,
    "class_names": class_names,
    "label_mapping": {str(cls): int(i) for i, cls in enumerate(class_names)},
    "bias": {
        "GALAXY": float(best_bias[0]),
        "QSO": float(best_bias[1]),
        "STAR": float(best_bias[2]),
    },
    "raw_eval": raw_eval,
    "biased_eval": biased_eval,
    "use_original": False,
    "use_fe": True,
    "use_bias_search": True,
    "adjusted_probability_method": "softmax(log(raw_proba) + class_bias)",
    "search_ranges": {
        "coarse": {"min": -0.20, "max": 0.20, "step": 0.01},
        "local": {"around_best": 0.02, "step": 0.002},
        "ultra_local": {"around_best": 0.004, "step": 0.0005},
    },
    "submission_path": str(submission_path),
    "oof_path": str(OOF_BIASED_NPY),
    "pred_path": str(PRED_BIASED_NPY),
    "raw_013_oof_path": str(OOF_013_PATH),
    "raw_013_pred_path": str(PRED_013_PATH),
}
save_json(cv_result, OUTDIR / "cv_result.json")

print("Artifacts saved to:", OUTDIR)
for p in sorted(OUTDIR.glob("*")):
    print(" -", p.name)
# Out:
# Artifacts saved to: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend
#  - bias_search_results.csv
#  - bias_vector.npy
#  - cv_result.json
#  - oof_bias_search_on_013_best_blend.csv
#  - oof_exp_20260605_014_bias_search_on_013_best_blend_proba.npy
#  - oof_exp_20260605_014_bias_search_on_013_best_blend_raw013_best_blend_proba.npy
#  - pred_bias_search_on_013_best_blend.csv
#  - pred_exp_20260605_014_bias_search_on_013_best_blend_proba.npy
#  - pred_exp_20260605_014_bias_search_on_013_best_blend_raw013_best_blend_proba.npy
#  - raw_vs_biased_oof_eval.csv
#  - submission_bias_search_on_013_best_blend.csv

# %%
# ============================================================
# 8. Registry and memo
# ============================================================

registry_path = WORKDIR / "oof_registry.csv"

registry_row = {
    "exp_id": EXP_ID,
    "model_family": "Blend",
    "feature_family": "013_best_blend_postprocess",
    "cv_metric": "balanced_accuracy_score",
    "cv_score": float(biased_eval["balanced_accuracy"]),
    "raw_cv_score": float(raw_eval["balanced_accuracy"]),
    "cv_delta_vs_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
    "public_lb": np.nan,
    "use_original": False,
    "use_fe": True,
    "use_bias_search": True,
    "oof_path": str(OOF_BIASED_NPY),
    "pred_path": str(PRED_BIASED_NPY),
    "submission_path": str(submission_path),
    "role": "final_blend_bias_candidate",
    "status": "completed",
    "keep_hold_drop": "pending_public_lb",
    "notes": "Class-wise bias search on 013 best blend. Input npy loaded from fixed npy-files dataset. Blend-ready adjusted OOF/pred proba saved with exp_* filenames.",
}

if registry_path.exists():
    registry = pd.read_csv(registry_path)
    registry = registry[registry["exp_id"] != EXP_ID]
    registry = pd.concat([registry, pd.DataFrame([registry_row])], ignore_index=True)
else:
    registry = pd.DataFrame([registry_row])

registry.to_csv(registry_path, index=False)
registry.to_csv(OUTDIR / "oof_registry.csv", index=False)

memo = {
    "experiment": {
        "id": EXP_ID,
        "title": "Bias search on 013 best blend",
        "competition": COMPETITION,
        "status": "completed",
        "metric": "balanced_accuracy_score",
        "model": "013 best blend postprocess",
        "created_at": "2026-06-05",
    },
    "objective": {
        "summary": (
            "Apply class-wise bias search to 013 best blend OOF/test probabilities. "
            "Do not retrain. GALAXY bias is fixed to 0 and QSO/STAR biases are searched. "
            "Input npy files are read from /kaggle/input/datasets/mizushimatoshihiko/npy-files."
        ),
        "success_criteria": [
            "load 013 best blend OOF and test predictions from npy-files dataset",
            "confirm raw 013 best blend OOF score",
            "search class-wise bias on OOF",
            "save adjusted OOF proba as npy",
            "save adjusted test pred proba as npy",
            "save biased submission",
            "save bias vector and search results",
            "update oof_registry",
        ],
    },
    "data": {
        "train_path": str(TRAIN_PATH),
        "test_path": str(TEST_PATH),
        "sample_submission_path": str(SAMPLE_SUB_PATH),
        "target_col": TARGET_COL,
        "id_col": ID_COL,
        "npy_dir": str(NPY_DIR),
        "raw_013_oof_path": str(OOF_013_PATH),
        "raw_013_pred_path": str(PRED_013_PATH),
        "use_original": False,
    },
    "reference": {
        "exp_id": REF_013_EXP_ID,
        "best_set": REF_013_BEST_SET,
        "best_method": REF_013_BEST_METHOD,
        "cv": REF_013_CV,
        "public_lb": REF_013_PUBLIC_LB,
    },
    "bias_search": {
        "bias_space": {
            "GALAXY": "fixed_0",
            "QSO": "searched",
            "STAR": "searched",
        },
        "best_bias": {
            "GALAXY": float(best_bias[0]),
            "QSO": float(best_bias[1]),
            "STAR": float(best_bias[2]),
        },
        "raw_cv": float(raw_eval["balanced_accuracy"]),
        "biased_cv": float(biased_eval["balanced_accuracy"]),
        "delta_biased_minus_raw": float(biased_eval["balanced_accuracy"] - raw_eval["balanced_accuracy"]),
        "raw_eval": raw_eval,
        "biased_eval": biased_eval,
        "adjusted_probability_method": "softmax(log(raw_proba) + class_bias)",
    },
    "outputs": {
        "submission": "submission_bias_search_on_013_best_blend.csv",
        "bias_vector": "bias_vector.npy",
        "oof_proba": OOF_BIASED_NPY.name,
        "pred_proba": PRED_BIASED_NPY.name,
        "bias_search_results": "bias_search_results.csv",
        "raw_vs_biased_oof_eval": "raw_vs_biased_oof_eval.csv",
        "oof_csv": "oof_bias_search_on_013_best_blend.csv",
        "pred_csv": "pred_bias_search_on_013_best_blend.csv",
        "cv_result": "cv_result.json",
        "registry": "oof_registry.csv",
    },
    "judgement": {
        "status": "pending_public_lb",
        "reason": (
            "This is final class-wise threshold tuning on the current best 013 blend. "
            "Adoption depends on whether Public LB improves over 013 best blend LB 0.96562."
        ),
        "next_action": [
            "Submit submission_bias_search_on_013_best_blend.csv",
            "Record Public LB",
            "If LB improves over 0.96562, promote 014 to current best attack candidate",
            "If LB drops, keep 013 best blend as current best",
            "Add 014 OOF/pred to npy-files dataset only if it is useful for later blend/final comparison",
        ],
    },
}

memo_path = OUTDIR / "memo.yml"
if yaml is not None:
    with open(memo_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(memo, f, allow_unicode=True, sort_keys=False)
else:
    with open(memo_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(memo, indent=2, ensure_ascii=False, default=str))

print("registry saved:", registry_path)
print("memo saved:", memo_path)
display(registry.tail())
# Out:
# registry saved: /kaggle/working/oof_registry.csv
# memo saved: /kaggle/working/exp_20260605_014_bias_search_on_013_best_blend/memo.yml
#                                            exp_id model_family  \
# 0  exp_20260605_014_bias_search_on_013_best_blend        Blend
#
#                feature_family                cv_metric  cv_score  \
# 0  013_best_blend_postprocess  balanced_accuracy_score  0.966009
#
#    raw_cv_score  cv_delta_vs_raw  public_lb  use_original  use_fe  \
# 0      0.964807         0.001202        NaN         False    True
#
#    use_bias_search                                           oof_path  \
# 0             True  /kaggle/working/exp_20260605_014_bias_search_o...
#
#                                            pred_path  \
# 0  /kaggle/working/exp_20260605_014_bias_search_o...
#
#                                      submission_path  \
# 0  /kaggle/working/exp_20260605_014_bias_search_o...
#
#                          role     status     keep_hold_drop  \
# 0  final_blend_bias_candidate  completed  pending_public_lb
#
#                                                notes
# 0  Class-wise bias search on 013 best blend. Inpu...
